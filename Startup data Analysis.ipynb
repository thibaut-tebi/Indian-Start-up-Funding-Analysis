# %% [markdown]
# ##                                                         Indian Startup Ecosystem Analysis

# %% [markdown]
# ## Details
#
# Name: Thibaut Kwadzo Tebi
#
# Email: thibaut.tebi@azubiafrica.org
# Project: Indian Starup Funding

# %% [markdown]
# ## Introduction
#
# #### Exploratory Data Analysis (EDA)
# Exploratory Data Analysis (EDA) plays a vital role in understanding and extracting insights from datasets. It allows us to uncover patterns, relationships, and key characteristics of the data. The main objective of this project is to utilize the CRISP-DM framework as a guiding framework for conducting exploratory data analysis (EDA) and extracting valuable insights. The CRoss Industry Standard Process for Data Mining (CRISP-DM) is a process model that serves as the base for data processing
#
# We seek to analyse funding received by startups in India. The aim is to prescribe the best course of action for a startup looking into the Indian business ecosystem. Our first step will be to gain business understanding of the problem.

# %% [markdown]
# ### Business Understanding
# Business understanding refers to the process of gaining a comprehensive understanding of the business problem or opportunity at hand. It involves gathering knowledge and insights about the business domain, its goals, objectives, and challenges.
# India has become an attractive location for investors and has seen number of successful startups achieve the coveted "unicorn" status. To guide our quest for the best course of action as an upcoming startup, few questions were asked which will attempt to answer using the data on hand.

# %% [markdown]
# #### Questions
#
# 1. Which company received the most funding?
# 2. Which company received the lowest amount of funding?
# 3. Which Sector received the highest amount of funding?
# 4. Which Sector received the lowest amount of funding?
# 5. Which HeadQuarters recorded the highest amount of funding received?
# 6. What is the total amount funding received each year?
# 7. what is the average amount received in 2019, 2020 and 2021
# 8. At what stage do startups receive the most funding?
# 9. Does the location affect the funding received?
# 10. which Sector received the highest funding in 2018.

# %% [markdown]
# # Import necessary libraries
# Here is the section to import all the packages/libraries that will be used through this notebook.

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading
#  Here is the section to load the datasets  and the additional files

# %%
df21= pd.read_csv("startup_funding2021.csv")
df20= pd.read_csv("startup_funding2020.csv")
df19= pd.read_csv("startup_funding2019.csv")
df18 = pd.read_csv("startup_funding2018.csv")

# %% [markdown]
# ## Exploratory Data Analysis: EDA

# %% [raw]
# It is an approach to analyzing and summarizing data sets to gain insights and understand the underlying patterns,relationships, and characteristics of the data. It involves the use of various statistical and visualization techniques to explore the data and uncover meaningful information.

# %% [markdown]
# ### Cleaning 2021 dataset

# %% [raw]
# Here is the section to inspect the datasets in depth, present it, make hypotheses and think the cleaning, processing and features creation.

# %%
df21.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
# Checking the number of rows and colunms in the 2021 dataset
df21.shape
# Out:
# (1209, 9)

# %%
df21.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %% [markdown]
# #### Check the data type

# %%
df21.dtypes
# Out:
# Company/Brand     object
# Founded          float64
# HeadQuarter       object
# Sector            object
# What it does      object
# Founders          object
# Investor          object
# Amount($)         object
# Stage             object
# dtype: object

# %% [markdown]
# ###  Inspect each columns:
# To get a general overview of the data and  apply a step ny step  by step approach in cleaning of each column in the dataset

# %%
#considering the Company/Brand column
df21['Company/Brand'].unique()
# Out:
# array(['Unbox Robotics', 'upGrad', 'Lead School', ..., 'Gigforce',
#        'Vahdam', 'WeRize'], dtype=object)

# %%
## Considering the Founded Column 
df20['Founded'].unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', nan, '1999', '1994', '2005', '1973', '-',
#        '2002', '2004', '2001'], dtype=object)

# %%
# Total Number of empty rows in the Founded Column 
df21['Founded'].isnull().sum()
# Out:
# 1

# %%
# Extracting the row with  missing data in the Founded column
df21[df21['Founded'].isna()]
# Out:
#      Company/Brand  Founded HeadQuarter     Sector  \
# 137  Smart Express      NaN      Mumbai  Logistics
#
#                                           What it does        Founders  \
# 137  India’s Most Innovative and Awarded Express Lo...  Yogesh Dhingra
#
#                                               Investor  Amount($) Stage
# 137  IIFL India Private Equity Fund, Smiti Holding ...  $10000000  Seed

# %%
# replace NaN using np.nan

df21["Founded"].replace("nan", np.nan, inplace = True, regex=True)

#Change the datatype of Founded column from Float to int first to remove the decimal
# fill NaN rows with 0
df21['Founded'] = df21['Founded'].replace(np.nan, 0)
df21['Founded'] = df21['Founded'].astype(int)
df21['Founded']
# Out:
# 0       2019
# 1       2015
# 2       2012
# 3       2015
# 4       2021
#         ...
# 1204    2019
# 1205    2015
# 1206    2019
# 1207    2015
# 1208    2019
# Name: Founded, Length: 1209, dtype: int32

# %% [markdown]
# ## Considering the HeadQuaters column

# %%
# checking the overview of the Company/Brand column
df21['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
#        'Online Media\t#REF!', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
#remove t#REF!from names in headquarters

df21['HeadQuarter'] = df21['HeadQuarter'].replace({'\t#REF!': ''}, regex=True)
df21['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals', 'Kolkata', 'Ahmedabad',
#        'Mohali', 'Haryana', 'Indore', 'Powai', 'Ghaziabad', 'Nagpur',
#        'West Bengal', 'Patna', 'Samsitpur', 'Lucknow', 'Telangana',
#        'Silvassa', 'Thiruvananthapuram', 'Faridabad', 'Roorkee',
#        'Ambernath', 'Panchkula', 'Surat', 'Coimbatore', 'Andheri',
#        'Mangalore', 'Telugana', 'Bhubaneswar', 'Kottayam', 'Beijing',
#        'Panaji', 'Satara', 'Orissia', 'Jodhpur', 'New York', 'Santra',
#        'Mountain View, CA', 'Trivandrum', 'Jharkhand', 'Kanpur',
#        'Bhilwara', 'Guwahati', 'Online Media', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
# from our unique function, we see that food and beverages, pharmaceuticals and Information Technology & Services
# are in our headquarter column. Lets extract them 

df21[df21['HeadQuarter'].str.contains('Information Technology & Services|Online Media|Pharmaceuticals|Food & Beverages|Computer Games',case=False, na=False)]
# Out:
#            Company/Brand  Founded                        HeadQuarter  \
# 98               FanPlay     2020                     Computer Games
# 111              FanPlay     2020                     Computer Games
# 241           MasterChow     2020                   Food & Beverages
# 242   Fullife Healthcare     2009                    Pharmaceuticals
# 255           MasterChow     2020                   Food & Beverages
# 256   Fullife Healthcare     2009                    Pharmaceuticals
# 1100            Sochcast     2020                       Online Media
# 1176                Peak     2014  Information Technology & Services
#
#                                                  Sector  \
# 98                                       Computer Games
# 111                                      Computer Games
# 241                                           Hauz Khas
# 242   Primary Business is Development and Manufactur...
# 255                                           Hauz Khas
# 256   Primary Business is Development and Manufactur...
# 1100  Sochcast is an Audio experiences company that ...
# 1176                     Manchester, Greater Manchester
#
#                                            What it does  \
# 98    A real money game app specializing in trivia g...
# 111   A real money game app specializing in trivia g...
# 241                 A ready-to-cook Asian cuisine brand
# 242                                        Varun Khanna
# 255                 A ready-to-cook Asian cuisine brand
# 256                                        Varun Khanna
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1176  Peak helps the world's smartest companies put ...
#
#                                      Founders                     Investor  \
# 98                                     YC W21  Pritesh Kumar, Bharat Gupta
# 111                                    YC W21  Pritesh Kumar, Bharat Gupta
# 241             Vidur Kataria, Sidhanth Madan                 WEH Ventures
# 242        Morgan Stanley Private Equity Asia                    $22000000
# 255             Vidur Kataria, Sidhanth Madan                 WEH Ventures
# 256        Morgan Stanley Private Equity Asia                    $22000000
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal                 $Undisclosed
# 1176                              Atul Sharma       SoftBank Vision Fund 2
#
#       Amount($)     Stage
# 98     Upsparks  $1200000
# 111    Upsparks  $1200000
# 241     $461000      Seed
# 242    Series C       NaN
# 255     $461000      Seed
# 256    Series C       NaN
# 1100        NaN       NaN
# 1176  $75000000  Series C

# %%
# replacing with NaN
df21['HeadQuarter'] = df21['HeadQuarter'].replace(['Pharmaceuticals', 'Computer Games', 'Food & Beverages', 'Online Media', 'Information Technology & Services'], np.nan)
df21["HeadQuarter"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Cochin',
#        'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara', 'Kolkata',
#        'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai', 'Ghaziabad',
#        'Nagpur', 'West Bengal', 'Patna', 'Samsitpur', 'Lucknow',
#        'Telangana', 'Silvassa', 'Thiruvananthapuram', 'Faridabad',
#        'Roorkee', 'Ambernath', 'Panchkula', 'Surat', 'Coimbatore',
#        'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar', 'Kottayam',
#        'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur', 'New York',
#        'Santra', 'Mountain View, CA', 'Trivandrum', 'Jharkhand', 'Kanpur',
#        'Bhilwara', 'Guwahati', 'Kochi', 'London', 'The Nilgiris',
#        'Gandhinagar'], dtype=object)

# %% [markdown]
# ## Considering the Stage column

# %%
#Overview of the Stage column
df21['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        '$1200000', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I'],
#       dtype=object)

# %%
# replace NaN using np.nan
df21["Stage"].replace("nan", np.nan, inplace = True, regex=True)
# Extracting the row with  missing data in the NaN column
df21[df21['Stage'].isna()]
# Out:
#         Company/Brand  Founded HeadQuarter                 Sector  \
# 1              upGrad     2015      Mumbai                 EdTech
# 5       Urban Company     2014   New Delhi          Home services
# 6      Comofi Medtech     2018   Bangalore             HealthTech
# 8            Vitra.ai     2020   Bangalore           Tech Startup
# 9              Taikee     2010      Mumbai             E-commerce
# ...               ...      ...         ...                    ...
# 1172       Peppermint     2019        Pune  Industrial Automation
# 1182        Sugar.fit     2021   Bangalore                 Health
# 1192        Geniemode     2021    Gurugram                    B2B
# 1193  Sapio Analytics     2019      Mumbai      Computer Software
# 1202       Voxelgrids     2017   Bangalore               Deeptech
#
#                                            What it does  \
# 1        UpGrad is an online higher education platform.
# 5     Urban Company (Formerly UrbanClap) is a home a...
# 6      Comofi Medtech is a healthcare robotics startup.
# 8     Vitra.ai is an AI-based video translation plat...
# 9     Taikee is the ISO-certified, B2B e-commerce pl...
# ...                                                 ...
# 1172  Intelligent Housekeeping Robots for public and...
# 1182  Innovative technology, compassionate diabetes ...
# 1192  Transforming global sourcing for retailers & s...
# 1193  Sapio helps government create policies driven ...
# 1202  Voxelgrids is an Magnetic Resonance Imaging te...
#
#                                                Founders  \
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 5     Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 6                                            Gururaj KB
# 8                                        Akash Nidhi PS
# 9                    Nidhi Ramachandran, Sachin Chhabra
# ...                                                 ...
# 1172                       Runal Dahiwade, Miraj C Vora
# 1182                 Shivtosh Kumar, Madan Somasundaram
# 1192                        Amit Sharma, Tanuj Gangwani
# 1193  Hardik Somani, Ashwin Srivastava, Shripal Jain...
# 1202                                  Arjun Arunachalam
#
#                                         Investor     Amount($) Stage
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000   NaN
# 5                                     Vy Capital  $188,000,000   NaN
# 6                              CIIE.CO, KIIT-TBI      $200,000   NaN
# 8                              Inflexor Ventures   Undisclosed   NaN
# 9                                            NaN    $1,000,000   NaN
# ...                                          ...           ...   ...
# 1172     Venture Catalysts, Indian Angel Network       $600000   NaN
# 1182  Cure.fit, Endiya Partners, Tanglin Venture     $10000000   NaN
# 1192                          Info Edge Ventures      $2000000   NaN
# 1193                 Rachit Poddar, Rajesh Gupta  $Undisclosed   NaN
# 1202                                        Zoho      $5000000   NaN
#
# [428 rows x 9 columns]

# %%
# the Stage contains amounts therefore there is a need to extract the rows with figures in them using the $ sign as our condition . 
df21[df21['Stage'].str.contains('\$', na=False)]
# Out:
#         Company/Brand  Founded HeadQuarter                  Sector  \
# 98            FanPlay     2020         NaN          Computer Games
# 111           FanPlay     2020         NaN          Computer Games
# 538       Little Leap     2020   New Delhi                  EdTech
# 551             BHyve     2020      Mumbai         Human Resources
# 674      MYRE Capital     2020      Mumbai  Commercial Real Estate
# 677  Saarthi Pedagogy     2015   Ahmadabad                  EdTech
#
#                                           What it does  \
# 98   A real money game app specializing in trivia g...
# 111  A real money game app specializing in trivia g...
# 538                Soft Skills that make Smart Leaders
# 551  A Future of Work Platform for diffusing Employ...
# 674                Democratising Real Estate Ownership
# 677  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 111                                             YC W21
# 538  Holistic Development Programs for children in ...
# 551                                  Backed by 100x.VC
# 674            Own rent yielding commercial properties
# 677                                           Pedagogy
#
#                             Investor                        Amount($)  \
# 98       Pritesh Kumar, Bharat Gupta                         Upsparks
# 111      Pritesh Kumar, Bharat Gupta                         Upsparks
# 538                     Vishal Gupta                     ah! Ventures
# 551  Omkar Pandharkame, Ketaki Ogale   ITO Angel Network, LetsVenture
# 674                      Aryaman Vir                              NaN
# 677                   Sushil Agarwal  JITO Angel Network, LetsVenture
#
#         Stage
# 98   $1200000
# 111  $1200000
# 538   $300000
# 551   $300000
# 674  $6000000
# 677  $1000000

# %%
# Confirm if there is any raw with amount in the Stage column
df21[df21['Stage'].str.contains('\$', na=False)]
# Out:
#         Company/Brand  Founded HeadQuarter                  Sector  \
# 98            FanPlay     2020         NaN          Computer Games
# 111           FanPlay     2020         NaN          Computer Games
# 538       Little Leap     2020   New Delhi                  EdTech
# 551             BHyve     2020      Mumbai         Human Resources
# 674      MYRE Capital     2020      Mumbai  Commercial Real Estate
# 677  Saarthi Pedagogy     2015   Ahmadabad                  EdTech
#
#                                           What it does  \
# 98   A real money game app specializing in trivia g...
# 111  A real money game app specializing in trivia g...
# 538                Soft Skills that make Smart Leaders
# 551  A Future of Work Platform for diffusing Employ...
# 674                Democratising Real Estate Ownership
# 677  India's fastest growing Pedagogy company, serv...
#
#                                               Founders  \
# 98                                              YC W21
# 111                                             YC W21
# 538  Holistic Development Programs for children in ...
# 551                                  Backed by 100x.VC
# 674            Own rent yielding commercial properties
# 677                                           Pedagogy
#
#                             Investor                        Amount($)  \
# 98       Pritesh Kumar, Bharat Gupta                         Upsparks
# 111      Pritesh Kumar, Bharat Gupta                         Upsparks
# 538                     Vishal Gupta                     ah! Ventures
# 551  Omkar Pandharkame, Ketaki Ogale   ITO Angel Network, LetsVenture
# 674                      Aryaman Vir                              NaN
# 677                   Sushil Agarwal  JITO Angel Network, LetsVenture
#
#         Stage
# 98   $1200000
# 111  $1200000
# 538   $300000
# 551   $300000
# 674  $6000000
# 677  $1000000

# %%
#Remove all amount values with $ sign in the Stage column and put them in the Amount ($) colum
currency = df21['Stage'].str.contains('\$', na=False)
df21.loc[currency, ['Stage', 'Amount($)']] = df21.loc[currency, ['Amount($)', 'Stage']].to_numpy()

# %%
#Lets check the column again and make sure the stage column does not have any values with $ sign.
df21['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Upsparks', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', 'ah! Ventures', 'ITO Angel Network, LetsVenture',
#        'Early seed', 'Series D1', 'JITO Angel Network, LetsVenture',
#        'Seies A', 'Pre-series', 'Series A2', 'Series I'], dtype=object)

# %%
#replace foreign values with NaN
df21['Stage'] = df21['Stage'].replace(["PE", "ah! Ventures", "ITO Angel Network, LetsVenture", "JITO Angel Network, LetsVenture", "Upsparks"], np.nan)

# %%
df21['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Bridge', 'Seed+', 'Series F2', 'Series A+', 'Series G',
#        'Series F', 'Series H', 'Series B3', 'Series F1', 'Pre-series A1',
#        'Early seed', 'Series D1', 'Seies A', 'Pre-series', 'Series A2',
#        'Series I'], dtype=object)

# %%
#replace misspelled stage names with the appropriate stage names 
df21['Stage'] = df21['Stage'].replace({'Seed+':'Seed','Seies A':'Series A'})
df21['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Bridge', 'Series F2', 'Series A+', 'Series G', 'Series F',
#        'Series H', 'Series B3', 'Series F1', 'Pre-series A1',
#        'Early seed', 'Series D1', 'Pre-series', 'Series A2', 'Series I'],
#       dtype=object)

# %% [markdown]
# ## Considering the Sector column

# %%
df21['Sector'].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas',
#        'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.',
#        "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",
#        'Cosmetics', 'Mobility', 'Social media', 'Real Estate',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Social commerce', 'Mobile Games', 'Food Production', 'Podcast',
#        'HeathTech', 'Battery', 'Content publishing', 'Water purification',
#        'Content commerce', 'Innovation Management', 'Software company',
#        'Automation', 'Food Industry', 'Celebrity Engagement',
#        'Trading platform', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'Consulting', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Home Decor', 'Solar',
#        'TaaS startup', 'EV startup', 'HR Tech', 'Blockchain startup',
#        'Food and Beverages', 'Beverages', 'Manufacturing startup',
#        'Cryptocurrency', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup',
#        'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#        'Design', 'B2B Travel', 'Interior Design',
#        'Manchester, Greater Manchester', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
#Extarct wrong sector value 
df21[df21['Sector'].str.contains('MoEVing is')]
# Out:
#     Company/Brand  Founded HeadQuarter  \
# 257       MoEVing     2021    Gurugram
#
#                                                 Sector  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                     What it does  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Founders  Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000      Seed   NaN

# %%
 df21[df21['Sector'].str.contains('Primary Business is Development and Manufacturing of Novel')]
# Out:
#           Company/Brand  Founded HeadQuarter  \
# 242  Fullife Healthcare     2009         NaN
# 256  Fullife Healthcare     2009         NaN
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %%
df21[df21['Sector'].str.contains('Sochcast is an Audio experiences company')]
# Out:
#      Company/Brand  Founded HeadQuarter  \
# 1100      Sochcast     2020         NaN
#
#                                                  Sector  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                            What it does  \
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   NaN

# %%
# replace the entries with NaN
df21['Sector']= df21['Sector'].replace({'MoEVing is India\'s only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.':np.nan})
df21['Sector']= df21['Sector'].replace({'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.':np.nan})
df21['Sector']= df21['Sector'].replace({'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience':np.nan})

# %%
df21['Sector'].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas', nan, 'Cosmetics',
#        'Mobility', 'Social media', 'Real Estate', 'Digital platform',
#        'B2B Ecommerce', 'Online Media', 'Social commerce', 'Mobile Games',
#        'Food Production', 'Podcast', 'HeathTech', 'Battery',
#        'Content publishing', 'Water purification', 'Content commerce',
#        'Innovation Management', 'Software company', 'Automation',
#        'Food Industry', 'Celebrity Engagement', 'Trading platform',
#        'Personal Care', 'Cannabis startup', 'Blogging', 'Consulting',
#        'BioTechnology', 'B2B Marketplace', 'Health care', 'Social audio',
#        'Fashion and lifestyle', 'Delivery service', 'B2B Manufacturing',
#        'Home Decor', 'Solar', 'TaaS startup', 'EV startup', 'HR Tech',
#        'Blockchain startup', 'Food and Beverages', 'Beverages',
#        'Manufacturing startup', 'Cryptocurrency',
#        'Vehicle repair startup', 'Advisory firm', 'Legaltech',
#        'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup', 'Design', 'B2B Travel',
#        'Interior Design', 'Manchester, Greater Manchester',
#        'Product studio', 'Aviation & Aerospace', 'Staffing & Recruiting'],
#       dtype=object)

# %%
# Rename 
df21['Sector'] = df21['Sector'].replace(["Healtcare","Helathcare", "Health", "Heathcare", "Heathtech" ], "Healthtech")

# %%
# Standardize the sector names by converting them to title case
df21["Sector"] = df21["Sector"].str.title()
df21['Sector'].unique()
# Out:
# array(['Ai Startup', 'Edtech', 'B2B E-Commerce', 'Fintech',
#        'Home Services', 'Healthtech', 'Tech Startup', 'E-Commerce',
#        'B2B Service', 'Renewable Energy', 'Electronics', 'It Startup',
#        'Food & Beverages', 'Aeorspace', 'Deep Tech', 'Dating', 'Gaming',
#        'Robotics', 'Retail', 'Food', 'Oil And Energy', 'Agritech',
#        'Telecommuncation', 'Milk Startup', 'Ai Chatbot', 'It',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'Legaltech', 'Food Delivery', 'Automotive',
#        'Saas Startup', 'Fantasy Sports', 'Video Communication',
#        'Social Media', 'Skill Development', 'Rental', 'Recruitment',
#        'Healthcare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Sportstech', 'Hrtech',
#        'Wine & Spirits', 'Mechanical & Industrial Engineering',
#        'Spiritual', 'Financial Services', 'Industrial Automation',
#        'Lifestyle', 'Iot', 'Banking', 'Computer Software',
#        'Digital Mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B Marketplace', 'Location Analytics', 'Media',
#        'Consumer Electronics', 'Tobacco', 'Deeptech', 'Insuretech',
#        'Mlops Platform', 'Venture Capital', 'Pet Care', 'Drone',
#        'Wholesale', 'Construction', 'E-Learning', 'Consumer Services',
#        'Venture Capital & Private Equity', 'Health, Wellness & Fitness',
#        'Ott', 'Education Management', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social Network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas', nan, 'Cosmetics',
#        'Mobility', 'Real Estate', 'Digital Platform', 'B2B Ecommerce',
#        'Online Media', 'Social Commerce', 'Mobile Games',
#        'Food Production', 'Podcast', 'Heathtech', 'Battery',
#        'Content Publishing', 'Water Purification', 'Content Commerce',
#        'Innovation Management', 'Software Company', 'Automation',
#        'Food Industry', 'Celebrity Engagement', 'Trading Platform',
#        'Personal Care', 'Cannabis Startup', 'Blogging', 'Consulting',
#        'Biotechnology', 'Health Care', 'Social Audio',
#        'Fashion And Lifestyle', 'Delivery Service', 'B2B Manufacturing',
#        'Home Decor', 'Solar', 'Taas Startup', 'Ev Startup', 'Hr Tech',
#        'Blockchain Startup', 'Food And Beverages', 'Beverages',
#        'Manufacturing Startup', 'Cryptocurrency',
#        'Vehicle Repair Startup', 'Advisory Firm',
#        'Pollution Control Equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Farming', 'Nft Marketplace', 'Internet',
#        'Spacetech', 'Consumer Software', 'Social Community', 'Fishery',
#        'Renewables & Environment', 'Online Storytelling', 'Aviation',
#        'It Company', 'Environmental Service', 'Job Discovery Platform',
#        'D2C Fashion', 'Crm', 'Software', 'Nutrition', 'D2C Startup',
#        'Community Platform', 'Venture Capitalist', 'Networking',
#        'Commercial Real Estate', 'Ar Startup', 'Consumer Service',
#        'Martech', 'Advertisement', 'Content Creation',
#        'Augmented Reality', 'Rental Space', 'Bike Rental',
#        'Beauty Products', 'Tourism', 'Femtech', 'Cultural', 'Co-Working',
#        'Supply Chain Platform', 'Social Platform', 'Cleantech',
#        'Ai Company', 'Sports Startup', 'Matrimony', 'Crypto', 'Clothing',
#        'Analytics', 'Finance', 'Iot Platform', 'Commerce',
#        'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'Nft', 'Oil & Energy', 'Ev',
#        'Company-As-A-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud Kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C Jewellery',
#        'Sales And Distribution', 'Saas', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Foootwear',
#        'Legal Services', 'Veterinary', 'Arts & Crafts',
#        'Investment Management', 'Education', 'Management Consulting',
#        'B2B Startup', 'Design', 'B2B Travel', 'Interior Design',
#        'Manchester, Greater Manchester', 'Product Studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %% [markdown]
# ### Categorization
# The Sector column has many unique values. Some values may be inputted under synonyms so aggregate column into fewer unique values or categories

# %%
# Loop to get the values in the unique values in the Industry column

Sector_name_list = df21['Sector'].tolist()

unique_Sector = []
for Sector in Sector_name_list:
    if Sector not in unique_Sector:
        unique_Sector.append(Sector)


        
for Sector in unique_Sector:
    print(Sector)
# Out:
# Ai Startup
# Edtech
# B2B E-Commerce
# Fintech
# Home Services
# Healthtech
# Tech Startup
# E-Commerce
# B2B Service
# Renewable Energy
# Electronics
# It Startup
# Food & Beverages
# Aeorspace
# Deep Tech
# Dating
# Gaming
# Robotics
# Retail
# Food
# Oil And Energy
# Agritech
# Telecommuncation
# Milk Startup
# Ai Chatbot
# It
# Logistics
# Hospitality
# Fashion
# Marketing
# Transportation
# Legaltech
# Food Delivery
# Automotive
# Saas Startup
# Fantasy Sports
# Video Communication
# Social Media
# Skill Development
# Rental
# Recruitment
# Healthcare
# Sports
# Computer Games
# Consumer Goods
# Information Technology
# Apparel & Fashion
# Logistics & Supply Chain
# Sportstech
# Hrtech
# Wine & Spirits
# Mechanical & Industrial Engineering
# Spiritual
# Financial Services
# Industrial Automation
# Lifestyle
# Iot
# Banking
# Computer Software
# Digital Mortgage
# Information Technology & Services
# Furniture
# B2B Marketplace
# Location Analytics
# Media
# Consumer Electronics
# Tobacco
# Deeptech
# Insuretech
# Mlops Platform
# Venture Capital
# Pet Care
# Drone
# Wholesale
# Construction
# E-Learning
# Consumer Services
# Venture Capital & Private Equity
# Health, Wellness & Fitness
# Ott
# Education Management
# Insurance
# Software Startup
# Computer & Network Security
# Capital Markets
# Social Network
# Hospital & Health Care
# Music
# Hauz Khas
# nan
# Cosmetics
# Mobility
# Real Estate
# Digital Platform
# B2B Ecommerce
# Online Media
# Social Commerce
# Mobile Games
# Food Production
# Podcast
# Heathtech
# Battery
# Content Publishing
# Water Purification
# Content Commerce
# Innovation Management
# Software Company
# Automation
# Food Industry
# Celebrity Engagement
# Trading Platform
# Personal Care
# Cannabis Startup
# Blogging
# Consulting
# Biotechnology
# Health Care
# Social Audio
# Fashion And Lifestyle
# Delivery Service
# B2B Manufacturing
# Home Decor
# Solar
# Taas Startup
# Ev Startup
# Hr Tech
# Blockchain Startup
# Food And Beverages
# Beverages
# Manufacturing Startup
# Cryptocurrency
# Vehicle Repair Startup
# Advisory Firm
# Pollution Control Equiptment
# Fashion & Lifestyle
# Blockchain
# Fitness
# D2C
# Automobile
# Environmental Services
# Merchandise
# Facilities Services
# Marketing & Advertising
# Human Resources
# Eyewear
# D2C Business
# Farming
# Nft Marketplace
# Internet
# Spacetech
# Consumer Software
# Social Community
# Fishery
# Renewables & Environment
# Online Storytelling
# Aviation
# It Company
# Environmental Service
# Job Discovery Platform
# D2C Fashion
# Crm
# Software
# Nutrition
# D2C Startup
# Community Platform
# Venture Capitalist
# Networking
# Commercial Real Estate
# Ar Startup
# Consumer Service
# Martech
# Advertisement
# Content Creation
# Augmented Reality
# Rental Space
# Bike Rental
# Beauty Products
# Tourism
# Femtech
# Cultural
# Co-Working
# Supply Chain Platform
# Social Platform
# Cleantech
# Ai Company
# Sports Startup
# Matrimony
# Crypto
# Clothing
# Analytics
# Finance
# Iot Platform
# Commerce
# Defense & Space
# Entertainment
# Business Supplies & Equipment
# Nft
# Oil & Energy
# Ev
# Company-As-A-Service
# Textiles
# Professional Training & Coaching
# Maritime
# Housing Marketplace
# Furniture Rental
# Telecommunications
# Equity Management
# Cloud Kitchen
# Nanotechnology
# Community
# Higher Education
# B2B
# Mechanical Or Industrial Engineering
# D2C Jewellery
# Sales And Distribution
# Saas
# Information Services
# Translation & Localization
# Investment Banking
# Foootwear
# Legal Services
# Veterinary
# Arts & Crafts
# Investment Management
# Education
# Management Consulting
# B2B Startup
# Design
# B2B Travel
# Interior Design
# Manchester, Greater Manchester
# Product Studio
# Aviation & Aerospace
# Staffing & Recruiting

# %%
# re-categorize the Sector column
Agriculture = ['Agritech', 'Food Production', 'Farming', 'Biotechnology']
Marketing = ['Advertisement','Marketing', 'Brand Marketing', 'Market Research', 'Advertising', 'Digital Marketing','Trading Platform','Marketing & Advertising','Martech']
Technology = ['Networking', 'Ar Startup','CRM','Automation','It Startup','Ai Chatbot', 'Telecommunications','It','Ai Startup', 'Edtech', 'Fintech', 'Tech Startup', 'Deep Tech', 'Gaming', 'Robotics', 'Saas Startup', 'Video Communication', 'Social Media', 'Skill Development', 'Fantasy Sports', 'Computer Games', 'Sportstech', 'Iot', 'Computer Software', 'Information Technology', 'Digital Mortgage', 'Information Technology & Services', 'Computer & Network Security', 'Computer & Network Security','Internet', 'Information Technology', 'Digital Platform', 'Software Company', 'Blockchain', 'Software', 'Networking', 'Augmented Reality', 'Nanotechnology', 'Product Studio']
Bank_Fin = ['Financial Services', 'Banking', 'Insurance', 'Venture Capital', 'Capital Markets', 'Insurance', 'Venture Capital & Private Equity', 'Cryptocurrency', 'Equity Management', 'Investment Banking', 'Investment Management']
Accounting = ['Accounting']
Insurance = ['Insurance']
Digital_Platform =['NFT Marketplace','Community Platform','Blogging' ]
Food = ['Home Services', 'Food & Beverages', 'Food', 'Milk Startup', 'Food Delivery', 'Restaurant', 'Food Industry', 'Food And Beverages', 'Beverages', 'Cloud Kitchen']
Transport = ['Aviation & Aerospace''Aeorspace', 'Aerospace','Transportation','Vehicle Repair Startup', 'Bike Rental', 'Transport', 'Aviation']
Energy = ['Battery','Renewable Energy', 'Oil And Energy', 'Solar', 'Renewables & Environment', 'Oil & Energy', 'Ev', 'Cleantech', 'Energy']
Health = ['Heathtech','Healthtech','Primary Business Is Development And Manufacturing Of Novel Healthcare Products In Effervescent Forms Using Imported Propriety Ingredients.', 'Healthcare', 'Health, Wellness & Fitness', 'Hospital & Health Care', 'Health Care', 'Medical & Health', 'Housing Marketplace', 'Veterinary']
Sport_Fit = ['Sports', 'Sports Startup', 'Fitness', 'Sportstech']
Manufacturing = ['Electronics', 'Consumer Goods', 'Manufacturing Startup', 'Automobile', 'Automotive', 'Manufacturing', 'Manufacturing Startup', 'Mechanical & Industrial Engineering', 'Automobile', 'Manufacturing Startup', 'Mechanical Or Industrial Engineering']
Beauty = ['Cosmetics', 'Personal Care', 'Beauty Products','Beauty']
Info_media = ['Media', 'Online Media', 'Podcast', 'Content Publishing', 'Content Commerce', 'Content Creation', 'Online Storytelling']
Services = [ 'Sales And Distribution', 'Innovation Management', 'Celebrity Engagement','Furniture Rental','Logistics', 'Logistics & Supply Chain','Rental', 'Recruitment', 'Consumer Services', 'Facilities Services', 'Human Resources', 'Rental Space', 'Content Creation', 'Legal Services', 'Community', 'Professional Training & Coaching', 'Legal Services', 'Translation & Localization', 'Legal Services', 'Staffing & Recruiting','Delivery Service']
Government = ['Government']
Tourism = [ 'Tourism']
Events = ['Event Management', 'Event Services']
Edu = ['Education', 'Edtech', 'Higher Education', 'Arts & Crafts']
Hospitality = ['Hospitality', 'Hotel']
Fashion = ['Fashion', 'Fashion And Lifestyle', 'Fashion & Lifestyle', 'Fashion & Lifestyle', 'Eyewear', 'Fashion & Lifestyle']
B2B = ['B2B E-Commerce', 'B2B Service', 'B2B Marketplace', 'B2B Trave', 'B2B', 'B2B Startup','B2B Manufacturing', 'B2B Ecommerce', 'D2C Fashion']
D2C = [ 'D2C', 'D2C Fashion', 'D2C Jewellery', 'D2C Startup','D2C Business']
nan = ['nan', 'Nan', 'NaN', None]
Housing = ['Housing Marketplace', 'Commercial Real Estate']
Music = ['Music','Sochcast Is An Audio Experiences Company That Give The Listener And Creators An Immersive Audio Experience']
Others = [ 'Cannabis Startup','Design' , 'Product Studio']

# %%
# Write function to put values into new categories
def new_cat(Sector):
    if Sector in Marketing:
        return 'Marketing'
    elif Sector in Agriculture:
        return 'Agriculture'
    elif Sector in Bank_Fin:
        return 'Banking & Finance'
    elif Sector in Accounting:
        return 'Accounting'
    elif Sector in Insurance:
        return 'Insurance'
    elif Sector in Technology:
        return 'Technology'
    elif Sector in Food:
        return 'Food & Beverage'
    elif Sector in Transport :
        return 'Transport'
    elif Sector in Energy:
        return 'Energy'
    elif Sector in Health:
        return 'Health'
    elif Sector in Sport_Fit :
        return 'Sports & Fitness'
    elif Sector in Manufacturing:
        return 'Manufacturing'
    elif Sector in Beauty:
        return 'Beauty'
    elif Sector in Info_media:
        return 'Media & Entertainment'
    elif Sector in Services:
        return 'Services'
    elif Sector in Government:
        return 'Government'
    elif Sector in Tourism:
        return 'Tourism'
    elif Sector in Events:
        return 'Events'
    elif Sector in Edu:
        return 'Education'
    elif Sector in nan:
        return 'NaN'
    elif Sector in Hospitality:
        return 'Hospitality'
    elif Sector in Fashion:
        return 'Fashion'
    elif Sector in B2B:
        return 'B2B'
    elif Sector in Music:
        return 'Music'
    elif Sector in Housing:
        return 'Housing'
    elif Sector in D2C:
        return 'D2C'
    elif Sector in Digital_Platform:
        return 'Digital_Platform'
    elif Sector in Others:
        return 'Others'

# %%
df21['Sector'] = df21['Sector'].apply(new_cat)

# %%
df21['Sector'].unique()
# Out:
# array(['Technology', 'B2B', 'Food & Beverage', 'Health', None, 'Energy',
#        'Manufacturing', 'Agriculture', 'Services', 'Hospitality',
#        'Fashion', 'Marketing', 'Transport', 'Sports & Fitness',
#        'Banking & Finance', 'Media & Entertainment', 'Music', 'Beauty',
#        'Others', 'Digital_Platform', 'D2C', 'Housing', 'Tourism',
#        'Education'], dtype=object)

# %%
df21.head()
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 0  Unbox Robotics     2019   Bangalore  Technology
# 1          upGrad     2015      Mumbai  Technology
# 2     Lead School     2012      Mumbai  Technology
# 3         Bizongo     2015      Mumbai         B2B
# 4        FypMoney     2021    Gurugram  Technology
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %% [markdown]
# ## Considering the Investor column

# %%
df21['Investor'].unique()
# Out:
# array(['BEENEXT, Entrepreneur First',
#        'Unilazer Ventures, IIFL Asset Management',
#        'GSV Ventures, Westbridge Capital', 'CDC Group, IDG Capital',
#        'Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal', 'Vy Capital',
#        'CIIE.CO, KIIT-TBI', 'Inflection Point Ventures',
#        'Inflexor Ventures', nan,
#        '9Unicorns Accelerator Fund, Metaform Ventures',
#        'SucSEED Indovation, IIM Calcutta Innovation Park',
#        'Safe Planet Medicare', 'Impact Partners, C4D Partners',
#        'Tiger Global Management, InnoVen Capital', 'Novo Tellus Capital',
#        'Raintree Family Office, ADB arm',
#        'Mumbai Angels, Narendra Shyamsukha', 'Paradigm, Kunal Shah',
#        'Matrix Partners India, GIC', 'Chiratae Ventures, JAFCO Asia',
#        'Mumbai Angels Network, Expert DOJO', 'GVFL',
#        'Kotak Mahindra Bank, FMO', 'Kalaari Capital',
#        'NB Ventures, IAN Fund',
#        'Sequoia Capital India, Hummingbird Ventures',
#        'Gaurav Munjal, Snehil Khanor', 'JITO Angel Network, SOSV',
#        'Chiratae Ventures, YourNest Venture Capital', 'STRIVE VC',
#        'Venture Catalysts', 'Jaipuria Family Office', 'Amazon',
#        'Riso Capital', 'MTG Ventures',
#        'Qualcomm Ventures, Warburg Pincus', '9Unicorns', 'Morgan Stanley',
#        'Alfa Ventures, Agility Venture Partners',
#        'Stellaris Venture Partners, Ramakant Sharma', 'Spanache',
#        'DSG Consumer Partners, Saama Capital', 'Hindustan Media Ventures',
#        'Stellaris Venture Partners, Omidyar Network India, Flourish Ventures',
#        'Angelbay Holdings, Faad Network',
#        'Alteria Capital, Chiratae Ventures',
#        'WaterBridge Ventures, Info Edge',
#        'Carmignac, Falcon Edge Capital', 'Vaibhav Domkundwar, Kunal Shah',
#        'Chiratae Ventures, Bharat Innovation Fund',
#        'Acko Technology, Services, LetsVenture',
#        'Bertelsmann India Investments, Fullerton Financial Holdings',
#        'Dragoneer Investment Group, Tiger Global Management',
#        'http://100x.vc/',
#        'TPG Growth, Caisse de Depot et Placement du Quebec',
#        'Centrum Financial Services', 'Chiratae Ventures, BEENEXT',
#        'Harsha Bhogle', 'GetVantage, Prakash Katama',
#        'Tiger Global Management, Y Combinator Continuity Fund',
#        'Michael & Susan Dell Foundation', 'Marquee fintech founders',
#        'Falcon Edge India, Norwest Venture Partners',
#        'SOSV, Omphalos Ventures India', 'Twitter Ventures, Pawan Munjal',
#        'CitiusTech', 'Arena Holdings, Think Investments',
#        'T Choithrams BVI, Ardor',
#        'Kogta Financial India Limited, ICICI Bank',
#        'SucSEED Venture Partners, TMT Connekt',
#        'SAIF Partners, Venture Highway', 'Global Founders Capital',
#        'JAFCO Asia, Chiratae Ventures', 'Y Combinator',
#        'Artha Venture Fund', 'Jitendra Gupta, Amrish Rau',
#        'FJ Labs, Brian Norgard', 'Indian Angel Network',
#        'Jitendra Gupta, Harsh Shah',
#        'Elevation Partners, Emergent Ventures',
#        'Kalaari Capital, Dream Capital', 'Lumikai',
#        'Matrix Partners India', 'C4D Partners', 'Bertelsmann India',
#        'Iron Pillar, Nordstar, Binny Bansal',
#        'FMC, Omnivore, Blume Ventures', 'InvestCorp',
#        'Pritesh Kumar, Bharat Gupta',
#        'Y Combinator, 9Unicorns, Titan Capital',
#        'Unicorn India Ventures, SEA Fund, Devdatt Shah',
#        'Matrix Partners India, Elevation Capital',
#        'Avaana Capital, Orios Ventures', 'Punit Balan',
#        'Y Combinator, Broom Ventures, Kunal Shah',
#        'Skycatcher, AET Fund, BAce Capital, Dream Incubator, 1Up Ventures',
#        'Eclear Leasing', 'First Cheque, Letsventure',
#        'Sequoia Capital India, BEENEXT', 'Velocity',
#        'Tribe Capital, Moore Strategic Ventures (MSV)',
#        'Fireside Ventures', 'Inflection Point Ventures, ONGC',
#        'Y Combinator, Incubate Fund India',
#        'Titan Capital, Rockstud Capital,  John Abraham, WEH Ventures',
#        'Info Edge Ventures', 'NB Ventures', 'Accel',
#        'Binny Bansal, Kunal Shah', 'TradeCred', 'Unicorn India Ventures',
#        'UC Inclusive Credit, Western Capital',
#        'IIFL India Private Equity Fund, Smiti Holding & Trading Company',
#        'Faering Capital', 'responsAbility Investments, Blue Orchard',
#        'Sanchit Agarwal, Sujan Sinha, Michael Cooke',
#        'CRV, Nexus Venture Partners',
#        'Salesforce Ventures, Sierra Ventures, Sequoia Capital India’s Surge',
#        'Micelio Fund, growX ventures',
#        'IIFL Wealth, Asset Management, Northern Arc Capital',
#        'Better Capital, Ashish Achrekar', 'IAN', 'Alpha Wave Incubation',
#        'Point One Capital, Yatra Angel Network (YAN), Opus Consulting, Manipal Technologies.',
#        'Microsoft', 'Shell Ventures, Yamaha, Kunal Shah',
#        'We Founder Circle',
#        'Saama Capital, DSG Consumer Partners, Sharrp Ventures',
#        'Tiger Global’s Scott Schleifer', 'Elevation Capital',
#        'Venture Catalysts, Auxano Capital, Venture Garage, Yoga Capital, Ah!Ventures, Lead Angels',
#        'Sixth Sense Ventures', '9Unicorns, Sequoia Capital India’s Surge',
#        'Anicut Angel Fund, 9 Unicorns', 'Info Edge, FalconEdge',
#        'WestCap Group, Tomales Bay Capital',
#        'Chiratae Ventures, Better Capital',
#        'Siguler Guff, Baillie Gifford',
#        'IIFL AMC, Mankind Pharma Family Office, Aroa Ventures',
#        'ITI Growth Opportunities', 'Amrac Investment Trust',
#        'Bhavin Turakhia', 'Amara Raja Batteries',
#        'India Infoline Finance', 'Venture Highway', 'BEENEXT, Orios',
#        'Axilor', 'Westbridge Capital, Tanglin Venture Partners',
#        '100X.VC\ufeff,\ufeff Titan Capital, Rahul Mathur, Gaurav Mandlecha',
#        'IIFL, Amicus Capital, Ananta Capital',
#        'Venture Highway, Endiya Partners',
#        'Verlinvest, Sequoia Capital India', 'Anicut Angel Fund',
#        'Tiger Global',
#        'Alphabit Fund, Fulgur Ventures, Stacks Accelerator, SBX Capital',
#        'Roots Ventures, Velo Partners', 'Nexus Venture Partners',
#        'Mumbai Angels Network, Huddle, Lumis Partners',
#        'SucSEED Indovation Fund',
#        'Potencia Ventures, Bisk Ventures, LetsVenture, Ronnie Screwvala, Arihant Patni',
#        'Better Capital, First Cheque, Titan Capital', 'Evolvence Capital',
#        'SARA ELGI',
#        'Nubank, Global Founders Capital, Sequoia Capital India, Matrix Partners India',
#        'ah! Ventures High Tables',
#        'Eight Roads Ventures, Think Investments, Mankekar Family Office',
#        'A91 Partners', 'Chiratae Ventures', 'Sequoia’s Surge',
#        'Lead Angels, Titan Capital, Pravega Ventures',
#        'Accel Partners, Elevation Capital',
#        'Inflection Point Ventures, Rockstud Capital, FirstPort Capital, Bliss Flow Investments Pvt Ltd',
#        'Anicut Angel Fund, Axilor Ventures',
#        'Ecosystem Ventures, CMM group',
#        'Mumbai Angels Network, Social Alpha', 'Disrupt ADQ, QIC',
#        'Valar Ventures, IA Ventures', 'Sequoia Capital India', 'Zomato',
#        'Lightspeed, Times Group, Tanglin Venture Partners',
#        'Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gokul Rajaram, Shirish Nadkarni',
#        'Tuscan Ventures, Ohm Stock Brokers, Artha Venture Fund',
#        'Signal Peak Ventures', 'Evolvence, Hero Enterprise',
#        'BlueOrchard Impact Investment Managers', 'Steadview Capital',
#        'MassMutual Ventures', 'YourNest VC', 'Accel India',
#        'Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose',
#        'TVS Motor, Zoho', 'IIFL Asset Management',
#        'Oasis Capital, Scorpio VC, DeltaHub Capital',
#        'Titan Capital, Haresh Chawla, AngelList Syndicate',
#        '9Unicorns, Ashneer Grover', 'Founders Room Capital',
#        '9Unicorns, ZNL', 'WEH Ventures', '$22000000', '$5000000',
#        'Kunal Shah, Deepinder Goyal, Abhiraj Singh Bhal',
#        'Guild Capital, RPSG Capital Ventures',
#        'General Catalyst, Eight Roads Ventures, Elevation Capital',
#        'NB Ventures, Earlsfield Capital', 'Varun Alagh, Sahil Barua',
#        'SoftBank Vision Fund 2', 'Tribe Capital, Prime Venture Partners',
#        'Jungle Ventures', 'Marquee international institutional investors',
#        'Alkeon Capital', 'Y Combinator, Harvard Management',
#        'Y Combinator\ufeff, \ufeffGoodwater Capital',
#        'Shrishti Sahu, Umang Vohra', 'Astra Ventures, Gaurav Jaitly',
#        'Capital A, Collective Artists Network',
#        'Aditya Singhal, Nishant Sinha', 'Pentathlon Ventures',
#        'Alpha Wave Ventures II, Tiger Global Management, SoftBank Vision Fund II',
#        'KRAFTON', 'Chiratae Ventures, Lenskart Vision Fund', 'Recur Club',
#        'DevX Venture Fund, Blume Founder Fund', 'Ajith Daneil',
#        'Aurum Proptech', 'Y-Combinator', 'The Good Glamm Group', 'Invus',
#        'Tiger Global, Prosus Ventures',
#        'Shuru Up, Ankit Kedia, Arun Gupta',
#        'Ankit Mehrotra, Saurabh Aggarwal', 'Sauce.vc',
#        '3one4 Capital, Sixth Sense Ventures',
#        'YCombinator, Justin Mateen, Pioneer Fund',
#        'Sojitz Corporation, Stride Ventures',
#        'IIFL Wealth, TPG Growth, Norwest Venture Partners',
#        'Nabventures, Avaana Capital', 'Fluid Ventures, Mulberry Silks',
#        'Rajesh Rajendran', 'Mike Novogratz, Neeraj Arora',
#        'Reliance Digital Health', 'DevX Venture Fund',
#        'Ritu Marya Family Office.', 'Ten Innovate',
#        'Tiger Global, Sequoia Capital', 'Shark Tank India',
#        'Premji Invest, Steadview Capital', 'Sequoia',
#        'Apis Insurtech Fund I', 'SK Tripathi, Sanjeev Gupta',
#        'Hardcastle Petrofer', 'Ocean View Investment, QED Fund',
#        'Omidyar Network, Tencent Holdings',
#        'ITI Growth Opportunities Fund, Unit-E Ventures',
#        'InnoVen Capital, Nexus Venture Partners', 'CIIE.CO',
#        'Orios Venture Partners', 'Omidyar Network India',
#        'Wipro venture capital arm', 'Yuj Ventures, Sixth Sense Ventures',
#        'Premji Invest, Mirae Asset Naver Asia Growth Fund, Alpine Capital',
#        'Inflection Point Ventures, SucSEED Venture Partners',
#        'Anas Rahman Junaid, Vinod Jose', 'Capital One, Arrowroot Capital',
#        'YourNest Venture Capital', 'Incubate Fund India',
#        'Kunal Shah, Greg Kidd', 'InnoVen Capital, TEAMFund',
#        'Venture Catalysts, 9Unicorns Accelerator Fund',
#        'Venture Highway, Rohit Bansal', 'Fresco Capital, Social Starts',
#        'Y Combinator, Rebright Partners',
#        'Rohit Goutamchand, India CXO Fund',
#        'Rajasthan Venture Capital Fund, ACPL Exports',
#        'Amplo, Insight Partners', 'Better Capital', 'Justin Mateen',
#        'View Trade Holding Corp',
#        'InnoVen Capital, Bertelsmann India Investments', 'ScoopWhoop',
#        'Canaan Valley Capital, Glade Brook Capital Partners',
#        'Vijay Shekhar Sharma, Dr Ritesh Malik',
#        'RTP Global, Harshil Mathur', 'Paragon Partners, NABVENTURES',
#        'EXPERT DOJO', 'Saama Capital, India Quotient',
#        'InCred Financial Services, Vivriti Capital, Northern Arc Capital',
#        'ah! Ventures', 'Somak Ghosh, M V Nair', 'Wurk',
#        'Plutus Wealth Management, Turtle Entertainment',
#        'Ambiga Subramanian, Goutham Ekollu', 'Accel, Owl Ventures',
#        'Rajan Anadan', 'Jesse Lucas',
#        'IDFC Private Equity, Bessemer Venture Partners',
#        'Sequoia Capital India, Accel',
#        'Venture Catalysts, Tahseen Consulting', 'Equanimity Ventures',
#        'BlueOrchard Finance S A, Gojo & Company',
#        'Better Capital, Titan Capital', 'Gojo & Company', 'Mumbai Angels',
#        'Pegasus Tech Ventures, Base Partners', '3one4 Capital, Accel',
#        'Hitesh Oberoi, Lightbox', 'YES Bank', 'Campus Fund',
#        'Hyperplane Venture Capital', 'Matrix Partners India, RTP Global',
#        'Info Edge, Ruizheng Investment', 'Quess Corp India',
#        'Sunil Kumar Singhvi, 9Unicorns Accelerator Fund',
#        'India Accelerator’s Angel Investor Network', 'Shell Foundation',
#        'Jimmy Singh', 'Kunal Shah, Deepak Abbot', 'Accel, Nexus Venture',
#        'Singapore Angel Network, Artha India Ventures',
#        'Starfish Growth Partners, Investpad', 'Hashed', 'Titan Capital',
#        "Zerodha's Rainmatter Capital, Better Capital",
#        'Sixth Sense Ventures, Colgate Palmolive',
#        'Lightbox, Evolvence India Fund', 'Tomorrow Capital',
#        'Inflection Point Ventures, DLabs',
#        'InnoVen Capital, Steadview Capital', 'BlackSoil Capital',
#        'PointOne Capital, Core91 VC', 'A91 Partners, Faering Capital',
#        'Blockchain Capital, SBI Ven Capital',
#        'Baring Private Equity Partners India, Talbros',
#        'Sequoia Capital India, 3one4 Capital',
#        'Prosus Ventures, RTP Global',
#        'U.S. International Development Finance Corp, responsAbility',
#        'Binance Labs, Zee Prime Capital', 'RP-Sanjiv Goenka Group',
#        'IvyCap Ventures', 'Zone Startups In', 'Blue Ashva Capital',
#        'Ribbit Capital, Kunal Shah', 'Ecom Express', 'InnoVen Capital',
#        'Satish Grampurohit', 'Amit Singhal, Raine Ventures',
#        'Tiger Global, Dragoneer Investment Group, Steadview Capital, General Atlantic',
#        'CDC Group, Aavishkaar Venture Capital', 'GSF, Pras Hanuma',
#        'Ajat Hukkoo, Piyush Chaplot', 'Mumbai Angels, Amitesh Pandey',
#        'Think Investments',
#        'Nexus Venture Partners, 23 High Networth Individuals (HNIs)',
#        'Yatra Angel Network, BEENEXT',
#        'Orios Venture Partners, Matrix Partners India', 'Trishneet Arora',
#        'ContCentric', 'Siana Capital', 'DST Global, General Catalyst',
#        'Anthill Ventures', 'InnoVen Capital, InnoVen Capita',
#        '3one4 Capital, DSP Group', 'Enzia Ventures, AngelList',
#        'Steadview Capital, Insight Partners',
#        'Invested Development, Pratithi Investment Trust',
#        'Octahedron Capital, Moonstone Capital',
#        'Dhianu Das, Agility Venture Partners', 'Hindustan Media Venture',
#        'Omnivore', 'Awign Enterprises',
#        'Siddharth Bhaskar Shah, Upsparks', 'S Chand',
#        'Goldman Sachs, Tata Capital', 'growX ventures, Venture Gurukool',
#        'Mount Judi India Growth Fund', 'GEF Capital’s South Asia Fund',
#        'Sunil Sethia, Sunil Kumar Singhvi, Manish Mardia',
#        'Sequoia Capital', 'Mechanism Capital, DACM',
#        'Northern Arc Capital, Niyogin Fintech Limited, Credit Saison India, Vivriti Capital',
#        'Pearl Investment LLC', '021 Capital, Sparrow Capital',
#        'Kotak Investment Advisors Limited, Gruhas Proptech', 'VANS Group',
#        'Sachin Tendulkar', 'Xentel Investments', 'Accel Partners',
#        'Waterbridge, Lumikai', 'Auxano, Falcon5', 'Infoedge ventures',
#        'JITO Angel Network', 'Jupiter', 'Unitus Ventures',
#        'GIC, Infoedge', 'pi Ventures',
#        'Northern Arc, Caspian Impact Investments', 'Sofina Ventures SA',
#        'Tiger Global, Flipkart Ventures',
#        'Inflection Point Ventures, Rockstud Capital, Pentathlon Ventures, Prophetic Ventures syndicate',
#        'Prime VP', 'Tribe Capital, IFC Emerging Asia Fund, VEF',
#        'Sequoia’s Surge, Y Combinator', 'Endiya Partners',
#        'Gokul Rajaram, Pureland Venture, Wavemaker Partners',
#        'Callapina Capital', 'Khosla Ventures',
#        'Accel Partners, Matrix India',
#        'Omidyar Network India, Innoven Capital', 'Temasek, Falcon Edge',
#        'Deep Kalra, Ashish Kashyap, Rajesh Magow',
#        'IAN, Social Alpha, Startup Oasis', 'Capital India',
#        'FirstCry, Lightspeed Venture Partners',
#        'Accel, LetsVenture, 1Crowd', 'SAB Holdings',
#        'Lightspeed Venture Partners, Elevation Capital',
#        'Mumbai Angels Network', 'Jayanti Kanani',
#        'LeapFrog, Khosla Ventures', 'Ananta Capital',
#        'Northern Arc, Vivriti Capital', 'TATA Cleantech Capital',
#        'Aqua-Spark', 'Climate Angels Fund',
#        'Sequoia’s Surge, Nexus Venture Partners',
#        'Entrepreneur First (EF), GrowX Ventures', 'Zephyr Peacock',
#        'ADM Capital', 'SoftBank Vision Fund, Hindustan Media Venture',
#        '100x Entrepreneurs', 'Healthcare veterans, PIEDS',
#        'Bank of Baroda', 'YCombinator', 'IAN Fund', 'Vishal Gupta',
#        'Mirae Asset, H&M', 'Kotak Securities', 'Klub',
#        'Balaji Srinivasan', '$1000000', 'BASF Venture Capital GmbH',
#        'Rebright Partners, Flourish Ventures', 'Sequoia Surge',
#        'Titan Capital, Sequoia Capital', 'Parthiv Group',
#        'Omkar Pandharkame, Ketaki Ogale',
#        'GetVantage, Velocity, Shiprocket Capital', 'Krafton Inc, Omidyar',
#        'Blume Ventures, Exfinity Venture Partners',
#        'Beyond Next Ventures, M Venture Partners', 'AdvantEdge Founders',
#        'Faering Capital, Sequoia Capital India, IIFL Alternate Asset Managers',
#        'Sixth Sense Ventures, NABVENTURES', 'Temasek, Multiples PE',
#        'Griffin Gaming Partners', 'Zinnia Global',
#        'InfoEdge Ventures, IAN Fund', 'IIFL, Mumbai Angels',
#        'BEENEXT, Sequoia’s Surge', 'Antler India', 'Bharat Inclusion',
#        'Fidelity, BlackRock', 'Blacksoil', 'Speciale Invest',
#        'Canbank Venture Capital Fund', 'W Health Ventures',
#        '021 Capital, Y Combinator', 'Anand Prakash Sharma',
#        'Axilor Ventures', 'velocity.in', 'March Capital, Tribe Capital',
#        'Learn Capital', 'RTP Global', 'IAN, Yuj Ventures',
#        'Sequoia’s Surge, Accel Partners', 'Uday Sodhi', 'Fidelity, GIC',
#        'Auxano', 'Angelist India',
#        'Stanford Angels and Entrepreneurs India, Anjali Bansal',
#        'Vy Capital, Wellington Management', 'Avon Cycles',
#        'Matrix Partners India, 021 Capital', 'HNIs, Angels',
#        'NewQuest Capital Partners, Motilal Oswal Private Equity',
#        'Lasons India', 'Pankaj Chaddah, Srivatsan Rajan', 'Paytm',
#        'BlackSoil, CLSA Capital Partners', 'Saama, Whiteboard Capital',
#        'Indian Angel Network, Titan Capital, Lead Angels',
#        'The Chennai Angels',
#        'Venture Highway, Stellaris Venture Partners',
#        'State Bank of India, Y Combinator', 'Sanjay Baldwa, Ajay Jain',
#        'InfoEdge', 'Nitin Passi, Ruchirans Jaipuria',
#        'Stride Ventures, InnoVen Capital',
#        'Venture Catalysts, Jeevak Gupta',
#        'Triodos Investment Management, SAIF Partners', 'N+1 Capital',
#        'DST Global, RTP Global', 'Amit Singal, Manish Aggarwal',
#        'Trifecta Capital Advisors, Blume Ventures',
#        'Kumar Aakash, Amit Singhal', 'growX ventures',
#        'Shaival Desai, Alkemi Venture Partners',
#        'Aavishkaar Venture Capital, YWC Venture Capital',
#        'Alteria Capital', 'Tiga Investments, Baron Capital',
#        'Venture Catalysts, 9unicorns', 'Qualgro',
#        'Amit Lakhotia, Pravin Jadhav', 'Pravega Ventures',
#        'Greenoaks Capital, Elevation Capital',
#        'Sequoia Capital India, rocketship.vc', 'BLinC Invest',
#        'Spring Marketing Capital', 'Chaitanya Kalipatnapu, Kedar Gavane',
#        'Roha Investment Managers, angel investor Saumil Shah',
#        'TNF Ventures, Razorpay', 'Lok Capital, IIFL Asset Management',
#        'Nvidia Inception', 'Tiger Global Management, DST Global',
#        'Marquee investors', 'Ashish Hemrajani, Parikshit Dar',
#        'India Accelerator, Lyxel&Flamingo', 'Roshan Abbas, Ritesh Malik',
#        'Goat Capital, JAM Fund', 'General Catalyst, Jungle Ventures',
#        'Blackstone Group, ADQ', 'GoAhead Ventures',
#        'Paradigm Shift Capital, AngelList India', 'Arali Ventures',
#        'Anup Kumar Yama', 'Aryaman Vir', 'iSeed, Titan Capital',
#        'Research Innovation Incubation Design Labs', 'Sushil Agarwal',
#        'IvyCap Ventures, Endiya Partners',
#        'GUSEC Seed Fund, DeVX Venture Fund', 'Tiger Global, Sequoia',
#        'Quadria Capital', 'Blume Ventures, Whiteboard Capital',
#        'Ashwini Kakkar. 9Unicorns', 'Ashish Shah', 'Faad Network',
#        'Paragon Partners, Aavishkaar Capital', 'Krafton, Lumikai',
#        'Indovation Fund, Mumbai Angels', 'Gunosy, Blume Ventures',
#        'Edge Ventures, Elevation Capital', 'CDC Group',
#        'Titan Capital, Kunal Shah',
#        'Yamaha Motors, Omidyar Network India, Eight Roads Ventures',
#        'Norfund, The Rise Fund', 'Siti Cable',
#        'Crossbeam Venture Partners', 'Aavishkaar Capital', 'Mapmyindia',
#        'Jyoti Bansal', 'Accor',
#        'SRI Capital, Picus Capital, Alkemi Capital',
#        'Saama Capital, DSG Consumer Partners', 'Valar Ventures',
#        'Addition, SIG Global India Fund',
#        '9Unicorns Accelerator Fund, Indian Angel Network',
#        'Alfa Ventures', '1Crowd',
#        'TCV, D1 Capital Partners, Falcon Edge.',
#        'BanyanTree Finance Pvt. Ltd.', 'EXPERT DOJO, Mumbai Angels',
#        'Quona Capital', 'Ashv Finance, BlackSoil Capital',
#        'WaterBridge Ventures, SAIF Partners',
#        'Sweta Rau, 9Unicorns Accelerator Fund',
#        'Omnivore, Strive Ventures', 'Rajesh Sud, KULDEEP JAIN',
#        'PayU, Google', 'Sundi Natarajan, Srinivas Anumolu',
#        'Titan Capital, First Cheque', 'TPG Capital Asia, Epiq Capital',
#        'MaGEHold Pte. Ltd.', 'BlackRock, Owl Ventures',
#        'Asian Development Bank, Oman India Joint Investment Fund',
#        'JSW Ventures, Kalaari Capital',
#        'Unitus Ventures, Omidyar Network India',
#        'IvyCap Ventures, Pratithi Investment Trust',
#        'ACPI Investments, AdvantEdge Founders',
#        'RouteOne, Mankekar Family Office', 'India Quotient',
#        'TCN International Commerce', 'Alpine Capital, PremjiInvest',
#        'Bon Angels Venture Partners, Daesung Private Equity',
#        'Spring Marketing Capital, Verlinvest', 'Bain Capital',
#        'F-Prime Capital, Eight Roads Ventures India',
#        'Mumbai Angels, DNA Entertainment Networks',
#        'Hornbill Capital Advisers, Plutus Wealth Management',
#        'ADB Ventures, Jetty Ventures', 'Techstars, Ryan Johnson',
#        'Bessemer Venture Partners',
#        'Titan Capital, iSeed, First Cheque, 3.0 Fund.',
#        'Falcon Edge Capital, White Oak Global Advisors',
#        'Angel investors', 'Akya Ventures',
#        'Kayenne Ventures, Nordic Microfinance Initiative',
#        'Kae Capital, Pi Ventures', 'Elevar Equity, Accel India',
#        'Titan Capital, Y Combinator', 'Jitendra Gupta, Better Capital',
#        'Radiant Life Care Private Ltd, Life Healthcare',
#        'Mount Judi Ventures, growX Ventures, Season Two Ventures',
#        'Richard Rekhy', 'GAWA Capital, Gaja Capital',
#        'Better Capital, Bharat Inclusion Seed Fund', 'Krafton',
#        'Eight Roads Ventures India, Nexus Venture Partners',
#        'CDC Group, Partners Group',
#        'Matrix Partners India, Ankur Capital',
#        'U.S. International Development Finance Corp, Asian Development Bank',
#        'Hungama, Hindustan Talkies', 'Agility Venture Partners',
#        'Speciale Invest, Farid Ahsan',
#        'Bessemer Venture Partners, CDH Investments',
#        'Sequoia Capital India, Matrix Partners India',
#        'Chiratae Ventures, AET Fund',
#        'Omidyar Network, Falcon Edge Capital',
#        'Jetty Ventures, Srinivas Anumolu', 'Avendus', 'YourNest',
#        'National Skill Development Corporation, Rianta Capital',
#        'Sequoia Capital India, Rocketship.vc',
#        'Infosys, Qualcomm Ventures',
#        'Real Estate Accelerator Program (REAP), AngelList',
#        'Asian Development Bank, U.S. International Development Finance Corp',
#        'Kohlberg Kravis Roberts, Temasek Holdings',
#        'Shireen Rangaswamy, Dilesh Gathani',
#        'Rebright Partners, Wadhwani Foundation',
#        'Dinesh Godara, Aditya Talwar',
#        'Sistema Asia Capital, Evolvence India Fund',
#        'Rajesh Agarwal, Nandkishore Mundada',
#        'Kallol Banerjee, Jaydeep Barman',
#        'JITO Angel Network, LetsVenture',
#        'MyAsia VC, Orios Venture Partners',
#        'W Health Ventures, Pi Ventures',
#        'Artha India Ventures, Sriram Krishnan', 'GSV, Multiply Ventures',
#        'WorldBusiness Capital, Northern Arc',
#        'Tanglin Ventures, Better Capital, Whiteboard Capital',
#        'Y Combinator, Rehan A Khan', 'Balaji Srinivasan, Naval Ravikant',
#        'Devesh Sachdev, Bhavesh Manglani',
#        'Pradeep K Jaisingh, Jayant Mehrotra', 'Varun Alagh, Harish Daiya',
#        'IAN Fund, World Startup Factory',
#        'Omidyar Network India, Avaana Capital', 'Brex, Y-Combinator',
#        'Mark Cuban, MiH Ventures', 'IvyCap Ventures, IAN Fund',
#        'Gurj Aujla, Ashik K', 'Dream Sports',
#        'The Chatterjee Group, Prophetic Ventures',
#        'Harsh Jain, Lalit Keshre', 'Supriya Kumari, Premanshu Singh',
#        '9Unicorns Accelerator Fund, Sunder Nookala',
#        'Accel Partners, Falcon Edge Capital, Norwest Venture Partners',
#        'Pravesh Mehta', 'Gaurav Gupta, Vivek Srivatsav', 'Lead Angels',
#        'Induslaw, Reddy Futures', 'Yuj Ventures', 'Geekster',
#        'Manish Subramaniam, Upaya Social Ventures', 'Eaglewings Ventures',
#        'Appit Simple Infotek', 'Beyond Next Ventures',
#        'Ramakant Sharma, Elevation Capital',
#        'Keiretsu Forum, SucSEED Venture Partners',
#        'Lightspeed India Partners, CM Ventures',
#        'Skycatcher, Nexus Venture Partners',
#        'Avataar Venture Partners, Kalaari Capital',
#        'Alteria Capital, Matrix Partners India',
#        'Raghav Kapur, Indian Angel Network', 'GSF Accelerator',
#        'Rishi Kumar Bagla, Krishen Lal Khanna',
#        'Glade Brook Capital, Nexus, Y Combinator',
#        'Capital Group, Falcon Edge', 'Dinesh Agarwal, Amarjit Batra',
#        'Arcilla, Samir Khosla',
#        'SUNiCON Ventures, Shubhkam Ventures, Jito Angel network, FAAD Network',
#        'Baring PE India', 'Manuvel Malabar Jewellers', 'Nabventures',
#        'Y Combinator, Jetty Ventures, Earlsfield Capital, SMC Advisors, Kunal Shah',
#        'Kunal Shah, Snehal Fulzele', 'SternAegis Ventures',
#        'Blume Ventures, Orios Ventures',
#        'Warburg Pincus\ufeff, Prosus Ventures', 'BlackSoil',
#        'Akash Prakash, Madhu Jayakumar, Dipinder Sandhu, Shagun Khandelwal',
#        'OAKS Asset Management', 'Titan Capital, LetsVenture',
#        'Incofin, NabVentures, Orios', 'BEENEXT', 'SIG',
#        'Blume Ventures, Micelio Fund',
#        'CDC Group, Jungle Ventures, March Capital, Marshall Wace',
#        'Ashish Jain, Ajay Surana',
#        'We Founder Circle, Appyhigh, Mumbai Angels',
#        'Aroa Ventures, GVFL, Udaan', 'Investcorp, Omidyar Network',
#        '2000000',
#        'Riteesh Mohan Bakshi, Raghav Mohan Bakshi, Achin Kochar',
#        'Info Edge Ventures, Omnivore', 'Sequoia Capital , Together Fund',
#        'Alpha Wave Ventures, Falcon Edge Capital',
#        'Vivek Vaidya, Kevin Donlon, Ayush Singh',
#        'Kieretsu Forum, Lets Venture, Shell',
#        'Sixth Sense Ventures, Godrej Family office, Malpani Group',
#        'Y-Combinator, AME Cloud Ventures, Gokul Rajaram', 'Smallcase',
#        'The StarupLab, AngelBay',
#        'Dallas Venture Capital, Mars Growth Capital',
#        'Raj Nair, Gopinath Latpate',
#        'Y Combinator, Goat VC, JAM Fund, Goodwater Capital',
#        'Binny Bansal, General Catalyst',
#        'General Atlantic, Tiger Global, Moore Strategic Ventures',
#        'Ascent Capital',
#        'Northern Arc, Arthmate, Shine Star, E clear, Hinduja',
#        'Family Office of Kantamaneni, IIM Calcutta Innovation Park',
#        'Saama Capital\ufeff, \ufeffTitan Capital\ufeff, DSG Consumer Partners',
#        'Omidyar Network, Flourish Ventures, Elevar Equity, Accel',
#        'ah! Ventures, We Founder Circle',
#        'Sequoia Capital, Matrix Partners',
#        'Falcon Edge, DST Global, D1 Capital, Redbird Capital, Tiger Global',
#        'Abu Dhabi Growth Fund, Tiger Global', 'Accel, Bain Capital',
#        'Tiger Global, Insight Partners', 'Ronnie Screwvala',
#        'WestBridge Capital', 'Elevation, General Catalyst',
#        'Equanimity Ventures, 9Unicorns', 'Nueva',
#        'Blume Ventures, Nexus Venture Partners',
#        'Apoorva Sharma, The Chennai Angels, Karthik Bhat',
#        'Gokul Rajaram, Venture Catalysts', 'Kvanto Payment Services',
#        'Siana Capital, Inflexor Ventures, Stride Ventures',
#        'Oxshott Capital Partners, XN Exponent, Edelweiss',
#        'Kunal Shah, Better Capital', 'Lightrock India, Filter Capital',
#        'EKKI', 'Stakeboat Capital',
#        'Coinbase Ventures, Andreessen Horowitz', 'BEENEXT, 3one4 Capital',
#        'Let’s Venture, Better Capital',
#        'International Finance Corporation',
#        'Alia Bhatt, IAN Fund, Social Alpha, Draper Richards Kaplan Foundation',
#        'Sequoia Capital India, ICONIQ Capital, Perceptive Advisors',
#        'LetsVenture', 'India Accelerator', 'Qatar Investment Authority',
#        'Netcore Cloud, Vallabh Bhansali, Jimmy Mahtani',
#        'Petronas Ventures', 'Solana', 'Falcon Edge, Softbank',
#        'Enzia Ventures, Kunal Shah', 'Auxano Capital',
#        'Prashant Pansare, Supermorpheus', 'Docprime Technologies',
#        'LC Nueva AIF', 'Nitish Mittersain, Gaurav Munjal',
#        '9Unicorns, Venture Catalysts, Sandeep Singhal',
#        'Temasek, Google, SBI Investment', 'Elevar Equity',
#        'Aroa Ventures',
#        '9Unicorns, Symphony International Holdings Limited, Value Quest',
#        'Republic Crypto, Woodstock, DCG, Sahil Lavingia',
#        'Data Point Capital',
#        'Momentum 6, Basics Capital, Krypital Capital, Shima Capital, Magnus Capital',
#        'Norwest Venture Partners', 'Sabre Partners',
#        'Vertex Ventures, Omnivore',
#        'Base 10 Partners, Eight Roads Ventures', 'enture Catalyst, IPV',
#        'Tiger Global, Falcon Edge',
#        'BAce Capital, Heritas Capital, 3Lines Venture Capital',
#        'Leo Capital, Mayfield Fund',
#        'Plutus Wealth, Oaks Asset Management',
#        'Anil Thadani, Ashutosh Sinha, Roy van Leeuwen',
#        'Pi Ventures LLP, Tanas Capital, Prodapt Holdings', 'Vitol',
#        'Ruchirans Jaipuria, Rishi Kajaria', 'Manish Choksi, Varun Vakil',
#        'Nadir B Godrej', 'Celesta Capital', 'TransUnion, Blume Ventures',
#        'Blume, Alpha Wave Incubation',
#        'Habitat for Humanity International',
#        'Global Founders Capital, Enzia Ventures, Better Capital',
#        'Kora Capital, Stripe, Alua Capital', 'Iconiq Growth',
#        'Rukam Capital, DSG Consumer Partners, The Chennai Angels',
#        'MAS Financial Services', 'Rocketship.vc, Vulcan Capital',
#        'Tiger Global, Vitruvian Partners',
#        'Think Investments, Venture Highway',
#        'Alok Kohli, Sanjeev Bhargava',
#        'Venture Catalysts, Gruhas Proptech',
#        "LetsVenture, AngelList India, Founder's Room Circle",
#        'Dinesh Godara, Anuj Ahuja, Aditya', 'Z3Partners',
#        'Celesta Capital, Omidyar Network India', 'Pavestone Ventures',
#        'LetsVenture, Paradigm Shift VC, Binny Bansal',
#        'Sofina, Lightrock India, Temasek', 'Dia Mirza', 'DST Global',
#        'Pritt Investment Partners, 9Unicorns',
#        'Darq Capital, Jagadeesh Atukuri', 'Stellaris Venture Partners',
#        'StartupXseed Ventures', 'Xponentia Capital Partners',
#        'General Atlantic, Multiples', 'Vulcan Capital', 'InCorp India',
#        'Oikocredit, Nomura, The Bill & Melinda Gates Foundation',
#        'Kedaara', 'Moore Strategic Ventures, BEENEXT',
#        'Kalaari Capital, Incubate Fund India',
#        'Sequoia Capital, Lightspeed, TVS Capital Funds', 'ABC World Asia',
#        'IIFL AMC, Sistema Asia Fund, CX Partners, Singularity Growth Opportunities Fund',
#        'Prime Securities Limited', 'Fidelity, B Capital',
#        '9Unicorns, Varanium NexGen Fund',
#        'Sequoia Capital, Sandeep Nailwal',
#        'Old Fashion Research, Nothing Research, Tenzor capital',
#        'Aavishkaar Capital, Rajiv Dadlani Group', 'NEVF, AccelNest',
#        'The Treasury', '9Unicorns, Spearhead Capital, Venture Catalysts',
#        'Ramp, Rainfall Ventures, Roka Works, Y Combinator',
#        'India Angel Network',
#        'Responsibility, Blue Ashva Capital, Pravega Ventures',
#        'Dream Capital, Elysian Park Ventures', 'CDC Group, Creaegis',
#        'Lee Fixel’s venture capital firm, Addition',
#        'Y Combinator, JAFCO Asia, Incubate Fund India, marquee angels',
#        'The Xander Group', 'Aarin Capital', 'James Milner, Adam Lallana',
#        'LetsVenture, Ajay Garg, Tarun Sharma', 'Kunal Sarkar',
#        'Morgan Stanley Private Equity Asia', 'Westbridge Capital',
#        'Lightrock India', '$Undisclosed', 'JAM, Better Tomorrow Ventures',
#        'SOSV, Venture Catalysts', 'Incofin’s India Progress Fund',
#        '9Unicorns, Anthill Ventures', 'Jani Ventures INC',
#        'CreedCap Asia Advisors', 'Joseph Joy',
#        'DST Global, Falcon Edge, SoftBank Vision Fund 2',
#        'Trifecta Capital', "Titan Capital, AngelList's syndicate",
#        'Vineet Singh, Krishna D, Deependra Bisht, Alan Aim',
#        'Westbridge Capital, Sixth Sense Ventures', 'MaGEHold',
#        'Season Two Ventures, IndiaMart', 'Kunal Shah, Anant Maheshwari',
#        'WaterBridge Ventures, Enzia Ventures',
#        'Tree Line Investment Management', 'Orbimed Asia Partners',
#        'Zip Co', 'Eight Roads Ventures, GSV', 'Kunal Shah, Krishna Kumar',
#        'Vijay Shekhar Sharma, Rohit Kapoor, Amanpreet Bajaj, Lalit Singh',
#        'Stellaris Venture Partners, Chiratae Ventures',
#        'Lightspeed, Sequioa', 'TheVentures',
#        'Titan Capital, Archana Priyadarshini, Gaurav Ahuja',
#        'Jungle Ventures, CX Partners',
#        'Cygnus Medicare Group, Probal Ghoshal, Shuchin Bajaj',
#        'M2P Fintech',
#        'SucSEED  Indovation Fund, Uincept, Palimala Ventures',
#        'Anicut Angel Fund, Sauce.VC',
#        'Omidyar Network India, Chiratae Ventures',
#        'Elevation Capital, Accel India', 'Legatum Capital',
#        'Navneet Education', '1000000\t#REF!',
#        'Sonu Nigam, Whiteboard Capital', 'Aditya Duggar',
#        'Vertex Ventures, Stellaris Venture Partners',
#        'Omnivore, India Quotient', 'We Founder Circle, Dexter Angels',
#        'IIFL\ufeff, \ufeffAnicut Angel Fund\ufeff, \ufeffKae Capital\ufeff, TradeCred',
#        'Indian Angel Network, Axilor', 'Invesco Developing Markets Fund',
#        'Cholamandalam', 'Curesense Therapeutics', 'Ka Enterprises',
#        'IAN Fund, Malabar Angel Network, Native Angel Network',
#        'DSG Consumer Partners, Titan Capital',
#        'Sujeet Kumar, SucSEED Indovation Fund',
#        'Ameba Capital, 9Unicorns',
#        'Susquehanna International Group, Bessemer Venture Partners',
#        'IIFL AMC, Oman India Joint Investment Fund', 'Unilazer Ventures',
#        'Tribe Capital, Arkam Ventures, WEH, Kunal Shah',
#        'Venture Catalysts, Indian Angel Network',
#        'Elevation Capital, Matrix Partners India', 'Ashok Goyal',
#        'Cure.fit, Endiya Partners, Tanglin Venture',
#        'HOF Capital, Old Well Ventures, LetsVenture, 9Unicorns',
#        'Jinisha Sharma, Aditya Agarwal, Victoria, Abhishek Shroff',
#        'LetsVenture, 2am VC, magic.fund',
#        'Arvind Venugopal Nair, Amritendu Mukherjee',
#        'Rajasthan Venture Capital Fund',
#        'Covalent, Double Peak, GenBlock Capital, Ledger Prime, MEXC Global, Synaps',
#        'Vijayan', 'Gokul Rajaram, JPIN, Venture Catalysts UK, AngelList',
#        'Rachit Poddar, Rajesh Gupta',
#        'Virenxia Group, Rajesh Jain, Nitin Agarwal', 'Addition',
#        'Prashasta Seth',
#        'Matrix Partners India, Jitendra Gupta, RTP Global',
#        'Shaival Desai, Flowstate Ventures', 'Zoho', 'Transworld Group',
#        'IIFL AMC', 'Owl Ventures', 'Winter Capital, ETS, Man Capital',
#        '3one4 Capital, Kalaari Capital'], dtype=object)

# %%
df21[df21['Investor'].str.contains('\$', na=False)]
# Out:
#            Company/Brand  Founded HeadQuarter      Sector  \
# 242   Fullife Healthcare     2009         NaN        None
# 256   Fullife Healthcare     2009         NaN        None
# 257              MoEVing     2021    Gurugram        None
# 545            AdmitKard     2016       Noida  Technology
# 1100            Sochcast     2020         NaN        None
#
#                                            What it does  \
# 242                                        Varun Khanna
# 256                                        Varun Khanna
# 257                         Vikash Mishra, Mragank Jain
# 545   A tech solution for end to end career advisory...
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
#
#                                               Founders      Investor  \
# 242                 Morgan Stanley Private Equity Asia     $22000000
# 256                 Morgan Stanley Private Equity Asia     $22000000
# 257     Anshuman Maheshwary, Dr Srihari Raju Kalidindi      $5000000
# 545   Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!      $1000000
# 1100           Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed
#
#          Amount($) Stage
# 242       Series C   NaN
# 256       Series C   NaN
# 257           Seed   NaN
# 545   Pre-series A   NaN
# 1100           NaN   NaN

# %%
# replace the row with NaN
df21['Investor'] = df21['Investor'].replace(["http://100x.vc/","$Undisclosed", "$1000000", "$5000000", "$22000000", "2000000", ], np.nan)
df21['Investor'].unique()
# Out:
# array(['BEENEXT, Entrepreneur First',
#        'Unilazer Ventures, IIFL Asset Management',
#        'GSV Ventures, Westbridge Capital', 'CDC Group, IDG Capital',
#        'Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal', 'Vy Capital',
#        'CIIE.CO, KIIT-TBI', 'Inflection Point Ventures',
#        'Inflexor Ventures', nan,
#        '9Unicorns Accelerator Fund, Metaform Ventures',
#        'SucSEED Indovation, IIM Calcutta Innovation Park',
#        'Safe Planet Medicare', 'Impact Partners, C4D Partners',
#        'Tiger Global Management, InnoVen Capital', 'Novo Tellus Capital',
#        'Raintree Family Office, ADB arm',
#        'Mumbai Angels, Narendra Shyamsukha', 'Paradigm, Kunal Shah',
#        'Matrix Partners India, GIC', 'Chiratae Ventures, JAFCO Asia',
#        'Mumbai Angels Network, Expert DOJO', 'GVFL',
#        'Kotak Mahindra Bank, FMO', 'Kalaari Capital',
#        'NB Ventures, IAN Fund',
#        'Sequoia Capital India, Hummingbird Ventures',
#        'Gaurav Munjal, Snehil Khanor', 'JITO Angel Network, SOSV',
#        'Chiratae Ventures, YourNest Venture Capital', 'STRIVE VC',
#        'Venture Catalysts', 'Jaipuria Family Office', 'Amazon',
#        'Riso Capital', 'MTG Ventures',
#        'Qualcomm Ventures, Warburg Pincus', '9Unicorns', 'Morgan Stanley',
#        'Alfa Ventures, Agility Venture Partners',
#        'Stellaris Venture Partners, Ramakant Sharma', 'Spanache',
#        'DSG Consumer Partners, Saama Capital', 'Hindustan Media Ventures',
#        'Stellaris Venture Partners, Omidyar Network India, Flourish Ventures',
#        'Angelbay Holdings, Faad Network',
#        'Alteria Capital, Chiratae Ventures',
#        'WaterBridge Ventures, Info Edge',
#        'Carmignac, Falcon Edge Capital', 'Vaibhav Domkundwar, Kunal Shah',
#        'Chiratae Ventures, Bharat Innovation Fund',
#        'Acko Technology, Services, LetsVenture',
#        'Bertelsmann India Investments, Fullerton Financial Holdings',
#        'Dragoneer Investment Group, Tiger Global Management',
#        'TPG Growth, Caisse de Depot et Placement du Quebec',
#        'Centrum Financial Services', 'Chiratae Ventures, BEENEXT',
#        'Harsha Bhogle', 'GetVantage, Prakash Katama',
#        'Tiger Global Management, Y Combinator Continuity Fund',
#        'Michael & Susan Dell Foundation', 'Marquee fintech founders',
#        'Falcon Edge India, Norwest Venture Partners',
#        'SOSV, Omphalos Ventures India', 'Twitter Ventures, Pawan Munjal',
#        'CitiusTech', 'Arena Holdings, Think Investments',
#        'T Choithrams BVI, Ardor',
#        'Kogta Financial India Limited, ICICI Bank',
#        'SucSEED Venture Partners, TMT Connekt',
#        'SAIF Partners, Venture Highway', 'Global Founders Capital',
#        'JAFCO Asia, Chiratae Ventures', 'Y Combinator',
#        'Artha Venture Fund', 'Jitendra Gupta, Amrish Rau',
#        'FJ Labs, Brian Norgard', 'Indian Angel Network',
#        'Jitendra Gupta, Harsh Shah',
#        'Elevation Partners, Emergent Ventures',
#        'Kalaari Capital, Dream Capital', 'Lumikai',
#        'Matrix Partners India', 'C4D Partners', 'Bertelsmann India',
#        'Iron Pillar, Nordstar, Binny Bansal',
#        'FMC, Omnivore, Blume Ventures', 'InvestCorp',
#        'Pritesh Kumar, Bharat Gupta',
#        'Y Combinator, 9Unicorns, Titan Capital',
#        'Unicorn India Ventures, SEA Fund, Devdatt Shah',
#        'Matrix Partners India, Elevation Capital',
#        'Avaana Capital, Orios Ventures', 'Punit Balan',
#        'Y Combinator, Broom Ventures, Kunal Shah',
#        'Skycatcher, AET Fund, BAce Capital, Dream Incubator, 1Up Ventures',
#        'Eclear Leasing', 'First Cheque, Letsventure',
#        'Sequoia Capital India, BEENEXT', 'Velocity',
#        'Tribe Capital, Moore Strategic Ventures (MSV)',
#        'Fireside Ventures', 'Inflection Point Ventures, ONGC',
#        'Y Combinator, Incubate Fund India',
#        'Titan Capital, Rockstud Capital,  John Abraham, WEH Ventures',
#        'Info Edge Ventures', 'NB Ventures', 'Accel',
#        'Binny Bansal, Kunal Shah', 'TradeCred', 'Unicorn India Ventures',
#        'UC Inclusive Credit, Western Capital',
#        'IIFL India Private Equity Fund, Smiti Holding & Trading Company',
#        'Faering Capital', 'responsAbility Investments, Blue Orchard',
#        'Sanchit Agarwal, Sujan Sinha, Michael Cooke',
#        'CRV, Nexus Venture Partners',
#        'Salesforce Ventures, Sierra Ventures, Sequoia Capital India’s Surge',
#        'Micelio Fund, growX ventures',
#        'IIFL Wealth, Asset Management, Northern Arc Capital',
#        'Better Capital, Ashish Achrekar', 'IAN', 'Alpha Wave Incubation',
#        'Point One Capital, Yatra Angel Network (YAN), Opus Consulting, Manipal Technologies.',
#        'Microsoft', 'Shell Ventures, Yamaha, Kunal Shah',
#        'We Founder Circle',
#        'Saama Capital, DSG Consumer Partners, Sharrp Ventures',
#        'Tiger Global’s Scott Schleifer', 'Elevation Capital',
#        'Venture Catalysts, Auxano Capital, Venture Garage, Yoga Capital, Ah!Ventures, Lead Angels',
#        'Sixth Sense Ventures', '9Unicorns, Sequoia Capital India’s Surge',
#        'Anicut Angel Fund, 9 Unicorns', 'Info Edge, FalconEdge',
#        'WestCap Group, Tomales Bay Capital',
#        'Chiratae Ventures, Better Capital',
#        'Siguler Guff, Baillie Gifford',
#        'IIFL AMC, Mankind Pharma Family Office, Aroa Ventures',
#        'ITI Growth Opportunities', 'Amrac Investment Trust',
#        'Bhavin Turakhia', 'Amara Raja Batteries',
#        'India Infoline Finance', 'Venture Highway', 'BEENEXT, Orios',
#        'Axilor', 'Westbridge Capital, Tanglin Venture Partners',
#        '100X.VC\ufeff,\ufeff Titan Capital, Rahul Mathur, Gaurav Mandlecha',
#        'IIFL, Amicus Capital, Ananta Capital',
#        'Venture Highway, Endiya Partners',
#        'Verlinvest, Sequoia Capital India', 'Anicut Angel Fund',
#        'Tiger Global',
#        'Alphabit Fund, Fulgur Ventures, Stacks Accelerator, SBX Capital',
#        'Roots Ventures, Velo Partners', 'Nexus Venture Partners',
#        'Mumbai Angels Network, Huddle, Lumis Partners',
#        'SucSEED Indovation Fund',
#        'Potencia Ventures, Bisk Ventures, LetsVenture, Ronnie Screwvala, Arihant Patni',
#        'Better Capital, First Cheque, Titan Capital', 'Evolvence Capital',
#        'SARA ELGI',
#        'Nubank, Global Founders Capital, Sequoia Capital India, Matrix Partners India',
#        'ah! Ventures High Tables',
#        'Eight Roads Ventures, Think Investments, Mankekar Family Office',
#        'A91 Partners', 'Chiratae Ventures', 'Sequoia’s Surge',
#        'Lead Angels, Titan Capital, Pravega Ventures',
#        'Accel Partners, Elevation Capital',
#        'Inflection Point Ventures, Rockstud Capital, FirstPort Capital, Bliss Flow Investments Pvt Ltd',
#        'Anicut Angel Fund, Axilor Ventures',
#        'Ecosystem Ventures, CMM group',
#        'Mumbai Angels Network, Social Alpha', 'Disrupt ADQ, QIC',
#        'Valar Ventures, IA Ventures', 'Sequoia Capital India', 'Zomato',
#        'Lightspeed, Times Group, Tanglin Venture Partners',
#        'Binny Bansal, Deep Kalra, Dr Ashish Gupta, Gokul Rajaram, Shirish Nadkarni',
#        'Tuscan Ventures, Ohm Stock Brokers, Artha Venture Fund',
#        'Signal Peak Ventures', 'Evolvence, Hero Enterprise',
#        'BlueOrchard Impact Investment Managers', 'Steadview Capital',
#        'MassMutual Ventures', 'YourNest VC', 'Accel India',
#        'Vijay Shekhar Sharma, Ritesh Agarwal, Ankiti Bose',
#        'TVS Motor, Zoho', 'IIFL Asset Management',
#        'Oasis Capital, Scorpio VC, DeltaHub Capital',
#        'Titan Capital, Haresh Chawla, AngelList Syndicate',
#        '9Unicorns, Ashneer Grover', 'Founders Room Capital',
#        '9Unicorns, ZNL', 'WEH Ventures',
#        'Kunal Shah, Deepinder Goyal, Abhiraj Singh Bhal',
#        'Guild Capital, RPSG Capital Ventures',
#        'General Catalyst, Eight Roads Ventures, Elevation Capital',
#        'NB Ventures, Earlsfield Capital', 'Varun Alagh, Sahil Barua',
#        'SoftBank Vision Fund 2', 'Tribe Capital, Prime Venture Partners',
#        'Jungle Ventures', 'Marquee international institutional investors',
#        'Alkeon Capital', 'Y Combinator, Harvard Management',
#        'Y Combinator\ufeff, \ufeffGoodwater Capital',
#        'Shrishti Sahu, Umang Vohra', 'Astra Ventures, Gaurav Jaitly',
#        'Capital A, Collective Artists Network',
#        'Aditya Singhal, Nishant Sinha', 'Pentathlon Ventures',
#        'Alpha Wave Ventures II, Tiger Global Management, SoftBank Vision Fund II',
#        'KRAFTON', 'Chiratae Ventures, Lenskart Vision Fund', 'Recur Club',
#        'DevX Venture Fund, Blume Founder Fund', 'Ajith Daneil',
#        'Aurum Proptech', 'Y-Combinator', 'The Good Glamm Group', 'Invus',
#        'Tiger Global, Prosus Ventures',
#        'Shuru Up, Ankit Kedia, Arun Gupta',
#        'Ankit Mehrotra, Saurabh Aggarwal', 'Sauce.vc',
#        '3one4 Capital, Sixth Sense Ventures',
#        'YCombinator, Justin Mateen, Pioneer Fund',
#        'Sojitz Corporation, Stride Ventures',
#        'IIFL Wealth, TPG Growth, Norwest Venture Partners',
#        'Nabventures, Avaana Capital', 'Fluid Ventures, Mulberry Silks',
#        'Rajesh Rajendran', 'Mike Novogratz, Neeraj Arora',
#        'Reliance Digital Health', 'DevX Venture Fund',
#        'Ritu Marya Family Office.', 'Ten Innovate',
#        'Tiger Global, Sequoia Capital', 'Shark Tank India',
#        'Premji Invest, Steadview Capital', 'Sequoia',
#        'Apis Insurtech Fund I', 'SK Tripathi, Sanjeev Gupta',
#        'Hardcastle Petrofer', 'Ocean View Investment, QED Fund',
#        'Omidyar Network, Tencent Holdings',
#        'ITI Growth Opportunities Fund, Unit-E Ventures',
#        'InnoVen Capital, Nexus Venture Partners', 'CIIE.CO',
#        'Orios Venture Partners', 'Omidyar Network India',
#        'Wipro venture capital arm', 'Yuj Ventures, Sixth Sense Ventures',
#        'Premji Invest, Mirae Asset Naver Asia Growth Fund, Alpine Capital',
#        'Inflection Point Ventures, SucSEED Venture Partners',
#        'Anas Rahman Junaid, Vinod Jose', 'Capital One, Arrowroot Capital',
#        'YourNest Venture Capital', 'Incubate Fund India',
#        'Kunal Shah, Greg Kidd', 'InnoVen Capital, TEAMFund',
#        'Venture Catalysts, 9Unicorns Accelerator Fund',
#        'Venture Highway, Rohit Bansal', 'Fresco Capital, Social Starts',
#        'Y Combinator, Rebright Partners',
#        'Rohit Goutamchand, India CXO Fund',
#        'Rajasthan Venture Capital Fund, ACPL Exports',
#        'Amplo, Insight Partners', 'Better Capital', 'Justin Mateen',
#        'View Trade Holding Corp',
#        'InnoVen Capital, Bertelsmann India Investments', 'ScoopWhoop',
#        'Canaan Valley Capital, Glade Brook Capital Partners',
#        'Vijay Shekhar Sharma, Dr Ritesh Malik',
#        'RTP Global, Harshil Mathur', 'Paragon Partners, NABVENTURES',
#        'EXPERT DOJO', 'Saama Capital, India Quotient',
#        'InCred Financial Services, Vivriti Capital, Northern Arc Capital',
#        'ah! Ventures', 'Somak Ghosh, M V Nair', 'Wurk',
#        'Plutus Wealth Management, Turtle Entertainment',
#        'Ambiga Subramanian, Goutham Ekollu', 'Accel, Owl Ventures',
#        'Rajan Anadan', 'Jesse Lucas',
#        'IDFC Private Equity, Bessemer Venture Partners',
#        'Sequoia Capital India, Accel',
#        'Venture Catalysts, Tahseen Consulting', 'Equanimity Ventures',
#        'BlueOrchard Finance S A, Gojo & Company',
#        'Better Capital, Titan Capital', 'Gojo & Company', 'Mumbai Angels',
#        'Pegasus Tech Ventures, Base Partners', '3one4 Capital, Accel',
#        'Hitesh Oberoi, Lightbox', 'YES Bank', 'Campus Fund',
#        'Hyperplane Venture Capital', 'Matrix Partners India, RTP Global',
#        'Info Edge, Ruizheng Investment', 'Quess Corp India',
#        'Sunil Kumar Singhvi, 9Unicorns Accelerator Fund',
#        'India Accelerator’s Angel Investor Network', 'Shell Foundation',
#        'Jimmy Singh', 'Kunal Shah, Deepak Abbot', 'Accel, Nexus Venture',
#        'Singapore Angel Network, Artha India Ventures',
#        'Starfish Growth Partners, Investpad', 'Hashed', 'Titan Capital',
#        "Zerodha's Rainmatter Capital, Better Capital",
#        'Sixth Sense Ventures, Colgate Palmolive',
#        'Lightbox, Evolvence India Fund', 'Tomorrow Capital',
#        'Inflection Point Ventures, DLabs',
#        'InnoVen Capital, Steadview Capital', 'BlackSoil Capital',
#        'PointOne Capital, Core91 VC', 'A91 Partners, Faering Capital',
#        'Blockchain Capital, SBI Ven Capital',
#        'Baring Private Equity Partners India, Talbros',
#        'Sequoia Capital India, 3one4 Capital',
#        'Prosus Ventures, RTP Global',
#        'U.S. International Development Finance Corp, responsAbility',
#        'Binance Labs, Zee Prime Capital', 'RP-Sanjiv Goenka Group',
#        'IvyCap Ventures', 'Zone Startups In', 'Blue Ashva Capital',
#        'Ribbit Capital, Kunal Shah', 'Ecom Express', 'InnoVen Capital',
#        'Satish Grampurohit', 'Amit Singhal, Raine Ventures',
#        'Tiger Global, Dragoneer Investment Group, Steadview Capital, General Atlantic',
#        'CDC Group, Aavishkaar Venture Capital', 'GSF, Pras Hanuma',
#        'Ajat Hukkoo, Piyush Chaplot', 'Mumbai Angels, Amitesh Pandey',
#        'Think Investments',
#        'Nexus Venture Partners, 23 High Networth Individuals (HNIs)',
#        'Yatra Angel Network, BEENEXT',
#        'Orios Venture Partners, Matrix Partners India', 'Trishneet Arora',
#        'ContCentric', 'Siana Capital', 'DST Global, General Catalyst',
#        'Anthill Ventures', 'InnoVen Capital, InnoVen Capita',
#        '3one4 Capital, DSP Group', 'Enzia Ventures, AngelList',
#        'Steadview Capital, Insight Partners',
#        'Invested Development, Pratithi Investment Trust',
#        'Octahedron Capital, Moonstone Capital',
#        'Dhianu Das, Agility Venture Partners', 'Hindustan Media Venture',
#        'Omnivore', 'Awign Enterprises',
#        'Siddharth Bhaskar Shah, Upsparks', 'S Chand',
#        'Goldman Sachs, Tata Capital', 'growX ventures, Venture Gurukool',
#        'Mount Judi India Growth Fund', 'GEF Capital’s South Asia Fund',
#        'Sunil Sethia, Sunil Kumar Singhvi, Manish Mardia',
#        'Sequoia Capital', 'Mechanism Capital, DACM',
#        'Northern Arc Capital, Niyogin Fintech Limited, Credit Saison India, Vivriti Capital',
#        'Pearl Investment LLC', '021 Capital, Sparrow Capital',
#        'Kotak Investment Advisors Limited, Gruhas Proptech', 'VANS Group',
#        'Sachin Tendulkar', 'Xentel Investments', 'Accel Partners',
#        'Waterbridge, Lumikai', 'Auxano, Falcon5', 'Infoedge ventures',
#        'JITO Angel Network', 'Jupiter', 'Unitus Ventures',
#        'GIC, Infoedge', 'pi Ventures',
#        'Northern Arc, Caspian Impact Investments', 'Sofina Ventures SA',
#        'Tiger Global, Flipkart Ventures',
#        'Inflection Point Ventures, Rockstud Capital, Pentathlon Ventures, Prophetic Ventures syndicate',
#        'Prime VP', 'Tribe Capital, IFC Emerging Asia Fund, VEF',
#        'Sequoia’s Surge, Y Combinator', 'Endiya Partners',
#        'Gokul Rajaram, Pureland Venture, Wavemaker Partners',
#        'Callapina Capital', 'Khosla Ventures',
#        'Accel Partners, Matrix India',
#        'Omidyar Network India, Innoven Capital', 'Temasek, Falcon Edge',
#        'Deep Kalra, Ashish Kashyap, Rajesh Magow',
#        'IAN, Social Alpha, Startup Oasis', 'Capital India',
#        'FirstCry, Lightspeed Venture Partners',
#        'Accel, LetsVenture, 1Crowd', 'SAB Holdings',
#        'Lightspeed Venture Partners, Elevation Capital',
#        'Mumbai Angels Network', 'Jayanti Kanani',
#        'LeapFrog, Khosla Ventures', 'Ananta Capital',
#        'Northern Arc, Vivriti Capital', 'TATA Cleantech Capital',
#        'Aqua-Spark', 'Climate Angels Fund',
#        'Sequoia’s Surge, Nexus Venture Partners',
#        'Entrepreneur First (EF), GrowX Ventures', 'Zephyr Peacock',
#        'ADM Capital', 'SoftBank Vision Fund, Hindustan Media Venture',
#        '100x Entrepreneurs', 'Healthcare veterans, PIEDS',
#        'Bank of Baroda', 'YCombinator', 'IAN Fund', 'Vishal Gupta',
#        'Mirae Asset, H&M', 'Kotak Securities', 'Klub',
#        'Balaji Srinivasan', 'BASF Venture Capital GmbH',
#        'Rebright Partners, Flourish Ventures', 'Sequoia Surge',
#        'Titan Capital, Sequoia Capital', 'Parthiv Group',
#        'Omkar Pandharkame, Ketaki Ogale',
#        'GetVantage, Velocity, Shiprocket Capital', 'Krafton Inc, Omidyar',
#        'Blume Ventures, Exfinity Venture Partners',
#        'Beyond Next Ventures, M Venture Partners', 'AdvantEdge Founders',
#        'Faering Capital, Sequoia Capital India, IIFL Alternate Asset Managers',
#        'Sixth Sense Ventures, NABVENTURES', 'Temasek, Multiples PE',
#        'Griffin Gaming Partners', 'Zinnia Global',
#        'InfoEdge Ventures, IAN Fund', 'IIFL, Mumbai Angels',
#        'BEENEXT, Sequoia’s Surge', 'Antler India', 'Bharat Inclusion',
#        'Fidelity, BlackRock', 'Blacksoil', 'Speciale Invest',
#        'Canbank Venture Capital Fund', 'W Health Ventures',
#        '021 Capital, Y Combinator', 'Anand Prakash Sharma',
#        'Axilor Ventures', 'velocity.in', 'March Capital, Tribe Capital',
#        'Learn Capital', 'RTP Global', 'IAN, Yuj Ventures',
#        'Sequoia’s Surge, Accel Partners', 'Uday Sodhi', 'Fidelity, GIC',
#        'Auxano', 'Angelist India',
#        'Stanford Angels and Entrepreneurs India, Anjali Bansal',
#        'Vy Capital, Wellington Management', 'Avon Cycles',
#        'Matrix Partners India, 021 Capital', 'HNIs, Angels',
#        'NewQuest Capital Partners, Motilal Oswal Private Equity',
#        'Lasons India', 'Pankaj Chaddah, Srivatsan Rajan', 'Paytm',
#        'BlackSoil, CLSA Capital Partners', 'Saama, Whiteboard Capital',
#        'Indian Angel Network, Titan Capital, Lead Angels',
#        'The Chennai Angels',
#        'Venture Highway, Stellaris Venture Partners',
#        'State Bank of India, Y Combinator', 'Sanjay Baldwa, Ajay Jain',
#        'InfoEdge', 'Nitin Passi, Ruchirans Jaipuria',
#        'Stride Ventures, InnoVen Capital',
#        'Venture Catalysts, Jeevak Gupta',
#        'Triodos Investment Management, SAIF Partners', 'N+1 Capital',
#        'DST Global, RTP Global', 'Amit Singal, Manish Aggarwal',
#        'Trifecta Capital Advisors, Blume Ventures',
#        'Kumar Aakash, Amit Singhal', 'growX ventures',
#        'Shaival Desai, Alkemi Venture Partners',
#        'Aavishkaar Venture Capital, YWC Venture Capital',
#        'Alteria Capital', 'Tiga Investments, Baron Capital',
#        'Venture Catalysts, 9unicorns', 'Qualgro',
#        'Amit Lakhotia, Pravin Jadhav', 'Pravega Ventures',
#        'Greenoaks Capital, Elevation Capital',
#        'Sequoia Capital India, rocketship.vc', 'BLinC Invest',
#        'Spring Marketing Capital', 'Chaitanya Kalipatnapu, Kedar Gavane',
#        'Roha Investment Managers, angel investor Saumil Shah',
#        'TNF Ventures, Razorpay', 'Lok Capital, IIFL Asset Management',
#        'Nvidia Inception', 'Tiger Global Management, DST Global',
#        'Marquee investors', 'Ashish Hemrajani, Parikshit Dar',
#        'India Accelerator, Lyxel&Flamingo', 'Roshan Abbas, Ritesh Malik',
#        'Goat Capital, JAM Fund', 'General Catalyst, Jungle Ventures',
#        'Blackstone Group, ADQ', 'GoAhead Ventures',
#        'Paradigm Shift Capital, AngelList India', 'Arali Ventures',
#        'Anup Kumar Yama', 'Aryaman Vir', 'iSeed, Titan Capital',
#        'Research Innovation Incubation Design Labs', 'Sushil Agarwal',
#        'IvyCap Ventures, Endiya Partners',
#        'GUSEC Seed Fund, DeVX Venture Fund', 'Tiger Global, Sequoia',
#        'Quadria Capital', 'Blume Ventures, Whiteboard Capital',
#        'Ashwini Kakkar. 9Unicorns', 'Ashish Shah', 'Faad Network',
#        'Paragon Partners, Aavishkaar Capital', 'Krafton, Lumikai',
#        'Indovation Fund, Mumbai Angels', 'Gunosy, Blume Ventures',
#        'Edge Ventures, Elevation Capital', 'CDC Group',
#        'Titan Capital, Kunal Shah',
#        'Yamaha Motors, Omidyar Network India, Eight Roads Ventures',
#        'Norfund, The Rise Fund', 'Siti Cable',
#        'Crossbeam Venture Partners', 'Aavishkaar Capital', 'Mapmyindia',
#        'Jyoti Bansal', 'Accor',
#        'SRI Capital, Picus Capital, Alkemi Capital',
#        'Saama Capital, DSG Consumer Partners', 'Valar Ventures',
#        'Addition, SIG Global India Fund',
#        '9Unicorns Accelerator Fund, Indian Angel Network',
#        'Alfa Ventures', '1Crowd',
#        'TCV, D1 Capital Partners, Falcon Edge.',
#        'BanyanTree Finance Pvt. Ltd.', 'EXPERT DOJO, Mumbai Angels',
#        'Quona Capital', 'Ashv Finance, BlackSoil Capital',
#        'WaterBridge Ventures, SAIF Partners',
#        'Sweta Rau, 9Unicorns Accelerator Fund',
#        'Omnivore, Strive Ventures', 'Rajesh Sud, KULDEEP JAIN',
#        'PayU, Google', 'Sundi Natarajan, Srinivas Anumolu',
#        'Titan Capital, First Cheque', 'TPG Capital Asia, Epiq Capital',
#        'MaGEHold Pte. Ltd.', 'BlackRock, Owl Ventures',
#        'Asian Development Bank, Oman India Joint Investment Fund',
#        'JSW Ventures, Kalaari Capital',
#        'Unitus Ventures, Omidyar Network India',
#        'IvyCap Ventures, Pratithi Investment Trust',
#        'ACPI Investments, AdvantEdge Founders',
#        'RouteOne, Mankekar Family Office', 'India Quotient',
#        'TCN International Commerce', 'Alpine Capital, PremjiInvest',
#        'Bon Angels Venture Partners, Daesung Private Equity',
#        'Spring Marketing Capital, Verlinvest', 'Bain Capital',
#        'F-Prime Capital, Eight Roads Ventures India',
#        'Mumbai Angels, DNA Entertainment Networks',
#        'Hornbill Capital Advisers, Plutus Wealth Management',
#        'ADB Ventures, Jetty Ventures', 'Techstars, Ryan Johnson',
#        'Bessemer Venture Partners',
#        'Titan Capital, iSeed, First Cheque, 3.0 Fund.',
#        'Falcon Edge Capital, White Oak Global Advisors',
#        'Angel investors', 'Akya Ventures',
#        'Kayenne Ventures, Nordic Microfinance Initiative',
#        'Kae Capital, Pi Ventures', 'Elevar Equity, Accel India',
#        'Titan Capital, Y Combinator', 'Jitendra Gupta, Better Capital',
#        'Radiant Life Care Private Ltd, Life Healthcare',
#        'Mount Judi Ventures, growX Ventures, Season Two Ventures',
#        'Richard Rekhy', 'GAWA Capital, Gaja Capital',
#        'Better Capital, Bharat Inclusion Seed Fund', 'Krafton',
#        'Eight Roads Ventures India, Nexus Venture Partners',
#        'CDC Group, Partners Group',
#        'Matrix Partners India, Ankur Capital',
#        'U.S. International Development Finance Corp, Asian Development Bank',
#        'Hungama, Hindustan Talkies', 'Agility Venture Partners',
#        'Speciale Invest, Farid Ahsan',
#        'Bessemer Venture Partners, CDH Investments',
#        'Sequoia Capital India, Matrix Partners India',
#        'Chiratae Ventures, AET Fund',
#        'Omidyar Network, Falcon Edge Capital',
#        'Jetty Ventures, Srinivas Anumolu', 'Avendus', 'YourNest',
#        'National Skill Development Corporation, Rianta Capital',
#        'Sequoia Capital India, Rocketship.vc',
#        'Infosys, Qualcomm Ventures',
#        'Real Estate Accelerator Program (REAP), AngelList',
#        'Asian Development Bank, U.S. International Development Finance Corp',
#        'Kohlberg Kravis Roberts, Temasek Holdings',
#        'Shireen Rangaswamy, Dilesh Gathani',
#        'Rebright Partners, Wadhwani Foundation',
#        'Dinesh Godara, Aditya Talwar',
#        'Sistema Asia Capital, Evolvence India Fund',
#        'Rajesh Agarwal, Nandkishore Mundada',
#        'Kallol Banerjee, Jaydeep Barman',
#        'JITO Angel Network, LetsVenture',
#        'MyAsia VC, Orios Venture Partners',
#        'W Health Ventures, Pi Ventures',
#        'Artha India Ventures, Sriram Krishnan', 'GSV, Multiply Ventures',
#        'WorldBusiness Capital, Northern Arc',
#        'Tanglin Ventures, Better Capital, Whiteboard Capital',
#        'Y Combinator, Rehan A Khan', 'Balaji Srinivasan, Naval Ravikant',
#        'Devesh Sachdev, Bhavesh Manglani',
#        'Pradeep K Jaisingh, Jayant Mehrotra', 'Varun Alagh, Harish Daiya',
#        'IAN Fund, World Startup Factory',
#        'Omidyar Network India, Avaana Capital', 'Brex, Y-Combinator',
#        'Mark Cuban, MiH Ventures', 'IvyCap Ventures, IAN Fund',
#        'Gurj Aujla, Ashik K', 'Dream Sports',
#        'The Chatterjee Group, Prophetic Ventures',
#        'Harsh Jain, Lalit Keshre', 'Supriya Kumari, Premanshu Singh',
#        '9Unicorns Accelerator Fund, Sunder Nookala',
#        'Accel Partners, Falcon Edge Capital, Norwest Venture Partners',
#        'Pravesh Mehta', 'Gaurav Gupta, Vivek Srivatsav', 'Lead Angels',
#        'Induslaw, Reddy Futures', 'Yuj Ventures', 'Geekster',
#        'Manish Subramaniam, Upaya Social Ventures', 'Eaglewings Ventures',
#        'Appit Simple Infotek', 'Beyond Next Ventures',
#        'Ramakant Sharma, Elevation Capital',
#        'Keiretsu Forum, SucSEED Venture Partners',
#        'Lightspeed India Partners, CM Ventures',
#        'Skycatcher, Nexus Venture Partners',
#        'Avataar Venture Partners, Kalaari Capital',
#        'Alteria Capital, Matrix Partners India',
#        'Raghav Kapur, Indian Angel Network', 'GSF Accelerator',
#        'Rishi Kumar Bagla, Krishen Lal Khanna',
#        'Glade Brook Capital, Nexus, Y Combinator',
#        'Capital Group, Falcon Edge', 'Dinesh Agarwal, Amarjit Batra',
#        'Arcilla, Samir Khosla',
#        'SUNiCON Ventures, Shubhkam Ventures, Jito Angel network, FAAD Network',
#        'Baring PE India', 'Manuvel Malabar Jewellers', 'Nabventures',
#        'Y Combinator, Jetty Ventures, Earlsfield Capital, SMC Advisors, Kunal Shah',
#        'Kunal Shah, Snehal Fulzele', 'SternAegis Ventures',
#        'Blume Ventures, Orios Ventures',
#        'Warburg Pincus\ufeff, Prosus Ventures', 'BlackSoil',
#        'Akash Prakash, Madhu Jayakumar, Dipinder Sandhu, Shagun Khandelwal',
#        'OAKS Asset Management', 'Titan Capital, LetsVenture',
#        'Incofin, NabVentures, Orios', 'BEENEXT', 'SIG',
#        'Blume Ventures, Micelio Fund',
#        'CDC Group, Jungle Ventures, March Capital, Marshall Wace',
#        'Ashish Jain, Ajay Surana',
#        'We Founder Circle, Appyhigh, Mumbai Angels',
#        'Aroa Ventures, GVFL, Udaan', 'Investcorp, Omidyar Network',
#        'Riteesh Mohan Bakshi, Raghav Mohan Bakshi, Achin Kochar',
#        'Info Edge Ventures, Omnivore', 'Sequoia Capital , Together Fund',
#        'Alpha Wave Ventures, Falcon Edge Capital',
#        'Vivek Vaidya, Kevin Donlon, Ayush Singh',
#        'Kieretsu Forum, Lets Venture, Shell',
#        'Sixth Sense Ventures, Godrej Family office, Malpani Group',
#        'Y-Combinator, AME Cloud Ventures, Gokul Rajaram', 'Smallcase',
#        'The StarupLab, AngelBay',
#        'Dallas Venture Capital, Mars Growth Capital',
#        'Raj Nair, Gopinath Latpate',
#        'Y Combinator, Goat VC, JAM Fund, Goodwater Capital',
#        'Binny Bansal, General Catalyst',
#        'General Atlantic, Tiger Global, Moore Strategic Ventures',
#        'Ascent Capital',
#        'Northern Arc, Arthmate, Shine Star, E clear, Hinduja',
#        'Family Office of Kantamaneni, IIM Calcutta Innovation Park',
#        'Saama Capital\ufeff, \ufeffTitan Capital\ufeff, DSG Consumer Partners',
#        'Omidyar Network, Flourish Ventures, Elevar Equity, Accel',
#        'ah! Ventures, We Founder Circle',
#        'Sequoia Capital, Matrix Partners',
#        'Falcon Edge, DST Global, D1 Capital, Redbird Capital, Tiger Global',
#        'Abu Dhabi Growth Fund, Tiger Global', 'Accel, Bain Capital',
#        'Tiger Global, Insight Partners', 'Ronnie Screwvala',
#        'WestBridge Capital', 'Elevation, General Catalyst',
#        'Equanimity Ventures, 9Unicorns', 'Nueva',
#        'Blume Ventures, Nexus Venture Partners',
#        'Apoorva Sharma, The Chennai Angels, Karthik Bhat',
#        'Gokul Rajaram, Venture Catalysts', 'Kvanto Payment Services',
#        'Siana Capital, Inflexor Ventures, Stride Ventures',
#        'Oxshott Capital Partners, XN Exponent, Edelweiss',
#        'Kunal Shah, Better Capital', 'Lightrock India, Filter Capital',
#        'EKKI', 'Stakeboat Capital',
#        'Coinbase Ventures, Andreessen Horowitz', 'BEENEXT, 3one4 Capital',
#        'Let’s Venture, Better Capital',
#        'International Finance Corporation',
#        'Alia Bhatt, IAN Fund, Social Alpha, Draper Richards Kaplan Foundation',
#        'Sequoia Capital India, ICONIQ Capital, Perceptive Advisors',
#        'LetsVenture', 'India Accelerator', 'Qatar Investment Authority',
#        'Netcore Cloud, Vallabh Bhansali, Jimmy Mahtani',
#        'Petronas Ventures', 'Solana', 'Falcon Edge, Softbank',
#        'Enzia Ventures, Kunal Shah', 'Auxano Capital',
#        'Prashant Pansare, Supermorpheus', 'Docprime Technologies',
#        'LC Nueva AIF', 'Nitish Mittersain, Gaurav Munjal',
#        '9Unicorns, Venture Catalysts, Sandeep Singhal',
#        'Temasek, Google, SBI Investment', 'Elevar Equity',
#        'Aroa Ventures',
#        '9Unicorns, Symphony International Holdings Limited, Value Quest',
#        'Republic Crypto, Woodstock, DCG, Sahil Lavingia',
#        'Data Point Capital',
#        'Momentum 6, Basics Capital, Krypital Capital, Shima Capital, Magnus Capital',
#        'Norwest Venture Partners', 'Sabre Partners',
#        'Vertex Ventures, Omnivore',
#        'Base 10 Partners, Eight Roads Ventures', 'enture Catalyst, IPV',
#        'Tiger Global, Falcon Edge',
#        'BAce Capital, Heritas Capital, 3Lines Venture Capital',
#        'Leo Capital, Mayfield Fund',
#        'Plutus Wealth, Oaks Asset Management',
#        'Anil Thadani, Ashutosh Sinha, Roy van Leeuwen',
#        'Pi Ventures LLP, Tanas Capital, Prodapt Holdings', 'Vitol',
#        'Ruchirans Jaipuria, Rishi Kajaria', 'Manish Choksi, Varun Vakil',
#        'Nadir B Godrej', 'Celesta Capital', 'TransUnion, Blume Ventures',
#        'Blume, Alpha Wave Incubation',
#        'Habitat for Humanity International',
#        'Global Founders Capital, Enzia Ventures, Better Capital',
#        'Kora Capital, Stripe, Alua Capital', 'Iconiq Growth',
#        'Rukam Capital, DSG Consumer Partners, The Chennai Angels',
#        'MAS Financial Services', 'Rocketship.vc, Vulcan Capital',
#        'Tiger Global, Vitruvian Partners',
#        'Think Investments, Venture Highway',
#        'Alok Kohli, Sanjeev Bhargava',
#        'Venture Catalysts, Gruhas Proptech',
#        "LetsVenture, AngelList India, Founder's Room Circle",
#        'Dinesh Godara, Anuj Ahuja, Aditya', 'Z3Partners',
#        'Celesta Capital, Omidyar Network India', 'Pavestone Ventures',
#        'LetsVenture, Paradigm Shift VC, Binny Bansal',
#        'Sofina, Lightrock India, Temasek', 'Dia Mirza', 'DST Global',
#        'Pritt Investment Partners, 9Unicorns',
#        'Darq Capital, Jagadeesh Atukuri', 'Stellaris Venture Partners',
#        'StartupXseed Ventures', 'Xponentia Capital Partners',
#        'General Atlantic, Multiples', 'Vulcan Capital', 'InCorp India',
#        'Oikocredit, Nomura, The Bill & Melinda Gates Foundation',
#        'Kedaara', 'Moore Strategic Ventures, BEENEXT',
#        'Kalaari Capital, Incubate Fund India',
#        'Sequoia Capital, Lightspeed, TVS Capital Funds', 'ABC World Asia',
#        'IIFL AMC, Sistema Asia Fund, CX Partners, Singularity Growth Opportunities Fund',
#        'Prime Securities Limited', 'Fidelity, B Capital',
#        '9Unicorns, Varanium NexGen Fund',
#        'Sequoia Capital, Sandeep Nailwal',
#        'Old Fashion Research, Nothing Research, Tenzor capital',
#        'Aavishkaar Capital, Rajiv Dadlani Group', 'NEVF, AccelNest',
#        'The Treasury', '9Unicorns, Spearhead Capital, Venture Catalysts',
#        'Ramp, Rainfall Ventures, Roka Works, Y Combinator',
#        'India Angel Network',
#        'Responsibility, Blue Ashva Capital, Pravega Ventures',
#        'Dream Capital, Elysian Park Ventures', 'CDC Group, Creaegis',
#        'Lee Fixel’s venture capital firm, Addition',
#        'Y Combinator, JAFCO Asia, Incubate Fund India, marquee angels',
#        'The Xander Group', 'Aarin Capital', 'James Milner, Adam Lallana',
#        'LetsVenture, Ajay Garg, Tarun Sharma', 'Kunal Sarkar',
#        'Morgan Stanley Private Equity Asia', 'Westbridge Capital',
#        'Lightrock India', 'JAM, Better Tomorrow Ventures',
#        'SOSV, Venture Catalysts', 'Incofin’s India Progress Fund',
#        '9Unicorns, Anthill Ventures', 'Jani Ventures INC',
#        'CreedCap Asia Advisors', 'Joseph Joy',
#        'DST Global, Falcon Edge, SoftBank Vision Fund 2',
#        'Trifecta Capital', "Titan Capital, AngelList's syndicate",
#        'Vineet Singh, Krishna D, Deependra Bisht, Alan Aim',
#        'Westbridge Capital, Sixth Sense Ventures', 'MaGEHold',
#        'Season Two Ventures, IndiaMart', 'Kunal Shah, Anant Maheshwari',
#        'WaterBridge Ventures, Enzia Ventures',
#        'Tree Line Investment Management', 'Orbimed Asia Partners',
#        'Zip Co', 'Eight Roads Ventures, GSV', 'Kunal Shah, Krishna Kumar',
#        'Vijay Shekhar Sharma, Rohit Kapoor, Amanpreet Bajaj, Lalit Singh',
#        'Stellaris Venture Partners, Chiratae Ventures',
#        'Lightspeed, Sequioa', 'TheVentures',
#        'Titan Capital, Archana Priyadarshini, Gaurav Ahuja',
#        'Jungle Ventures, CX Partners',
#        'Cygnus Medicare Group, Probal Ghoshal, Shuchin Bajaj',
#        'M2P Fintech',
#        'SucSEED  Indovation Fund, Uincept, Palimala Ventures',
#        'Anicut Angel Fund, Sauce.VC',
#        'Omidyar Network India, Chiratae Ventures',
#        'Elevation Capital, Accel India', 'Legatum Capital',
#        'Navneet Education', '1000000\t#REF!',
#        'Sonu Nigam, Whiteboard Capital', 'Aditya Duggar',
#        'Vertex Ventures, Stellaris Venture Partners',
#        'Omnivore, India Quotient', 'We Founder Circle, Dexter Angels',
#        'IIFL\ufeff, \ufeffAnicut Angel Fund\ufeff, \ufeffKae Capital\ufeff, TradeCred',
#        'Indian Angel Network, Axilor', 'Invesco Developing Markets Fund',
#        'Cholamandalam', 'Curesense Therapeutics', 'Ka Enterprises',
#        'IAN Fund, Malabar Angel Network, Native Angel Network',
#        'DSG Consumer Partners, Titan Capital',
#        'Sujeet Kumar, SucSEED Indovation Fund',
#        'Ameba Capital, 9Unicorns',
#        'Susquehanna International Group, Bessemer Venture Partners',
#        'IIFL AMC, Oman India Joint Investment Fund', 'Unilazer Ventures',
#        'Tribe Capital, Arkam Ventures, WEH, Kunal Shah',
#        'Venture Catalysts, Indian Angel Network',
#        'Elevation Capital, Matrix Partners India', 'Ashok Goyal',
#        'Cure.fit, Endiya Partners, Tanglin Venture',
#        'HOF Capital, Old Well Ventures, LetsVenture, 9Unicorns',
#        'Jinisha Sharma, Aditya Agarwal, Victoria, Abhishek Shroff',
#        'LetsVenture, 2am VC, magic.fund',
#        'Arvind Venugopal Nair, Amritendu Mukherjee',
#        'Rajasthan Venture Capital Fund',
#        'Covalent, Double Peak, GenBlock Capital, Ledger Prime, MEXC Global, Synaps',
#        'Vijayan', 'Gokul Rajaram, JPIN, Venture Catalysts UK, AngelList',
#        'Rachit Poddar, Rajesh Gupta',
#        'Virenxia Group, Rajesh Jain, Nitin Agarwal', 'Addition',
#        'Prashasta Seth',
#        'Matrix Partners India, Jitendra Gupta, RTP Global',
#        'Shaival Desai, Flowstate Ventures', 'Zoho', 'Transworld Group',
#        'IIFL AMC', 'Owl Ventures', 'Winter Capital, ETS, Man Capital',
#        '3one4 Capital, Kalaari Capital'], dtype=object)

# %% [markdown]
# ## Considering the Amount($) Column

# %%
df21['Amount($)'].unique()
# Out:
# array(['$1,200,000', '$120,000,000', '$30,000,000', '$51,000,000',
#        '$2,000,000', '$188,000,000', '$200,000', 'Undisclosed',
#        '$1,000,000', '$3,000,000', '$100,000', '$700,000', '$9,000,000',
#        '$40,000,000', '$49,000,000', '$400,000', '$300,000',
#        '$25,000,000', '$160,000,000', '$150,000', '$1,800,000',
#        '$5,000,000', '$850,000', '$53,000,000', '$500,000', '$1,100,000',
#        '$6,000,000', '$800,000', '$10,000,000', '$21,000,000',
#        '$7,500,000', '$26,000,000', '$7,400,000', '$1,500,000',
#        '$600,000', '$800,000,000', '$17,000,000', '$3,500,000',
#        '$15,000,000', '$215,000,000', '$2,500,000', '$350,000,000',
#        '$5,500,000', '$83,000,000', '$110,000,000', '$500,000,000',
#        '$65,000,000', '$150,000,000,000', '$300,000,000', '$2,200,000',
#        '$35,000,000', '$140,000,000', '$4,000,000', '$13,000,000', nan,
#        '$Undisclosed', '$2000000', '$800000', '$6000000', '$2500000',
#        '$9500000', '$13000000', '$5000000', '$8000000', '$1000000',
#        '$1200000', '$200000', '$12000000', '$1500000', '$1700000',
#        '$5500000', '$400000', '$150000000', '$4000000', '$100000000',
#        '$500000', '$15000000', '$10000000', '$40000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$21000000',
#        '$52000000', '$3800000', '$17500000', '$42000000', '$2300000',
#        '$7000000', '$30000000', '$450000000', '$28000000', '$300000',
#        '$3500000', '$8500000', '$25000000', '$3000000', '$37000000',
#        '$370000000', '$700000', '$16000000', '$100000', '$44000000',
#        '$770000', '$125000000', '$35000000', '$50000000', '$4900000',
#        '$145000000', '$22000000', '$70000000', '$6600000', '$32000000',
#        '$24000000', '$725000', '$461000', 'Series C', 'Seed', '$96000000',
#        '$60000000', '$500000000', '$266000000', '$4500000', '$325000000',
#        '$6500000', '$1600000', '$225000', '$85000000', '$235000',
#        '$260000', '$2900000', '$53000000', '$1100000', '$150000',
#        '$86000000', '$130000', '$$100,00', '$111000000', '$265000',
#        '$76000000', '$100,000,000', '$75,000,000', '$3,800,000',
#        '$12,000,000', '$1,600,000', '$260,000', '$1,000,000,000',
#        '$18,000,000', '$20,000,000', '$350,000', '$95,000,000',
#        '$4,100,000', '$5,200,000', '$8,000,000', '$1,400,000',
#        '$2,600,000', '$900,000', '$250,000', '$16,000,000', '$7,000,000',
#        '$11,000,000', '$50,000,000', '$14,300,000', '$81,000,000',
#        '$1,300,000', '$8,200,000', '$280,000,000', '$70,000,000',
#        '$720,000', '$600000', '$9000000', '$1800000', '$330000',
#        '$undisclosed', '$200000000', '$36000000', '$67000000',
#        '$10200000', '$220000000', '$108000000', '$75000000', '$450000',
#        '$660000000', '$45000000', '$3200000', '$370000', 'Pre-series A',
#        '$48000000', '$3600000', '$11000000', '$192000000', '$65000000',
#        '$1400000', '$1900000', '$41000000', '$144000000', '$5200000',
#        '$270000000', '$140000', '$250000000', '$320000', '$350000000',
#        '$4800000', '$38000000', '$125000', '$26000000', '$64000000',
#        '$620000', '$900000', '$2600000', '$1,250,000', '$400,000,000',
#        '$1,700,000', '$27,000,000', '$234,000,000', '$460,000,000',
#        '$13,500,000', '$5,100,000', '$195,000,000', '$125,000',
#        '$45,000,000', '$200,000,000', '$7,300,000', '$6,300,000',
#        '$12,500,000', '$24,000,000', '$140,000', '$16,500,000',
#        '$340,000', '$43,000,000', '$150,000,000', '$3300000', '$92000000',
#        '$17000000', '$135000000', '$$1,55,000', '$2100000', '$840000000',
#        '$248000000', '$4300000', '$570000', '$2200000', '$4700000',
#        '$300000000', '$260000000', '$140000000', '$175000000',
#        '$19000000', '$810000', '$7500000', '$600000000', '$90000000',
#        '$5700000', '$6750000', '$78000000', '$5400000', '$115000000',
#        '$255000000', '$18000000', '$570000000', '$550000', '$2700000',
#        '$4200000', '$31000000', '$540000', '$14000000', '$340000', '$',
#        '$6200000', '$750000', '$6300000', '$23000000', '$55000000'],
#       dtype=object)

# %%
# Extract rows that do not have the currency sign $ in the amount column
df21[-df21['Amount($)'].astype(str).str.contains('\$', na=False)]
# Out:
#                 Company/Brand  Founded HeadQuarter                 Sector  \
# 7                 Qube Health     2016      Mumbai                 Health
# 8                    Vitra.ai     2020   Bangalore             Technology
# 21                      Uable     2020   Bangalore             Technology
# 39                   TruNativ     2019      Mumbai        Food & Beverage
# 54                     AntWak     2019   Bangalore             Technology
# 64                Rage Coffee     2018   New Delhi        Food & Beverage
# 67                      Kudos     2014        Pune             Technology
# 86                   Onsurity     2020   Bangalore                 Health
# 242        Fullife Healthcare     2009         NaN                   None
# 256        Fullife Healthcare     2009         NaN                   None
# 257                   MoEVing     2021    Gurugram                   None
# 316                 Hubhopper     2015   New Delhi  Media & Entertainment
# 319             Battery Smart     2019   New Delhi                 Energy
# 321                   Onelife     2019      Mumbai                 Health
# 325                     Aisle     2014   Bangalore                   None
# 334                   Zingbus     2019     Haryana              Transport
# 336                  Codingal     2020   Bangalore             Technology
# 345                Hypd Store     2020   New Delhi  Media & Entertainment
# 367                 PrepBytes     2019    Gurugram             Technology
# 376                     ExMyB     2018    Gurugram                   None
# 379                      Qin1     2019       Noida             Technology
# 383                   KIKO TV     2020      Mumbai                   None
# 384               Quali55Care     2018      Mumbai                 Health
# 386                    RevFin     2018   New Delhi             Technology
# 393                      Zouk     2016      Mumbai                Fashion
# 406           Digit Insurance     2016   Bangalore             Technology
# 428                    Bolkar     2018   Bangalore                   None
# 429           Wright Research     2019      Mumbai                   None
# 436            Oneiric Gaming     2020  Chandigarh             Technology
# 452                   Agri10x     2018        Pune            Agriculture
# 545                 AdmitKard     2016       Noida             Technology
# 724                 Instoried     2018   Bangalore  Media & Entertainment
# 732                  Homingos     2018   Bangalore             Technology
# 733   Anar Business Community     2020      Mumbai             Technology
# 735                   Settlrs     2018   Bangalore               Services
# 766                      Wysa     2015   Bangalore             Technology
# 769                   Firmway     2016      Mumbai             Technology
# 794                    Bijnis     2014   New Delhi                    B2B
# 801                   Virohan     2018    Gurugram             Technology
# 807                 ParkSmart     2018   New Delhi          Manufacturing
# 810              Spark Studio     2020   Bangalore             Technology
# 814                     Keito     2016        Pune                   None
# 820                  LegalPay     2019   New Delhi             Technology
# 824               Avalon Labs     2017   Bangalore             Technology
# 827                   Rezo.ai     2017       Noida             Technology
# 833                   Polygon     2017      Mumbai                   None
# 846                  Ingenium     2018   New Delhi             Technology
# 853                   Celcius     2020      Mumbai               Services
# 1100                 Sochcast     2020         NaN                   None
# 1148                Godamwale     2016      Mumbai               Services
#
#                                            What it does  \
# 7     India's Most Respected Workplace Healthcare Ma...
# 8     Vitra.ai is an AI-based video translation plat...
# 21    Uable offers role based programmes to empower ...
# 39                   TruNativ Foods & Beverages Pvt Ltd
# 54    AntWak provides a video platform for e-learnin...
# 64    Rage Coffee is infused with plant based vitami...
# 67    Kudos is a full stack NBFC, a digital lending ...
# 86    Onsurity is an employee healthcare platform pr...
# 242                                        Varun Khanna
# 256                                        Varun Khanna
# 257                         Vikash Mishra, Mragank Jain
# 316   Hubhopper is India's leading podcast hosting, ...
# 319   Battery Smart provides advanced Li-ion batteri...
# 321   Aspire to leverage the gifts of nature and sci...
# 325   Aisle connects the new generation of single in...
# 334   Zingbus is an emerging brand in the intercity ...
# 336         Coding education platform for K-12 students
# 345       A shop worthy content platform, personalized!
# 367   PrepBytes helps college students to learn codi...
# 376   ExMyB provides financial service and consultin...
# 379                  Re-imagining Kids of 21st Century!
# 383   KIKO TV is an AI-based short live video e-comm...
# 384   Deliver highly durable & affordable medical eq...
# 386                RevFin is a digital lending company.
# 393                         100% Vegan bags from India.
# 406   Digit Insurance is a financial services compan...
# 428   Bolkar App is an Audio Based Q&A platform for ...
# 429     Quantitative Investment Management and Research
# 436   Oneiric Gaming connects to fellow dreamers aro...
# 452   Agri10x integrates the entire Agri value-chain...
# 545   A tech solution for end to end career advisory...
# 724   Instoried is an augmented writing platform whi...
# 732   Homingos is an Augmented reality (AR)-based so...
# 733   Anar is a communications and networking platfo...
# 735   A B2B rental services company for furniture, h...
# 766   Wysa is an AI conversational agent that has be...
# 769   Firmway is a platform that digitizes balance c...
# 794   Digitizing the Factories of the Unorganised In...
# 801   Virohan is an edtech company using technology ...
# 807      ParkSmart is a parking management application.
# 810   Online courses to build creativity and confide...
# 814   NO-CODE <> Human-assisted machine learning pla...
# 820   A trusted financial partner for advocates and ...
# 824   Avalon Labs incubates, invests, partners with ...
# 827   Conversational AI platform - Innovate the way ...
# 833       Polygon is a blockchain scalability platform.
# 846   Ingenium Education has been pushing e-learning...
# 853   The “ONLINE” Cold Chain network for Reefer tru...
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                                Founders  \
# 7                                           Gagan Kapur
# 8                                        Akash Nidhi PS
# 21                                       Saurabh Saxena
# 39                      Pranav Malhotra, Mamta Malhotra
# 54    Basav Nagur, Joybroto Ganguly, Sudhanshu Shekh...
# 64                                         Bharat Sethi
# 67                                          Naresh Vigh
# 86                           Kulin Shah, Yogesh Agarwal
# 242                  Morgan Stanley Private Equity Asia
# 256                  Morgan Stanley Private Equity Asia
# 257      Anshuman Maheshwary, Dr Srihari Raju Kalidindi
# 316                                    Gautam Raj Anand
# 319                     Pulkit Khurana, Siddharth Sikka
# 321                                     Gaurav Aggarwal
# 325                                         Able Joseph
# 334                                   Mratunjay Beniwal
# 336                      Satyam Baranwal, Vivek Prakash
# 345                     Ashwarya Garg, Akshay Bhatnagar
# 367                  Aditya Bhushan Verma, Mamta Kumari
# 376                                        Nishant Behl
# 379                                         Ishan Gupta
# 383                                     Shivam Varshney
# 384                                     Harddik K Patel
# 386                                     Sameer Aggarwal
# 393                                         Disha Singh
# 406                                        Kamesh Goyal
# 428   Abhishek Tripathi, Dhruv Kaushal, Prince Tripa...
# 429                                    Sonam Srivastava
# 436                                        Avneet Singh
# 452   Abhijith Naraparaju, Pankajj P. Ghode, Sundeep...
# 545    Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!
# 724                           Sharmin Ali, Sutanshu Raj
# 732          Shourya Agarwal, Malhar Patil, Rajat Gupta
# 733                           Nishank Jain, Sanjay Bhat
# 735                 Gaurav Ranebennur, Nishanth Janadri
# 766                       Jo Aggarwal, Ramakant Vempati
# 769                       Prashant Gupta, Vivek Chandan
# 794   Chaitanya Rathi, Shubham Agarwal, Siddharth Ra...
# 801         Archit Jayasal, Kunaal Dudeja, Nalin Saluja
# 807   Prateek Garg, Rahul Gupta, Ratan Anmol Sethi, ...
# 810                                     Anushree Goenka
# 814                                            Amal P S
# 820                                        Kundan Shahi
# 824                                         Varun Mayya
# 827                           Manish Gupta, Rashi Gupta
# 833        Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 846       Pramudit Somvanshi, Mohit Patel, Aakash Gupta
# 853            Swarup Bose, Rajneesh Raman, Arbind Jain
# 1100            Vinners, Raj Nayak, Amritaanshu Agrawal
# 1148          Basant Kumar, Vivek Tiwari, Ranbir Nandan
#
#                                                Investor     Amount($)  \
# 7                             Inflection Point Ventures   Undisclosed
# 8                                     Inflexor Ventures   Undisclosed
# 21                        Chiratae Ventures, JAFCO Asia   Undisclosed
# 39                                            9Unicorns   Undisclosed
# 54                       Vaibhav Domkundwar, Kunal Shah   Undisclosed
# 64                           GetVantage, Prakash Katama   Undisclosed
# 67                             Marquee fintech founders   Undisclosed
# 86                           Jitendra Gupta, Harsh Shah           NaN
# 242                                                 NaN      Series C
# 256                                                 NaN      Series C
# 257                                                 NaN          Seed
# 316      ITI Growth Opportunities Fund, Unit-E Ventures   Undisclosed
# 319                              Orios Venture Partners   Undisclosed
# 321                           Wipro venture capital arm   Undisclosed
# 325                      Anas Rahman Junaid, Vinod Jose   Undisclosed
# 334       Venture Catalysts, 9Unicorns Accelerator Fund   Undisclosed
# 336                     Y Combinator, Rebright Partners   Undisclosed
# 345                                          ScoopWhoop   Undisclosed
# 367                                 Equanimity Ventures   Undisclosed
# 376                                         Campus Fund   Undisclosed
# 379                                   Venture Catalysts   Undisclosed
# 383     Sunil Kumar Singhvi, 9Unicorns Accelerator Fund   Undisclosed
# 384          India Accelerator’s Angel Investor Network   Undisclosed
# 386                                    Shell Foundation   Undisclosed
# 393                                       Titan Capital   Undisclosed
# 406                       A91 Partners, Faering Capital   Undisclosed
# 428                                    GSF, Pras Hanuma   Undisclosed
# 429                         Ajat Hukkoo, Piyush Chaplot   Undisclosed
# 436                                     Trishneet Arora   Undisclosed
# 452                                            Omnivore   Undisclosed
# 545                                                 NaN  Pre-series A
# 724                          EXPERT DOJO, Mumbai Angels   Undisclosed
# 732                   Sundi Natarajan, Srinivas Anumolu   Undisclosed
# 733                         Titan Capital, First Cheque   Undisclosed
# 735                                  MaGEHold Pte. Ltd.   Undisclosed
# 766                            Kae Capital, Pi Ventures   Undisclosed
# 769                                                 NaN   Undisclosed
# 794        Sequoia Capital India, Matrix Partners India   Undisclosed
# 801   National Skill Development Corporation, Rianta...   Undisclosed
# 807                  Shireen Rangaswamy, Dilesh Gathani   Undisclosed
# 810                                      Better Capital   Undisclosed
# 814                 Rajesh Agarwal, Nandkishore Mundada   Undisclosed
# 820                                           9Unicorns   Undisclosed
# 824   Tanglin Ventures, Better Capital, Whiteboard C...   Undisclosed
# 827                    Devesh Sachdev, Bhavesh Manglani   Undisclosed
# 833                            Mark Cuban, MiH Ventures   Undisclosed
# 846                                         Lead Angels   Undisclosed
# 853                                 Eaglewings Ventures   Undisclosed
# 1100                                                NaN           NaN
# 1148                                     1000000\t#REF!          Seed
#
#              Stage
# 7     Pre-series A
# 8              NaN
# 21            Seed
# 39            Seed
# 54            Seed
# 64    Pre-series A
# 67    Pre-series A
# 86             NaN
# 242            NaN
# 256            NaN
# 257            NaN
# 316            NaN
# 319           Seed
# 321            NaN
# 325   Pre-series A
# 334   Pre-series A
# 336            NaN
# 345       Pre-seed
# 367            NaN
# 376           Seed
# 379   Pre-series A
# 383   Pre-series A
# 384           Seed
# 386            NaN
# 393           Seed
# 406            NaN
# 428            NaN
# 429       Pre-seed
# 436            NaN
# 452           Seed
# 545            NaN
# 724            NaN
# 732            NaN
# 733            NaN
# 735   Pre-series A
# 766            NaN
# 769       Pre-seed
# 794            NaN
# 801            NaN
# 807           Seed
# 810           Seed
# 814           Seed
# 820           Seed
# 824   Pre-series A
# 827           Seed
# 833            NaN
# 846           Seed
# 853           Seed
# 1100           NaN
# 1148           NaN

# %%
df21.loc[df21["Amount($)"] == "Pre-series A"]
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 545     AdmitKard     2016       Noida  Technology
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders Investor     Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!      NaN  Pre-series A
#
#     Stage
# 545   NaN

# %%
df21.loc[df21["Company/Brand"] == "AdmitKard", ["Amount($)", "Stage", "Investor"]] = ["$1000000", np.nan, "Pre-series A"]
df21.loc[df21["Company/Brand"] == "AdmitKard"]
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 545     AdmitKard     2016       Noida  Technology
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders      Investor Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  Pre-series A  $1000000
#
#     Stage
# 545   NaN

# %%
#  Replace empty column with 0
df21["Amount($)"].replace(" ", 0, inplace = True, regex=True)
# remove comma from the amounts 
df21["Amount($)"].replace(",", "", inplace = True, regex=True)
# Replace  "Undisclosed", "undisclosed", "Undiclsosed", "Undislosed" and "$undisclosed" with NaN
df21["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
df21["Amount($)"].replace("undisclosed", np.nan, inplace = True, regex=True)
df21["Amount($)"].replace("Undiclsosed", np.nan, inplace = True, regex=True)
df21["Amount($)"].replace("Undislosed", np.nan, inplace = True, regex=True)
df21["Amount($)"].replace("$undisclosed", np.nan, inplace = True, regex=True)

# %%
df21.loc[df21["Amount($)"] == "JITO Angel Network, LetsVenture", ["Amount($)", "Stage"]] = ["$1000000", np.nan]
df21.loc[df21["Company/Brand"] == "Saarthi Pedagogy"]
# Out:
#         Company/Brand  Founded HeadQuarter      Sector  \
# 677  Saarthi Pedagogy     2015   Ahmadabad  Technology
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor Amount($) Stage
# 677  Sushil Agarwal  $1000000   NaN

# %%
df21.loc[df21["Amount($)"] == "Seed"]
# Out:
#      Company/Brand  Founded HeadQuarter    Sector  \
# 257        MoEVing     2021    Gurugram      None
# 1148     Godamwale     2016      Mumbai  Services
#
#                                            What it does  \
# 257                         Vikash Mishra, Mragank Jain
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                             Founders        Investor  \
# 257   Anshuman Maheshwary, Dr Srihari Raju Kalidindi             NaN
# 1148       Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!
#
#      Amount($) Stage
# 257       Seed   NaN
# 1148      Seed   NaN

# %%
df21.loc[df21["Company/Brand"] == "MoEVing", ["Amount($)", "Stage", "Investor"]] = ["$5000000", "Seed", np.nan]
df21.loc[df21["Company/Brand"] == "Godamwale", ["Amount($)", "Stage", "Investor"]] = ["1000000", "Seed", np.nan]
df21.loc[df21["Company/Brand"] == "MoEVing"]
# Out:
#     Company/Brand  Founded HeadQuarter Sector                 What it does  \
# 257       MoEVing     2021    Gurugram   None  Vikash Mishra, Mragank Jain
#
#                                            Founders Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi      NaN  $5000000  Seed

# %%
df21.loc[df21["Company/Brand"] == "Godamwale"]
# Out:
#      Company/Brand  Founded HeadQuarter    Sector  \
# 1148     Godamwale     2016      Mumbai  Services
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders Investor Amount($) Stage
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan      NaN   1000000  Seed

# %%
df21.loc[df21["Amount($)"] == "Series C"]
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage]
# Index: []

# %%
df21.loc[df21["Company/Brand"] == "Fullife Healthcare", ["HeadQuarter","Amount($)", "Stage", "Investor"]] = [np.nan, "$22000000000", "Series C", np.nan]
df21.loc[df21["Company/Brand"] == "Fullife Healthcare"]
# Out:
#           Company/Brand  Founded HeadQuarter Sector  What it does  \
# 242  Fullife Healthcare     2009         NaN   None  Varun Khanna
# 256  Fullife Healthcare     2009         NaN   None  Varun Khanna
#
#                                Founders Investor     Amount($)     Stage
# 242  Morgan Stanley Private Equity Asia      NaN  $22000000000  Series C
# 256  Morgan Stanley Private Equity Asia      NaN  $22000000000  Series C

# %%
# Convert the 'Amount' column to string
df21["Amount($)"] = df21["Amount($)"].apply(str)

# Remove the "$" and Replace specific patterns with NaN values in the 'Amount($)' Column
df21["Amount($)"] = df21["Amount($)"].apply(lambda x: str(x).replace("$",""))
df21["Amount($)"].replace("^\s*$", np.nan, inplace=True, regex=True)

# %%
# Conform the changes made on the unique vlaues in the column
df21['Amount($)'].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', 'nan', '1000000', '3000000', '100000',
#        '700000', '9000000', '40000000', '49000000', '400000', '300000',
#        '25000000', '160000000', '150000', '1800000', '5000000', '850000',
#        '53000000', '500000', '1100000', '6000000', '800000', '10000000',
#        '21000000', '7500000', '26000000', '7400000', '1500000', '600000',
#        '800000000', '17000000', '3500000', '15000000', '215000000',
#        '2500000', '350000000', '5500000', '83000000', '110000000',
#        '500000000', '65000000', '150000000000', '300000000', '2200000',
#        '35000000', '140000000', '4000000', '13000000', '9500000',
#        '8000000', '12000000', '1700000', '150000000', '100000000',
#        '225000000', '6700000', '1300000', '20000000', '250000',
#        '52000000', '3800000', '17500000', '42000000', '2300000',
#        '7000000', '450000000', '28000000', '8500000', '37000000',
#        '370000000', '16000000', '44000000', '770000', '125000000',
#        '50000000', '4900000', '145000000', '22000000', '70000000',
#        '6600000', '32000000', '24000000', '725000', '461000',
#        '22000000000', '96000000', '60000000', '266000000', '4500000',
#        '325000000', '6500000', '1600000', '225000', '85000000', '235000',
#        '260000', '2900000', '86000000', '130000', '10000', '111000000',
#        '265000', '76000000', '75000000', '1000000000', '18000000',
#        '350000', '95000000', '4100000', '5200000', '1400000', '2600000',
#        '900000', '11000000', '14300000', '81000000', '8200000',
#        '280000000', '720000', '330000', '200000000', '36000000',
#        '67000000', '10200000', '220000000', '108000000', '450000',
#        '660000000', '45000000', '3200000', '370000', '48000000',
#        '3600000', '192000000', '1900000', '41000000', '144000000',
#        '270000000', '140000', '250000000', '320000', '4800000',
#        '38000000', '125000', '64000000', '620000', '1250000', '400000000',
#        '27000000', '234000000', '460000000', '13500000', '5100000',
#        '195000000', '7300000', '6300000', '12500000', '16500000',
#        '340000', '43000000', '3300000', '92000000', '135000000', '155000',
#        '2100000', '840000000', '248000000', '4300000', '570000',
#        '4700000', '260000000', '175000000', '19000000', '810000',
#        '600000000', '90000000', '5700000', '6750000', '78000000',
#        '5400000', '115000000', '255000000', '570000000', '550000',
#        '2700000', '4200000', '31000000', '540000', '14000000', nan,
#        '6200000', '750000', '23000000', '55000000'], dtype=object)

# %%
#convert the datatype for Amount to float to two decimal places 
df21['Amount($)'] = df21['Amount($)'].astype(float).round(2)

# %%
# Drop duplicates in the dataset
df21.drop_duplicates(inplace=True)
df21
# Out:
#        Company/Brand  Founded HeadQuarter             Sector  \
# 0     Unbox Robotics     2019   Bangalore         Technology
# 1             upGrad     2015      Mumbai         Technology
# 2        Lead School     2012      Mumbai         Technology
# 3            Bizongo     2015      Mumbai                B2B
# 4           FypMoney     2021    Gurugram         Technology
# ...              ...      ...         ...                ...
# 1204        Gigforce     2019    Gurugram           Services
# 1205          Vahdam     2015   New Delhi    Food & Beverage
# 1206    Leap Finance     2019   Bangalore  Banking & Finance
# 1207    CollegeDekho     2015    Gurugram         Technology
# 1208          WeRize     2019   Bangalore  Banking & Finance
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor    Amount($)         Stage
# 0                       BEENEXT, Entrepreneur First    1200000.0  Pre-series A
# 1          Unilazer Ventures, IIFL Asset Management  120000000.0           NaN
# 2                  GSV Ventures, Westbridge Capital   30000000.0      Series D
# 3                            CDC Group, IDG Capital   51000000.0      Series C
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    2000000.0          Seed
# ...                                             ...          ...           ...
# 1204                                Endiya Partners    3000000.0  Pre-series A
# 1205                                       IIFL AMC   20000000.0      Series D
# 1206                                   Owl Ventures   55000000.0      Series C
# 1207               Winter Capital, ETS, Man Capital   26000000.0      Series B
# 1208                 3one4 Capital, Kalaari Capital    8000000.0      Series A
#
# [1190 rows x 9 columns]

# %% [markdown]
# ## Create Funding year to the data frame.

# %%
# Create the Funding year Column
df21["Funding Year"] = "2021"
df21.head( )
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 0  Unbox Robotics     2019   Bangalore  Technology
# 1          upGrad     2015      Mumbai  Technology
# 2     Lead School     2012      Mumbai  Technology
# 3         Bizongo     2015      Mumbai         B2B
# 4        FypMoney     2021    Gurugram  Technology
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor    Amount($)         Stage  \
# 0                    BEENEXT, Entrepreneur First    1200000.0  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  120000000.0           NaN
# 2               GSV Ventures, Westbridge Capital   30000000.0      Series D
# 3                         CDC Group, IDG Capital   51000000.0      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    2000000.0          Seed
#
#   Funding Year
# 0         2021
# 1         2021
# 2         2021
# 3         2021
# 4         2021

# %%
#retrieve empty columns in the amount column
df21[df21['Amount($)'].isna()]
# Out:
#               Company/Brand  Founded HeadQuarter            Sector  \
# 7               Qube Health     2016      Mumbai            Health
# 8                  Vitra.ai     2020   Bangalore        Technology
# 21                    Uable     2020   Bangalore        Technology
# 39                 TruNativ     2019      Mumbai   Food & Beverage
# 54                   AntWak     2019   Bangalore        Technology
# ...                     ...      ...         ...               ...
# 1146                    MPL     2018   Bangalore  Sports & Fitness
# 1160  Atomberg Technologies     2012      Mumbai              None
# 1161        Genext Students     2013      Mumbai        Technology
# 1166              OckyPocky     2015    Gurugram        Technology
# 1193        Sapio Analytics     2019      Mumbai        Technology
#
#                                            What it does  \
# 7     India's Most Respected Workplace Healthcare Ma...
# 8     Vitra.ai is an AI-based video translation plat...
# 21    Uable offers role based programmes to empower ...
# 39                   TruNativ Foods & Beverages Pvt Ltd
# 54    AntWak provides a video platform for e-learnin...
# ...                                                 ...
# 1146  Mobile Premier League (MPL), is India’s larges...
# 1160             A maker of energy-efficient smart fans
# 1161  LIVE online classes with expert tutors for K-1...
# 1166  OckyPocky is India's 1st interactive English l...
# 1193  Sapio helps government create policies driven ...
#
#                                                Founders  \
# 7                                           Gagan Kapur
# 8                                        Akash Nidhi PS
# 21                                       Saurabh Saxena
# 39                      Pranav Malhotra, Mamta Malhotra
# 54    Basav Nagur, Joybroto Ganguly, Sudhanshu Shekh...
# ...                                                 ...
# 1146              Sai Srinivas Kiran GV, Shubh Malhotra
# 1160                         Manoj Meena, Sibabrata Das
# 1161                    Ali Asgar Kagzi, Piyush Dhanuka
# 1166                                       Amit Agrawal
# 1193  Hardik Somani, Ashwin Srivastava, Shripal Jain...
#
#                                    Investor  Amount($)         Stage  \
# 7                 Inflection Point Ventures        NaN  Pre-series A
# 8                         Inflexor Ventures        NaN           NaN
# 21            Chiratae Ventures, JAFCO Asia        NaN          Seed
# 39                                9Unicorns        NaN          Seed
# 54           Vaibhav Domkundwar, Kunal Shah        NaN          Seed
# ...                                     ...        ...           ...
# 1146                        Legatum Capital        NaN      Series E
# 1160                         Ka Enterprises        NaN           NaN
# 1161                      Navneet Education        NaN           NaN
# 1166  Sujeet Kumar, SucSEED Indovation Fund        NaN          Seed
# 1193            Rachit Poddar, Rajesh Gupta        NaN           NaN
#
#      Funding Year
# 7            2021
# 8            2021
# 21           2021
# 39           2021
# 54           2021
# ...           ...
# 1146         2021
# 1160         2021
# 1161         2021
# 1166         2021
# 1193         2021
#
# [141 rows x 10 columns]

# %%
df21.drop(columns=['What it does'], inplace=True) # drop the "What it does" column

# %%
df21.head()
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 0  Unbox Robotics     2019   Bangalore  Technology
# 1          upGrad     2015      Mumbai  Technology
# 2     Lead School     2012      Mumbai  Technology
# 3         Bizongo     2015      Mumbai         B2B
# 4        FypMoney     2021    Gurugram  Technology
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor    Amount($)         Stage  \
# 0                    BEENEXT, Entrepreneur First    1200000.0  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  120000000.0           NaN
# 2               GSV Ventures, Westbridge Capital   30000000.0      Series D
# 3                         CDC Group, IDG Capital   51000000.0      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    2000000.0          Seed
#
#   Funding Year
# 0         2021
# 1         2021
# 2         2021
# 3         2021
# 4         2021

# %%
#replace all the 0 with the mean 
df21['Amount($)'].replace(to_replace= np.nan, value = df21['Amount($)'].mean(), inplace = True)
#replace the nan values with mean 
#df21.fillna(df21.mean(), inplace=True)

# %%
df21["Amount($)"].unique()
# Out:
# array([1.20000000e+06, 1.20000000e+08, 3.00000000e+07, 5.10000000e+07,
#        2.00000000e+06, 1.88000000e+08, 2.00000000e+05, 1.92170187e+08,
#        1.00000000e+06, 3.00000000e+06, 1.00000000e+05, 7.00000000e+05,
#        9.00000000e+06, 4.00000000e+07, 4.90000000e+07, 4.00000000e+05,
#        3.00000000e+05, 2.50000000e+07, 1.60000000e+08, 1.50000000e+05,
#        1.80000000e+06, 5.00000000e+06, 8.50000000e+05, 5.30000000e+07,
#        5.00000000e+05, 1.10000000e+06, 6.00000000e+06, 8.00000000e+05,
#        1.00000000e+07, 2.10000000e+07, 7.50000000e+06, 2.60000000e+07,
#        7.40000000e+06, 1.50000000e+06, 6.00000000e+05, 8.00000000e+08,
#        1.70000000e+07, 3.50000000e+06, 1.50000000e+07, 2.15000000e+08,
#        2.50000000e+06, 3.50000000e+08, 5.50000000e+06, 8.30000000e+07,
#        1.10000000e+08, 5.00000000e+08, 6.50000000e+07, 1.50000000e+11,
#        3.00000000e+08, 2.20000000e+06, 3.50000000e+07, 1.40000000e+08,
#        4.00000000e+06, 1.30000000e+07, 9.50000000e+06, 8.00000000e+06,
#        1.20000000e+07, 1.70000000e+06, 1.50000000e+08, 1.00000000e+08,
#        2.25000000e+08, 6.70000000e+06, 1.30000000e+06, 2.00000000e+07,
#        2.50000000e+05, 5.20000000e+07, 3.80000000e+06, 1.75000000e+07,
#        4.20000000e+07, 2.30000000e+06, 7.00000000e+06, 4.50000000e+08,
#        2.80000000e+07, 8.50000000e+06, 3.70000000e+07, 3.70000000e+08,
#        1.60000000e+07, 4.40000000e+07, 7.70000000e+05, 1.25000000e+08,
#        5.00000000e+07, 4.90000000e+06, 1.45000000e+08, 2.20000000e+07,
#        7.00000000e+07, 6.60000000e+06, 3.20000000e+07, 2.40000000e+07,
#        7.25000000e+05, 4.61000000e+05, 2.20000000e+10, 9.60000000e+07,
#        6.00000000e+07, 2.66000000e+08, 4.50000000e+06, 3.25000000e+08,
#        6.50000000e+06, 1.60000000e+06, 2.25000000e+05, 8.50000000e+07,
#        2.35000000e+05, 2.60000000e+05, 2.90000000e+06, 8.60000000e+07,
#        1.30000000e+05, 1.00000000e+04, 1.11000000e+08, 2.65000000e+05,
#        7.60000000e+07, 7.50000000e+07, 1.00000000e+09, 1.80000000e+07,
#        3.50000000e+05, 9.50000000e+07, 4.10000000e+06, 5.20000000e+06,
#        1.40000000e+06, 2.60000000e+06, 9.00000000e+05, 1.10000000e+07,
#        1.43000000e+07, 8.10000000e+07, 8.20000000e+06, 2.80000000e+08,
#        7.20000000e+05, 3.30000000e+05, 2.00000000e+08, 3.60000000e+07,
#        6.70000000e+07, 1.02000000e+07, 2.20000000e+08, 1.08000000e+08,
#        4.50000000e+05, 6.60000000e+08, 4.50000000e+07, 3.20000000e+06,
#        3.70000000e+05, 4.80000000e+07, 3.60000000e+06, 1.92000000e+08,
#        1.90000000e+06, 4.10000000e+07, 1.44000000e+08, 2.70000000e+08,
#        1.40000000e+05, 2.50000000e+08, 3.20000000e+05, 4.80000000e+06,
#        3.80000000e+07, 1.25000000e+05, 6.40000000e+07, 6.20000000e+05,
#        1.25000000e+06, 4.00000000e+08, 2.70000000e+07, 2.34000000e+08,
#        4.60000000e+08, 1.35000000e+07, 5.10000000e+06, 1.95000000e+08,
#        7.30000000e+06, 6.30000000e+06, 1.25000000e+07, 1.65000000e+07,
#        3.40000000e+05, 4.30000000e+07, 3.30000000e+06, 9.20000000e+07,
#        1.35000000e+08, 1.55000000e+05, 2.10000000e+06, 8.40000000e+08,
#        2.48000000e+08, 4.30000000e+06, 5.70000000e+05, 4.70000000e+06,
#        2.60000000e+08, 1.75000000e+08, 1.90000000e+07, 8.10000000e+05,
#        6.00000000e+08, 9.00000000e+07, 5.70000000e+06, 6.75000000e+06,
#        7.80000000e+07, 5.40000000e+06, 1.15000000e+08, 2.55000000e+08,
#        5.70000000e+08, 5.50000000e+05, 2.70000000e+06, 4.20000000e+06,
#        3.10000000e+07, 5.40000000e+05, 1.40000000e+07, 6.20000000e+06,
#        7.50000000e+05, 2.30000000e+07, 5.50000000e+07])

# %%
df21.head(20)
# Out:
#        Company/Brand  Founded HeadQuarter           Sector  \
# 0     Unbox Robotics     2019   Bangalore       Technology
# 1             upGrad     2015      Mumbai       Technology
# 2        Lead School     2012      Mumbai       Technology
# 3            Bizongo     2015      Mumbai              B2B
# 4           FypMoney     2021    Gurugram       Technology
# 5      Urban Company     2014   New Delhi  Food & Beverage
# 6     Comofi Medtech     2018   Bangalore           Health
# 7        Qube Health     2016      Mumbai           Health
# 8           Vitra.ai     2020   Bangalore       Technology
# 9             Taikee     2010      Mumbai             None
# 10         Fitterfly     2016      Mumbai           Health
# 11         FreeStand     2017   New Delhi              B2B
# 12      MyDentalPlan     2014   Bangalore           Health
# 13      Freyr Energy     2014   Hyderabad           Energy
# 14         DealShare     2018      Jaipur             None
# 15          Tessolve     1993   Bangalore    Manufacturing
# 16      Smart Joules     2014   New Delhi           Energy
# 17              ORAI     2020   Bangalore       Technology
# 18           ixamBee     2016   New Delhi       Technology
# 19  CoinSwitch Kuber     2017   Bangalore       Technology
#
#                                              Founders  \
# 0                         Pramod Ghadge, Shahid Memon
# 1   Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                          Smita Deorah, Sumeet Mehta
# 3             Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                       Kapil Banwari
# 5   Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 6                                          Gururaj KB
# 7                                         Gagan Kapur
# 8                                      Akash Nidhi PS
# 9                  Nidhi Ramachandran, Sachin Chhabra
# 10                                 Dr Arbinder Singal
# 11                           Konark Sharma, Sneh Soni
# 12  Dr Mohender Narula, Dr AnandKrishna, Dr Girish...
# 13                    Radhika Choudary, Saurabh Marda
# 14          Sankar Bora, Sourjyendu Medda, Vineet Rao
# 15  P Raja Manickam, Srinivas Chinamilli, Veerappan V
# 16     Arjun P Gupta, Ujjal Majumdar, Sidhartha Gupta
# 17                     Swapnil Jain, Sujit Das Biswas
# 18                               Chandraprakash Joshi
# 19    Ashish Singhal, Govind Soni, Vimal Sagar Tiwari
#
#                                             Investor     Amount($)  \
# 0                        BEENEXT, Entrepreneur First  1.200000e+06
# 1           Unilazer Ventures, IIFL Asset Management  1.200000e+08
# 2                   GSV Ventures, Westbridge Capital  3.000000e+07
# 3                             CDC Group, IDG Capital  5.100000e+07
# 4      Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal  2.000000e+06
# 5                                         Vy Capital  1.880000e+08
# 6                                  CIIE.CO, KIIT-TBI  2.000000e+05
# 7                          Inflection Point Ventures  1.921702e+08
# 8                                  Inflexor Ventures  1.921702e+08
# 9                                                NaN  1.000000e+06
# 10     9Unicorns Accelerator Fund, Metaform Ventures  3.000000e+06
# 11  SucSEED Indovation, IIM Calcutta Innovation Park  1.000000e+05
# 12                              Safe Planet Medicare  7.000000e+05
# 13                     Impact Partners, C4D Partners  2.000000e+06
# 14          Tiger Global Management, InnoVen Capital  9.000000e+06
# 15                               Novo Tellus Capital  4.000000e+07
# 16                   Raintree Family Office, ADB arm  4.900000e+07
# 17                         Inflection Point Ventures  4.000000e+05
# 18                Mumbai Angels, Narendra Shyamsukha  3.000000e+05
# 19                              Paradigm, Kunal Shah  2.500000e+07
#
#            Stage Funding Year
# 0   Pre-series A         2021
# 1            NaN         2021
# 2       Series D         2021
# 3       Series C         2021
# 4           Seed         2021
# 5            NaN         2021
# 6            NaN         2021
# 7   Pre-series A         2021
# 8            NaN         2021
# 9            NaN         2021
# 10  Pre-series A         2021
# 11           NaN         2021
# 12          Seed         2021
# 13           NaN         2021
# 14           NaN         2021
# 15           NaN         2021
# 16           NaN         2021
# 17  Pre-series A         2021
# 18          Seed         2021
# 19      Series B         2021

# %%
# Droping duplicates in the DataFrame 
df21.drop_duplicates(inplace=True)

# %%
df21.describe()
# Out:
#            Founded     Amount($)
# count  1189.000000  1.189000e+03
# mean   2014.937763  1.921636e+08
# std      58.658440  4.395532e+09
# min       0.000000  1.000000e+04
# 25%    2015.000000  1.000000e+06
# 50%    2018.000000  5.000000e+06
# 75%    2020.000000  4.000000e+07
# max    2021.000000  1.500000e+11

# %% [markdown]
# ## save the cleaned data

# %%
df21.to_csv("India_funding2021_cleaned.csv", index=False)

# %% [markdown]
# # Preprocessing 2020 dataset

# %%
df20.head( )
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
# checking basic information about the dataset
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %%
df20.dtypes
# Out:
# Company/Brand    object
# Founded          object
# HeadQuarter      object
# Sector           object
# What it does     object
# Founders         object
# Investor         object
# Amount($)        object
# Stage            object
# Unnamed: 9       object
# dtype: object

# %% [markdown]
# ## Company/Brand column

# %%
df20["Company/Brand"].unique()
# Out:
# array(['Aqgromalin', 'Krayonnz', 'PadCare Labs', 'NCOME', 'Gramophone',
#        'qZense', 'MyClassboard', 'Metvy', 'Rupeek', 'Gig India',
#        'Slurrp Farm', 'Medfin', 'MasterG', 'Brila 91', 'FoodyBuddy',
#        'Zomato', 'OurEye.ai', 'Shiprocket', 'Pine Labs',
#        'Moneyboxx Finance', 'EWar', 'SucSEED Indovation', 'TaxBuddy.com',
#        'Awign Enterprises', 'Circle of Angels', 'CoinDCX', 'Glance',
#        'VerSe Innovation', 'Voosh', 'Delhivery', 'Arya', 'Pickrr',
#        'PhonePe', 'Countingwell', 'Callify.ai', 'Hudle', 'Cover it Up',
#        'BiteSpeed', 'WakeFit', 'Sreyas Holistic Remedies', 'Fleeca India',
#        'M1xchange', 'Exotel', 'PagarBook', 'PointOne Capital', 'Ayana',
#        'Fisdom', 'Tinker Coders', 'Infinite Uptime', 'HappyLocate',
#        'Loop Health', 'NeoDocs', 'The ePlane', 'TagMango', 'The New Shop',
#        'MobiKwik', 'DebugsBunny', 'BHIVE Investech', 'Rivigo', 'ZipLoan',
#        'Swipez', 'Humus', 'Artivatic.ai', 'Prescinto', 'Toppeq',
#        'Bolo Indya', 'Bombay Play', 'FreshToHome', 'KIKO TV',
#        'Atomberg Technologies', 'DealShare', 'Smallcase', 'CueMath',
#        'Gamerji', '5C Network', 'Ethereum Push Notification Service',
#        'Mihup', 'RuralBasket', 'WayCool Foods', 'Infra.Market',
#        'Info Edge Venture', 'Clovia', 'Codingal', 'CRED',
#        'Vistaar Finance', "Let's Dive", 'Habitat', 'SAWO Labs', 'Signzy',
#        'KopyKitab', 'Kyt', 'Raskik', 'GetWork',
#        'Mobile Premier League (MPL)', 'Pravasirojgar', 'Omatra Hotels',
#        'Awign', 'NewsReach', 'Cashfree', 'Credgenics', 'GeoIQ',
#        'Country Delight', 'Quintype', 'CARS24', 'Astrogate Labs',
#        'Power Gummies', 'Cityflo', 'AlgoBulls', 'Inntot', 'Ensuredit',
#        'Shipsy', 'ERPNext', 'LightSpeedAI', 'Grip Invest', 'Unacademy',
#        'Yellow Classes', 'Plum', 'STAGE', 'Nykaa', 'Kaagaz Scanner',
#        'NIRA', 'Prolixr', "Byju's", 'DaMENSCH', 'SignalX', 'Lancify',
#        'Krimanshi', 'Instoried', 'PlayerzPot', 'Instamojo', 'Turtlemint',
#        'Arata', 'MPL', 'True Balance', 'Thrive', 'Kitchens Centre',
#        'Prescribe', 'Nepra', 'inFeedo', 'Shilpa Sciences', 'Arzooo',
#        'MindTickle', 'Slice', 'Rapawalk', "Oga Fit's", 'LAVAL',
#        'Stride Ventures', 'BlackSoil', 'Biocon', 'Clientjoy',
#        'Xpressbees', 'GalaxyCard', 'Wellness Forever', 'MoooFarm',
#        'BitClass', 'Gonuts', 'Uolo', 'Kirana King', 'Jade Forest',
#        'iKure', 'FrontRow', 'Reliance Retail', 'TUBBR', 'Ather Energy',
#        'Routematic', 'LivFin', 'Universal Sportsbiz Pvt Ltd',
#        'Lattu Kids', 'Eggoz', 'Steradian Semiconductors', 'CHARGE+ZONE',
#        'Stones2milestones', 'Udacity', 'AjnaLens', 'Gully Network',
#        'TurboHire', 'Traya', 'Charcoal Eats', 'Mitron TV', 'Svami',
#        'Dhurnia', 'Expertrons', 'Leena AI', 'Bizlog', 'Tamasha.live',
#        'Fedo', 'FabHotels', 'Freshokartz', 'FlexiLoans', 'Agrix',
#        'BharatAgri', 'FreshtoHome', 'Credable', 'Railofy',
#        'Finova Capital', 'Teachmint', 'Peel-Works', 'Janani',
#        'Finelistings', 'Wellversed', 'Jumbotail', 'Winzo', 'mCaffeine',
#        'Pocket FM', 'Snackible', 'TagZ Foods', 'Genius Teacher',
#        'Krimanshi Feeds', 'Origo', 'GetVantage', 'Betterplace', 'Biddano',
#        'InVideo', 'Hubilo', 'BASIC Home Loan', 'Ketos', 'SUGAR cosmetics',
#        'Ahaguru', 'Tekion', 'Brighteye Ventures', 'EzeRx', 'VitalTech',
#        'Ultraviolette Automotive', 'Tring', 'Rare Planet', 'GoodGamer',
#        'InnAccel', 'Tiliter', 'Slintel', 'SoOLEGAL', 'HobSpace',
#        'Supplynote', 'Hire Me Car', 'ShopUp', 'Harmonizer India',
#        'Dukaan', 'CredR', 'Satyukt', 'RACEnergy', 'TREAD', 'Anveshan',
#        'TeaMonk', 'Fleetx', 'ReNEWate', 'Tango Eye', 'Avataa Me',
#        'Arrival', 'Cover Genius', 'Phononic Vibes', 'MikeLegal', 'Clair',
#        'Gourmet Garden', 'Miko', 'Razorpay', 'Ninjacart', 'Wow! Momo',
#        'Pepper Content', 'LIVSPACE', 'Acculi Labs', 'Your MD', 'Antaios',
#        'Unnati', 'Disprz', 'Uni', 'Credit Wise Capital', 'Chargebee',
#        'Reliance Retail Ventures Ltd', 'Winuall', 'Genrobotics', 'Livve',
#        'Ergos', 'Krishitantra', 'PakkaProfile', 'Monet Networks',
#        'Unocoin', 'Pesto', 'NirogStreet', 'Bambrew', 'Omnify',
#        'Fanball XI', 'Treebo Hotels', 'GPS Renewables', 'Public',
#        'Legal Salah', 'FanPlay', 'ECOSTP', 'Coralogix', 'Equiwatt',
#        'Reliance Retail Ventures', 'Zhangmen', 'AgroWave',
#        'Sapio Analytics', 'Taimei', 'Avanse Financial Services',
#        'Industry Buying', 'Hopscotch', 'Pristyn Care', 'WoodenStreet',
#        'ACKO', 'Farmers Fresh Zone', 'Invento', 'Infurnia',
#        "AnalytIQSports's SuperCric", 'Snowflake', 'GenieTalk',
#        'Classplus', 'Mobile Premier League', 'Fourth Partner Energy',
#        'Flipkart', 'Vivriti Capital', 'InsuranceDekho', 'BestDoc',
#        'Byju’s', 'Melorra', 'Reliance', 'Inflexor Ventures', 'Pandorum',
#        'SpeakIn', 'LetsUp', 'Newsreach', 'Dream11', 'JetSynthesys',
#        'Vesta Space Technology', 'Dozee', 'Rebel Foods', 'Ketto',
#        'Suryoday', 'SucSEED', 'Strata', '3one4 Capital', 'WE-Hub',
#        'Vicara', 'Gaana', 'EM3 Agri', 'Odwen', 'Fasal', 'Trukky',
#        'BankBazaar', 'Specsmakers', 'Grinntech', 'CreditMantri',
#        'Chai Waale', 'Deepsync', 'ConnectedH', 'QShala', 'Pitstop',
#        'Customfit ai', 'Nirmata', 'Oga Fit', 'ShipsKart', 'SquadStack',
#        'Financepeer', 'Cashify', 'Etrio', 'Codeyoung', 'StayQrious',
#        'Sunstone Eduversity', 'Infilect', 'MobiGarage', 'Samunnati',
#        'WeInnovate Biosolutions', 'Yummy Corp', 'Clairvolex', 'Assiduus',
#        'Brinton', 'AFK Gaming', 'Infarm', 'Zuper', 'Origa',
#        'GullyBuy Software', 'Recordent', 'Penny', 'Onsitego', 'Precily',
#        'SmartClean', 'ClanConnect', 'Servify', 'ShareChat', 'Rephrase.ai',
#        'EkAnek', 'Cub McPaws', 'Zimyo', 'PumPumPum', 'Burgerama',
#        'Moms Co', 'DillyHub', 'FPL Technologies', 'FITTR', 'Illumnus',
#        'CashKaro', 'Newton School', 'Airmeet', 'Observe ai', 'InCred',
#        'Toppr', 'CarTrade', 'LEAD School', 'Lido Learning', 'Apna.co',
#        'Quintype Technologies', 'Dunzo', 'Entropik', 'Livspace', 'WinZO',
#        'SenseHawk', 'Eloelo', 'Aibono', 'BuildPan', 'Homelane', 'MyGlamm',
#        'Aviom', 'Flinto', 'WayCool', 'YAP', 'Big Bang Boom Solutions',
#        'GUVI', 'BluSmart', 'Cell Propulsion', 'Spoonshot', 'Pulse',
#        'Groww', 'i3 Systems', 'SOAL', 'OckyPocky', 'Hippo Video',
#        'Hasura', 'Qapita', 'Sunday', 'Gamezop', 'Phool.co',
#        'Chiratae Ventures', 'MedLife', 'IDfy', 'Bira91', 'Max wholesale',
#        'Craftsvilla', 'MechMocha', 'Mindhouse', 'DeepSync', 'Eruditus',
#        'Gradeup', 'Tracxn', 'Purple Style Labs', 'ProPhysio',
#        'Flickstree', 'Settl', 'Fanspole', 'Sarva', 'Univ.ai', 'PurohitJi',
#        'CredoLab', 'Brick&Bolt', '6Degree', 'Exprs', 'Bikayi',
#        'Virtual Forest', 'The Health company', 'TrulyMadly Matchmakers',
#        'TrueFan', 'Avail Finance', 'The Money Club', 'Virohan', 'OneCode',
#        'Verloop.io', 'Otipy', 'Evage', 'Trell', 'Captain Fresh', 'Pixxel',
#        'Habbit Health', 'SmarterBiz', 'Able Jobs', 'Vieroots',
#        'Stack Finance', 'Masai School', 'Mitron', 'Daalchini',
#        'Suno India', 'LendingKart', 'Text Mercato', 'Eden Smart Homes',
#        'GrayQuest', 'BigHaat', 'CityCash', 'HomeLane', 'HungerBox',
#        'DaveAI', 'Eduvanz', 'DocSumo', 'CUSMAT', 'Chingari',
#        'Data Sutram', 'Wobot Intelligence', 'DrinkPrime', 'Infeedo',
#        'Probus Smart Things', 'CrowdPouch', 'Hevo', 'BigSpoon Foods',
#        'DatStop', 'IPHM Services', 'Wellcure', 'VilCart', 'Firescore',
#        'BulBul', 'Pickright Technologies', 'Muse Wearables',
#        'SATYA Microcapital', 'WYN Studio', 'Entri', 'Snack Amor',
#        'MPowered', 'Leap Club', 'Gigforce', 'Vegrow', 'Finn', 'Bijnis',
#        'iNurture', 'StyleDotMe', 'Ripsey', 'ThriveFNC', 'Vedantu',
#        'Magicpin', 'Procol', 'Yumlane', 'Crio', 'Openapp',
#        'uFony Services Pvt ltd', 'Protinus Fashion Networking Pvt Ltd',
#        'Uable', 'ParkSmart', 'IncNut Digital', 'GigIndia', 'Specsmaker',
#        'Piggy Ride', 'NOTO', 'Cuemath', 'Cars24', 'Earth Energy EV',
#        'Green Cure', 'Blue Sky Analytics', 'Edhusk', 'Decentro',
#        'Zolostays', 'Frontier Markets', 'Brainwired', 'Aye Finance',
#        'Paper Boat', 'Ken42', 'Forbidden Foods', 'Universal Sportsbiz',
#        'Gobbly', 'Aerostrovilos', 'Bulk MRO', 'Inspektlabs', 'Zetwerk',
#        'ChitMonks', 'Walrus', 'Arth Designbuild', 'goDutch', 'Rusk Media',
#        'Bold Care', 'Samosa Party', 'High Street Essentials', 'Fullife',
#        'Oziva', 'Aether Biomedical', '91springboard', 'Yulu',
#        'Milkbasket', 'MergerDomo', 'GoMechanic', 'Milk Mantra', 'Myglamm',
#        'Drishti Technologies', 'Instasolv', 'GoldenPi', 'Peppermint',
#        'Jai Kisan', 'Agro2o', 'LetsTransport', 'GabbarDeals',
#        'Crimson Healthcare', 'Biomoneta', 'Edvizo', 'Drum Food',
#        'Innoviti', 'Jiffy ai', 'Postman', 'F5', 'Waycool',
#        'Myelin Foundry', 'Ameliorate Biotech', 'Hapramp', 'MyKaam',
#        'HealthPlix', 'YoloBus', 'iNurture Education', 'Pocket52',
#        'QuaQua', 'Crofarm', 'Timios', 'Wooden Street', 'Rentmojo',
#        'Credgencies', 'Knorish', 'Vahak', 'Nutrova', 'Cube Wealth',
#        'IVF Access', 'Hoi Foods', 'Ola Financial Services', 'Awifs',
#        'Swiflearn', 'Remedo', 'Blowhorn', 'Toch', 'Gram Cover',
#        'Coin DCX', 'HomeCapital', 'Euler Motors', 'Riskcovry',
#        'NWNT (No Worry No Tension Healthcare)', 'Voicezen',
#        'Credit Mantri', 'Xtracap', 'Vakilsearch', 'Khatabook',
#        'Indian School Finance Company', 'Juicy Chemistry', 'DeepTek',
#        'Stepathlon Lifestyle', 'Sindhuja Microcredit',
#        'Tesco Charge Zone', 'Intello Labs', 'SirionLabs', 'GroCurv',
#        'Refrens', 'Spyne', 'Docsapp', 'Phable', 'Generic Aadhaar', 'Nium',
#        'Mintoak', 'VestSpace', 'Blackbuck', 'Vernacular ai', 'Clover',
#        'Varthana', 'Codeninja', 'MetaMerphoSys', 'Rooter', 'Aker Foods',
#        'Sascan Meditech pvt ltd', 'DailyHunt', 'Pratilipi',
#        'Biryani By Kilo', 'Consure Medical', 'Tessol', 'News Reach',
#        'RoomSoom', 'Pedagogy', 'Medlife', 'Qin1', 'MYSUN', 'ShopX',
#        'NewsBytes', 'Wagonfly', 'Convosight', 'Fittr', 'AsknBid',
#        'Finaureus Technologies', 'Daily Ninja',
#        'Guvi Geek Network Pvt Ltd', 'LoadShare', 'Indusface', 'DMI Group',
#        'Spintly', 'Credr', 'Bijak', 'Bugworks', 'Yap', 'UzhavarBumi',
#        'Tattva', 'Pariksha', 'NoBroker', 'Box8', 'Capital Float',
#        'ITILITE', 'Morning Context', 'Aavenir', 'Savvy Co op', 'BLive',
#        'Yellow Messenger', 'Ewar', 'Setu', 'Wellthy Therapeutics',
#        'Locale ai', 'FarEye', 'Porter', 'SugarBox', 'Big Basket', 'Amica',
#        'Fingerlix', 'Plop', 'Zupee', 'DeHaat', 'Swiggy', 'Akna Medical',
#        'RaRa Delivery', 'JusPay', 'Obviously AI', 'Fingpay', 'Recko',
#        'Furlenco', 'Mera Cashier', 'Camp K12', 'MedGenome', 'Samadhan',
#        'SaScan', 'CureFit', 'Nimesa', 'Design X', 'Driftly Electric',
#        'Imstrong', 'Rupifi', 'SnackAmor', 'Zealthy', 'NuNu TV', 'QTalk',
#        'Shadez', 'Excess2Sell', 'Stanplus', 'Univariety', 'Peel Works',
#        'CoreStack', 'Agnikul', 'Fintso', 'Smart Coin', 'ZunRoof',
#        'Shop101', 'OM Bhakti', 'Lal10', 'Anaxee Digital Runner',
#        'CollegeKhabri', 'Ola Electric', 'Multi Living', 'FamPay',
#        'UnboxRobotics Labs', 'Karbon Card', 'Innerchef', 'Epigamia',
#        'StyleNook', 'Callido Learning', 'Soxytoes', 'Salesken',
#        'Leap Finance', 'Sleepy Owl', 'Tricog', 'GogoBus',
#        'Spaciya Consultants', 'Bounce', 'Neeman', 'Chqbook', 'SMEcorner',
#        'Oda Class', 'Spinny', 'goStops', 'Umeed Housing', 'Vogo',
#        'Flick Stree', 'Qure ai', 'MinionLabs', 'Josh Talks',
#        'PhoneParLoan', 'RailYatri', 'Pepper', 'iMerit', 'BharatPe',
#        'Invideo', 'AvalonMeta', 'Near Store', 'ElecTorq',
#        'Prayaan Capital', 'Sanfe', 'Go Desi', 'Whatfix', 'Zvesta',
#        'Digit Insurance', 'Yolo', 'SmartVizX', 'MaxWholesale',
#        'Carbon Clean', 'Genius Corner', 'PlanetSpark', 'CamCom', 'Simsim',
#        'Shuttl', 'HooLiv', 'ClassMonitor', 'Friyey', 'Oga', 'CYFIRMA',
#        'Paytm money', 'Nova Credit', 'CodingNinjas', 'HempStreet',
#        'MoEngage', 'Chaayos', 'PetPooja', 'Altor', 'Pepperfry',
#        'FirstCry', 'Byju', 'WorkIndia', 'Qyuki', 'Leap India', 'Picxy',
#        'NEETprep', 'Dot Pvt. Ltd', 'Kuku FM', 'SuperMoney', 'AlphaVector',
#        'Fox Capital', 'Tribe Theory', 'Embibe', 'Oye! Rickshaw',
#        'Seal Professional', 'Sprinng Foods', '1MG', 'Aagey', 'Doubtnut',
#        'AdonMo', 'Kisan Network', 'Unotech', 'CureSkin', 'WizKlub',
#        'Interviewbit', 'MoneyTap', 'Uniplatform Tech', 'INdwealth',
#        'Bizongo', 'AppsFlyer', 'Konfinity', 'Nupay', 'LogiNext',
#        'Samosa Singh', 'Crysta', 'Eupheus Learning', 'Park+', 'Goodmylk',
#        'SmartKarrot', 'Skylo', 'Tea Trunk', 'Zoomcar', 'Samya AI',
#        'Kristal AI', 'Invento Robotics', 'Sabse Sasta Dukaan',
#        'Fitphilia', 'Medicus', 'Monech', 'Teach Us', 'Dealberg',
#        'Phenom People', 'Extra Edge', 'Capital Quotient', 'Karfa',
#        'Zinier', 'ProEves', 'Toddle', 'Aesthetic Nutrition',
#        'TechnifyBiz', 'Wysh', 'Keito', 'Klub', 'Aadhar', 'IncubateHub',
#        'Rage Coffee', 'Skilancer', 'Harappa Education', 'Rheo',
#        'Axio Biosolutions', 'Techbooze', 'PayMart', 'Testbook',
#        'FabAlley', 'HaikuJAM', 'Mamaearth', 'Rentomojo', 'Generico',
#        'HighRadius', 'Chai Kings', 'Shiksha', 'Super Surfaces', 'Quicko',
#        'Satin Creditcare', 'XpressBees', 'FarmERP', 'Wealth Bucket',
#        'Fashor', 'Leverage Edu', 'EpiFi', 'Purplle', 'Pando'],
#       dtype=object)

# %%
# Total Number of empty rows in the Founded Column 
df20['Company/Brand'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Founded culumn

# %%
# confirming the Founded column 
df20['Founded'].unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', nan, '1999', '1994', '2005', '1973', '-',
#        '2002', '2004', '2001'], dtype=object)

# %%
#checking summary statistics of the Founded column
df20['Founded'].describe()
# Out:
# count      843
# unique      27
# top       2015
# freq       136
# Name: Founded, dtype: object

# %%
# replace all dash(-) and empty spaces IN THE Founded column with NaN
df20["Founded"] = df20["Founded"].replace(["-", "", "nan"], np.nan)
df20["Founded"].unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', nan, '1999', '1994', '2005', '1973',
#        '2002', '2004', '2001'], dtype=object)

# %%
df20['Founded'].isnull().sum()
# Out:
# 213

# %% [markdown]
# ## HeadQuarter Column

# %%
# Check the unique items in the HeadQuarter culumn to know the overview of the column
df20['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli, Tamilnadu', 'Thane', nan,
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Jaipur, Rajastan', 'Delhi', 'Frisco, Texas, United States',
#        'California', 'Dhingsara, Haryana', 'New York, United States',
#        'Patna', 'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Chandigarh', 'Warangal',
#        'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Banglore', 'Coimbatore', 'Bengaluru'],
#       dtype=object)

# %%
# Standardize city names
df20["HeadQuarter"] = df20["HeadQuarter"].str.replace("Bangalore|Bengaluru", "Bangalore")
df20["HeadQuarter"] = df20["HeadQuarter"].str.replace("Hyderebad", "Hyderabad")
df20["HeadQuarter"] = df20["HeadQuarter"].str.replace("New Delhi|Delhi", "New Delhi")
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\659402701.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df20["HeadQuarter"] = df20["HeadQuarter"].str.replace("Bangalore|Bengaluru", "Bangalore")
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\659402701.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df20["HeadQuarter"] = df20["HeadQuarter"].str.replace("New Delhi|Delhi", "New Delhi")

# %%
# Handling missing values
df20["HeadQuarter"] = df20["HeadQuarter"].replace(["", "-", "nan"], np.nan)

# %%
df20["HeadQuarter"].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli, Tamilnadu', 'Thane', nan,
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Jaipur, Rajastan', 'Frisco, Texas, United States', 'California',
#        'Dhingsara, Haryana', 'New York, United States', 'Patna',
#        'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Chandigarh', 'Warangal',
#        'Odisha', 'Bihar', 'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal',
#        'Banglore', 'Coimbatore'], dtype=object)

# %% [markdown]
# ## Sector Column

# %%
df20["Sector"].unique()
# Out:
# array(['AgriTech', 'EdTech', 'Hygiene management', 'Escrow',
#        'Networking platform', 'FinTech', 'Crowdsourcing',
#        'Food & Bevarages', 'HealthTech', 'Fashion startup',
#        'Food Industry', 'Food Delivery', 'Virtual auditing startup',
#        'E-commerce', 'Gaming', 'Work fulfillment', 'AI startup',
#        'Telecommunication', 'Logistics', 'Tech Startup', 'Sports',
#        'Retail', 'Medtech', 'Tyre management', 'Cloud company',
#        'Software company', 'Venture capitalist', 'Renewable player',
#        'IoT startup', 'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Hospitality', 'Digital Media', 'Dairy startup',
#        'Content management', 'Spacetech', 'Transportation',
#        'Trading platform', 'AI Company', 'Photonics startup',
#        'Entertainment', 'Cosmetics', 'Scanning app', 'Skincare startup',
#        'Food and Beverages', 'Biotechnology company', 'FoodTech',
#        'Proptech', 'CleanTech', 'Fitness startup', 'Healthcare',
#        'PaaS startup', 'Beverages', 'Social Media', 'Automobiles',
#        'Deeptech', 'EV startup', 'AR/VR startup', 'Recruitment startup',
#        'QSR startup', 'Video platform', 'Edtech', 'Fertility tech',
#        'Luxury car startup', 'FM', 'Food', 'Nutrition sector',
#        'Tech platform', 'Video', 'Retail Tech', 'HeathTech',
#        'Sles and marketing', 'LegalTech', 'Car Service',
#        'Bike marketplace', 'Agri tech', 'Reatil startup', 'AR platform',
#        'Consumer Goods', 'Content marketplace', 'Interior Design',
#        'Rental space', 'Soil-Tech', 'Ayurveda tech',
#        'Packaging solution startup', 'Cleantech', 'Sanitation solutions',
#        'HealthCare', 'Home Design', 'InsureTech', 'AI Startup',
#        'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Fashion', 'Finance',
#        'Venture capital', 'Entreprenurship', 'Food devlivery',
#        'Warehouse', 'Online financial service', 'Eyeglasses',
#        'Battery design', 'Online credit management startup', 'Beverage',
#        'TravelTech', 'Agriculture', 'Startup laboratory',
#        'Personal care startup', 'Customer service company',
#        'SaaS\xa0\xa0startup', 'Marketing startup', 'Service industry',
#        'Social media', 'AI', 'Jewellery', 'AR startup', 'HR Tech startup',
#        'Automotive Startup', 'Food Startup', 'EdTech Startup',
#        'Car Trade', 'EdtTech', 'Manufacturing', 'AI Platform',
#        'Automation', 'Solar SaaS', 'WL & RAC protection',
#        'Social commerce', 'Home interior services', 'Agritech startup',
#        'API platform', 'Deep Tech', 'Electricity', 'Automotive company',
#        'FMCG', 'Insurance Tech', 'Video personalization',
#        'Software Company', 'Biomaterial startup', 'Health', 'IT',
#        'Craft Beer', 'Healthtech', 'Education', 'Investment',
#        'Linguistic Spiritual', 'Construction', 'Battery manufacturer',
#        'Nano Distribution Network', 'AI health', 'Dating app', 'Media',
#        'Fintech', 'Healthcare/Edtech', 'Social Commerce',
#        'Agritech/Commerce', 'Mobility tech', 'Social e-commerce',
#        'Food & Logistics', 'SpaceTech', 'Nutrition Tech', 'HR', 'IoT',
#        nan, 'Agritech', 'Interior design', 'Foodtech', 'AR/VR',
#        'Appliance', 'HR tech', 'Food tech', 'Mental Health', 'Ecommerce',
#        'Solar Solution', 'SaaS', 'Automobile', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages', 'Automotive',
#        'B2B', 'Defense tech', 'Marketplace', 'Construction tech',
#        'Nutrition', 'Coworking', 'Micro-mobiity', 'Auto-tech', 'Beauty',
#        'Robotics', 'Yoga & wellness', 'Logitech', 'Med Tech',
#        'Life sciences', 'Retail Aggregator', 'Deep Tech AI', 'Biotech',
#        'Blockchain', 'HrTech', 'Mobility/Transport', 'Travel', 'Rental',
#        'AI & Debt', 'SaaS/Edtech', 'Transport', 'Co-working', 'Insurtech',
#        'Cryptocurrency', 'Automotive tech', 'Legal', 'Fitness', 'EV',
#        'Supply chain, Agritech', 'Pharma', 'Insurance technology',
#        'Foodtech & Logistics', 'Housing', 'Pharmaceutical',
#        'Data Analytics', 'Investment Tech', 'Financial Services',
#        'Biopharma', 'Dairy', 'Beauty & wellness', 'Travel & SaaS',
#        'Tourism & EV', 'Media Tech', 'Location Analytics', 'E store',
#        'Data Science', 'Insurance', 'Health and Fitness', 'Technology',
#        'Interior & decor', 'eMobility', 'Automation tech',
#        'Media & Networking', 'E-market', 'AI & Data science',
#        'Travel tech', 'Automotive and Rentals', 'E-tail', 'Accomodation',
#        'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'Marketing',
#        'E tailor', 'E-mobility', 'Ad-tech', 'Neo-banking',
#        'Transport Automation', 'Techonology', 'Transport & Rentals',
#        'AI Robotics', 'Preschool Daycare', 'Food diet', 'B2B Agritech',
#        'E-connect', 'Tech hub', 'Consultancy', 'Pharmacy', 'Deisgning',
#        'Taxation', 'Automobile Technology'], dtype=object)

# %%
# Loop to get the values in the unique values in the Sector column

Sector_name_list = df20['Sector'].tolist()

unique_Sector = []
for Sector in Sector_name_list:
    if Sector not in unique_Sector:
        unique_Sector.append(Sector)

for Sector in unique_Sector:
    print(Sector)
# Out:
# AgriTech
# EdTech
# Hygiene management
# Escrow
# Networking platform
# FinTech
# Crowdsourcing
# Food & Bevarages
# HealthTech
# Fashion startup
# Food Industry
# Food Delivery
# Virtual auditing startup
# E-commerce
# Gaming
# Work fulfillment
# AI startup
# Telecommunication
# Logistics
# Tech Startup
# Sports
# Retail
# Medtech
# Tyre management
# Cloud company
# Software company
# Venture capitalist
# Renewable player
# IoT startup
# SaaS startup
# Aero company
# Marketing company
# Retail startup
# Co-working Startup
# Finance company
# Tech company
# Solar Monitoring Company
# Video sharing platform
# Gaming startup
# Video streaming platform
# Consumer appliances
# Blockchain startup
# Conversational AI platform
# Real Estate
# SaaS platform
# AI platform
# Fusion beverages
# HR Tech
# Job portal
# Hospitality
# Digital Media
# Dairy startup
# Content management
# Spacetech
# Transportation
# Trading platform
# AI Company
# Photonics startup
# Entertainment
# Cosmetics
# Scanning app
# Skincare startup
# Food and Beverages
# Biotechnology company
# FoodTech
# Proptech
# CleanTech
# Fitness startup
# Healthcare
# PaaS startup
# Beverages
# Social Media
# Automobiles
# Deeptech
# EV startup
# AR/VR startup
# Recruitment startup
# QSR startup
# Video platform
# Edtech
# Fertility tech
# Luxury car startup
# FM
# Food
# Nutrition sector
# Tech platform
# Video
# Retail Tech
# HeathTech
# Sles and marketing
# LegalTech
# Car Service
# Bike marketplace
# Agri tech
# Reatil startup
# AR platform
# Consumer Goods
# Content marketplace
# Interior Design
# Rental space
# Soil-Tech
# Ayurveda tech
# Packaging solution startup
# Cleantech
# Sanitation solutions
# HealthCare
# Home Design
# InsureTech
# AI Startup
# Solar solution
# Jewellery startup
# Multinational conglomerate company
# Deeptech startup
# Social Network
# Publication
# Tech
# Fashion
# Finance
# Venture capital
# Entreprenurship
# Food devlivery
# Warehouse
# Online financial service
# Eyeglasses
# Battery design
# Online credit management startup
# Beverage
# TravelTech
# Agriculture
# Startup laboratory
# Personal care startup
# Customer service company
# SaaS  startup
# Marketing startup
# Service industry
# Social media
# AI
# Jewellery
# AR startup
# HR Tech startup
# Automotive Startup
# Food Startup
# EdTech Startup
# Car Trade
# EdtTech
# Manufacturing
# AI Platform
# Automation
# Solar SaaS
# WL & RAC protection
# Social commerce
# Home interior services
# Agritech startup
# API platform
# Deep Tech
# Electricity
# Automotive company
# FMCG
# Insurance Tech
# Video personalization
# Software Company
# Biomaterial startup
# Health
# IT
# Craft Beer
# Healthtech
# Education
# Investment
# Linguistic Spiritual
# Construction
# Battery manufacturer
# Nano Distribution Network
# AI health
# Dating app
# Media
# Fintech
# Healthcare/Edtech
# Social Commerce
# Agritech/Commerce
# Mobility tech
# Social e-commerce
# Food & Logistics
# SpaceTech
# Nutrition Tech
# HR
# IoT
# nan
# Agritech
# Interior design
# Foodtech
# AR/VR
# Appliance
# HR tech
# Food tech
# Mental Health
# Ecommerce
# Solar Solution
# SaaS
# Automobile
# B2B marketplace
# Fashion Tech
# Nutrition tech
# Health & Wellness
# Cloud Kitchen
# IoT/Automobile
# Eye Wear
# Digital tech
# Data Intelligence
# Co-living
# Food & Beverages
# Automotive
# B2B
# Defense tech
# Marketplace
# Construction tech
# Nutrition
# Coworking
# Micro-mobiity
# Auto-tech
# Beauty
# Robotics
# Yoga & wellness
# Logitech
# Med Tech
# Life sciences
# Retail Aggregator
# Deep Tech AI
# Biotech
# Blockchain
# HrTech
# Mobility/Transport
# Travel
# Rental
# AI & Debt
# SaaS/Edtech
# Transport
# Co-working
# Insurtech
# Cryptocurrency
# Automotive tech
# Legal
# Fitness
# EV
# Supply chain, Agritech
# Pharma
# Insurance technology
# Foodtech & Logistics
# Housing
# Pharmaceutical
# Data Analytics
# Investment Tech
# Financial Services
# Biopharma
# Dairy
# Beauty & wellness
# Travel & SaaS
# Tourism & EV
# Media Tech
# Location Analytics
# E store
# Data Science
# Insurance
# Health and Fitness
# Technology
# Interior & decor
# eMobility
# Automation tech
# Media & Networking
# E-market
# AI & Data science
# Travel tech
# Automotive and Rentals
# E-tail
# Accomodation
# AI & Media
# Machine Learning
# Content Marktplace
# Visual Media
# Hygiene
# VR & SaaS
# Sales & Services
# AI & Deep learning
# Housing & Rentals
# Estore
# Marketing
# E tailor
# E-mobility
# Ad-tech
# Neo-banking
# Transport Automation
# Techonology
# Transport & Rentals
# AI Robotics
# Preschool Daycare
# Food diet
# B2B Agritech
# E-connect
# Tech hub
# Consultancy
# Pharmacy
# Deisgning
# Taxation
# Automobile Technology

# %%
# Merge similar categories and  Group related sectors
Agriculture = ['AgriTech', 'agri tech']

Marketing = ['Brand Marketing', 'Market Research', 'Advertising', 'Digital Marketing']

Technology = ['AI Company', 'AI platform', 'AI', 'AI Startup', 'AI Platform', 'AI & Debt', 'AI & Data science', 'AI & Deep learning', 'AI Robotics','EdTech', 'Hygiene management', 'Escrow', 'Networking platform', 'FinTech', 'Crowdsourcing', 'AI startup', 'Telecommunication', 'Tech Startup', 'Retail Tech', 'AR/VR startup', 'QSR startup', 'Edtech', 'Fashion Tech', 'HR Tech startup', 'Automotive Startup', 'EdTech Startup', 'Manufacturing', 'Automation', 'AI Platform', 'Solar SaaS', 'AI Company', 'AI Startup', 'Deeptech', 'AR/VR startup', 'AI', 'AR startup', 'AI health', 'AI Platform', 'Deep Tech', 'AI & Deep learning', 'Technology', 'AI & Data science', 'E-connect', 'Consultancy', 'Deisgning']

Data_Science_Analytics = ['Data Analytics', 'Data Science', 'Data Intelligence', 'Location Analytics']

Legal = ['LegalTech', 'Legal']

Bank_Fin = ['Finance company','Neo-banking', 'Venture capitalist', 'Finance', 'Venture capital', 'Taxations']

Accounting = ['Financial Services'] 

Insurance = ['InsureTech', 'Insurance Tech', 'Insurance', 'Insurance technology']

Food = ['Food & Bevarages', 'Food Industry', 'Food Delivery', 'Food and Beverages', 'FoodTech', 'Fusion beverages', 'Food', 'FM', 'Food devlivery', 'Beverage', 'Food & Logistics', 'Cloud Kitchen', 'Food tech', 'Nutrition', 'Coworking', 'Food & Beverages', 'Food & Beverages', 'Food & Beverages', 'Food & Beverages', 'Food & Beverages', 'Food & Beverages', 'Food & Beverages', 'Food & Beverages']

Transport = [ 'Transportation', 'Automobiles', 'TransportTech', 'Auto-tech', 'Mobility/Transport', 'Transport', 'Transport', 'Transport & Rentals', 'Transport Automation', 'Transport & Rentals', 'E-mobility', 'Transport & Rentals']

Automotive = ['Automobiles', 'Automotive Startup', 'Automotive company', 'Automotive Startup', 'Automobile', 'EV startup', 'AR/VR startup', 'EV startup', 'EV', 'Automotive tech', 'Automotive and Rentals', 'Automobile Technology']

Energy = ['Renewable player', 'Solar Monitoring Company', 'Solar solution', 'Solar Solution', 'Solar solution', 'Solar SaaS', 'Solar Solution', 'Solar Solution', 'Energy', 'Electricity']

Health = ['Pharmaceuticals', 'Pharmaceutical', 'Biopharma','HealthTech', 'Medtech', 'Healthcare', 'HealthCare', 'Health', 'Healthtech', 'Mental Health', 'Health & Wellness', 'AI health', 'Health', 'Healthcare/Edtech', 'Health', 'Healthcare', 'Health and Fitness']

Sport_Fit= ['Sports', 'Fitness startup', 'Fitness', 'Sports']

Manufacturing = ['Tyre management', 'Cloud company', 'Software company', 'Manufacturing', 'Automotive company', 'Manufacturing']

Beauty = ['Cosmetics', 'Skincare startup', 'Beauty', 'Beauty & wellness']

Info_media = ['Media & Networking','Entertainment','Digital Media','Video sharing platform', 'Gaming startup', 'Video streaming platform', 'Social Media', 'Media', 'Publication', 'Media Tech', 'Visual Media']

Services = ['Logistics','Retail', 'Retail startup', 'Co-working Startup', 'Retail startup', 'FMCG', 'Bike marketplace', 'Craft Beer', 'Customer service company', 'Marketing company', 'Service industry', 'Home interior services', 'Customer service company', 'Sles and marketing', 'Services', 'Services', 'Services', 'Preschool Daycare']

Government = ['Government']

Tourism = ['Tourism & EV', 'Tourism', 'Tourism', 'Tourism']
    
Events = ['Event', 'Events']

Edu = ['EdTech', 'EdTech', 'EdTech Startup']

Hospitality = ['Hospitality']

Digital_Platform = ['E-commerce', 'Retail Aggregator', 'eMobility', 'Estore', 'E-tail', 'E-store']

Fashion = ['Fashion startup', 'Fashion', 'Fashion Tech']

Housing =['Real Estate']

B2B = ['B2B marketplace', 'B2B Agritech']

Construction = ['Construction', 'Construction tech']

nan = ['nan', 'Nan', 'NaN', None]

# %%
# Write function to put values into new categories
def new_cat(Sector):
    if Sector in Marketing:
        return 'Marketing'
    elif Sector in Construction:
        return 'Construction'
    elif Sector in Agriculture:
        return 'Agriculture'
    elif Sector in Bank_Fin:
        return 'Banking & Finance'
    elif Sector in Accounting:
        return 'Accounting'
    elif Sector in Insurance:
        return 'Insurance'
    elif Sector in Technology:
        return 'Technology'
    elif Sector in Food:
        return 'Food & Beverages'
    elif Sector in Transport :
        return 'Transport'
    elif Sector in Energy:
        return 'Energy'
    elif Sector in Health:
        return 'Health'
    elif Sector in Sport_Fit :
        return 'Sport & Fitness'
    elif Sector in Manufacturing:
        return 'Manufacturing'
    elif Sector in Beauty:
        return 'Beauty'
    elif Sector in Info_media:
        return 'Media & Entertainment'
    elif Sector in Services:
        return 'Services'
    elif Sector in Government:
        return 'Government'
    elif Sector in Tourism:
        return 'Tourism'
    elif Sector in Events:
        return 'Events'
    elif Sector in Edu:
        return 'Education'
    elif Sector in nan:
        return 'NaN'
    elif Sector in Hospitality:
        return 'Hospitality'
    elif Sector in Fashion:
        return 'Fashion'
    elif Sector in B2B:
        return 'B2B'
    elif Sector in Music:
        return 'Music'
    elif Sector in Housing:
        return 'Housing'
    elif Sector in Automotive:
        return 'Automotive'
    elif Sector in Digital_Platform:
        return 'Digital_Platform'
    elif Sector in Legal:
        return 'Legal'
    elif Sector in Data_Science_Analytics:
        return 'Data_Science_ Analytics'

# %%
df20['Sector'] = df20['Sector'].apply(new_cat)

# %%
df20['Sector'].isnull().sum()
# Out:
# 435

# %%
#Confirm changes 
df20['Sector'].unique()
# Out:
# array(['Agriculture', 'Technology', 'Food & Beverages', 'Health',
#        'Fashion', None, 'Digital_Platform', 'Services', 'Sport & Fitness',
#        'Manufacturing', 'Banking & Finance', 'Energy',
#        'Media & Entertainment', 'Housing', 'Hospitality', 'Transport',
#        'Beauty', 'Automotive', 'Legal', 'Insurance', 'Construction',
#        'B2B', 'Data_Science_ Analytics', 'Accounting', 'Tourism'],
#       dtype=object)

# %% [markdown]
# ## Founders column

# %%
df20.head()
# Out:
#   Company/Brand Founded HeadQuarter       Sector  \
# 0    Aqgromalin    2019     Chennai  Agriculture
# 1      Krayonnz    2019   Bangalore   Technology
# 2  PadCare Labs    2018        Pune   Technology
# 3         NCOME    2020   New Delhi   Technology
# 4    Gramophone    2016      Indore  Agriculture
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
df20["Founders"].unique()
# Out:
# array(['Prasanna Manogaran, Bharani C L',
#        'Saurabh Dixit, Gurudutt Upadhyay', 'Ajinkya Dhariya',
#        'Ritesh Tiwari',
#        'Ashish Rajan Singh, Harshit Gupta, Nishant Mahatre, Tauseef Khan',
#        'Rubal Chib, Dr Srishti Batra', 'Ajay Sakhamuri',
#        'Shawrya Mehrotra', 'Amar Prabhu, Ashwin Soni, Sumit Maniyar',
#        'Aditya Shirole, Sahil Sharma', 'Meghana Narayan',
#        'Arjun Kumar, Arun Kumar, Sidharth Gurjar', 'Gayatri Jolly',
#        'Ankur Jain', 'Akil Sethuraman, Anup Gopinath, Rachna Rao',
#        'Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah',
#        'Miran Junaidi, Saurabh Ghanekar, Sourav Sanyal',
#        'Gautam Kapoor, Saahil Goel, Vishesh Khurana', 'Amrish Rau',
#        'Prashant Agarwal', 'Parth Chadha, Rahul Singh',
#        'Vikrant Varshney', 'Sujit Bangar',
#        'Annanya Sarthak, Gurpreet Singh, Praveen Sah', 'Karanpal Singh',
#        'Neeraj Khandelwal, Sumit Gupta', 'Naveen Tewari',
#        'Virendra Gupta', 'Priyam Saraswat',
#        'Kapil Bharati, Mohit Tandon, Sahil Barua, Suraj Saharan',
#        'Chattanathan Devarajan, Prasanna Rao, Anand Chandra',
#        'Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder',
#        'Burzin Engineer, Rahul Chari, Sameer Nigam', 'Nirmal Shah',
#        'Chetan Indap, Sunny Sharma, Deepanti Kavi', 'Suhail Narain',
#        'Ronak Sarda', 'Vinayak, Kshitij Abhishek, Apoorv Sadana',
#        'Ankit Garg, Chaitanya Ramalingegowda', 'Dr Prashant Soma',
#        'Tikam Jain', 'Sundeep Mohindru', 'Shivakumar Ganesan',
#        'Adarsh Kumar, Rupesh Mishra', 'Mihir Jha', 'Shivanand N',
#        'Anand Dalmia, Ramganesh Iyer, Subramanya S.V., Subramanya Venkat',
#        'Anoop Gautam', 'Raunak Bhinge', 'Ajay Tiwari, Sainadh Duvvuru',
#        'Mayank Kale, Ryan Singh',
#        'Anurag Meena, Nikunj Malpani, Pratik Lodha',
#        'Satya Chakravarthy, Pranjal Mehta',
#        'Divyanshu Damani, Mohammad Hasan',
#        'Charak Almast, Aastha Almast, Mani Dev Gyawali',
#        'Bipin Singh, Upasana Taku', 'Sumit Sanjay Singare',
#        'Monnappa Bayavanda, Prashant Reddy, Ravindra M.K, Ravindra M.K., Shesh Paplikar, Shesh Paplikar, Sridhar Venkataraman',
#        'Deepak Garg, Gazal Kalra', 'KSHITIJ Puri, Shalabh Singhal',
#        'Vivek Iyer', 'Manjunatha T N, Shilpa Gopalaiah', 'Layak Singh',
#        'Puneet Singh Jaggi, Sanjay Bhasin, Ram Menon', 'Nandini Sankar',
#        'Tanmai Paul, Varun Saxena',
#        'Abhas Saroha, Oliver Jones, Oliver Jones', 'Shan Kadavil',
#        'Shivam Varshney, Alok Chawla', 'Manoj Meena, Sibabrata Das',
#        'Sankar Bora, Sourjyendu Medda, Vineet Rao',
#        'Anugrah Shrivastava, Rohan Gupta, Vasanth Kamath', 'Manan Khurma',
#        'Soham Thacker, Valay Patel, Varun Gajjar', 'Kalyan Sivasailam',
#        'Harsh Rajat, Richa Joshi',
#        'Biplab Chakraborty, Sandipan Chattopadhyay, Sandipan Mandal, Tapan Barman',
#        'Palani Rajan', 'Karthik Jayaraman, Sanjay Dasari',
#        'Aaditya Sharda, Souvik Sengupta', 'Sanjeev Bikhchandani',
#        'Neha Kant, Pankaj Vermani', 'Satyam Baranwal, Vivek Prakash',
#        'Kunal Shah', 'Brahmanad, Ramakrishna Nishtala',
#        'Nitesh Agrawal, Om Prakash', 'Rohit Pande, Shikhar Sachan',
#        'Prabhat Sahu', 'Ankit Ratan, Ankur Pandey, Arpit Ratan',
#        'Amit Shrivastava, Sumeet Verma', 'Bhavik Rathod, Tripti Ahuja',
#        'Vikas Chawla, Abhay Parnerkar, Satyajit Ram', 'Rahul Veerwal',
#        'Sai Srinivas Kiran G, Shubham Malhotra', 'Sonu Sood',
#        'NAVEED AHAMED, SYED SAQQA ABBAS', 'Darshan Shah, Soniya Kundnani',
#        'Akash Sinha, Reeju Datta',
#        'Anand Agrawal, Mayank Khera, Rishabh Goel',
#        'Devashish Fuloria, Tusheet Shrivastava, Ankita Thakur',
#        'Chakradhar Gade, Nitin Kaushal', 'Chirdeep Shetty',
#        'Mehul Agrawal, Ruchit Agarwal, Vikram Chopra', nan, 'Divij Bajaj',
#        'Advaith Vishwanath, Ankit Agrawal, Jerin Venad, Rushabh Shah, Sankalp Kelshikar, Subhash Sundaravadivelu',
#        'Pushpak Dagade, Jimmit Patel and Suraj Bathija', 'Rajith Nair',
#        'Amit, Rohit Sadhu, and Vikas Ranga',
#        'Dhruv Agrawal, Himanshu Gupta, Soham Chokshi', 'Rushabh Mehta',
#        'Rohin Y, PV Ramana', 'Nikhil Aggarwal, Vivek Gulati',
#        'Gaurav Munjal, Hemesh Singh, Roman Saini, Sachin Gupta',
#        'Arpit Mittal, Anshul Gupta', 'Abhishek Poddar, Saurabh Arora',
#        'Shashank Vaishnav, Vinay Singhal, Parveen Singhal',
#        'Falguni Nayar', 'Snehanshu Gandhi, Gaurav Shrishrimal',
#        'Rohit Sen, Nupur Gupta', 'Aditya Sharma, Jayesh Hans',
#        'Byju Raveendran, Divya Gokulnath', 'Anurag Saboo, Gaurav Pushkar',
#        'Govind Balachandran, Zakir Wahab, Piyush Arora',
#        'Gowtham Sundaresan, Azan Barodawala', 'Nikhil Bohra',
#        'Sharmin Ali, Sutanshu Raj', 'Yogesh, Mitesh Gangar',
#        'Aditya Sengupta, Akash Gehani, Harshad Sharma, Sampad Swain',
#        'Anand Prabhudesai, Dhirendra Mahyavanshi, Kunal Shah',
#        'Dhruv Madhok, Dhruv Bhasin', 'Cheolwon Lee, Jay Yi, Martin Lee',
#        'Dhruv Dewan, Krishi Fagwani', 'Lakshay Jain', 'Nived Narayanan',
#        'Sandeep Patel', 'Tanmaya Jain', 'Ashwin Lal',
#        'Khushnud Khan, Rishi Raj Rathore',
#        'Deepak Diwakar, Krishna Depura, Mohit Garg, Nishant Mungali',
#        'Deepak Malhotra, Rajan Bajaj',
#        'Kashif Mohammad, Aravind Maddireddy', 'Ashish Rawat',
#        'Shrishti, Prithika', 'Ishpreet Gandhi', 'Ankur Bansal',
#        'Kiran Mazumdar-Shaw',
#        'Abhishek Doshi, Anupama Panchal, Shashwat Bhatt, Yash Shah',
#        'Amitava Saha, Supam Maheshwari', 'Amit Kumar, Gunjeet Singh',
#        'Ashraf Biran, Gulshan Bakhtiani, Mohan Chavan',
#        'Param Singh, Aashna Singh, Abhijeet Mittal, Jitesh Arora',
#        'Gunjan Kejriwal, Utsav Tiwary',
#        'Vinamra Pandiya, Mayank Gupta, Joji George',
#        'Pallav Pandey, Ankur Pandey, Siddharth Singh', 'Anup Kumar',
#        'Punweet Singh, Shuchir Suri', 'Sujay Santra',
#        'Mikhil Raj, Shubhadit Sharma, Ishaan Preet Singh',
#        'Mukesh Ambani', 'Saurabh Uttam, Ravi Singhal',
#        'Arun Vinayak, Swapnil Jain, Tarun Mehta',
#        'Sriram Kannan, Surajit Das', 'Rakesh Malhotra', 'Anjana Reddy',
#        'Vivek Bhutyani',
#        'Abhishek Negi, Aditya Singh, Pankaj Pandey, Uttam Kumar',
#        'Gireesh Rajendran, Ashish Lachhwani, Apu Sivadas, Rakesh Kumar and Alok Joshi',
#        'Kartikey Hariyani, Pavan Bakeri', 'Kavish Gadia, Nikhil Saraf',
#        'David Stavens, Mike Sokolsky, Sebastian Thrun',
#        'Abhijit Patil, Abhishek Tomar, Pankaj Raut',
#        'Ajay Nain, Prateek Chaturvedi', 'Abhishek Kabra, Aman Gour',
#        'Altaf Saiyed, Saloni Anand',
#        'Anurag Mehrotra, Krishnakant Thakur, Mohammed Bhol, Gautam Singh',
#        'Shivank Agarwal, Anish Khandelwal', 'Sahil Jatana',
#        'Ajay Kumar, Murari Singh', 'Jatin Solanki',
#        'Adit Jain, Anand Prajapati, Mayank Goyal',
#        'HS Srinivasan, Krishnan Rajan, E.V. Shunmugam',
#        'Saurabh Gupta, Siddharth Swarnkar',
#        'Arun Mallavarapu, Prasanth Madavana',
#        'Adarsh Manpuria, Vaibhav Aggarwal', 'Chandrakanta, Rajendra Lora',
#        'Abhishek Kothari, Deepak Jain, Manish Lunia, Ritesh Jain',
#        'Nilay Pandey, Saurav Singh, Vivek Kumar',
#        'Siddharth Dialani, Sai Gole', 'Nirav Choksi',
#        'Rohan Dedhia, Vaibhav Saraf, Hrishabh Sanghvi',
#        'Mohit Sahney, Sunita Sahney',
#        'Mihir, Payoj Jain, Divyansh Bordia, Anshuman Kumar',
#        'Sachin Chhabra, Nidhi Ramachandran', 'Nilay Mehrotra',
#        'Aneesh Mathur', 'Aanan Khurma, Aditya Seth, Ripunjay Chachan',
#        'Ashish Jhina, Karthik Venkateswaran',
#        'Paavan Nanda, Saumya Singh Rathore',
#        'Tarun Sharma, Vikas Lachhwani', 'Rohan Nayak',
#        'Sagar Bhalotia, Anish Basu Roy', 'Advitiya Sharma, Gaurav Lahoti',
#        'Sunoor Kaul,',
#        'Amit Srivastava, Bhavik Vasa, Sachin Tagra, Sachin Tagra',
#        'Saurabh Tandan, Pravin Agarwala', 'Talha Shaikh',
#        'Harsh Vakharia, Pankit Chheda, Sanket Shah',
#        'Mayank Agarwal, Vaibhav Jain', 'Atul Monga', 'Meena Sankaran',
#        'Kasuhik Mukherjee, Vineeta Singh', 'Gomathi S, Dr Balaji Sampath',
#        'Guru Sankararaman, Jay Vijayan', 'David guerin',
#        'Amit mandahar, Chaitali roy', 'Anjan Panneer Selvam',
#        'Narayan Subramaniam, Niraj Rajmohan',
#        'Akshay Saini, Rahul Saini, Pranav Chabhadia',
#        'Ranodeep Saha, Vijay Kumar', 'Charles Creighton', 'Siraj Dhanani',
#        'Chris Sampson, Marcel Herz, Martin Karafilis',
#        'Deepak Anchala, Rahul Bhattacharya, Ranjana TN', 'Manish Kaul',
#        'Priya Goel Sheth, Harsh Jain',
#        'Abhishek Verma, Harshit Mittal, Kumar Kushang, Nitin Prakash',
#        'Pankaj Sharma',
#        'Afeef Zaman, Ataur Rahim Chowdhury, Siffat Sarwar',
#        'M R Srinivas', 'Subhash Choudhary, Suumit Shah',
#        'Nikhil Jain, Nittin Mittal, Sumit Chhazed',
#        'Sat Tomer, Yukti Gill', 'Arun Sreyas, Gautham Maheswaran',
#        'Dinesh Godara',
#        'Aayushi Khandelwal, Akhil Kansal, Kuldeep Parewa',
#        'Amit Dutta, Ashok Mittal',
#        'Abhay Jeet Gupta, Parveen Kataria, Udbhav Rai, Vineet Sharma, Vishal Mishra',
#        'Supratik Ghatak', 'Surender Gounder', 'Gaurav Baid',
#        'Denis Sverdlov', 'Angus McDonald, Chris Bayley',
#        "Andrea Boeri, Braghin Francesco, Giovanni Capellari, Luca D'Alessandro, Stefano Caverni",
#        'Tushar Bhargava, Anshul Gupta',
#        'Alex Kostecki, Erich Nussbaumer, Nico Simko', 'Arjun Balaji',
#        'Chintan Raikar, Prashant Iyengar, Sneh Vaswani',
#        'Harshil Mathur, Shashank Kumar',
#        'Ashutosh Vikram, Kartheeswaran K K, Sharath Loganathan, Thiru Nagarajan, Thirukumaran Nagarajan, Vasu Devan',
#        'Binod Kumar Homagai, Sagar Daryani, Shah Miftaur Rahman',
#        'Anirudh Singla, Rishabh Shekhar',
#        'Anuj Srivastava, Ramakant Sharma, Shagufta Anurag',
#        'HariPrasath M., Rupam Das',
#        'Alessandro Traverso, Birger Lie, Harald Jellum, Matteo Berlucchi',
#        'Jean Pierre Nozieres', 'Amit Sinha, Ashok Prasad',
#        'Kuljit Chadha, Subramanian Viswanathan', 'Nitin Gupta',
#        'Hirak Joshi, Aalesh Avlani',
#        'KP Saravanan, Krish Subramanian, Rajaraman Santhanam, Thiyagarajan T',
#        'Ashwini Purohit, MS Chouhan',
#        'Arun George, Nikhil NP, Rashid Bin Abdulla, Vimal Govind MK',
#        'Maya Lakshman', 'Kishor Kumar Jha, Praveen Kumar',
#        'Sandeep Kondaji, Vishnuprasada Bhat, Anand Bellan Raman',
#        'Nagmanjunath Shivakumar, Savio Sebastian', 'Anurag Bist',
#        'Abhinand Kaseti, Harish B V, Sathvik Vishwanath, Sunny Ray',
#        'Andrew Linfoot, Ayush Jaiswal', 'Ram N Kumar', 'Vaibhav Anant',
#        'Kabandi Saika, Manik Mehta', 'Vinayak Seth',
#        'Kadam Jeet Jain, Rahul Chaudhary, Sidharth Gupta',
#        'Mainak, Sreekrishna', 'Azhar Iqubal', 'CA Abhinit Singh',
#        'Bharat Gupta, Pritesh Kumar',
#        'Simar Kohli, Tharun Kumar, Praseed KK',
#        'Ariel Assaraf, Guy Kroupp, Lior Redlus, Yoni Farin',
#        'Johnson Fernandes, Ravneet Kaur', 'Yi Zhang', 'Anu Meena',
#        'Ashwin Srivastava, Hardik Somani', 'Lu Zhao', 'Amit Gainda',
#        'Rahul Gupta, Swati Gupta', 'Rahul Anand',
#        'Harsimarbir (Harsh) Singh',
#        'Dinesh Pratap, Lokendra Ranawat, Vikas Baheti, Virendra Ranawat',
#        'Ruchi Deepak, Varun Dua', 'Pradeep PS',
#        'Balaji Viswanathan, Bharat Kumar, Mahalakshmi Radhakrishnan',
#        'Lovepreet Mann, Nikhil Kumar, Parul Jain',
#        'Suhail Chandhok, Arvind Sivdas, Dhanya Param',
#        'Benoit Dageville, Bob Muglia, Marcin Zukowski, Thierry Cruanes',
#        'Santosh Kataria, Ankit Kimtee, Vivek Jain',
#        'Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, Vatsal Rustagi',
#        'Saif Dhorajiwala, Vikas saluguti, Vivek Subramanian',
#        'Binny Bansal, Sachin Bansal',
#        'Aniket Deshpande, Gaurav Kumar, Irfan Mohammed, Soumendra Ghosh, Vineet Sukumar',
#        'Ankit Agrawal', 'Afsal Salu, Fayaz Bin Abdu, Soudabi',
#        'Byju Raveendran', 'Krishna Kumar, Saroja Yeramilli',
#        'Dhirubhai Ambani',
#        'Parampara Capital, Venkat Vallabhaneni, Jatin Desai',
#        'Tuhin Bhowmick', 'Deepshikha Kumar', 'Suhas raikar',
#        'Bhavit Sheth, Harsh Jain', 'Govind Balachandran', 'Rajan Navani',
#        'Arun Kumar Sureban', 'Gaurav Parchani',
#        'Jaydeep Barman, Kallol Banerjee', 'Varun Sheth, Kunal Kapoor',
#        'R. Baskar Babu', 'Gaurav Munjal, \u200eRoman Saini\u200e',
#        'Lodha, Priyanka Rathore', 'Pranav Pai, Siddarth Pai',
#        'Deepthi Ravula', 'Deepinder Goyal, Pankaj Chaddah',
#        'Abhishek Satish, Adarsh Warrier', 'Pawan Agarwal',
#        'Rohtash Mal CMD, Adwitiya', 'Shankar Prasad',
#        'Vijay Anand Bhagavatula',
#        'Ananda Prakash Verma, Shailendra Tiwari',
#        'Saswat Sahu, Rishi Raj',
#        'Adhil Shetty, Arjun Shetty, Rati Shetty', 'Pratik Shah',
#        'Nikhilesh Mishra, Puneet Jain',
#        'Ranjit Punja, R Sudarshan, Gowri Mukherjee', 'Vidur Maheswari',
#        'Ishan Sharma, Rishikesh Kumar', 'Shubham Gupta, Suresh Singh',
#        'Sachin Ravi, Raghav Chakravarthy', 'Mihir Mohan Mishra',
#        'Ashwin Kumar, Shoaib Mohammed',
#        'Damien Toledo, Jim Bugwadia, Ritesh Patel', 'Anmol Singh Jaggi',
#        'Dhruv Sawhney, Vivek Sahi, Sunny Bagla',
#        'Apurv Agrawal, Kanika Jain, Rishabh Ladha, Vikas Gulati',
#        'Debi Prasad Baral, Naveesh Reddy, Rohit Gajbhiye, Sunit Gajbhiye',
#        'Amit Sethi, Mandeep Manocha, Nakul Kumar', 'Deepak MV',
#        'Shailendra Dhakad, Rupika Taneja',
#        'Aanand Srinivas, Avinash Anand, Shankar Ram A',
#        'Ashish Munjal, Piyush Nangru',
#        'Anand Prabhu Subramanian, Vijay Gabale',
#        'Vaibhav Kapoor, Pulkit Kapoor', 'Anil Kumar',
#        'Dr Milind Choudhari, Dr Prasad Bhagat, and Dr Anupama',
#        'Mario Suntanu', 'Manoj Pillai', 'Somdutta Singh', 'Rahul Darda',
#        'Nishant Patel', 'Erez Galonska, Guy Galonska, Osnat Michaeli',
#        'Vijay Narasiman', 'Shrirang Tambe', 'Shirish Deodhar',
#        'Harish Mamtani', 'Shubham Malhotra, Sai Srinivas',
#        'Iyad Aldalooj, Majid Aldalooj, Mohammed Ibrahim', 'Kunal Mahipal',
#        'Bharath Rao',
#        'Abhishek Mishra, Kush Agarwal, Lav Agarwal, Stella Hu',
#        'Kunal Kishore Sinha, Sagar Pushp', 'Sreevathsa Prabhakar',
#        'Ankush Sachdeva, Bhanu Pratap Singh, Bhanu Singh, Farid Ahsan',
#        'Ashray Malhotra, Nisheeth Lahoti, Shivam Mangla',
#        'Saroja Yeramilli, R Krishnakumar',
#        'Chandranshu Sinha, Kartik Sheth', 'Shah, Abhay Bhat',
#        'Ajay Kadyan, Kumar Mayank', 'Tarun Lawadia, Sameer Kalra',
#        'Kabir Bose', 'Malika Datt Sadani, Mohit Sadaani', 'Ji Cheol Ryu',
#        'Anurag Sinha, Rupesh Kumar, Vibhav Hathi',
#        'Jitendra Chouksey, Sonal Singh, Jyoti Dabas, Bala Krishna Reddy, Rohit Chattopadhyay.',
#        'Akash Deep Singhal, Akshaya Singhal, Devashish Saxena, Gauri Dehnkar',
#        'Rohan Bhargava, Swati Bhargava',
#        'Nishant Chandra, Siddharth Maheshwari',
#        'Lalit Mangal, Manoj Singh, Vinay Kumar Jasti',
#        'Akash Singh, Sharath Keshava Narayana, Swapnil Jain',
#        'Bhupinder Singh', 'Zishaan Hayath, Hemanth Goteti',
#        'Vinay Sanghi', 'Sumeet Mehta, Smita Deorah', 'Sahil Sheth',
#        'Nirmit Parikh', 'Amit Rathore',
#        'Kabeer Biswas, Ankur Agarwal, Dalvir Suri, Mukund Jha',
#        'Ranjan Kumar', 'Anuj Srivastava, Ramakant Sharma',
#        'Swarup Mavanoor, Rahul Sankhe', 'Saurabh Pandey, Akshay Dubey',
#        'Vivek Rajkumar',
#        'Sonal Dandotia, Shantanu S, Virendra Chouhan, Vaibhav Tiwari',
#        'Rama Harinath, Srikanth Iyer', 'Darpan Sanghvi', 'Kajal Ilmi',
#        'Arunprasad Durairaj, Vijaybabu Gandhi, Shreenidhi Srirangam',
#        'Madhusudanan R, Prabhu R',
#        'Dr. R. Shivaraman, Praveen Dwarakanath', 'Arun Prakash',
#        'Anmol Singh Jaggi, Punit K Goyal',
#        'Nakul Kukar, Paras Kaushal, Supratim Naskar',
#        'Sai Srinivas Kiran Garimella, Shubham Malhotra',
#        'Kishan Vasani, Sai Sreenivas Kodur', 'Amit Dhakad, Hiral Jain',
#        'Lalit Keshre, Harsh Jain, Neeraj Singh, Ishan Bansal',
#        'Dr Mallesh Bommanahal, Varzavand Batliwala',
#        'Pratik Agarwal, Raj Desai, Varsha Bhambhani', 'Amit Agrawal',
#        'Karthi Mariappan', 'Tanmai Gopal, Rajoshi Ghosh',
#        'Ravi Ravulaparthi, Lakshman Gupta, Vamsee Mohan', 'Cindy Kua',
#        'Yashash Agarwal, Gaurav Agarwal', 'Ankit Agarwal',
#        'Vaishali Kulkarni, Arjun Singh Bajwa',
#        'Ananth Narayanan, T-ushar Kumar', 'Ashok Hariharan, Vineet Jawa',
#        'Charlie, Jay, Martin', 'Samarth Agrawal, Rohit Narang',
#        'Manoj Gupta, Monica Gupta',
#        'Arpita Kapoor, Mohit Rangaraju, Shilp Gupta',
#        'Pankaj Chaddah, Staff Pooja Khanna', 'Ishan Sharma, Rishikesh',
#        'Chaitanya Kalipatnapu, Ashwin Damera', 'Shobhit Bhatnagar',
#        'Abhishek Goyal, Neha Singh', 'Abhishek Agarwal',
#        'Pramod Ravindra', 'Saurabh Singh, Rahul Jain, Nagender Sangra',
#        'Amit Singh, Deepanshu Malviya', 'Aniket Shinde, Hardik Gondaliya',
#        'Sarvesh Shashi',
#        'Siddharth Das, Dr Rahul Dave, Dr Pavlos Protopapas',
#        'Nakerikanti Harish', 'Peter Barcak',
#        'Arpit Rajpurohit, Jayesh Rajpurohit',
#        'Amit Bhardwaj, Nikhil Hegde.',
#        'Srinivas Madhavam, Srikanth Rajashekhar, Rahul Mehta',
#        'Sonakshi Nathani, Ashutosh Singla', 'Omer Basith',
#        'Devansh Jain Nawal, Ackshay Jain', 'Snehil Khanor',
#        'Nimish Goel, Nevaid Aggarwal, Devender Bindal',
#        'Ankush Aggarwal, Tushar Mehndiratta', 'Manuraj Jain, Surajit Raj',
#        'Kunaal Dudeja, Nalin Saluja, Archit Jayaswal',
#        'Manish Shara, Yash Desai', 'Gaurav Singh', 'Varun Khanna',
#        'Inderveer Singh', 'Sumeet Yashpal Mehta, Smita Deorah',
#        'Pulkit Agrawal, Prashant Sachan, Arun Lodhi, Bimal Kartheek Rebba, Nirav Sheth',
#        'Utham Gowda',
#        'Mihir Gupta, Payoj Jain, Divyansh Bordia, Anshuman Kumar',
#        'Kshitij Khandelwal, Awais Ahmed', 'Dhruv Bhushan',
#        'Rajesh Bernard, Vijay Krishna, Prateek Mehta',
#        'Ravish Agrawal, Swatantra Kumar, Siddharth Srivastav',
#        'Sanjeev Nair', 'Smriti Tomar', 'Anurag Sinha',
#        'Prateek Shukla, Nrupul Dev, Yogesh Bhat',
#        'Shivank Agarwal, Anish Khandelwal.',
#        'Prerna Kalra, Vidya Bhushan',
#        'DVL Padma Priya, Rakesh Kamal, Tarun Nirwan',
#        'Public banks, Private lenders',
#        'Kiran Ramakrishna, Subhajit Mukherjee',
#        'Pranjal Kacholia, Divyansh Mathur', 'Rishab Mehta',
#        'Sateesh Nukala, SachinNandwana', 'Vineet Toshniwala',
#        'Srikanth Iyer, Rama Harinath', 'Sandipan Mitra, Uttam Kumar',
#        'Ananthakrishnan Gopal, Ashok Balasundaram, Sriram P H',
#        'Varun Chopra, Raheel Shah', 'Kshitj Puri, Shalabh Singhal',
#        'Rushabh Sheth, Bikram Dahl',
#        'Abhinav Ayan, Anirban Jyoti Chakravorty, Soumyaranjan Harichandan',
#        'Biswatma Nayak, Siddharth Gautam', 'Varun Saxena',
#        'Rajit Bhattacharya, Aisik Paul, Ankit Das',
#        'Adit Chhabra, Tapan Dixit,Tanay Dixit.',
#        'Viijender Reddy, Manas Ranjan Hota', 'Tanmaya Jain, Varun Puri',
#        'Anand Singh, Ankit Vaish', 'Vittal Ramakrishna',
#        'Jaydeep Barman, Kallol Bannerjee',
#        'Manish Jethani, Sourabh Agarwal',
#        'Kapil Mathrani, Rohan Bhatt, Poojan Thakkar', 'Sumit Ghosh',
#        'Ankush Sachdeva, Bhanu Pratap Singh, Farid Ahsan', 'Dhruvin Shah',
#        'Dr. Sachin Bhavsar', 'Sumeet Kapur, Ankur Bhatia, Aanchal Kapur',
#        'Prasanna Kumar, Mahesh Bhat, Rajasekhar, Amith S Mali',
#        'Karan Khairajani, Surojit Roy', 'Sachin Bhatia, Atit Jain',
#        'Zishaan Hayath',
#        'Archana Elapavuluri, Namandeep Bhatia, Siddharth Panjwani',
#        'K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Prathyusha',
#        'Vivek Tiwari', 'Bijay Gautam, Souniya Khurana',
#        'Saif Dhorajiwala', 'Mohammed Hisamuddin', 'Deepak Grover',
#        'Sudeep Singh', 'Ragini Das, Anand Sinha',
#        'Tarun Mehta, Swapnil Jain',
#        'Chirag Mittal, Parag Modi, Anirudh Syal',
#        'Praneeth Kumar, Shobhit Jain, Mrudhukar Batchu, Kiran Naik',
#        'Suman Maram, Sudheer Maram',
#        'Siddharth Vij, Siddharth Rastogi, Shubham Agarwal, Chaitanya Rathi',
#        'Ashwin Ajila', 'Meghna Saraogi, Akhil Tolani',
#        'Silky Singh, Alkheya Boora Rpsey', 'Mugdha Pradhan',
#        'Saurabh Saxena, Pulkit Jain, Anand Prakash, Vamsi Krishna',
#        'Anshoo Sharma, Brij Bhushan', 'Gaurav Baheti, Sumit Mendiratta',
#        'Hitesh Ahuja', 'Rathinamurthy R, Sridher Jeyachandran',
#        'Gotama Gowda', 'Ashish C', 'Nikhil Hegde, Amit Bhardwaj',
#        'Saurabh Saxena',
#        'Prateek Garg, Vishva Sharma, Rahul Gupta, Rishabh Nagpal, Ratan Sethi',
#        'Chaitanya Nallan, Sangram Simha, Veerendra Shivhare',
#        'Sahil Sharma, Aditya Shirole', 'Manish Tewari',
#        'Vidur Maheshwari', 'Ashni Sheth, Varun Sheth', 'Vikram Chopra',
#        'RajanNavani', 'Rushi Shenghani', 'Sanchit Garg, Sanjeev Dadhich',
#        'Abhilasha, Kshitij Purwar',
#        'Anuj Bhuria, Himanshu Kumar, Himanshu Meena', 'Rohit Taneja',
#        'Akhil Sikri, Nikhil Sikri, Sneha Choudhry', 'Ajaitha Shah',
#        'Sreeshankar S Nair, Romeo P Jerard',
#        'Vikram Jetley, Sanjay Sharma',
#        'Neeraj Kakkar, James Nutall, Suhas Misra, Neeraj Biyani',
#        'Ganesh Raju', 'Anuj Krishnan', 'Ooshma Garg',
#        'Rohit Grover, Pradeep Thangappan', 'Devang Shah, Gaurang Shah',
#        'Devesh Trivedi, Sanchit',
#        'Praveen Dwarkanath, Dr. Shivaraman Ramaswamy',
#        'Vijay Babu Gandhi, Shreenidhi Srirangam, Arunprasad Durairaj',
#        'Amrit Acharya, Srinath Ramakkrushnan, Vishal Chaudhary',
#        'Pavan Adipuram',
#        'Bhagaban Behera, Sriharsha Shetty, Nakul Kelkar', 'Swapnil Sahu',
#        'Aniruddh Singh, Riyaz Khan, Sagar Sheth', 'Mayank Yadav',
#        'Rajat Jadhav, Rahul Krishnan, Harsh Singh, Mohit Yadav',
#        'Amit Nanwani', 'Shivani Poddar, Tanvi Malik', 'Rajan Bajaj',
#        'Abhas Saroha, Oliver Jones', 'Aarti Gill, Mihir Gadani',
#        'Dhruv Agrawal, Faith Jiwakhan',
#        'Vemuri, Deepak Sharma, Pranay Gupta, Varun Chawla', 'Amit Gupta',
#        'Anant Goel', 'Hormazd Charna, Manoj Mishra',
#        'Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh Karwa',
#        'Srikumar Misra', 'Prasad Akella',
#        'Aditya Singhal, Nishant Sinha, Bahul Arora',
#        'Abhijit Roy, Samir Pratihar',
#        'Runal Dahiwade, Nityanand Prabhutendolkar, Miraj C. Vora',
#        'Arjun Ahluwalia, Adriel Maniego', 'Yash Vyas',
#        'Pushkar Singh, Sudarshan Ravi, Ankit Parasher',
#        'Niraj Raka, Poonam Gugale, Piyush Raka',
#        'Pranav Chopra, Neeraj Kumar', 'Dr Janani Venkatraman',
#        'Ravi Nishant',
#        'Rohan Mirchandani, Ganesh Krishnamurthy, Rahul Jain,Uday Thakkar.',
#        'Rajeev Agrawal', 'Babu Sivadasan',
#        'Abhijit Kane, Abhinav Asthana, Ankit Sobti',
#        'Raghav Arora, Lalit Kumar Aggarwal',
#        'Karthick Jayraman, Sanjay Dasari',
#        'Dr Gopichand Katragadda, Ganesh Suryanarayanan, Aditi Olemann.',
#        'Dr Binita Shrivastava Tunga, Dr Rashbehari Tunga',
#        'Shubhendra Vikram, Ankit Kumar', 'Ashish Gupta',
#        'Raghuraj Sunder Raju, Prasad Basavaraj, Sandeep Gudibanda',
#        'Shailesh Gupta, Mukul Shah', 'Nitesh Salvi',
#        'Purav Shah, Sandesh Reddy', 'Prashant Jain, Varun Khurana',
#        'Aswani Chaitanya',
#        'Lokendra Ranawat, Dinesh Pratap Singh, Virendra Ranawat, Vikas Baheti',
#        'Adhil Shetty, Arjun Shetty, Rati Shetty,', 'Geetansh Bamania',
#        'Rishabh Goel, Anand Agrawal, Mayank Khera',
#        'Kinner N Sacchdev, Rakhi Wadhwa', 'Karan Shaha, Vikas Chandrawat',
#        'Akshay Pai', 'Satyen Kothari, Beenext, Asuka Holding',
#        'Naresh Rao, Nikhil Rajmohan, Harinath Chakravarthy, Pravin Sethuraman',
#        'Indrajeet Roy', 'Bhavish Aggarwal', 'Amit Ramani',
#        'Kabeer Biswas,  Mukund Jha, Dalvir Suri, Ankur Aggarwal',
#        'Abhinav Agarwal, Anand Bakode',
#        'Dr Ruchir Mehra, Harsh Bansal, Richeek Arya',
#        'Mithun Srivatsa, Nikhil Shivaprasad',
#        'Vinayak Srivastav, Saket Dandotia, Alok Patil', 'Jatin Singh',
#        'Sumit Gupta, Neeraj Khandelwal', 'Lalit Menghani', 'Saurav Kumar',
#        'Suvendu Prusty, Sorabh Bhandari, Chiranth Patil.',
#        'Sandeep Vohra', 'Anurba Nath',
#        'Gowri Mukherjee, Ranjit Punja, Rajasundaram Sudarshan',
#        'Mohammed Riaz', 'Hrishikesh Datar', 'Ravish Naresh',
#        'Harshvardhan Lunia, Mukul Sachan',
#        'Akash Deep Singhal, Akshaya Singhal', 'Uttam Kumar',
#        'Ashwini Purohit', 'Pritesh Asher',
#        'Amit Kharat, Ajit Patil, Aniruddha Pant',
#        'Krishnan, Shane Bilsborough', 'Abhisheka Kumar, Malkit Didyala',
#        'Kartikey Hariyani',
#        'Milan Sharma, Nishant Mishra, Himani Shah, Devendra Chandani',
#        'Ajay Agrawal', 'Venkatesh Rangachari, Vipul Gupta',
#        'Naman Sarawagi, Mohit Jain', 'Saahil Goel',
#        'Sanjay Kumar, Deepti Prasad', 'Satish Kannan',
#        'Sumit Sinha,\xa0\xa0Mukesh Bansal', 'Arjun Deshpande',
#        'Prajit Nanu', 'Raman Khanduja, Sanjay Nazareth', 'Rajesh Yabaji',
#        'Gupta, Akshay Deshraj, Manoj Sarda',
#        'Avinash BR, Gururaj Rao, Arvind Murali, Santhosh Narasipura',
#        'Steve Hardgrave',
#        'Prashanth Kuppur, Deepak Kalhan, Saurabh Kukreti, Richpal Gora',
#        'Amit Naik, Kewal Vargante', 'Piyush, Dipesh Agarwal',
#        'Suraj Saste', 'Dr Subhash Narayanan',
#        'Ranjeet Pratap Singh, Sankaranarayanan Devarajan, Sahradayi Modi, Rahul Ranjan, Prashant Gupta',
#        'Vishal Jindal', 'Nishith Chasmawala, Amit Sharma', 'Rajat Gupta',
#        'Harsh Bansal', 'Darshan Shah', 'Nitin Agrawal, Garima Agrawal',
#        'Archin Shah, Abhilash Sonwane, Ritesh Gandhi',
#        'Mukul Rustagi, Bhaswat Agarwal', 'Tushar Kumar, Prashant Singh',
#        'Ishan Gupta, Aarti Gupta',
#        'Gagan Vermani, Divyanshu Sachdev, Gyan Prakash Tiwari',
#        'Amit Sharma, Apoorva Jois', 'Vivek Gupta, Jatin Solanki',
#        'Romesh Khaddar, Shikha Chaudhry, Sumedh Chaudhry',
#        'Raghavendra Prasad', 'Tarun Dhamija, Kartik Bansal',
#        'Jitendra Chouksey', 'Suresh Bavisetti, Paarth Dhar',
#        'Arindam Ghosh, U R Bhatt', 'Sagar Yarnalkar',
#        'SP Balamurugan, Arun Prakash, Sri Devi',
#        'Raghuram Talluri, Tanmoy Karmakar, Rakib Ahmed',
#        'Venkatesh Sundar, Nandini Tandon',
#        'Shivashish Chatterjee, Yuvraja Singh',
#        'Rohin Parkar, Malcolm Dsouza', 'Mittal',
#        'Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwal, Daya Rai, Nikhil Tripathi',
#        'Anand Anandkumar', 'Manas Ranjan Hota, Vijender Reddy',
#        'Madhusudanan R, Muthukumar and Prabhu',
#        'Vetrivel Palani, Paneerselvam', 'Megha Wadhwa, Karnesh Mahendru',
#        'Karanvir Singh, Utkarsh Bagri, Vikram Shekhawat, Deepak Choudhary',
#        'Amit Kumar Agarwal, Akhil Gupta, Saurabh Garg',
#        'Amit Raj, Anshul Gupta', 'Gaurav Hinduja, Sashank Rishyasringa',
#        'Mayank Kukreja, Anish Khadiya', 'Ashish Bhandari',
#        'Jen Horonjeff', 'Samarth Kholkar, Sandeep Mukherjee',
#        'Raghavendra Kumar Ravinutala',
#        'Vinayak Shrivastav, Saket Dandotia, Alok Patil',
#        'Sahil Kini, Nikhil Kumar', 'Abhishek Shah',
#        'Rishabh Jain, Aditi Sinha',
#        'Gaurav Srivastava, Gautam Kumar, Kushal Nahata',
#        'Pranav Goel, Uttam Digga', 'Rohit Paranjpe',
#        'Abhinay Choudhari, Hari Menon, Vipul Parekh, VS Sudhakar',
#        'Jitendra Gupta',
#        'Shrikrishna Bharambe, Shripad Nadkarni, Varun Khanna, Abhijit Berde',
#        'Vineet Shetty, Anushka Shetty', 'Malhi, Siddhant Saurabh',
#        'Shashank Kumar', 'Nandan Reddy, Sriharsha Majety, Rahul Jaimini',
#        'Saurabh Pandey, Mahadevan Narayanamoni', 'Deepinder Goyal',
#        'Karan Bhardwaj', 'Vimal Kumar', 'Tapojit Debnath, Nirman Dave',
#        'Pratyush Halen, Anuraag Agrawal',
#        'Prashant Border, Saurya Prakash Sinha', 'Ajith Mohan Karimpana',
#        'Suneel Kumar, Gaurav Tomar, Sucharita Redd',
#        'Anshul Bhagi, Sandeep Bhagi', 'Sam Santhosh',
#        'Kishor Jha, Praveen Kumar',
#        'Deepak Bhuvneshwari Uniyal, Shilpa Arora, Shailesh Kumar, Sanjay Aggarwal',
#        'Subhash Narayanan', 'Mukesh Bansal, Ankit Nagori',
#        'Tapesh Goyal, Rajesh Vaidhyanathan', 'Preet Arjun Singh',
#        'Sneha Roy', 'Dilip Kumar, Selvan Thamarai, Deepti Nair',
#        'Monica Gupta. Manoj Gupta',
#        'Anubhav Jain, Ankit Singh, Jawaid Iqbal',
#        'Rishi Malhotra, Akhil Gupta', 'Sumit Gupta',
#        'Sagar Modi, Advaith Vishwanath', 'Adarsh Anand, Amit Tiwari',
#        'Rajan Sharma', 'Prabhdeep Singh', 'Mihir Mohan mishra',
#        'Jaideep Gupta',
#        'Ezhilarasan Natarajan, Sabapathy Arumugam, Krishnakumar Narayanan, Thiruvalluvar NB',
#        'Gaurav Kumar, Vineet Sukumar', 'Srinath Ravichandran',
#        'George Mitra, Rajan Pathak',
#        'Amit Chandel, Rohit Garg, Vinay Kumar, Jayant Upadhyay',
#        'Pranesh Chaudhary, Sushant Sachan', 'Abhinav Jain, Aditya Gupta',
#        'Sridhar Joshi, Prashant Kulkarni',
#        'Maneet Gohil, Sanchit Govil, Albin Jose',
#        'Govind Agrawal, Arti Agrawal', 'Arshi Khan',
#        'Ankit Jain, Anand Shah', 'Pankaj Singh', 'Kush Taneja',
#        'Pramod Ghadge', 'Pei-fu Hsieh, Amit Jangir',
#        'Lalit Mangal, Vinay Jaasti, Manoj Singh', 'Rajesh',
#        'Rohan Mirchandani', 'Lathika Pai', 'Sriram Subramanian',
#        'Vidushi Kajaria, Aayush Goenka',
#        'Sudarshan Lodha, Priyanka Rathore',
#        'Sreeraman Vaidyanathan, Surga Thilakan', 'Prasanna Rao',
#        'Vaibhav Singh, Arnav Kumar',
#        'Ajai Thandi, Arman Sood, Ashwajeet Singh',
#        'Charit Bhograj, Zainul Charbiwala, Udayan Dasgupta, Abhinav Gujjar',
#        'Ajit Panda', 'Vivekananda Hallekere, Anil Giri Raju, Arun Agni',
#        'Taran Chhabra, Amar Preet Singh',
#        'Vipul Sharma, Rajat Kumar, Sachin Arora, Mohit Goel',
#        'Bhatia, Sneha Shah', 'Li Yong, Shushant Srivastava',
#        'Niraj Singh, Mohit Gupta, Ramanshu Mahuar',
#        'Pallavi Agarwal, Pankaj Parwanda', 'Ashutosh Sharma',
#        'Anand Ayyadurai, Padmanabhan Balakrishnan, Sanchit Mittal',
#        'Saurabh Singh', 'Prashant Warier, Pooja Rao', 'Gokul Shrinivas',
#        'Supriya Paul, Shobhit Banga', 'Ringaile Noq',
#        'Manish Rathi, Kapil Raizada, Sachin Saxena',
#        'Pankaj Raut, Abhishek Tomar, Abhijit Patil',
#        'Anirudh Singla and Rishabh Shekhar', 'Radha Basu',
#        'Ashneer Grover', 'Sanket Shah',
#        'Varun Mayya, Shashank Udupa, Abhinav Arora', 'Anubhav Sharma',
#        'Madhan Mohan , Akash Chelvam', 'Archit Agarwal, Harry Sehrawat',
#        'Vinay Kothari', 'Khadim Batti, Vara Kumar',
#        'Gaurav Munjal, Roman Saini, Hemesh Singh',
#        'Rajan Dang, Anushree Srivastava', 'Kabeer Biswas', 'Kamesh Goyal',
#        'Shailesh Gupta, Mukul Shah, Danish Chopra',
#        'Tithi Tewari, Gautam Tewari', 'Samarth Agrawal',
#        'Aniruddha Sharma, Prateek Bumb', 'Mahipal',
#        'Vishal Khatter, Dheeraj Khatter, Dipak Varshney',
#        'Maneesh Dhooper, Kunal Malik',
#        'Ajith Nayar, Umesh, Mahesh Subramanian', 'Amit Bagaria',
#        'Chinmoy Mishra, Gaurav Vij, and Abhishek Verma',
#        'Vijeet Pandey, Vikas Rishishwar', 'Yogesh Thore', 'Ritesh Kumar',
#        'Vijay Shekhar Sharma', 'Nicky Goulimis',
#        'Singla, Kannu Mittal, Dhawal Parate',
#        'Jayesh Rajpurohit, Arpit Rajpurohit', 'Abhishek Mohan',
#        'Raviteja Dodda, Yashwanth Kumar', 'Rustagi, Bhaswat Agarwal',
#        'Nitin Saluja, Raghav Verma', 'Apurv Patel',
#        'Shamik Guha, Sayan Tapadar, Muhammad Bilal Shakil, Anirban Datta Gupta',
#        'Ambareesh Murty, Ashish Shah', 'Supam Maheshwari, Amitava Saha',
#        'Karthick Jayraman and Sanjay Dasari', 'Kunal Patil',
#        'AR Rahman, Shekhar Kapur', 'Narain Karthikeyan.',
#        'Jitendra Emmani', 'Kapil Gupta', 'Shailaz Nag',
#        'Lal Chand Bisu, Vikas Goyal, Vinod Kumar Meena',
#        'Nikhil Banerjee', 'Sachin Chopra', 'Rakesh Sharma',
#        'Katie Russel and Daniel Wiegand',
#        'Vineet Sharma, Abhay Jeet Gupta, Udbhav Rai, Parveen Kataria, Vishal Misra',
#        'Aditi Avasthi', 'Mohammed Hisamuddin, Rahul Ramesh', 'Akash Deep',
#        'Tarun Khanna', 'Prashant Tandon, Gaurav Agarwal, Vikas Chauhan',
#        'Akaash Shankar', 'Tanushri Nagori, Aditya Shankar',
#        'Sandeep Bommireddi, Sravanth Gajula',
#        'Aditya Agarwalla, Sanjay Agarwalla', 'Vikash Jha',
#        'Guna Kakulapati, Rama Rajanna, Charu Sharma', 'Amit Bansal',
#        'Abhimanyu Saxena', 'Bala Parthasarathy, Anuj Kacker, Kunal Varma',
#        'Rohit Manghnani, Amit K Jaiswal, Iccha Manghnani',
#        'Ashish Kashyap', 'Sachin Agarwal, Aniket Deb, Ankit Tomar',
#        'Oren Kaniel, Reshef Mann', 'Bhavik Vasa',
#        'Navratn Singh, Kamal Pandey',
#        'Lokvir Kapoor, Rajul Garg, Tarun Upaday', 'Sharmin Ali',
#        'Neeraj Singh, Alok Arora', 'Dhruvil Sanghvi, Manisha Raisinghani',
#        'Shikhar Veer Singh, Nidhi Singh',
#        'Sarvesh Shrivastava, Ved Prakash Khatri, Amit Kapoor',
#        'Vivekananda Hallekere, Anil Giri Raju,Arun Agni', 'Amit Lakhotia',
#        'Abhay Rangan', 'Prithwi Dasgupta, Arnab Chatterjee', 'Trivedi',
#        'Snigdha Manchanda, Vikas Kumar, Aishwarya Malhi',
#        'Greg Moran, David Back',
#        'Suneel Kumar, Sucharita Reddy, Gaurav Tomar, Akhilesh Nigam,',
#        'Shailendra Singh, Deepinder Dhingra, Pavan Palety',
#        'Asheesh Chanda, Vineeth Narasimhan',
#        'Balaji Viswanathan, Be Limitless Inc., Zingfin.com, NalandaU',
#        'Kumar Mayank, Ajay Kadyan', 'Anish Agarwal, Anant Jain',
#        'Nirav Patil', 'Bhavesh Shah, Manav Shah', 'Abhishek Emmanuel',
#        'Mahe Bayireddi', 'Kavita Dhillon', 'Sousthav Chakrabarty',
#        'Kartikeya Goel', 'Soham Thacker, Varun Gajjar', 'Arka Dhar',
#        'Divya Agarwal, Ketika Kapoor', 'Deepanshu Arora, Parita Parekh',
#        'Thirukumaran Nagarajan, Sharath Loganathan, Sachin Jose, Kartheeswaran KK, Vasudevan Chinnathambi',
#        'Akash Sharma, Abhishek Agarwal',
#        'Mahesh Gogineni, Varun MS, Manan Maheshwari', 'Amal PS',
#        'Anurakt Jain, Ishita Verma', 'Rajiv Mukherjee', 'Bharat Sethi',
#        'Neeraj Kumar', 'Pramath Raj Sinha', 'Gaurav Munjal', 'Leo Mavely',
#        'Mr. Subhashis Kar', 'Amit Narang',
#        'Praveen Agrawal, Yadvendar Champawat, Manoj Munna, Abhishek Sagar, Ashutosh Kumar, Narendra Agrawal',
#        'Tanvi Malik, Shivani Poddar.', 'Neer Sharma',
#        'Ghazal Alagh, Varun Alagh', 'Siddharth Gadia', 'Sashi Narahari',
#        'Jahabar Sadique, Balaji Sadagopan',
#        'Sonal Khandelwal, Vaibhav Tiwari', 'Kanav Sachdeva',
#        'Kumar Varma', 'Vishvajit Sonagara',
#        'Santosh Shinde, Sanjay Borkar', 'Himanshu Jain, Pulkit Jain',
#        'Vikram Kankaria, Priyanka Kankaria', 'Akshay Chaturvedi',
#        'Sujith Narayanan, Sumit Gwalani', 'Manish Taneja, Rahul Dash',
#        'Jayakrishnan, Abhijeet Manohar'], dtype=object)

# %%
df20['Founders'].isnull().sum()
# Out:
# 12

# %%
# Identify empty items in the Founders column
#empty_founders = 
#df20[df20["Founders"].isnull() | (df20["Founders"] == "")]

# Print the rows with empty founders
#print(empty_founders)

# %%
## df20['Amount($)'].unique()

# %%
# Identify empty, commas, and NaN values in the Founders column
df20[(df20["Founders"] == " ") | (df20["Founders"].str.contains(",")) | (df20["Founders"].isna())| df20["Founders"].isnull()]
# Out:
#      Company/Brand Founded HeadQuarter       Sector  \
# 0       Aqgromalin    2019     Chennai  Agriculture
# 1         Krayonnz    2019   Bangalore   Technology
# 4       Gramophone    2016      Indore  Agriculture
# 5           qZense    2019   Bangalore  Agriculture
# 8           Rupeek    2015   Bangalore   Technology
# ...            ...     ...         ...          ...
# 1049        Fashor    2017     Chennai      Fashion
# 1051         EpiFi     NaN         NaN         None
# 1052       Purplle    2012      Mumbai       Beauty
# 1053        Shuttl    2015   New Delhi    Transport
# 1054         Pando    2017     Chennai         None
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 4     Gramophone is an AgTech platform enabling acce...
# 5     qZense Labs is building the next-generation Io...
# 8     Rupeek is an online lending platform that spec...
# ...                                                 ...
# 1049                        Women’s fashion and apparel
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# 5                          Rubal Chib, Dr Srishti Batra
# 8               Amar Prabhu, Ashwin Soni, Sumit Maniyar
# ...                                                 ...
# 1049                 Vikram Kankaria, Priyanka Kankaria
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                            Investor    Amount($)  \
# 0                                   Angel investors     $200,000
# 1                                   GSF Accelerator     $100,000
# 4               Siana Capital Management, Info Edge     $340,000
# 5     Venture Catalysts, 9Unicorns Accelerator Fund     $600,000
# 8      KB Investment, Bertelsmann India Investments  $45,000,000
# ...                                             ...          ...
# 1049                        Sprout venture partners   $1,000,000
# 1051                  Sequoia India, Ribbit Capital  $13,200,000
# 1052                                     Verlinvest   $8,000,000
# 1053                     SIG Global India Fund LLP.   $8,043,000
# 1054                              Chiratae Ventures   $9,000,000
#
#              Stage Unnamed: 9
# 0              NaN        NaN
# 1         Pre-seed        NaN
# 4              NaN        NaN
# 5             Seed        NaN
# 8         Series C        NaN
# ...            ...        ...
# 1049  Pre Series A        NaN
# 1051    Seed Round        NaN
# 1052           NaN        NaN
# 1053      Series C        NaN
# 1054      Series A        NaN
#
# [660 rows x 10 columns]

# %%
# Using the replace() method to replace the specified values (empty string '', comma ,, and NaN np.nan) in the "Founders" column with NaN (np.nan)
df20["Founders"] = df20["Founders"].replace(['', ',', np.nan], np.nan)

# %% [markdown]
# ## Investor Column

# %%
df20["Investor"].unique()
# Out:
# array(['Angel investors', 'GSF Accelerator', 'Venture Center',
#        'Venture Catalysts, PointOne Capital',
#        'Siana Capital Management, Info Edge',
#        'Venture Catalysts, 9Unicorns Accelerator Fund', 'ICICI Bank.',
#        'HostelFund', 'KB Investment, Bertelsmann India Investments',
#        'Shantanu Deshpande, Subramaniam Ramadorai', 'Fireside Ventures',
#        'Axilor Ventures, S.D. Shibulal', "Acumen Fund's angel programme",
#        'Sequoia Capital India, Sixth Sense Ventures', 'Rebel Foods',
#        'Kora, Tiger Global Management', '100X VC, Amara Ventures',
#        'Bertelsmann India Investments, InnoVen Capital',
#        'Mastercard, Temasek Holdings', 'BlackSoil, Caspian',
#        'Jindal Steels, Jeet Banerjee', nan, 'Zenith Global',
#        'Unitus Ventures, Work10M', 'Coinbase Ventures, Polychain',
#        'Mithril Capital Management.', 'Google', 'Better Capital',
#        'Steadview Capital, Canada Pension Plan Investment Board',
#        'Quona Capital', 'Swastika', 'Flipkart, Walmart',
#        'Delhi Private School, UAE, Interstar', 'Malpani Ventures',
#        'Survam Partners', 'Whiteboard Capital', 'Sequoia Capital.',
#        'Blacksoil', 'Bridgestone India', 'BEENEXT, Mayfield Fund',
#        'A91 Partners, Artha India Ventures',
#        'Sequoia Capital, India Quotient', 'NIIF Ltd, CDC Group',
#        'PayU Finance India, Quona Capital', 'STEMROBO Technologies',
#        'Infrastructure Leasing & Financial Services Limited, Dorm Room Fund',
#        'The CoWrks Foundry', 'Flipkart', 'Y Combinator, Sierra Ventures',
#        '9Unicorns Accelerator Fund', 'Speciale Invest',
#        'XRM Media, Kevin Lin', 'Huddle Accelerator',
#        'Hindustan Media Venture, Nicolas Jarrosson', 'India Angel Fund',
#        'Blume Ventures', 'Elevation Capital, Trifecta Capital Advisors',
#        'Stride Ventures, Matrix Partners India', '9Unicorns, Anicut',
#        'Venture Catalysts, 9Unicorns, We Founders Circle.',
#        'SenseAI Ventures, Saurabh Chugh',
#        'Startup incubator, Accelerator Venture Catalysts',
#        'India Accelerator, Sunil Kamath',
#        'Ramakant Sharma, Leo Capital India',
#        'Investment Corporation of Dubai (ICD)',
#        '9Point8 Capital, Sunil Kumar Singhvi',
#        'Sandeep Tandon, Survam Partners',
#        'Falcon Edge Capital, Omidyar Network', 'WEH Ventures, BEENEXT',
#        'Sequoia Capital India, CapitalG', 'La Gajjar Group.',
#        'Axilor Ventures, Unitus Ventures', 'Prolific angel investors',
#        'Ideaspring Capital, Accel', 'Nativelead Foundation',
#        'FMO, IndusInd Bank',
#        'Trifecta Capital Advisors, Nexus Venture Partners', 'Lightbox',
#        'Golden Birch Investments, She Capital',
#        'Pras Hanuma, Rebright Partners, Java Capital, and GSF Accelerator.',
#        'General Catalyst, Ribbit Capital', 'FMO', 'Surge',
#        'Unitus Ventures, Whiteboard Capital',
#        'StartupXseed Ventures, 100X.VC',
#        'Stellaris Venture Partners, Mastercard',
#        'Paula Mariwala, Siddharth Anand', 'Sequoia Capital India’s Surge',
#        'Venture Catalysts, 9Unicorns', 'India Accelerator',
#        'Pegasus Tech Ventures, Base Partners', 'GoodWorker.', 'Capify',
#        'Mumbai Angels, JITO Angel Network.',
#        'George Osborne, Smilegate Investment',
#        'Accel India, Breadlake Ventures', 'Ankur Mittal, Mitesh Shah',
#        'IIFL Asset Management, Matrix Partners', 'IIFL AMC',
#        'Global Car Group, Freemark holdings',
#        'Venture Catalysts, Speciale Invest', 'Venture Catalysts',
#        'Anupam Mittal, India Quotient', 'Unicorn India Ventures',
#        'DTDC, Udaan Angel Partners', 'Rainmatter',
#        'YourNest, growX ventures', 'Gemba Capital',
#        'Dragoneer Investment Group, Tiger Global Management',
#        'India Quotient', 'Surge, Tanglin Venture Partners',
#        'Alia Bhatt, Katrina Kaif', 'Pravega Ventures',
#        'Techstars Bangalore Accelerator, Techstars',
#        'Alfa Ventures, Divij Bajaj',
#        'Owl Ventures, Tiger Global Management',
#        'Whiteboard Capital, Matrix Partners India',
#        'Orios Venture Partners, Matrix Partners India',
#        '9Unicorns, 3Lines VC, Hyderabad Angels',
#        'Techstars, Techstars Bangalore Accelerator',
#        'Rajasthan Venture Capital Fund, AIM Smart City',
#        'Venture Catalysts, SOSV', 'BASE, Gunosy Capital',
#        'Nexus Venture Partners, Dream Incubator', 'DSG Consumer Partners',
#        'IBK Capital, SB Partners', 'Whiteboard Capital, Ahimsa Capital',
#        'Jonathan Swanson, Ankush Gera', 'Titan Capital',
#        'Asha Impact, Aavishkaar Venture Capital',
#        'Peyush Bansal, Ritesh Malik', 'AngelList India',
#        '3Lines, Jabbar Internet Group',
#        'Canaan Partners, NewView Capital', 'Better Capital, Gunosy',
#        'Sanjay Ramakrishnan, Ravi Garikipati', '9Unicorns', 'Jazal Group',
#        'Small Industries Development Bank of India', 'Goldman Sachs',
#        'LetsVenture, Jyotsna Bapat', 'Alibaba Group, InnoVen Capital',
#        'Poonawalla, Allana Group', 'Navus Ventures, Rockstart',
#        'AET Japan, Figure Eight Investments, Waterbridge Ventures',
#        'Sweta Rau, Archana Priyadarshini', 'Rajul Garg, Purvi Capital',
#        'Rajasthan Venture Capital Fund',
#        'Ratan Tata, Inflection Point Ventures, Ankur Mittal',
#        'Lightspeed, Elevation, Deepika Padukone',
#        'Abu Dhabi Investment Authority, GIC', 'Global Ascent Partners',
#        'HeroMotoCorp Ltd and Sachin Bansal',
#        'VAMM Ventures, Naresh Malhotra', 'DEG, KFW DEG',
#        'Accel, Alteria Capital', 'Mumbai Angels Network',
#        'AVANA Capital, Rebright Partners', 'Endiya Partners.',
#        'Mumbai Angels', 'Menterra Venture Advisors, Emandi Sankara Rao',
#        'Hercules Capital, Inc.Bertelsmann', 'Mohsin Hani Al Bahrani, MoD',
#        'CP Ventures, Orios Venture Partners',
#        'Kia Ora Ventures, Pentathlon Ventures',
#        'Kae Capital, Whiteboard Capital', 'Lokmat Investments',
#        'Niren Shah, Rukam Capital Trust',
#        'Chandigarh Angels Network, Modulor Capital',
#        'Rohit Chanana, Sukanta Ganguly', 'Alan Patricof, Jim Moffatt',
#        'IAN Fund', '9Unicorns, Titan Capital, FirstCheque',
#        'AIM Smart City', 'RB Investments Pte. Ltd, Goldman Sachs',
#        'Rajasthan Venture Capital Fund, Innovana Thinklabs',
#        '>Vikram Sud', 'Maple Capital Advisors',
#        '021 Capital, India Quotient', 'Ascent Capital, Iron Pillar',
#        'Oaks Asset Management', 'Roots Ventures, Better Capital',
#        'Sequoia Capital India, Faering Capital', 'Lightspeed India',
#        'CESC Ventures, Brun Raschle', 'Accel, Sunder Nookala', 'Justdial',
#        'KLUB Works, Shankar Narayanan',
#        'Nexus Venture Partners and 23 High Networth Individuals (HNIs)',
#        'Makers Fund, Courtside Ventures', 'RPSG Ventures, Amicus Capital',
#        'Times Group, Lightspeed', 'Mumbai Angels, Murali Nair',
#        'Nexus Venture Partners, Capria Ventures',
#        'Katrina Kaif, Steadview Capital',
#        'Exfinity Venture Partners, Shesh Kondi',
#        'Sandeep Tandon, Daniel Lapus', 'Northern Arc Capital',
#        'Samyakth Capital, Venture Catalysts', 'Jungle Ventures',
#        'Windrose Capital', 'Base Partners, Sequoia Capital India',
#        'Nishant Rao, Jonathan Boutelle', 'Picus Capital',
#        'Citi Ventures, Illuminated Funds Group',
#        'A91 Partners, RB Investments Pte. Ltd',
#        'GenNext Ventures, Contrarian Drishti Partners', 'Anand Mahindra',
#        'Alliance Ventures, Storm Ventures', 'Tandem',
#        'Indian Oil Corporation, Krishna Chakravarty', 'Tech Mahindra',
#        'Whiteboard Capital, VKG Ventures LLP.', 'TVS Motor Company',
#        'Sujeet Kumar, Hemesh Singh', 'Mount Judi Ventures',
#        'AngelList, Investec', 'Accel, Stellaris Venture Partners',
#        'Artha Venture', 'MOX, SOSV',
#        'Flourish Ventures, Lonsdale Capital', 'Kapil Dev',
#        'Lightspeed, Matrix Partners.',
#        'Eight Roads Ventures, On Mauritius',
#        'NABVENTURES, Social Alpha (India)',
#        'growX Ventures, Huddle (Incubator)',
#        'Better Capital, Kunal Shah, Gaurav Munjal',
#        'Lead Angels Network, Roots Ventures',
#        'Rohit Bansal, Rohan Ranavat', 'Real Estate Accelerator Program',
#        'Riso Investments, Lenskart', 'Sequoia Capital India',
#        'UPS Ventures, Hyundai Motor Company',
#        'King River Capital, Leap Capital', 'SOSV, Artesian',
#        'Upfront Ventures, Walkabout Ventures', 'Advent Partners',
#        'Stride Ventures, YourNest Venture Capital',
#        'Tiger Global Management, Sequoia Capital India',
#        'Syngenta Ventures, Walmart',
#        'Tiger Global Management, William Bissell',
#        'Alok Mittal, Manan Maheshwari',
#        'Mercer Investments, Bessemer Venture Partners', 'Startup Basket.',
#        'Orkla Ventures, Smedvig Capital', 'NABVENTURES',
#        'Xseed Partners, InnoVen Capital',
#        'Lightspeed India Partners, Accel India',
#        'Accel, Steadview Capital',
#        'Silver Lake, Mubadala Investment Company',
#        'Amit Lakhotia, Akash Gehani',
#        'Aavishkaar Venture Capital, Chiratae Ventures',
#        'NABVENTURES, Omnivore', 'Java Capital',
#        'SenseAI Ventures, EvoNexus', 'Digital Finance Group, FundersClub',
#        'Sriharsha Majety, Rahul Jaimini', 'Wavemaker Partners, Subho Ray',
#        'Upsparks', 'Saurabh Arora, LD Sharma', 'Foxhog Ventures',
#        'Ramesh Mangaleswaran, Saikiran Krishnamurthy', 'Triodos, Caspian',
#        "Lee Fixel's Addition, SIG Global, Tanglin Venture Partners",
#        'I2I Capitals', 'Core91 Fund, Anupam Mittal', 'Terwilliger Centre',
#        '2B Angels, Janvest Capital Partners', 'Rising Stars',
#        'General Atlantic, Kohlberg Kravis Roberts',
#        'CICC Alpha, VMS Asset Management', 'Sekhar Puli',
#        'Cowin Venture, ZSVC', 'International Finance Corporation',
#        'BlackSoil, BEENEXT', 'Marc Lore, Rise Capital',
#        'Sequoia Capital India, Hummingbird Ventures',
#        'IAN Fund, Rajasthan Venture Capital Fund',
#        'RPS Ventures, Intact Ventures',
#        'Artha India Ventures, Nagaraja Prakasam',
#        'Chiripal Group, Ratish Kumar Nair',
#        'Pallav Nadhani, Idein Ventures',
#        'Salesforce Ventures, Dragoneer Investment Group',
#        'Spiral Ventures, Surge', 'Sequoia Capital India, Times Internet',
#        'responsAbility, Grameen Impact India (GIII)',
#        'Tencent Holdings, Walmart',
#        'Aspada, Creation Investments Capital Management, LLC',
#        'GirnarSoft',
#        'Jamshed Jeejeebhoy, Symphony International Holdings',
#        'Facebook, Google, KKR, Silver Lake',
#        '021 Capital, Karnataka Information Technology Venture Capital Fund',
#        'Homage Ventures.', 'Steadview Capital, Tencent Holdings',
#        'Adar C. Poonawalla, Kris Gopalakrishnan', 'Coatue Management',
#        'Steadview Capital', 'Mumbai Angels, Redcliffe Capital',
#        'Gaja Capital, Kotak Life, Lok Capital',
#        'DR. Moti Vyas, Udit Goyal',
#        'Nexus Venture Partners, Sequoia Capital',
#        'Propstack, SAIF Partners',
#        'MacRitchie Investments, Baillie Gifford',
#        'Tencent Holdings, Times Internet',
#        'Global Innovation Fund, Soros Economic Development Fund',
#        'Ronald Conway, Bay Partners', 'Prospect Partners.',
#        'Omnivore, Zeroth.AI', 'Mumbai Angels.',
#        'Ramesh Srinivasan, Amazon', 'Eight Roads Ventures',
#        'Ashok Leyland, V Lakshmi Narayanan',
#        'Ranjit Punja, R Sudarshan, Gowri Mukherjee',
#        'Gunavanth Vaid, Bharat Kumar Sohanraj', 'Venkat Raju',
#        'Silver Lake Partners',
#        'Clairvest Group, Ontario Centres of Excellence',
#        'Damien Toledo, Jim Bugwadia, Ritesh Patel',
#        'US based NRI Investors', 'Inflection Point Ventures, Mitesh Shah',
#        'Betatron', 'Chiratae Ventures, Blume Ventures',
#        'Ravi Sanghvi, PitchRight Venture',
#        'Bessemer Venture Partners, CDH Investments', 'HNIs',
#        'Guild Capital', 'Y Combinator', 'Prime Venture Partners',
#        'Mela Ventures, 1Crowd', 'responsAbility, Accel',
#        'Chiratae ventures', 'Palm Drive Capital, Amatil X Ventures',
#        'Sequoia Capital India, Blume Ventures',
#        'JF Mauritius SPV, IndusAge Partners', 'VC Firm K Partners',
#        'India Alternatives Private Equity Fund, Tata Capital',
#        'Bonnier Ventures, Hanaco Venture Capital',
#        'Gemba Capital, Gunderson Dettmer', '500 Startups, ah! Ventures',
#        'Base Partners, GO Ventures', 'Accel, Zodius Capital',
#        'Windrose Capital, Anil Advani', 'Seeds Capital, AIM Smart City',
#        'Blume Ventures, Tetrao',
#        'Lightspeed venture partners, saif partners',
#        'Shadows Holdings, Lightbox',
#        'Lightspeed India Partners, Sequoia Capital India',
#        'Abhishant Pant, Chiranth Patil', 'Madison, Anicut',
#        'DSG Consumer Partners, Saama Capital',
#        'Kakao Ventures, Shinhan Capital',
#        'Matrix Partners India, Hummingbird Ventures',
#        '23 High Networth Individuals (HNIs).',
#        'Ratan Tata, Kalaari Capital', 'Nexus Venture Partners',
#        'Global Founders Capital, Redpoint',
#        '01 Advisors, Steadview Capital', 'Pushpak Credit, Fiscal',
#        'Kaizenvest, Foundation Holdings',
#        'Pincus, JP Morgan, Temasek, March Capital',
#        'Westbridge Capital, Elevar Equity', 'BAce Capital, Madhur Deora',
#        'Lightspeed India, Sequoia Capital India',
#        'IIFL Asset Management, Raghav Bahl',
#        'Wes Schwalje, Alteria Capital',
#        'IDFC-Parampara Fund, Bharat Innovation Fund',
#        'Mercer Investments, Nicholas Cator',
#        'Falcon Edge Capital, SAIF Partners', 'Chiratae Ventures.',
#        'Menterra Venture Advisors, Rianta Capital',
#        'Sunil Kumar Singhvi, Yusho Kawata',
#        'Accel Partners, Sequoia Capital, Evolvence India, JSW Ventures',
#        'Bessemer Venture Partners', 'Insitor Partners, C4D Partners',
#        'Sinai Ventures, Y Combinator', 'Jitendra Gupta, Better Capital',
#        'Mumbai Angels, Defence Innovation Organisation',
#        'CBA Capital, Gray Matters Capital',
#        'Kalpavriksh, JITO Angel Network',
#        'growX ventures, Sangam Ventures',
#        'SRI Capital, Techstars Farm to Fork Accelerator',
#        'Y Combinator, Ribbit Capital', 'Hatanaka Yosuke, Minomiya Takeo',
#        'Krishnan Menon, Srinivas Kollipara',
#        'SucSEED Venture Partners, ah! Ventures', 'Surge, Kae Capital',
#        'Nexus Venture Partners, Sam Lambert',
#        'Alto Partners, Mission Holdings', 'SCB 10X, LINE Ventures',
#        'Powerhouse ventures, Tracxn,', 'Kaplan Foundation', 'Ivy Icon',
#        'Millenna FVCI III, NB Ventures, Dream Incubator', 'Balancehero',
#        'Anicut Capital',
#        'Al Falaj Commercial Investment Co, Vistra ITCL India',
#        'Supera Investments',
#        'Accel India, Blume Ventures, 3F Ventures, Akatsuki Inc',
#        'GGV Capital, Sahi Barual',
#        'Grand Anicut Angel Fund (GAAF), AL Trust, Beeline Impex Private Limited, 9Unicorns, Accelerator Fund',
#        'Bertelsmann India Investments, Sequoia Capital India',
#        'Times Internet, TLabs',
#        'Saif partners, Accel partners, Sequoia capital',
#        'Jitendra Gupta, Astarc Ventures.', 'Nestavera Ventures.',
#        'MOX, Venture Catalysts', 'Sojitz, SIG Global India Fund',
#        'Mohan Verma, Better Capital', 'Shikhar Dhawan, Mantra Capital',
#        'Kiran Mazumdar Shaw.', 'Bhadresh',
#        'GB Group, Walden International', 'Meghna Agarwal, Navin Dhanuka',
#        'V Sumantran, V Lakshmi Narayanan',
#        'Keiretsu Forum, SucSEED Venture Partners',
#        'Sweta Rau, Sandeep Kapoor', 'Mantis ventures',
#        'Napino Auto and Electronics Ltd',
#        'VCATS, First Cheque, 9Unicorns, Marquee investors',
#        'AngelList, Inflection Point Ventures, The Chennai Angels',
#        'Mayfield India, Saama Capital, Ronnie Screwvala', 'DST Global',
#        'Alphawave, Matrix Partners', 'Keiretsu Forum, Elea Foundation',
#        'WaterBridge Ventures', 'Alpha Wave incubation',
#        'Inflection Point Ventures', 'Anand Shah',
#        'WestBridge Capital, Elevar Equity',
#        'KTB Network, Samsung Ventures, Ankur Nagpal, Gokul Rajaram, Vineet Buch',
#        'Ankur Capital',
#        'Lightspeed India Partners, Blume Ventures, GrowX ventures',
#        '3one4 Capital, Angel list India',
#        'StartupXseed Ventures, Bhaskar Pramanik, MJ Aravinf, Ravi Viswanath, Ramesh Radhakrishnan, Ranjan Biswas, MJ Aniketh.',
#        'SAIF Partners, Y Combinator, Neeraj Arora, Titan Capital, First Cheque.',
#        'Suniel Shetty', 'SOSV, MOX (Mobile Only Accelerator)',
#        'Matrix Partners India, Sequoia Capital India, Hummingbird Ventures',
#        'Unitus Ventures, India Quotient, AngelList India',
#        'Artha Venture Fund', 'Shobu Yarlagadda',
#        'Fullerton Financial Holdings, Bertelsmann India Investments, Sistema Asia Fund, IndiaQuotient',
#        '1Crowd', 'Foundation Holdings',
#        'Ankur Capital, Beyond Next Ventures', 'Orios Venture Partners',
#        'Evolvence India Fund (EIF), Pidilite Group, FJ Labs',
#        'IIFL Income Opportunities Fund', 'Sequoia India',
#        'Stride Ventures', 'Better Capital, TechStars, Barclays.',
#        'Venture Catalysts,\xa0\xa0Raveen Sastry',
#        'AngelList India, Utsav Somani, Village Global, LogX Ventures, Jasminder Singh Gulati',
#        'Eagle10 Ventures, India Accelerator, HNIs',
#        'Uday Sodhi, Mitesh Shah, Nitin Jain', 'Sequoia Surge',
#        'Elina Investments', 'Qualgro, Lachy Groom',
#        'Urmin Family Office, Lemonade Ventures, TrueValue Group MD Yash Shah',
#        'LogX Ventures, AngelList’s Utsav Somani, NowFloats’ Jasminder Singh Gulati, AL Trust (Vistra ITCL), Village Global.',
#        'All About Inc, Beenext Pte Led, Beenos Asia, DG Ventures, Kanamori Assagement Singapore, Rebright Partners I, Rebright Partners II, Tetsuro Koda',
#        'Shabir Momin, OneDigital Entertainment,\xa0\xa0Saurabh Pathak.',
#        'Indian Angel Fund',
#        'N S Parthasarathy, Dilipkumar Khandelwal, Anand Nichani, Anath Ravi, Prashanth Prakash',
#        'Crazy Labs', 'Info Edge',
#        'Sanjay Mehta, Vikram Pandya, Gaurav Gupta, Vivel Srivatsav, Madhavi Bollipalli, Srinivas Paanem, Satish Bogullu',
#        'Dr. Bhaskar Rao Bollineni', 'BlueOrchard Finance Limited',
#        'ResponsAbility Investments AG', 'Good Capital',
#        'Dr Srinivas Chunduru', 'Ashok Nichani, Shelly Nichani',
#        'Hero MotoCorp', 'Unitus Venture',
#        'Matrix Partners India, Ankur Capital',
#        'Unicorn India, PointOne Capital, Astir Ventures',
#        'Sequoia Capital India, Matrix Partners India, InfoEdge, Waterbridge Ventures',
#        'BlackSoil Capital', 'Ah! Ventures', 'Rajesh Ranavat', 'Coatue',
#        'Samsung Venture Investment Corporation', 'Jetty Ventures',
#        '021 Capital', 'LetsVenture Syndicate', 'Chennai Angels',
#        'SucSEED Ventures', '3one4 Capital', 'Incubate Fund',
#        'RPSG Ventures', 'Incubate Fund India', 'Eight Road Ventures',
#        'JAFCO Asia, Artha Venture Fund',
#        'Tharun Dhariwal, Sunil Kumar Singhvi, Arun Ostwal, Vishal Ostwal, Gunavanth Vaid, Bharat Kumar',
#        'WEH Ventures', 'Trifecta Capital', 'Vivriti Capital',
#        'Adar Poonawalla, Kris Gopalakrishnan', 'LR Joshi',
#        'Beenext, Rainmatter CApital Pvt Ltd, Stanford Angels & Entrepreneurs',
#        'Mumbai Angel Network',
#        'Investcorp, Nexus Venture Partners, Mirae Assets, Trifecta Capital',
#        "ENGIE RAssembleurs d'Energies, The Rise Fund, and The Singh Family Trusts,Teja Ventures, Beyond Capital Fund.",
#        'Kritik Abiram, Parthiv Rokadia, Gaurav Saraogi',
#        'Invest in Vision',
#        'Sofina Ventures, A91 Emerging fund, SCI Growth Investment II, Catamarann Ventures',
#        'Turbostart',
#        'Globevestor, Secocha Ventures, First Cheque VC, Kashyap Deorah, Vijay Sivaram',
#        'NB Ventures', 'Sauce vc', '3One4 Capital, LetsVenture',
#        'Better Capital, Titan Capital', 'Lightbox Ventures', 'Greenoaks',
#        'Startup-O, Eden Ventures',
#        'Matrix India, Y Combinator, Global Founders Capital, Soma Capital, VentureSouq',
#        'InfoEdge Venture Fund, Sprout Venture Partners',
#        'Rajesh Ranavat, Abhishek Shah, Sheetal Bahl, Manu Rikhye, Ashish Taneja, Kabir Kochhar, Mohit Satyanand',
#        'SAIF Partners, India Quotient', 'BOND', 'Gunosy',
#        'Leo capital, Ramakant Sharma', 'Amansa Capital',
#        'Matrix Partners', "Capital G, Alphabet's Independent growth fund",
#        'Chiratae Ventures',
#        'Pearl Brook Holdings Ltd, Al Nour International Holdings Co.',
#        'Rocketship', 'Nadir Godrej, Individual Investors', 'Pawan Munjal',
#        'US International Development Finance Corporation',
#        'Tano India, L’Occitane, Bessemer', 'Sozo Ventures', 'Undisclosed',
#        'Rainmatter Capital', 'Venture Catalysts, Naveen Kshatriya,',
#        'Shikhar Dhawan', 'Arkam Ventures, Nabventures',
#        'Beyond Next Ventures, ArthaVida Ventures, Dr Aniruddha Malpani',
#        'Iron Pillar, Blume Ventures', 'Danone Manifesto, Mousse Partners',
#        'Entrepreneurial Development Bank, Bessemer Venture Partners',
#        'Insight Partners', 'Induslnd Bank', 'Pratithi',
#        'PadUp, Villgro USA, Vinners, LetsVenture, SINE IIT Bombay, DERBI',
#        'Dr Apoorva Ranjan Sharma, Mrunal Jhaveri, Nirav Panchmatia, Vikas Kapoor, Karan Garg',
#        'JSW Ventures, Chiratae Ventures, Kalaari Capital', 'Kimera Ltd',
#        'Gameskraft', 'Anthill Ventures', 'Smile group',
#        'Rangsons Technologies', 'WSV Capital',
#        'Gautam Dalmia, Pratithi Investment Trust, Shri Investment',
#        '100x VC', 'Black Soil',
#        'Leo Capaitals, Amit Gupta, Abhishek Goyal, Ramakant Sharma, Harsh Pokhran',
#        'Beenext, Asuka Holding', 'Vertex Ventures SEA & India',
#        'Crowd Fund', 'Bisque Limited, Link Investment Trust.',
#        'Stellaris Venture Partners, Venture Highway',
#        'River Rock Ventures. Inflection Point Ventures',
#        'Chinaccelerator, 9 Unicorns Fund, Inflection Point Ventures',
#        'EMVC, Flourish, Omidyar Network India', 'Polychain Capital',
#        'Varanium NexGen Fund', 'Inventus III India Fund',
#        'Bharat Inclusion Seed Fund, Varanium Capital, and Better Capital',
#        'Amit Burman', 'Bharti Airtel',
#        'Whiteboard Capital, FirstCheque, Artha India Ventures, Sweta Rau, Deepak Abbot, Amrish Rau, Harpreet Singh Grover',
#        'IDG Ventures, Elevar Equity, Accion', 'Angel Investors',
#        'Kalyan Krishnamurthy, Sujeet Kumar, Keshav Sanghi, Roman Saini, Sumit Jain, Hemesh Singh',
#        'Sujeet Kumar', 'B Capital Group', 'Angel investors. HNI',
#        'Innoven Capital', 'Tracxn Labs, Angellist, Tri-Deep Capital',
#        'Ankit Bhati, Nitin Gupta', 'Gray Matters Capital',
#        'Akya Ventures', 'GHV Accelerator', 'Josh Liberman, Mark Adams',
#        'Nordic Microfinance Initiative',
#        'Chiratae Ventures, Accel Partners, BCIP Venture Associates, Bain Capital, Renaud Laplanche',
#        'Saama Capital', 'Tiger Global, Avatar Growth Capital',
#        'Lightspeed Venture Partners', 'Unicorn Investments Pte Ltd',
#        'Vijay Shekhar Sharma, Anupam Mittal',
#        'Tribe Capital, Innoven Capital, BII',
#        'Angellist, Smile Group, Manish Amin, Anil Goel, Anubhav Sonthalia, Deepak Mittal',
#        'Steadview capital',
#        'Bessemer Venture Partners India, Fusian Capital, Rebright Partners, Milliways Fund LLC',
#        'Ratan Tata', 'VisaVentures, BRI Ventures', 'Next Capital',
#        'Trifecta Venture', 'Exfinity Ventures, IAN Fund',
#        'Alteria Capital', 'ChrysCapital',
#        'Hari Balasubramanian, EaSyndicate',
#        'Paytm, leAD Sports, Rockstud Capital, Founder Bank Capital',
#        'Lupa India', 'Tencent',
#        'Devanshu Dolat Desai, Anand M Khatau, Debasish Priyadarshi Purohit, Kaushik Shanghvi',
#        'Accel Partners, Jungle Ventures', 'Barkawi',
#        '1Funds Domestic Scheme', 'RiverRock Ventures', 'RTP Global',
#        'Hero Fincorp', 'Li and Fung', 'Mantra Capital, Patni Family',
#        'Nikhil Vora, Iceland Venture Studio, LetsVenture, Samyakth Capital',
#        'North Base Media', 'Investment Trust of India',
#        'IvyCap Ventures, Sequoia Capital',
#        'Sequoia Capital Surge, Better Capital',
#        'Ravikanth Reddy & Mumbai Angel Network',
#        'Sequoia Capital, Sofina', 'Pinetree Capital', 'Big Basket',
#        'Education Catalyst Fund', 'CDC Group', 'KB Global Platform Firm',
#        'Tata Capital Growth Fund II', 'NXC Corporation',
#        'Saltwater Venture Sparks',
#        'University of Tokyo Edge Capital, Global Brain Corporation',
#        'Abhishek Goyal, Bharat Jaisinghani, FirstCheque', 'BeeNext',
#        'Angel Network', 'Sukhbir Singh, Rakhee Singal',
#        'INSEAD Angels, IIT Kanpur Angels, Sixth Sense Ventures, Saahil Bhatia',
#        'Bytedance, Falcon Edge, Goldman Sachs, Advent Management',
#        'General Atlantic', 'IIFL Seed Ventures Fund, Menlo park',
#        'Ribbit Capital, SAIF Partners, Sequoia Capital India, Amazon',
#        'Greenoaks Capital, Vy Capital. Matrix Partners India', 'Accel',
#        'Indie VC',
#        'Lightspeed Venture Partners, Lightspeed India Partners.',
#        'Lightspeed Venture, Falcon Edge, Bharat Inclusive Technologies Seed Fund.',
#        'M12, Honeywell venture capital, Eight Roads Venture',
#        'Amazon, Sequoia, Walden SKT Venture Fund',
#        'Lightstone Global Funds', 'Zee Entertainment Enterprises Limited',
#        'Amazon Inc`, Dinesh J Hinduja', 'Alibaba Holdings',
#        'Hummingbird Ventures, Bedrock Capital', 'Legend Capital',
#        'Accel, Zephyr Peacock, Swiggy, RB Investments.',
#        'Better Capital, LetsVenture, Rohit Chanana, Jayant Kadambi, Sunil Kumar Singhvi',
#        'Bace Capital',
#        'Tencent, Ark Impact, Korea Investment Partners, Samsung Ventures, Mirae Asset Capital Markets',
#        'LGT Lightstone Aspada', 'Pacific Horizon',
#        'Der Shing Lim, 500 startups', 'Vostok Emerging Finance',
#        'Arka Venture Labs', 'IvyCap Ventures', 'Vertex Ventures',
#        'Chowdry Associates, Lightbox',
#        'Sukhbir Singh, India Accelerator, Boudhik Ventures, Shankar Nath, Shaurya Garg',
#        'Matrix Partners, SAIF Partners', 'LeapFrog Investments',
#        'Aavishkar Capital', 'Unicorn India ventures',
#        'Pecus Capital, Madhur Deora', 'Temasek', 'Ideaspring capital',
#        'ThinkNext LLC', 'MG Motor India',
#        'Ashneer Grover, Kunal Shah, Ramakant Sharma',
#        'KYT Ventures, First Cheque, AngelList',
#        'Polychain Capital, Bain Capital Ventures, HDR Group',
#        'Risers Accelerators', 'Accel India, Lightspeed Venture Partners',
#        'Gautham Madhavan', 'Pegasus FinInvest',
#        'TPG-backed Group Landmark', 'CESC Ventures', 'Naya Ventures',
#        'pi Ventures',
#        'Rajeev Juneja, Pratul Shroff, Dilip Khandelwal, Piyush Gupta',
#        'Mahendra Singh Dhoni', 'LGT LightstoneAspada',
#        'Godrej Investments',
#        'Stellaris Venture Partners, Unilever Ventures, Kalaari Capital, Vy Capital',
#        'Sorenson Impact', 'Vishal Dixit',
#        'Pawan Munjal Family Trust Fund', 'Lodha Ventures',
#        'Y Combinator, Venture Highway, Sequoia India, Global Founders Capital',
#        'Arali Ventures, CIIE.CO',
#        'Kunal Shah, Amrish Rau, Jitendra Gupta', 'Accel India',
#        'Mistletoe', 'KA Enterprise',
#        'Lead Angels Network, Stanford Angels', 'Angel network',
#        'LetsVenture investors',
#        'Advent Management, A91 Emerging Fund, Trifecta Venture',
#        'SAIF Partners, Mayfield India', 'Rukam Capital',
#        'UTEC-The University of Tokyo Edge Capital, Aflac Ventures, LLC, Dream Incubator, TeamFund',
#        'Ixigo', 'Sequoia’s Surge, Fosun RZ', 'Alok Garg',
#        'InnoVen Capital', 'Anicut Angel Fund', 'Aavishkaar Capital',
#        'Paragon Partners', 'Yuanfudao',
#        'Nandan Nilekani, Sanjeev Aggarwal', 'Atraxn Partners.',
#        'Morgan Stanley Private Equity Asia', 'Lightstone Aspada',
#        'Samsung Venture Investment', 'Indian Angel Network',
#        'Media Development Investment Fund', 'Accelerator MOX',
#        'Nandan Nilekani, Samsung Venture Investment Corporation',
#        'Maharashtra Defence, Aerospace Venture Fund (MDAVF)',
#        'Kunal Bahl, Rohit Bansal',
#        'GGV Capital, Bertelsmann India Investments, Binny Bansal, Sequoia India, Accel Partners',
#        'CDC Group Plc', 'Ribbit Capital', 'Sequoia Capital’s Surge',
#        'Peerplays', 'Sauce.vc', 'AdvantEdge', 'Accion Venture Lab',
#        'SucSEED Venture Partners, BIRAC, Elixir Pharma, Titan Capital',
#        'Prosus N.V',
#        'Facebook, General Atlantic, Sequoia India, Nexus Venture Partners, Steadview Capital, Blume Ventures',
#        'Hindustan Media Ventures', 'Virat Kohli, Anushka Sharma',
#        'Rockstud Capital',
#        'IAN Fund-I,\xa0\xa0Al Falaj Investment Company (AFI)',
#        'WAVE Equity Partners, Chevron Technology Ventures, Marubeni Corporation.',
#        'Zodius Growth Fund',
#        'Mahesh Mohta, Jyoti Arora, Nachu Subramanian, Srivats',
#        'Indian Angel Network, Lead Angels, Hyderabad Angels',
#        'Triton Investment Advisors,',
#        'Accel Partners, Shunwei Capital, Good Capital',
#        'SIG Global India Fund', 'Kolte-Patil Family Office',
#        'Ashwin Khorana', 'Tarun Bhalla', 'Z3 Partners',
#        'One97 Communications', 'GGV Capital',
#        'Amrish Rau, Kunal Shah, Jitendra Gupta',
#        'Omnivore, Accel Partners, Mayfield',
#        'Kleiner Perkins, Canapi Ventures, Index Ventures, Nyca Partners, General Catalyst.',
#        'Info Edge Ltd', 'Chowdry Associates', 'Pharmacon Holdings',
#        'Blume Ventures, Sequoia', 'Think Investment', 'Udaan',
#        'Pidilite Industries', 'Softbank’s Vision Fund',
#        'LightBox Ventures', 'Xiaomi', 'Info Edge Venture Fund',
#        'Neev Fund',
#        'FirstCheque, Angellist India, Aakrit Vaish, Ranjith Radhakrishnan',
#        'Arunachal Pradesh Social Entrepreneurship Meet', 'IndiaQuotient',
#        'PayU, Fosun RZ Capital', 'Unitus Ventures.',
#        'Avaana Capital, Titan Capital', 'Institutional Investors',
#        'Tim Draper', 'Beenext', 'Reliance Industries Limited (RIL)',
#        'Equanimity Ventures', 'Mistletoe, Info Edge Asia',
#        'Bill & Melinda Gates Foundation',
#        'JITO Angel Network, Ketan Kothari, Girish Jain, Sunil Singhvi, Vinay Jain',
#        'Ant Financial', 'GrowX ventures, Prophetic Ventures',
#        'Atsushi Taira', 'Manish Choksi', 'InnoVen capital',
#        'SenseAI Ventures',
#        'Tiger Global Management, Sequoia Capital India, Singapore’s Economic Development Board (EBD)',
#        'Aquiline Technology Growth (ATG), RTP Global, Sequoia India',
#        'Frontline Strategy Finds, SucSEED Venture Partners LLP',
#        'Tiger Global, Steadview Capital, DF International Private Partners',
#        'Schroder Adveq', 'A91 Partners, Faering Capital, TVS Capital',
#        'Tahoe Investment Group, Mercer Investment', 'Mastercard',
#        'SOSV, Chinaccelerator', 'Tiger Global, Steadview Capital',
#        'She Capital',
#        'Green Shots Capital, Alfa Ventures, Real Time Venture, Petrotech, Steel City Securities, Lalit Wadhwa, Dr Kriti Maroli',
#        'Yuj Ventures', 'Accel Partners, B Capital',
#        'Sequoia Capital, Matrix Partners India',
#        'Ginni International, Elisa Khong, Sandeep Singh, VegInvest',
#        'SoftBank Group', 'Sony Innovation Fund',
#        'Amit Singal, Manish Aggarwal',
#        'Windrose Capital, ITI Growth Opportunities Venture Fund',
#        'Yatra Angel Network (YAN)', 'WestBridge Capital',
#        'Sprout Venture Partners, Indian Angel Network', 'La Gajjar Group',
#        'ICONIQ Capital', 'Matrix Partners India',
#        'Sequoia Capital, Ribbit Capital, Amazon, Saif Partners',
#        'Flipkart India, Singapore-based GEC3',
#        'Omnivore, Insitor Impact Asia Fund', 'Kalaari Capital',
#        'Suma Soft Pvt Ltd',
#        'Sprout Venture Partners, JITO Angel Network, LetsVenture',
#        'Refex Capital', 'James Murdoch-led Lupa Systems',
#        'Lightspeed Venture Partners, Sequoia Surge',
#        'Omidyar Network India', 'Space Capital',
#        'IIM Ahmedabad’s incubator (CIIE.CO),Chandigarh Angels Network',
#        'Iron Pillar', 'Lightbox. Social Capital, Dunce Capital',
#        'GMO Payment Gateway', 'Tiger Global', 'The Chennai Angels (TCA)',
#        'HNIs in India, Japan, and the US', 'Vishnu Reddy',
#        'Zerodha fintech fund, Rainmatter', 'Austrian Bank', 'Alibaba',
#        'TechnoGen', 'NorthStar, Vinod Khatumal',
#        'Chiratae Ventures, Sequoia Capital, Orios Venture Partners',
#        'Sprout venture partners', 'DSG Consumer Partners, Blume Ventures',
#        'Sequoia India, Ribbit Capital', 'Verlinvest',
#        'SIG Global India Fund LLP.'], dtype=object)

# %%
df20[df20["Investor"].isnull() | (df20["Investor"] == "")|(df20["Investor"] == "nan")]
# Out:
#                   Company/Brand Founded               HeadQuarter  \
# 21           SucSEED Indovation    2016                 Hyderabad
# 24             Circle of Angels    2018                   Gurgaon
# 44             PointOne Capital    2020                 Bangalore
# 65                       Toppeq    2019                    Mumbai
# 131                  PlayerzPot    2015                    Mumbai
# 151                   BlackSoil    2016                    Mumbai
# 162                 Jade Forest     NaN                 New Delhi
# 237                   GoodGamer    2020                 Bangalore
# 241                    SoOLEGAL    2015                 New Delhi
# 244                 Hire Me Car     NaN                     Noida
# 262              Phononic Vibes    2018  Milano, Lombardia, Italy
# 274                     Antaios    2016                    France
# 283                       Livve    2015                    Cochin
# 305             Sapio Analytics    2018                    Mumbai
# 316  AnalytIQSports's SuperCric    2019                 Bangalore
# 318                   GenieTalk    2016                    Indore
# 325                     BestDoc    2016                     Kochi
# 329           Inflexor Ventures    2020                    Mumbai
# 332                      LetsUp    2015                    Mumbai
# 335                     SignalX    2018                 Hyderabad
# 337      Vesta Space Technology    2018                      Pune
# 338                       Dozee    2015                 Bangalore
# 346               3one4 Capital    2016                 Bangalore
# 347                      WE-Hub    2018                 Hyderabad
# 349                      Vicara    2017                 Bangalore
# 363                  ConnectedH    2016                   Gurgaon
# 365                      QShala    2014                 Bangalore
# 368                Customfit ai    2019                 Bangalore
# 381                  MobiGarage    2017                 New Delhi
# 389                  AFK Gaming    2012                    Mumbai
# 394           GullyBuy Software    2019                      Pune
# 395                   Recordent    2019                 Hyderabad
# 397                       Penny    2020                    Riyadh
# 401                 ClanConnect     NaN                 New Delhi
# 410                   PumPumPum    2018                   Gurgaon
# 436                      Eloelo    2020                 Bangalore
# 451                       Pulse    2015                    Mumbai
# 462           Chiratae Ventures    2018                 Bangalore
#
#                     Sector                                       What it does  \
# 21              Technology  SucSEED INDOVATION FACILITATES ACCESS TO CAPIT...
# 24              Technology  Circles of Angels aims to solve this issue thr...
# 44       Banking & Finance                 Pre-seed/Seed focussed VC investor
# 65                    None              SaaS-based equity management platform
# 131  Media & Entertainment  Favorite fantasy cricket, football & kabaddi l...
# 151             Technology  Blacksoil Advisory is an independent boutique ...
# 162                   None  NATURALLY THE BEST From zero artificial ingred...
# 237                   None  GoodGamer is India's first Daily Fantasy Sport...
# 241                  Legal  SoOLEGAL is a global integrated directory of l...
# 244                   None  India's largest cloud based digital discovery ...
# 262             Technology  Phononic Vibes introduces a new patented techn...
# 274                   None  Developer of memory-based technology intended ...
# 283                   None  An online platform where both owners and tenan...
# 305                   None  Sapio Analytics provides AI-powered policymaki...
# 316  Media & Entertainment  SuperCric is India's first strategy Cricket Ma...
# 318                   None  GenieTalk as a virtual assistant uses AI to br...
# 325                 Health  An Intelligent Patient Relationship Management...
# 329             Technology  Experienced Venture Capital-General Partner fo...
# 332  Media & Entertainment  Provides News, Jobs, Information & Entertainme...
# 335                   None  An AI-powered SaaS platform for corporate risk...
# 337             Technology  VestaSpace Technology specialises in making sm...
# 338                 Health  Dozee offers health and wellness monitoring pr...
# 346      Banking & Finance  Use transformative capital and a deep involvem...
# 347                   None  WE HUB is the first-of-its-kind and only State...
# 349             Technology  A deep tech startup pioneering in motion-based...
# 363                 Health  The company’s vision is simple – Connected Hea...
# 365             Technology  A platform that helps kids learn about life sk...
# 368                   None  Operates on a SaaS model by providing a hyper-...
# 381       Digital_Platform  An ecommerce platform for refurbished electron...
# 389  Media & Entertainment  AFK Gaming is a media and entertainment and ga...
# 394             Technology  To deliver a solution that will provide shoppi...
# 395             Technology  A technology-enabled platform that helps MSMEs...
# 397                   None  Offer various development solutions and mainly...
# 401                   None  AI-driven influencer marketing platform ClanCo...
# 410             Technology                  Pumpumpum is a car rental company
# 436                   None  Social Commerce Venture for Wellness. View com...
# 451             Technology  Helps people navigate through and profit off f...
# 462      Banking & Finance  A leading tech venture capital fund focused on...
#
#                                               Founders Investor     Amount($)  \
# 21                                    Vikrant Varshney      NaN    $5,000,000
# 24                                      Karanpal Singh      NaN    $3,000,000
# 44                                           Mihir Jha      NaN           NaN
# 65                                      Nandini Sankar      NaN   Undisclosed
# 131                              Yogesh, Mitesh Gangar      NaN    $3,000,000
# 151                                       Ankur Bansal      NaN   $10,000,000
# 162                        Punweet Singh, Shuchir Suri      NaN      $250,000
# 237                                  Charles Creighton      NaN    $2,500,000
# 241                                        Manish Kaul      NaN    $4,000,000
# 244                                      Pankaj Sharma      NaN   Undisclosed
# 262  Andrea Boeri, Braghin Francesco, Giovanni Cape...      NaN    $2,300,000
# 274                               Jean Pierre Nozieres      NaN   $11,000,000
# 283                                      Maya Lakshman      NaN    $1,500,000
# 305                   Ashwin Srivastava, Hardik Somani      NaN      $150,000
# 316       Suhail Chandhok, Arvind Sivdas, Dhanya Param      NaN   Undisclosed
# 318          Santosh Kataria, Ankit Kimtee, Vivek Jain      NaN      $750,000
# 325                Afsal Salu, Fayaz Bin Abdu, Soudabi      NaN    $2,100,000
# 329  Parampara Capital, Venkat Vallabhaneni, Jatin ...      NaN   $10,000,000
# 332                                       Suhas raikar      NaN   Undisclosed
# 335                                Govind Balachandran      NaN      $750,000
# 337                                 Arun Kumar Sureban      NaN   $10,000,000
# 338                                    Gaurav Parchani      NaN    $1,600,000
# 346                           Pranav Pai, Siddarth Pai      NaN  $100,000,000
# 347                                     Deepthi Ravula      NaN   Undisclosed
# 349                    Abhishek Satish, Adarsh Warrier      NaN   Undisclosed
# 363                        Shubham Gupta, Suresh Singh      NaN   Undisclosed
# 365                   Sachin Ravi, Raghav Chakravarthy      NaN      $300,000
# 368                      Ashwin Kumar, Shoaib Mohammed      NaN   Undisclosed
# 381                      Vaibhav Kapoor, Pulkit Kapoor      NaN   Undisclosed
# 389                                      Nishant Patel      NaN      $200,000
# 394                                    Shirish Deodhar      NaN      $543,000
# 395                                     Harish Mamtani      NaN   Undisclosed
# 397    Iyad Aldalooj, Majid Aldalooj, Mohammed Ibrahim      NaN    $1,300,000
# 401                   Kunal Kishore Sinha, Sagar Pushp      NaN      $600,000
# 410                        Tarun Lawadia, Sameer Kalra      NaN      $360,000
# 436                       Saurabh Pandey, Akshay Dubey      NaN      $450,000
# 451                            Amit Dhakad, Hiral Jain      NaN      $750,000
# 462               Vaishali Kulkarni, Arjun Singh Bajwa      NaN   Undisclosed
#
#             Stage Unnamed: 9
# 21            NaN        NaN
# 24            NaN        NaN
# 44            NaN        NaN
# 65           Seed        NaN
# 131      Series A        NaN
# 151           NaN        NaN
# 162          Seed        NaN
# 237          Seed        NaN
# 241           NaN        NaN
# 244          Seed        NaN
# 262           NaN        NaN
# 274           NaN        NaN
# 283          Seed        NaN
# 305           NaN        NaN
# 316           NaN        NaN
# 318           NaN        NaN
# 325           NaN        NaN
# 329           NaN        NaN
# 332           NaN        NaN
# 335           NaN        NaN
# 337           NaN        NaN
# 338           NaN        NaN
# 346           NaN        NaN
# 347           NaN        NaN
# 349           NaN        NaN
# 363           NaN        NaN
# 365           NaN        NaN
# 368           NaN        NaN
# 381  Pre-series A        NaN
# 389  Pre-series A        NaN
# 394  Pre-series A        NaN
# 395          Seed        NaN
# 397          Seed        NaN
# 401          Seed        NaN
# 410          Debt        NaN
# 436          Seed        NaN
# 451  Pre-series A        NaN
# 462  Seed Funding        NaN

# %%
# Using the replace() method to replace the specified values (empty string '', comma ,, and NaN np.nan) in the "Founders" column with NaN (np.nan)
df20["Investor"] = df20["Investor"].replace(['', ',', np.nan], np.nan)

# %% [markdown]
# ### Amount($) column

# %%
df20["Amount($)"].unique()
# Out:
# array(['$200,000', '$100,000', 'Undisclosed', '$400,000', '$340,000',
#        '$600,000', '$45,000,000', '$1,000,000', '$2,000,000',
#        '$1,200,000', '$660,000,000', '$120,000', '$7,500,000',
#        '$5,000,000', '$500,000', '$3,000,000', '$10,000,000',
#        '$145,000,000', '$100,000,000', nan, '$21,000,000', '$4,000,000',
#        '$20,000,000', '$560,000', '$275,000', '$4,500,000', '$15,000,000',
#        '$390,000,000', '$7,000,000', '$5,100,000', '$700,000,000',
#        '$2,300,000', '$700,000', '$19,000,000', '$9,000,000',
#        '$40,000,000', '$750,000', '$1,500,000', '$7,800,000',
#        '$50,000,000', '$80,000,000', '$30,000,000', '$1,700,000',
#        '$2,500,000', '$40,000', '$33,000,000', '$35,000,000', '$300,000',
#        '$25,000,000', '$3,500,000', '$200,000,000', '$6,000,000',
#        '$1,300,000', '$4,100,000', '$575,000', '$800,000', '$28,000,000',
#        '$18,000,000', '$3,200,000', '$900,000', '$250,000', '$4,700,000',
#        '$75,000,000', '$8,000,000', '$121,000,000', '$55,000,000',
#        '$3,300,000', '$11,000,000', '$16,000,000', '$5,400,000',
#        '$150,000,000', '$4,200,000', '$22,000,000', '$52,000,000',
#        '$1,100,000', '$118,000,000', '$1,600,000', '$18,500,000',
#        '$70,000,000,000', '$800,000,000', '$400,000,000', '$150,000',
#        '$176,000,000', '$60,000,000', '$470,000', '$240,000',
#        '$3,000,000,000', '$74,000,000', '$62,000,000', '$2,100,000',
#        '$500,000,000', '$12,500,000', '$2,200,000,000', '$5,060,000',
#        '$225,000,000', '$24,700,000', '$7,700,000', '$1,90,67,328',
#        '$51,000,000', '$115,000', '$54,000', '$20,000', '$803,146',
#        '$238,000', '$10,220,000', '$1,020,000', '$12,000,000',
#        '$13,400,000', '$170,000,000', '$2,900,000', '$543,000',
#        '$90,000,000', '$3,400,000', '$23,000,000', '$8,090,000',
#        '$1,030,000', '$5,040,000', '$360,000', '$1,400,000', '$650,000',
#        '$54,000,000', '$42,500,000', '$11,370,000', '$325,000',
#        '$410,000', '$450,000', '$682,000', '$4,050,000', '$1,050,000',
#        '$1,080,000', '$4,300,000', '$6,800,000', '$2,110,000',
#        '$887,000, $23,000,000', '$764,000', '$603,000', '$409,000',
#        '$292,000', '$286,000', '$136,000', '$800,000,000 to $850,000,000',
#        '$546,000', '$887,000', '$43,000', '$40,900', '$2,200,000',
#        '$5,660,000', '$350,000', '$110,000', '$122,000,000',
#        '$11,635,000', '$2,800,000', '$1,065,000', '$669,000',
#        '$16,076,000', '$649,600', '$6,700,000', '$220,000', '$266,500',
#        '$2,879,000', '$26,500,000', '$351,000', '$ 8,700,000',
#        '$46,761,000', '$175,000', '9.600,000', '$11,241,000', '$804,000',
#        '$1,340,000', '$467,000', '$133,000', '$3,823,000', '$934,000',
#        '$293,000', '$198,000', '$927,000', '$971,000', '$3,060,000',
#        '$1,862,000', '$232,000', '$2,888,000', '$1,328,000',
#        '$15,500,000', '$56,000,000', '$2,250,000', '$16,753,000',
#        '$3,700,000', '$1,470,000', '$530,000', '$267,000', '$3,344,000',
#        '$7,200,000', '$2,743,000', '$6,082,000', '$6,609,000',
#        '$27,700,000', '$5,940,000', '$3,964,000', '$5,500,000',
#        '$197,000', '$4,327,000', '$459,000', '$3,937,000', '$1,313,500',
#        '$229,800', '$5,305,000', '$264,000', '$1,750,000', '$5,967,000',
#        '$2,980,000', 'Undiclsosed', '$323,000', '$1,326,000',
#        '$27,000,000', '$5,200,000', '$2,530,000', '$792,000',
#        '$11,363,000', '$1,715,000', '$329,000', '$5,271,000',
#        '$8,700,000', '$3,226,000', '$5,900,000', '$44,000,000',
#        '$3,879,000', '$13,000,000', '$8,800,000', '$9,500,000',
#        '$920,000', '$35,600,000', '$9,400,000', '$790,000', '$480,000',
#        '$160,000', '$8,200,000', '$4,257,000', '$1,410,000', '$349,800',
#        '$786,000', '$2,004,000', '$123,000,000', '$248,000',
#        '$24,000,000', '$14,259,000', '$24,500,000', '$3,800,000',
#        '$18,370,000', '$68,525,000', '$4,800,000', '$1,834,000',
#        '$23,850,000', '$43,000,000', '$21,600,000', '$4,598,000',
#        '$13,137,000', '$115,000,000', '$3,900,000', '$670,000',
#        '42.23,000', '$8,500,000', '$3,148,000', '$2,600,000', '25,58,000',
#        '$4,049,500', '$10,500,000', '$6,500,000', '$43,700,000',
#        '$13,800,000', '$306,900', '$420,000', '$627,300', '$113,000,000',
#        '$32,000,000', '$110,000,000', '$1,397,000', '$448,500',
#        '$7,975,700', '$330,000', '$5,600,000', '$1,402,000',
#        '$21,500,000', '$296,000,000', '$4,900,000', '$1,402,400',
#        '$12,618,300', '$9,900,000', '$982,530', '$70,185,200',
#        '$210,000,000', '$84,000,000', '$39,000,000', '$2,700,000',
#        '$1,403,400', '$105,000,000', '$103,000,000', '$281,300',
#        '$12,700', '$25,000', '$97,500,000', '$507,000', 'Undislosed',
#        '$8,400,000', '$18,300,000', '$125,000,000', '$181,000',
#        '$280,000', '$14,700,000', '$13,200,000', '$8,043,000'],
#       dtype=object)

# %%
#Replacing the amounts "887000 23000000" and 800000000 to 850000000 with their avaerage
df20["Amount($)"].replace("$887000, $23000000", "$119435500", inplace = True, regex=True)
df20["Amount($)"].replace("$800000000 to $850000000", "$825000000", inplace = True, regex=True)

# %%
# Extract rows that do not have the currency sign $ in the amount column
df20[-df20['Amount($)'].astype(str).str.contains('\$', na=False)]
# Out:
#           Company/Brand Founded HeadQuarter      Sector  \
# 2          PadCare Labs    2018        Pune  Technology
# 7                 Metvy    2018     Gurgaon  Technology
# 11               Medfin    2017   Bangalore      Health
# 12              MasterG    2015   New Delhi     Fashion
# 18            Pine Labs    1998       Noida  Technology
# ...                 ...     ...         ...         ...
# 1023          Skilancer     NaN       Noida  Technology
# 1024  Harappa Education     NaN   New Delhi  Technology
# 1028            PayMart    2015  Chandigarh        None
# 1040           BuildPan    2019      Indore        None
# 1046            FarmERP    2001        Pune        None
#
#                                            What it does  \
# 2      Converting bio-hazardous waste to harmless waste
# 7     AI driven networking platform for individuals ...
# 11    Medfin is a Discovery platform for medical pro...
# 12    MasterG is a design and skill development orga...
# 18    A merchant platform company that provides fina...
# ...                                                 ...
# 1023       Solar module cleaning system [MCS] providers
# 1024     Provides online courses on foundational skills
# 1028  Provides cardless cash withdrawals through sma...
# 1040  It helps developers to test, integrate and dep...
# 1046  Smart agriculture management ERP software plat...
#
#                                       Founders  \
# 2                              Ajinkya Dhariya
# 7                             Shawrya Mehrotra
# 11    Arjun Kumar, Arun Kumar, Sidharth Gurjar
# 12                               Gayatri Jolly
# 18                                  Amrish Rau
# ...                                        ...
# 1023                              Neeraj Kumar
# 1024                         Pramath Raj Sinha
# 1028                               Amit Narang
# 1040          Sonal Khandelwal, Vaibhav Tiwari
# 1046             Santosh Shinde, Sanjay Borkar
#
#                                                Investor    Amount($)  \
# 2                                        Venture Center  Undisclosed
# 7                                            HostelFund  Undisclosed
# 11                       Axilor Ventures, S.D. Shibulal  Undisclosed
# 12                        Acumen Fund's angel programme  Undisclosed
# 18                         Mastercard, Temasek Holdings  Undisclosed
# ...                                                 ...          ...
# 1023                                  Venture Catalysts  Undisclosed
# 1024                     James Murdoch-led Lupa Systems  Undisclosed
# 1028  IIM Ahmedabad’s incubator (CIIE.CO),Chandigarh...  Undisclosed
# 1040                   HNIs in India, Japan, and the US  Undisclosed
# 1046                                          TechnoGen  Undisclosed
#
#            Stage Unnamed: 9
# 2       Pre-seed        NaN
# 7     Pre-series        NaN
# 11      Series A        NaN
# 12           NaN        NaN
# 18           NaN        NaN
# ...          ...        ...
# 1023         NaN        NaN
# 1024         NaN        NaN
# 1028         NaN        NaN
# 1040  Seed Round        NaN
# 1046    Series A        NaN
#
# [251 rows x 10 columns]

# %%
# Remove commas
df20["Amount($)"] = df20["Amount($)"].str.replace(',', '')
# Replace undisclosed with NaN
df20["Amount($)"] = df20["Amount($)"].replace(["Undisclosed", "Undiclsosed"], np.nan)  
# Remove '$' sign
df20["Amount($)"] = df20["Amount($)"].str.replace('\$', '')  
# Extract numeric values
df20["Amount($)"] = df20["Amount($)"].str.extract('(\d+\.?\d*)', expand=False).astype(float)
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\3000296687.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df20["Amount($)"] = df20["Amount($)"].str.replace('\$', '')

# %%
df20["Amount($)"].unique()
# Out:
# array([2.0000000e+05, 1.0000000e+05,           nan, 4.0000000e+05,
#        3.4000000e+05, 6.0000000e+05, 4.5000000e+07, 1.0000000e+06,
#        2.0000000e+06, 1.2000000e+06, 6.6000000e+08, 1.2000000e+05,
#        7.5000000e+06, 5.0000000e+06, 5.0000000e+05, 3.0000000e+06,
#        1.0000000e+07, 1.4500000e+08, 1.0000000e+08, 2.1000000e+07,
#        4.0000000e+06, 2.0000000e+07, 5.6000000e+05, 2.7500000e+05,
#        4.5000000e+06, 1.5000000e+07, 3.9000000e+08, 7.0000000e+06,
#        5.1000000e+06, 7.0000000e+08, 2.3000000e+06, 7.0000000e+05,
#        1.9000000e+07, 9.0000000e+06, 4.0000000e+07, 7.5000000e+05,
#        1.5000000e+06, 7.8000000e+06, 5.0000000e+07, 8.0000000e+07,
#        3.0000000e+07, 1.7000000e+06, 2.5000000e+06, 4.0000000e+04,
#        3.3000000e+07, 3.5000000e+07, 3.0000000e+05, 2.5000000e+07,
#        3.5000000e+06, 2.0000000e+08, 6.0000000e+06, 1.3000000e+06,
#        4.1000000e+06, 5.7500000e+05, 8.0000000e+05, 2.8000000e+07,
#        1.8000000e+07, 3.2000000e+06, 9.0000000e+05, 2.5000000e+05,
#        4.7000000e+06, 7.5000000e+07, 8.0000000e+06, 1.2100000e+08,
#        5.5000000e+07, 3.3000000e+06, 1.1000000e+07, 1.6000000e+07,
#        5.4000000e+06, 1.5000000e+08, 4.2000000e+06, 2.2000000e+07,
#        5.2000000e+07, 1.1000000e+06, 1.1800000e+08, 1.6000000e+06,
#        1.8500000e+07, 7.0000000e+10, 8.0000000e+08, 4.0000000e+08,
#        1.5000000e+05, 1.7600000e+08, 6.0000000e+07, 4.7000000e+05,
#        2.4000000e+05, 3.0000000e+09, 7.4000000e+07, 6.2000000e+07,
#        2.1000000e+06, 5.0000000e+08, 1.2500000e+07, 2.2000000e+09,
#        5.0600000e+06, 2.2500000e+08, 2.4700000e+07, 7.7000000e+06,
#        1.9067328e+07, 5.1000000e+07, 1.1500000e+05, 5.4000000e+04,
#        2.0000000e+04, 8.0314600e+05, 2.3800000e+05, 1.0220000e+07,
#        1.0200000e+06, 1.2000000e+07, 1.3400000e+07, 1.7000000e+08,
#        2.9000000e+06, 5.4300000e+05, 9.0000000e+07, 3.4000000e+06,
#        2.3000000e+07, 8.0900000e+06, 1.0300000e+06, 5.0400000e+06,
#        3.6000000e+05, 1.4000000e+06, 6.5000000e+05, 5.4000000e+07,
#        4.2500000e+07, 1.1370000e+07, 3.2500000e+05, 4.1000000e+05,
#        4.5000000e+05, 6.8200000e+05, 4.0500000e+06, 1.0500000e+06,
#        1.0800000e+06, 4.3000000e+06, 6.8000000e+06, 2.1100000e+06,
#        8.8700000e+05, 7.6400000e+05, 6.0300000e+05, 4.0900000e+05,
#        2.9200000e+05, 2.8600000e+05, 1.3600000e+05, 5.4600000e+05,
#        4.3000000e+04, 4.0900000e+04, 2.2000000e+06, 5.6600000e+06,
#        3.5000000e+05, 1.1000000e+05, 1.2200000e+08, 1.1635000e+07,
#        2.8000000e+06, 1.0650000e+06, 6.6900000e+05, 1.6076000e+07,
#        6.4960000e+05, 6.7000000e+06, 2.2000000e+05, 2.6650000e+05,
#        2.8790000e+06, 2.6500000e+07, 3.5100000e+05, 8.7000000e+06,
#        4.6761000e+07, 1.7500000e+05, 9.6000000e+00, 1.1241000e+07,
#        8.0400000e+05, 1.3400000e+06, 4.6700000e+05, 1.3300000e+05,
#        3.8230000e+06, 9.3400000e+05, 2.9300000e+05, 1.9800000e+05,
#        9.2700000e+05, 9.7100000e+05, 3.0600000e+06, 1.8620000e+06,
#        2.3200000e+05, 2.8880000e+06, 1.3280000e+06, 1.5500000e+07,
#        5.6000000e+07, 2.2500000e+06, 1.6753000e+07, 3.7000000e+06,
#        1.4700000e+06, 5.3000000e+05, 2.6700000e+05, 3.3440000e+06,
#        7.2000000e+06, 2.7430000e+06, 6.0820000e+06, 6.6090000e+06,
#        2.7700000e+07, 5.9400000e+06, 3.9640000e+06, 5.5000000e+06,
#        1.9700000e+05, 4.3270000e+06, 4.5900000e+05, 3.9370000e+06,
#        1.3135000e+06, 2.2980000e+05, 5.3050000e+06, 2.6400000e+05,
#        1.7500000e+06, 5.9670000e+06, 2.9800000e+06, 3.2300000e+05,
#        1.3260000e+06, 2.7000000e+07, 5.2000000e+06, 2.5300000e+06,
#        7.9200000e+05, 1.1363000e+07, 1.7150000e+06, 3.2900000e+05,
#        5.2710000e+06, 3.2260000e+06, 5.9000000e+06, 4.4000000e+07,
#        3.8790000e+06, 1.3000000e+07, 8.8000000e+06, 9.5000000e+06,
#        9.2000000e+05, 3.5600000e+07, 9.4000000e+06, 7.9000000e+05,
#        4.8000000e+05, 1.6000000e+05, 8.2000000e+06, 4.2570000e+06,
#        1.4100000e+06, 3.4980000e+05, 7.8600000e+05, 2.0040000e+06,
#        1.2300000e+08, 2.4800000e+05, 2.4000000e+07, 1.4259000e+07,
#        2.4500000e+07, 3.8000000e+06, 1.8370000e+07, 6.8525000e+07,
#        4.8000000e+06, 1.8340000e+06, 2.3850000e+07, 4.3000000e+07,
#        2.1600000e+07, 4.5980000e+06, 1.3137000e+07, 1.1500000e+08,
#        3.9000000e+06, 6.7000000e+05, 4.2230000e+01, 8.5000000e+06,
#        3.1480000e+06, 2.6000000e+06, 2.5580000e+06, 4.0495000e+06,
#        1.0500000e+07, 6.5000000e+06, 4.3700000e+07, 1.3800000e+07,
#        3.0690000e+05, 4.2000000e+05, 6.2730000e+05, 1.1300000e+08,
#        3.2000000e+07, 1.1000000e+08, 1.3970000e+06, 4.4850000e+05,
#        7.9757000e+06, 3.3000000e+05, 5.6000000e+06, 1.4020000e+06,
#        2.1500000e+07, 2.9600000e+08, 4.9000000e+06, 1.4024000e+06,
#        1.2618300e+07, 9.9000000e+06, 9.8253000e+05, 7.0185200e+07,
#        2.1000000e+08, 8.4000000e+07, 3.9000000e+07, 2.7000000e+06,
#        1.4034000e+06, 1.0500000e+08, 1.0300000e+08, 2.8130000e+05,
#        1.2700000e+04, 2.5000000e+04, 9.7500000e+07, 5.0700000e+05,
#        8.4000000e+06, 1.8300000e+07, 1.2500000e+08, 1.8100000e+05,
#        2.8000000e+05, 1.4700000e+07, 1.3200000e+07, 8.0430000e+06])

# %%
#replace all the 0 with the mean 
df20['Amount($)'].replace(to_replace= np.nan, value = df20['Amount($)'].mean(), inplace = True)
#replace the nan values with mean 
#df20.fillna(df20.mean(), inplace=True)

# %%
## to confirm 
df20["Amount($)"].unique()
# Out:
# array([2.00000000e+05, 1.00000000e+05, 1.13208877e+08, 4.00000000e+05,
#        3.40000000e+05, 6.00000000e+05, 4.50000000e+07, 1.00000000e+06,
#        2.00000000e+06, 1.20000000e+06, 6.60000000e+08, 1.20000000e+05,
#        7.50000000e+06, 5.00000000e+06, 5.00000000e+05, 3.00000000e+06,
#        1.00000000e+07, 1.45000000e+08, 1.00000000e+08, 2.10000000e+07,
#        4.00000000e+06, 2.00000000e+07, 5.60000000e+05, 2.75000000e+05,
#        4.50000000e+06, 1.50000000e+07, 3.90000000e+08, 7.00000000e+06,
#        5.10000000e+06, 7.00000000e+08, 2.30000000e+06, 7.00000000e+05,
#        1.90000000e+07, 9.00000000e+06, 4.00000000e+07, 7.50000000e+05,
#        1.50000000e+06, 7.80000000e+06, 5.00000000e+07, 8.00000000e+07,
#        3.00000000e+07, 1.70000000e+06, 2.50000000e+06, 4.00000000e+04,
#        3.30000000e+07, 3.50000000e+07, 3.00000000e+05, 2.50000000e+07,
#        3.50000000e+06, 2.00000000e+08, 6.00000000e+06, 1.30000000e+06,
#        4.10000000e+06, 5.75000000e+05, 8.00000000e+05, 2.80000000e+07,
#        1.80000000e+07, 3.20000000e+06, 9.00000000e+05, 2.50000000e+05,
#        4.70000000e+06, 7.50000000e+07, 8.00000000e+06, 1.21000000e+08,
#        5.50000000e+07, 3.30000000e+06, 1.10000000e+07, 1.60000000e+07,
#        5.40000000e+06, 1.50000000e+08, 4.20000000e+06, 2.20000000e+07,
#        5.20000000e+07, 1.10000000e+06, 1.18000000e+08, 1.60000000e+06,
#        1.85000000e+07, 7.00000000e+10, 8.00000000e+08, 4.00000000e+08,
#        1.50000000e+05, 1.76000000e+08, 6.00000000e+07, 4.70000000e+05,
#        2.40000000e+05, 3.00000000e+09, 7.40000000e+07, 6.20000000e+07,
#        2.10000000e+06, 5.00000000e+08, 1.25000000e+07, 2.20000000e+09,
#        5.06000000e+06, 2.25000000e+08, 2.47000000e+07, 7.70000000e+06,
#        1.90673280e+07, 5.10000000e+07, 1.15000000e+05, 5.40000000e+04,
#        2.00000000e+04, 8.03146000e+05, 2.38000000e+05, 1.02200000e+07,
#        1.02000000e+06, 1.20000000e+07, 1.34000000e+07, 1.70000000e+08,
#        2.90000000e+06, 5.43000000e+05, 9.00000000e+07, 3.40000000e+06,
#        2.30000000e+07, 8.09000000e+06, 1.03000000e+06, 5.04000000e+06,
#        3.60000000e+05, 1.40000000e+06, 6.50000000e+05, 5.40000000e+07,
#        4.25000000e+07, 1.13700000e+07, 3.25000000e+05, 4.10000000e+05,
#        4.50000000e+05, 6.82000000e+05, 4.05000000e+06, 1.05000000e+06,
#        1.08000000e+06, 4.30000000e+06, 6.80000000e+06, 2.11000000e+06,
#        8.87000000e+05, 7.64000000e+05, 6.03000000e+05, 4.09000000e+05,
#        2.92000000e+05, 2.86000000e+05, 1.36000000e+05, 5.46000000e+05,
#        4.30000000e+04, 4.09000000e+04, 2.20000000e+06, 5.66000000e+06,
#        3.50000000e+05, 1.10000000e+05, 1.22000000e+08, 1.16350000e+07,
#        2.80000000e+06, 1.06500000e+06, 6.69000000e+05, 1.60760000e+07,
#        6.49600000e+05, 6.70000000e+06, 2.20000000e+05, 2.66500000e+05,
#        2.87900000e+06, 2.65000000e+07, 3.51000000e+05, 8.70000000e+06,
#        4.67610000e+07, 1.75000000e+05, 9.60000000e+00, 1.12410000e+07,
#        8.04000000e+05, 1.34000000e+06, 4.67000000e+05, 1.33000000e+05,
#        3.82300000e+06, 9.34000000e+05, 2.93000000e+05, 1.98000000e+05,
#        9.27000000e+05, 9.71000000e+05, 3.06000000e+06, 1.86200000e+06,
#        2.32000000e+05, 2.88800000e+06, 1.32800000e+06, 1.55000000e+07,
#        5.60000000e+07, 2.25000000e+06, 1.67530000e+07, 3.70000000e+06,
#        1.47000000e+06, 5.30000000e+05, 2.67000000e+05, 3.34400000e+06,
#        7.20000000e+06, 2.74300000e+06, 6.08200000e+06, 6.60900000e+06,
#        2.77000000e+07, 5.94000000e+06, 3.96400000e+06, 5.50000000e+06,
#        1.97000000e+05, 4.32700000e+06, 4.59000000e+05, 3.93700000e+06,
#        1.31350000e+06, 2.29800000e+05, 5.30500000e+06, 2.64000000e+05,
#        1.75000000e+06, 5.96700000e+06, 2.98000000e+06, 3.23000000e+05,
#        1.32600000e+06, 2.70000000e+07, 5.20000000e+06, 2.53000000e+06,
#        7.92000000e+05, 1.13630000e+07, 1.71500000e+06, 3.29000000e+05,
#        5.27100000e+06, 3.22600000e+06, 5.90000000e+06, 4.40000000e+07,
#        3.87900000e+06, 1.30000000e+07, 8.80000000e+06, 9.50000000e+06,
#        9.20000000e+05, 3.56000000e+07, 9.40000000e+06, 7.90000000e+05,
#        4.80000000e+05, 1.60000000e+05, 8.20000000e+06, 4.25700000e+06,
#        1.41000000e+06, 3.49800000e+05, 7.86000000e+05, 2.00400000e+06,
#        1.23000000e+08, 2.48000000e+05, 2.40000000e+07, 1.42590000e+07,
#        2.45000000e+07, 3.80000000e+06, 1.83700000e+07, 6.85250000e+07,
#        4.80000000e+06, 1.83400000e+06, 2.38500000e+07, 4.30000000e+07,
#        2.16000000e+07, 4.59800000e+06, 1.31370000e+07, 1.15000000e+08,
#        3.90000000e+06, 6.70000000e+05, 4.22300000e+01, 8.50000000e+06,
#        3.14800000e+06, 2.60000000e+06, 2.55800000e+06, 4.04950000e+06,
#        1.05000000e+07, 6.50000000e+06, 4.37000000e+07, 1.38000000e+07,
#        3.06900000e+05, 4.20000000e+05, 6.27300000e+05, 1.13000000e+08,
#        3.20000000e+07, 1.10000000e+08, 1.39700000e+06, 4.48500000e+05,
#        7.97570000e+06, 3.30000000e+05, 5.60000000e+06, 1.40200000e+06,
#        2.15000000e+07, 2.96000000e+08, 4.90000000e+06, 1.40240000e+06,
#        1.26183000e+07, 9.90000000e+06, 9.82530000e+05, 7.01852000e+07,
#        2.10000000e+08, 8.40000000e+07, 3.90000000e+07, 2.70000000e+06,
#        1.40340000e+06, 1.05000000e+08, 1.03000000e+08, 2.81300000e+05,
#        1.27000000e+04, 2.50000000e+04, 9.75000000e+07, 5.07000000e+05,
#        8.40000000e+06, 1.83000000e+07, 1.25000000e+08, 1.81000000e+05,
#        2.80000000e+05, 1.47000000e+07, 1.32000000e+07, 8.04300000e+06])

# %% [markdown]
# ## Stage column

# %%
df20["Stage"].unique()
# Out:
# array([nan, 'Pre-seed', 'Seed', 'Pre-series A', 'Pre-series', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Series E', 'Bridge', 'Series D', 'Series B2', 'Series F',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Seed round',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Pre series A', 'Seed Round', 'Bridge Round', 'Pre seed round',
#        'Pre series B', 'Pre series C', 'Seed Investment', 'Series D1',
#        'Mid series', 'Series C, D', 'Seed funding'], dtype=object)

# %%
# Convert to lowercase and strip leading/trailing spaces
df20["Stage"] = df20["Stage"].str.lower().str.strip()

# Replace similar stage names
df20["Stage"] = df20["Stage"].replace({
    'pre series a': 'pre-series a',
    'pre series b': 'pre-series b',
    'pre series c': 'pre-series c',
    'pre seed': 'pre-seed',
    'seed funding': 'seed',
    'seed investment': 'seed',
    'seed round': 'seed',
    'seed a': 'seed',
    'angel round': 'seed',
    'seed round & series a': 'seed',
    'pre seed round': 'pre-seed',
    'pre series a1': 'pre-series a',
    'series a-1': 'series a',
    'series c, d': 'series c',
    'pre-seed round': 'pre-seed',
    'pre series b': 'pre-series b',
    'pre series a': 'pre-series a',
    'seed round': 'seed' })

# %%
# Handle missing or unknown values
df20["Stage"] = df20["Stage"].replace([' ', ',', 'nan'], np.nan)

# %%
# Standardize the sector names by converting them to title case
df20["Stage"] = df20["Stage"].str.title()

# %%
df20['Stage'].unique()
# Out:
# array([nan, 'Pre-Seed', 'Seed', 'Pre-Series A', 'Pre-Series', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Pre-Series C', 'Pre-Series B',
#        'Series E', 'Bridge', 'Series D', 'Series B2', 'Series F',
#        'Pre- Series A', 'Edge', 'Series H', 'Series E2', 'Bridge Round',
#        'Series D1', 'Mid Series'], dtype=object)

# %%
#Drop the Unnamed: 9 and 'what is does culumn' from the data set
df20.drop(columns=['What it does', 'Unnamed: 9'], inplace=True)

# %%
df20.head(20)
# Out:
#         Company/Brand Founded HeadQuarter            Sector  \
# 0          Aqgromalin    2019     Chennai       Agriculture
# 1            Krayonnz    2019   Bangalore        Technology
# 2        PadCare Labs    2018        Pune        Technology
# 3               NCOME    2020   New Delhi        Technology
# 4          Gramophone    2016      Indore       Agriculture
# 5              qZense    2019   Bangalore       Agriculture
# 6        MyClassboard    2008   Hyderabad        Technology
# 7               Metvy    2018     Gurgaon        Technology
# 8              Rupeek    2015   Bangalore        Technology
# 9           Gig India    2017        Pune        Technology
# 10        Slurrp Farm    2016     Gurgaon  Food & Beverages
# 11             Medfin    2017   Bangalore            Health
# 12            MasterG    2015   New Delhi           Fashion
# 13           Brila 91    2014   New Delhi  Food & Beverages
# 14         FoodyBuddy    2015     Belgaum  Food & Beverages
# 15             Zomato    2008     Gurgaon  Food & Beverages
# 16          OurEye.ai    2020   Bangalore              None
# 17         Shiprocket    2017   New Delhi  Digital_Platform
# 18          Pine Labs    1998       Noida        Technology
# 19  Moneyboxx Finance    2019   New Delhi        Technology
#
#                                              Founders  \
# 0                     Prasanna Manogaran, Bharani C L
# 1                    Saurabh Dixit, Gurudutt Upadhyay
# 2                                     Ajinkya Dhariya
# 3                                       Ritesh Tiwari
# 4   Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# 5                        Rubal Chib, Dr Srishti Batra
# 6                                      Ajay Sakhamuri
# 7                                    Shawrya Mehrotra
# 8             Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 9                        Aditya Shirole, Sahil Sharma
# 10                                    Meghana Narayan
# 11           Arjun Kumar, Arun Kumar, Sidharth Gurjar
# 12                                      Gayatri Jolly
# 13                                         Ankur Jain
# 14         Akil Sethuraman, Anup Gopinath, Rachna Rao
# 15      Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah
# 16     Miran Junaidi, Saurabh Ghanekar, Sourav Sanyal
# 17        Gautam Kapoor, Saahil Goel, Vishesh Khurana
# 18                                         Amrish Rau
# 19                                   Prashant Agarwal
#
#                                           Investor     Amount($)         Stage
# 0                                  Angel investors  2.000000e+05           NaN
# 1                                  GSF Accelerator  1.000000e+05      Pre-Seed
# 2                                   Venture Center  1.132089e+08      Pre-Seed
# 3              Venture Catalysts, PointOne Capital  4.000000e+05           NaN
# 4              Siana Capital Management, Info Edge  3.400000e+05           NaN
# 5    Venture Catalysts, 9Unicorns Accelerator Fund  6.000000e+05          Seed
# 6                                      ICICI Bank.  6.000000e+05  Pre-Series A
# 7                                       HostelFund  1.132089e+08    Pre-Series
# 8     KB Investment, Bertelsmann India Investments  4.500000e+07      Series C
# 9        Shantanu Deshpande, Subramaniam Ramadorai  1.000000e+06  Pre-Series A
# 10                               Fireside Ventures  2.000000e+06      Series A
# 11                  Axilor Ventures, S.D. Shibulal  1.132089e+08      Series A
# 12                   Acumen Fund's angel programme  1.132089e+08           NaN
# 13     Sequoia Capital India, Sixth Sense Ventures  1.200000e+06           NaN
# 14                                     Rebel Foods  6.000000e+05           NaN
# 15                   Kora, Tiger Global Management  6.600000e+08           NaN
# 16                         100X VC, Amara Ventures  1.200000e+05           NaN
# 17  Bertelsmann India Investments, InnoVen Capital  7.500000e+06      Series C
# 18                    Mastercard, Temasek Holdings  1.132089e+08           NaN
# 19                              BlackSoil, Caspian  1.000000e+06           NaN

# %%
# Create the funding year column
df20['Funding Year']= 2020
df20
# Out:
#      Company/Brand Founded HeadQuarter       Sector  \
# 0       Aqgromalin    2019     Chennai  Agriculture
# 1         Krayonnz    2019   Bangalore   Technology
# 2     PadCare Labs    2018        Pune   Technology
# 3            NCOME    2020   New Delhi   Technology
# 4       Gramophone    2016      Indore  Agriculture
# ...            ...     ...         ...          ...
# 1050  Leverage Edu     NaN   New Delhi   Technology
# 1051         EpiFi     NaN         NaN         None
# 1052       Purplle    2012      Mumbai       Beauty
# 1053        Shuttl    2015   New Delhi    Transport
# 1054         Pando    2017     Chennai         None
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor     Amount($)     Stage  \
# 0                           Angel investors  2.000000e+05       NaN
# 1                           GSF Accelerator  1.000000e+05  Pre-Seed
# 2                            Venture Center  1.132089e+08  Pre-Seed
# 3       Venture Catalysts, PointOne Capital  4.000000e+05       NaN
# 4       Siana Capital Management, Info Edge  3.400000e+05       NaN
# ...                                     ...           ...       ...
# 1050  DSG Consumer Partners, Blume Ventures  1.500000e+06       NaN
# 1051          Sequoia India, Ribbit Capital  1.320000e+07      Seed
# 1052                             Verlinvest  8.000000e+06       NaN
# 1053             SIG Global India Fund LLP.  8.043000e+06  Series C
# 1054                      Chiratae Ventures  9.000000e+06  Series A
#
#       Funding Year
# 0             2020
# 1             2020
# 2             2020
# 3             2020
# 4             2020
# ...            ...
# 1050          2020
# 1051          2020
# 1052          2020
# 1053          2020
# 1054          2020
#
# [1055 rows x 9 columns]

# %%
# Drop duplicates in the dataset
df20.drop_duplicates(inplace=True)
df20
# Out:
#      Company/Brand Founded HeadQuarter       Sector  \
# 0       Aqgromalin    2019     Chennai  Agriculture
# 1         Krayonnz    2019   Bangalore   Technology
# 2     PadCare Labs    2018        Pune   Technology
# 3            NCOME    2020   New Delhi   Technology
# 4       Gramophone    2016      Indore  Agriculture
# ...            ...     ...         ...          ...
# 1050  Leverage Edu     NaN   New Delhi   Technology
# 1051         EpiFi     NaN         NaN         None
# 1052       Purplle    2012      Mumbai       Beauty
# 1053        Shuttl    2015   New Delhi    Transport
# 1054         Pando    2017     Chennai         None
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor     Amount($)     Stage  \
# 0                           Angel investors  2.000000e+05       NaN
# 1                           GSF Accelerator  1.000000e+05  Pre-Seed
# 2                            Venture Center  1.132089e+08  Pre-Seed
# 3       Venture Catalysts, PointOne Capital  4.000000e+05       NaN
# 4       Siana Capital Management, Info Edge  3.400000e+05       NaN
# ...                                     ...           ...       ...
# 1050  DSG Consumer Partners, Blume Ventures  1.500000e+06       NaN
# 1051          Sequoia India, Ribbit Capital  1.320000e+07      Seed
# 1052                             Verlinvest  8.000000e+06       NaN
# 1053             SIG Global India Fund LLP.  8.043000e+06  Series C
# 1054                      Chiratae Ventures  9.000000e+06  Series A
#
#       Funding Year
# 0             2020
# 1             2020
# 2             2020
# 3             2020
# 4             2020
# ...            ...
# 1050          2020
# 1051          2020
# 1052          2020
# 1053          2020
# 1054          2020
#
# [1051 rows x 9 columns]

# %%
df20.to_csv("India_funding2020_cleaned.csv", index=False)

# %% [markdown]
# # Cleaning 2019 dataset

# %%
df19.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
#Check the number of rows and columns
df19.shape
# Out:
# (89, 9)

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
# Check for missing values

df19.isna().sum()
# Out:
# Company/Brand     0
# Founded          29
# HeadQuarter      19
# Sector            5
# What it does      0
# Founders          3
# Investor          0
# Amount($)         0
# Stage            46
# dtype: int64

# %%
df19['Founded'].unique()
# Out:
# array([  nan, 2014., 2004., 2013., 2010., 2018., 2019., 2017., 2011.,
#        2015., 2016., 2012., 2008.])

# %%
# replace NaN using np.nan

df19["Founded"].replace("nan", np.nan, inplace = True, regex=True)

#Change the datatype of Founded column from Float to int first to remove the decimal
# fill NaN rows with 0
df19['Founded'] = df19['Founded'].replace(np.nan, 0)
df19['Founded'] = df19['Founded'].astype(int)
df19['Founded']
# Out:
# 0        0
# 1     2014
# 2        0
# 3     2014
# 4     2004
#       ...
# 84       0
# 85    2013
# 86    2016
# 87    2015
# 88       0
# Name: Founded, Length: 89, dtype: int32

# %%
# Check for number of unique values
df19['Sector'].nunique()
# Out:
# 52

# %%
# Check the unique values
df19['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %% [markdown]
# ##### Categorize sector column into less unique values

# %%
# Loop to get the values in the unique values in the Industry column

sector_name_list = df19['Sector'].tolist()

unique_sectors = []
for sector in sector_name_list:
    if sector not in unique_sectors:
        unique_sectors.append(sector)


        
for sector in unique_sectors:
    print(sector)
# Out:
# Ecommerce
# Edtech
# Interior design
# AgriTech
# Technology
# SaaS
# AI & Tech
# E-commerce
# E-commerce & AR
# Fintech
# HR tech
# Food tech
# Health
# Healthcare
# Safety tech
# Pharmaceutical
# Insurance technology
# AI
# Foodtech
# Food
# IoT
# E-marketplace
# Robotics & AI
# Logistics
# Travel
# Manufacturing
# Food & Nutrition
# Social Media
# nan
# E-Sports
# Cosmetics
# B2B
# Jewellery
# B2B Supply Chain
# Games
# Food & tech
# Accomodation
# Automotive tech
# Legal tech
# Mutual Funds
# Cybersecurity
# Automobile
# Sports
# Healthtech
# Yoga & wellness
# Virtual Banking
# Transportation
# Transport & Rentals
# Marketing & Customer loyalty
# Infratech
# Hospitality
# Automobile & Technology
# Banking

# %%
Agriculture = ['AgriTech',]

Marketing = ['Marketing & Customer loyalty']

Technology = ['Legal tech','Automotive tech','Cybersecurity','Automobile','Infratech','Automobile & Technology','Robotics & AI','E-marketplace','IoT','Foodtech','AI','Ecommerce','Technology','SaaS','AI & Tech','E-commerce','E-commerce & AR','Fintech','HR tech','Safety tech']

Bank_Fin = ['Mutual Funds','Virtual Banking','Banking']

Insurance = ['Insurance technology']

Food = ['Food tech','Food','Food & Nutrition','Food & tech']

Transport = ['Logistics','Travel','Transportation','Transport & Rentals']

Energy = ['Renewable Energy','Clean Energy','Energy']

Health = ['Pharmaceutical','Healthtech','Health']

Sport_Fit = ['Yoga & wellness','Sports','Yoga & wellness']

Manufacturing = ['Manufacturing']

Beauty = ['Cosmetics']

Info_media = ['Social Media','E-Sports','Games']

Services = ['Interior design','Accomodation']

Edu = ['Edtech']

Hospitality = ['Hospitality']

Fashion = ['Fashion','Eyewear','Jewellery']

B2B = ['B2B','B2B Supply Chain']

nan = ['nan']

# %%
# Write function to put values into new categories

def new_cat(Industry):
    if Industry in Marketing:
        return 'Marketing'
    elif Industry in Agriculture:
        return 'Agriculture'
    elif Industry in Bank_Fin:
        return 'Banking & Finance'
    elif Industry in Insurance:
        return 'Insurance'
    elif Industry in Technology:
        return 'Technology'
    elif Industry in Food:
        return 'Food & Beverage'
    elif Industry in Transport :
        return 'Logistics'
    elif Industry in Energy:
        return 'Energy'
    elif Industry in Health:
        return 'Health'
    elif Industry in Sport_Fit :
        return 'Sports & Fitness'
    elif Industry in Manufacturing:
        return 'Manufacturing'
    elif Industry in Beauty:
        return 'Beauty'
    elif Industry in Info_media:
        return 'Media & Entertainment'
    elif Industry in Services:
        return 'Services'
    elif Industry in Edu:
        return 'Education'
    elif Industry in nan:
        return 'NaN'
    elif Industry in Hospitality:
        return 'Hospitality'
    elif Industry in Fashion:
        return 'Fashion'
    elif Industry in B2B:
        return 'B2B'

# %%
# Apply function to Sector column for new categorization 
df19['Sector'] = df19['Sector'].apply(new_cat)
df19['Sector'].nunique()
# Out:
# 17

# %%
# confirm the Sector names 
df19.head(20)
# Out:
#                    Company/Brand  Founded HeadQuarter           Sector  \
# 0                 Bombay Shaving        0         NaN       Technology
# 1                      Ruangguru     2014      Mumbai        Education
# 2                       Eduisfun        0      Mumbai        Education
# 3                       HomeLane     2014     Chennai         Services
# 4                       Nu Genes     2004   Telangana      Agriculture
# 5                       FlytBase        0        Pune       Technology
# 6                          Finly        0   Bangalore       Technology
# 7                       Kratikal     2013       Noida       Technology
# 8                      Quantiphi        0         NaN       Technology
# 9                       Lenskart     2010       Delhi       Technology
# 10                    Cub McPaws     2010      Mumbai       Technology
# 11                      Appnomic        0   Bangalore       Technology
# 12                    Kaleidofin     2018     Chennai       Technology
# 13                     JobSquare     2019   Ahmedabad       Technology
# 14                   Open Secret        0         NaN  Food & Beverage
# 15                        LivFin     2017       Delhi       Technology
# 16                        Byju's     2011         NaN        Education
# 17                    Zest Money     2015   Bangalore       Technology
# 18                       Witblox     2014         NaN        Education
# 19  Azah Personal Care Pvt. Ltd.     2018    Gurugram           Health
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# 5                         A drone automation platform
# 6   It builds software products that makes work si...
# 7   It is a product-based cybersecurity solutions ...
# 8   It is an AI and big data services company prov...
# 9                             It is a eyewear company
# 10  A B2C  brand that focusses on premium and comf...
# 11  It is a self-healing enterprise, the IT operat...
# 12  Platform that provides complete financial solu...
# 13  Technology-based platform that is connecting s...
# 14           It produces and sells top quality snacks
# 15  Grants small business loans, supply chain fina...
# 16                   Provides online learning classes
# 17  Uses AI to do risk profiling of e-commerce con...
# 18          Offers a range of robotics learning tools
# 19  Aims to solve some problems in the feminine hy...
#
#                                            Founders  \
# 0                                Shantanu Deshpande
# 1             Adamas Belva Syah Devara, Iman Usman.
# 2                                     Jatin Solanki
# 3                      Srikanth Iyer, Rama Harinath
# 4                            Narayana Reddy Punyala
# 5                                       Nitin Gupta
# 6                         Vivek AG, Veekshith C Rai
# 7   Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa
# 8                                    Renuka Ramnath
# 9      Peyush Bansal, Amit Chaudhary, Sumeet Kapahi
# 10                          Abhay Bhat, Kinnar Shah
# 11                                    D Padmanabhan
# 12                Puneet Gupta, Sucharita Mukherjee
# 13                                     Ishit Jethwa
# 14                      Ahana Gautam, Udit Kejriwal
# 15                                  Rakesh Malhotra
# 16                                  Byju Raveendran
# 17       Chapman, Priya Sharma, Ashish Anantharaman
# 18                                        Amit Modi
# 19                         Mohammed, Shashwat Diesh
#
#                                              Investor     Amount($)  \
# 0                                Sixth Sense Ventures    $6,300,000
# 1                                    General Atlantic  $150,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4            Innovation in Food and Agriculture (IFA)    $6,000,000
# 5                                         Undisclosed   Undisclosed
# 6   Social Capital, AngelList India, Gemba Capital...   Undisclosed
# 7          Gilda VC, Art Venture, Rajeev Chitrabhanu.    $1,000,000
# 8                Multiples Alternate Asset Management   $20,000,000
# 9                                            SoftBank  $275,000,000
# 10                                  Venture Catalysts   Undisclosed
# 11                                   Avataar Ventures   $22,000,000
# 12                                         Oikocredit    $5,000,000
# 13                                      Titan Capital      $140,500
# 14                                    Matrix Partners   Undisclosed
# 15         German development finance institution DEG    $5,000,000
# 16  South Africa’s Naspers Ventures, the CPP Inves...  $540,000,000
# 17                                     Goldman Sachs.   $15,000,000
# 18                              Mumbai Angels Network      $182,700
# 19                          Kunal Bahl, Rohit Bansal.   Undisclosed
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# 5             NaN
# 6             NaN
# 7    Pre series A
# 8        Series A
# 9        Series G
# 10            NaN
# 11            NaN
# 12       Series A
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17       Series B
# 18            NaN
# 19   Pre series A

# %% [markdown]
# #### Exploring HeadQuarter Column

# %%
df19['HeadQuarter'].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# New Dehli is in Dehli so change all entries under New Dehli to Dehli

df19['HeadQuarter'].replace('New Delhi', 'Delhi', inplace=True)
df19[df19['HeadQuarter']=='New Delhi'].sum()
# Out:
# Company/Brand    0.0
# Founded          0.0
# HeadQuarter      0.0
# Sector           0.0
# What it does     0.0
# Founders         0.0
# Investor         0.0
# Amount($)        0.0
# Stage            0.0
# dtype: float64

# %%
#### Exploring 'What it does' column
df19['What it does']
# Out:
# 0            Provides a range of male grooming products
# 1     A learning platform that provides topic-based ...
# 2               It aims to make learning fun via games.
# 3                 Provides interior designing solutions
# 4     It is a seed company engaged in production, pr...
#                             ...
# 84    It connects client requirements to their suppl...
# 85                  Provides rooms for comfortable stay
# 86    Find automobile repair and maintenance service...
# 87                                  Online car retailer
# 88                Organised Non-Banking Finance Company
# Name: What it does, Length: 89, dtype: object

# %%
# 'What it does' column contains categorical data that will not be needed for this analysis so will be dropped
df19.drop(columns='What it does', axis=1,inplace = True)
df19.columns
# Out:
# Index(['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'Founders',
#        'Investor', 'Amount($)', 'Stage'],
#       dtype='object')

# %% [markdown]
# ## Exploring Amount($) column

# %%
df19['Amount($)']
# Out:
# 0       $6,300,000
# 1     $150,000,000
# 2      $28,000,000
# 3      $30,000,000
# 4       $6,000,000
#           ...
# 84     $20,000,000
# 85    $693,000,000
# 86      $5,000,000
# 87     $50,000,000
# 88     $33,000,000
# Name: Amount($), Length: 89, dtype: object

# %%
# Remove commas, dollar signs and change dtype to float 
df19['Amount($)'] = df19['Amount($)'].str.replace('$', '')
# Replace commas
df19['Amount($)'] = df19['Amount($)'].str.replace(',','')
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\742994300.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df19['Amount($)'] = df19['Amount($)'].str.replace('$', '')

# %%
# Amount column contains some other values that need to be changed before converting to float
df19['Amount($)'] = df19['Amount($)'].str.replace('Undisclosed','')
df19['Amount($)'] = df19['Amount($)'].replace('',np.nan)
# Change dtype to float
df19['Amount($)'] = df19['Amount($)'].astype(float)

# %%
#replace all the 0 with the mean 
df19['Amount($)'].replace(to_replace= np.nan, value = df19['Amount($)'].mean(), inplace = True)

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        89 non-null     int32
#  2   HeadQuarter    70 non-null     object
#  3   Sector         83 non-null     object
#  4   Founders       86 non-null     object
#  5   Investor       89 non-null     object
#  6   Amount($)      89 non-null     float64
#  7   Stage          43 non-null     object
# dtypes: float64(1), int32(1), object(6)
# memory usage: 5.3+ KB

# %%
df19['Amount($)'].unique()
# Out:
# array([6.30000000e+06, 1.50000000e+08, 2.80000000e+07, 3.00000000e+07,
#        6.00000000e+06, 4.33303013e+07, 1.00000000e+06, 2.00000000e+07,
#        2.75000000e+08, 2.20000000e+07, 5.00000000e+06, 1.40500000e+05,
#        5.40000000e+08, 1.50000000e+07, 1.82700000e+05, 1.20000000e+07,
#        1.10000000e+07, 1.55000000e+07, 1.50000000e+06, 5.50000000e+06,
#        2.50000000e+06, 1.40000000e+05, 2.30000000e+08, 4.94000000e+07,
#        3.20000000e+07, 2.60000000e+07, 1.50000000e+05, 4.00000000e+05,
#        2.00000000e+06, 1.00000000e+08, 8.00000000e+06, 1.00000000e+05,
#        5.00000000e+07, 1.20000000e+08, 4.00000000e+06, 6.80000000e+06,
#        3.60000000e+07, 5.70000000e+06, 2.50000000e+07, 6.00000000e+05,
#        7.00000000e+07, 6.00000000e+07, 2.20000000e+05, 2.80000000e+06,
#        2.10000000e+06, 7.00000000e+06, 3.11000000e+08, 4.80000000e+06,
#        6.93000000e+08, 3.30000000e+07])

# %% [markdown]
# ## Exploring Founded column

# %%
df19['Founded'].unique()
# Out:
# array([   0, 2014, 2004, 2013, 2010, 2018, 2019, 2017, 2011, 2015, 2016,
#        2012, 2008])

# %%
df19['Founded'].isna().sum()
# Out:
# 0

# %%
# Replace null values with NaN
df19['Amount($)'] = df19['Amount($)'].replace('',np.nan)
# Replace null values in Founded with median year
df19['Founded'].replace(to_replace = np.nan, value = df19['Founded'].median(), inplace = True)

# %%
df19['Founded'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Exploring Stage column

# %%
df19['Stage'].unique()
# Out:
# array([nan, 'Series C', 'Fresh funding', 'Series D', 'Pre series A',
#        'Series A', 'Series G', 'Series B', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series E', 'Series F', 'Series B+',
#        'Seed round', 'Pre-series A'], dtype=object)

# %%
# checking for null values
df19['Stage'].isna().sum()
# Out:
# 46

# %%
# Create new column Funding year to keep datasets identifiable
df19["Funding Year"] = "2019"

# %%
df19.head()
# Out:
#     Company/Brand  Founded HeadQuarter       Sector  \
# 0  Bombay Shaving        0         NaN   Technology
# 1       Ruangguru     2014      Mumbai    Education
# 2        Eduisfun        0      Mumbai    Education
# 3        HomeLane     2014     Chennai     Services
# 4        Nu Genes     2004   Telangana  Agriculture
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor    Amount($)  \
# 0                               Sixth Sense Ventures    6300000.0
# 1                                   General Atlantic  150000000.0
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000.0
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   30000000.0
# 4           Innovation in Food and Agriculture (IFA)    6000000.0
#
#            Stage Funding Year
# 0            NaN         2019
# 1       Series C         2019
# 2  Fresh funding         2019
# 3       Series D         2019
# 4            NaN         2019

# %% [markdown]
# # Cleaning 2018 Data

# %%
df18.head(50)
# Out:
#                               Company Name  \
# 0                          TheCollegeFever
# 1                          Happy Cow Dairy
# 2                               MyLoanCare
# 3                              PayMe India
# 4                                 Eunimart
# 5                                   Hasura
# 6                                Tripshelf
# 7                             Hyperdata.IO
# 8                             Freightwalla
# 9                       Microchip Payments
# 10              BizCrum Infotech Pvt. Ltd.
# 11                                 Emojifi
# 12                                   Flock
# 13                               Freshboxx
# 14              Wide Mobility Mechatronics
# 15                                 Pitstop
# 16                                  Mihuru
# 17                                    Fyle
# 18                                AppWharf
# 19        Antariksh Waste Ventures Pvt ltd
# 20                                Cogoport
# 21                              PaisaDukan
# 22                       Sleepy Owl Coffee
# 23                                BlueJack
# 24                               PregBuddy
# 25                     AgNext Technologies
# 26                                   Pando
# 27                                 Mintifi
# 28                                 Carcrew
# 29                                 NicheAI
# 30                            Chariot Tech
# 31  Ideal Insurance Brokers/ 121Policy.com
# 32                                 Loanzen
# 33                      Mojro Technologies
# 34                              Elemential
# 35                               Loadshare
# 36                                 Yumlane
# 37                           Kriger Campus
# 38                              Pipa+Bella
# 39                              Kaleidofin
# 40                        Chakr Innovation
# 41                             IndigoLearn
# 42                                  UClean
# 43                                Coutloot
# 44                               Letstrack
# 45                                 Pooltoo
# 46                                   Finzy
# 47                              Fitternity
# 48                                   Keito
# 49                      Tolet for Students
#
#                                              Industry Round/Series  \
# 0   Brand Marketing, Event Promotion, Marketing, S...         Seed
# 1                                Agriculture, Farming         Seed
# 2    Credit, Financial Services, Lending, Marketplace     Series A
# 3                         Financial Services, FinTech        Angel
# 4                  E-Commerce Platforms, Retail, SaaS         Seed
# 5                    Cloud Infrastructure, PaaS, SaaS         Seed
# 6                      Internet, Leisure, Marketplace         Seed
# 7                                     Market Research        Angel
# 8        Information Services, Information Technology         Seed
# 9                                     Mobile Payments         Seed
# 10                                         B2B, Shoes         Seed
# 11                                           Internet         Seed
# 12  Apps, Collaboration, Developer Platform, Enter...         Seed
# 13                                      Food Delivery         Seed
# 14                              Industrial Automation         Seed
# 15        Automotive, Search Engine, Service Industry         Seed
# 16                          Finance, Internet, Travel         Seed
# 17  Accounting, Business Information Systems, Busi...         Seed
# 18  Artificial Intelligence, Product Search, SaaS,...         Seed
# 19               Internet of Things, Waste Management         Seed
# 20  Air Transportation, Freight Service, Logistics...     Series A
# 21                                 Financial Services         Seed
# 22                                  Food and Beverage         Seed
# 23                                Autonomous Vehicles         Seed
# 24  Enterprise Software, Health Care, Hospital, Pa...         Seed
# 25          Agriculture, Analytics, Big Data, Farming     Series A
# 26                 Logistics, Supply Chain Management         Seed
# 27                        Financial Services, Lending         Seed
# 28            Automotive, Marketplace, Online Portals         Seed
# 29                            Artificial Intelligence        Angel
# 30             Internet of Things, Telecommunications         Seed
# 31                                          Insurance         Seed
# 32                                 Financial Services         Seed
# 33  Information Technology, Logistics, Supply Chai...         Seed
# 34   Blockchain, Developer Tools, Enterprise Software         Seed
# 35  Industrial Automation, Logistics, Supply Chain...     Series A
# 36       Food and Beverage, Food Delivery, Snack Food     Series A
# 37                                          Education         Seed
# 38               E-Commerce, Fashion, Jewelry, Retail     Series A
# 39                                 Financial Services         Seed
# 40                                   Renewable Energy         Seed
# 41                              E-Learning, Education         Seed
# 42  Clean Energy, CleanTech, Laundry and Dry-cleaning         Seed
# 43                        E-Commerce, Fashion, Mobile         Seed
# 44         Apps, Messaging, Navigation, Public Safety         Seed
# 45                                     Transportation         Seed
# 46                        Financial Services, Lending         Seed
# 47                     Fitness, Health Care, Wellness         Seed
# 48  Artificial Intelligence, Machine Learning, Saa...         Seed
# 49                                        Hospitality         Seed
#
#           Amount                          Location  \
# 0         250000       Bangalore, Karnataka, India
# 1    ₹40,000,000        Mumbai, Maharashtra, India
# 2    ₹65,000,000           Gurgaon, Haryana, India
# 3        2000000       Noida, Uttar Pradesh, India
# 4              —  Hyderabad, Andhra Pradesh, India
# 5        1600000       Bengaluru, Karnataka, India
# 6    ₹16,000,000             Kalkaji, Delhi, India
# 7    ₹50,000,000  Hyderabad, Andhra Pradesh, India
# 8              —        Mumbai, Maharashtra, India
# 9              —       Bangalore, Karnataka, India
# 10             —               Delhi, Delhi, India
# 11             —       Bengaluru, Karnataka, India
# 12             —                       India, Asia
# 13             —           Hubli, Karnataka, India
# 14             —       Bangalore, Karnataka, India
# 15  ₹100,000,000       Bengaluru, Karnataka, India
# 16        150000        Mumbai, Maharashtra, India
# 17       1100000       Bengaluru, Karnataka, India
# 18             —           New Delhi, Delhi, India
# 19      ₹500,000        Chennai, Tamil Nadu, India
# 20       6000000        Mumbai, Maharashtra, India
# 21        650000        Mumbai, Maharashtra, India
# 22   ₹35,000,000           New Delhi, Delhi, India
# 23   ₹64,000,000               Delhi, Delhi, India
# 24             —       Bengaluru, Karnataka, India
# 25             —             Mohali, Punjab, India
# 26       2000000        Chennai, Tamil Nadu, India
# 27       2000000        Mumbai, Maharashtra, India
# 28       2000000        Mumbai, Maharashtra, India
# 29             —  Hyderabad, Andhra Pradesh, India
# 30   ₹20,000,000           New Delhi, Delhi, India
# 31       1000000       Kolkata, West Bengal, India
# 32             —       Bangalore, Karnataka, India
# 33        650000       Bengaluru, Karnataka, India
# 34       1000000        Mumbai, Maharashtra, India
# 35       5000000       Bengaluru, Karnataka, India
# 36       4000000        Mumbai, Maharashtra, India
# 37   ₹30,000,000           New Delhi, Delhi, India
# 38       1000000        Mumbai, Maharashtra, India
# 39       2800000        Chennai, Tamil Nadu, India
# 40             —           New Delhi, Delhi, India
# 41        150000  Hyderabad, Andhra Pradesh, India
# 42   ₹40,000,000                       India, Asia
# 43       1000000        Mumbai, Maharashtra, India
# 44       1700000           New Delhi, Delhi, India
# 45             —           New Delhi, Delhi, India
# 46       1300000       Bangalore, Karnataka, India
# 47       2000000        Mumbai, Maharashtra, India
# 48             —          Pune, Maharashtra, India
# 49    ₹5,000,000         Jodhpur, Rajasthan, India
#
#                                         About Company
# 0   TheCollegeFever is a hub for fun, fiesta and f...
# 1   A startup which aggregates milk from dairy far...
# 2           Leading Online Loans Marketplace in India
# 3   PayMe India is an innovative FinTech organizat...
# 4   Eunimart is a one stop solution for merchants ...
# 5   Hasura is a platform that allows developers to...
# 6   Tripshelf is an online market place for holida...
# 7   Hyperdata combines advanced machine learning w...
# 8   Freightwalla is an international forwarder tha...
# 9   Microchip payments is a mobile-based payment a...
# 10           Building Transactionary B2B Marketplaces
# 11  Emojifi is an app that provides live emoji, st...
# 12  Flock is a real-time messaging and collaborati...
# 13  Freshboxx is incubated at Sandbox Startups, a ...
# 14  Wide Mobility Mechatronics is a Private Compan...
# 15  Pitstop offers general repair and maintenance ...
# 16  Mihuru is an online platform which gives micro...
# 17  Fyle is an intelligent expense management plat...
# 18  Appwharf is an intelligent assistant that help...
# 19                  Waste Management for Smart Cities
# 20  Cogoport is a platform that provides freight b...
# 21                 A P2P lending marketplace platform
# 22  Makers of a signature coffee that's exceptiona...
# 23      Delhi-based online used vehicles marketplace.
# 24  PregBuddy is a smart connected care platform f...
# 25  AgNext is an agricultural sensing and solution...
# 26  A startup which digitizes logistics operations...
# 27            Online lending startup based in Mumbai.
# 28             India's Online Auto Repair Marketplace
# 29  Early stage Artificial Intelligence (AI) start...
# 30  Chariot Tech is an Internet of Things (IoT) st...
# 31  Ideal Insurance Broking is one of the leaders ...
# 32  Loanzen helps small businesses get unsecured w...
# 33  Mojro envisions to be the world's largest tech...
# 34  Blockchain Development Platform To Design, Run...
# 35  LoadShare is India’s fastest growing logistics...
# 36  Food startup Yumlane operated by QwikPik Techn...
# 37                              A Education Start Up.
# 38  Pipa+Bella is an online store aimed at selling...
# 39                                A fintech platform.
# 40  Chakr has developed the world’s first retro-fi...
# 41  India's the premier education destination cate...
# 42  UClean is a tech enabled laundry service provi...
# 43                  The Fashion Re-commerce platform.
# 44  Letstrack GPS tracking devices to track your k...
# 45    Pooltoo offers a premium ride sharing platform.
# 46  finzy is the premier peer to peer lending solu...
# 47  India's largest online fitness platform that p...
# 48         Building an Intelligent Digital Assistant.
# 49  Reserve your Room, Hostel or Paying Guest, whi...

# %%
# Check the data types of the columns
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
# Check for missing values
df18.isnull().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %% [markdown]
# #### A simple dive into the data shows some missing data replaced by dashes(-) in multiple columns

# %%
# Find the missing values
df18[df18['Industry']=='—']
# Out:
#                                       Company Name Industry  \
# 58                        MissMalini Entertainment        —
# 105                               Jagaran Microfin        —
# 121                                         FLEECA        —
# 146                                      WheelsEMI        —
# 153                                    Fric Bergen        —
# 174                                       Deftouch        —
# 181                                    Corefactors        —
# 210                                Cell Propulsion        —
# 230                                       Flathalt        —
# 235                                          dishq        —
# 238                                          Trell        —
# 242                                 HousingMan.com        —
# 243                       Steradian Semiconductors        —
# 247                                   SaffronStays        —
# 251                           Inner Being Wellness        —
# 257                                       MySEODoc        —
# 258       ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED        —
# 259                                     Scale Labs        —
# 294                                       Roadcast        —
# 325                                         Toffee        —
# 326                                     ORO Wealth        —
# 346                                        Finwego        —
# 398                                           Cred        —
# 457                                          Origo        —
# 472                                      Sequretek        —
# 473               Avenues Payments India Pvt. Ltd.        —
# 476  Planet11 eCommerce Solutions India (Avenue11)        —
# 478                                 Iba Halal Care        —
# 480                                         Togedr        —
# 510                                       Scholify        —
#
#                  Round/Series        Amount                          Location  \
# 58                       Seed  ₹104,000,000        Mumbai, Maharashtra, India
# 105            Debt Financing  ₹550,000,000       Kolkata, West Bengal, India
# 121                      Seed             —          Jaipur, Rajasthan, India
# 146                  Series B   $14,000,000          Pune, Maharashtra, India
# 153  Venture - Series Unknown             —           Alwar, Rajasthan, India
# 174                      Seed             —       Bangalore, Karnataka, India
# 181                      Seed             —       Bangalore, Karnataka, India
# 210                      Seed    ₹7,000,000       Bangalore, Karnataka, India
# 230                     Angel         50000           Gurgaon, Haryana, India
# 235                      Seed        400000       Bengaluru, Karnataka, India
# 238                      Seed       1250000  Bangalore City, Karnataka, India
# 242                      Seed  ₹103,000,000       Bengaluru, Karnataka, India
# 243                      Seed             —       Bangalore, Karnataka, India
# 247                      Seed       2000000        Mumbai, Maharashtra, India
# 251                     Angel   ₹35,000,000  Hyderabad, Andhra Pradesh, India
# 257                      Seed             —               Delhi, Delhi, India
# 258                      Seed      ₹200,000          Pune, Maharashtra, India
# 259                      Seed       1000000               Delhi, Delhi, India
# 294                     Angel        250000           New Delhi, Delhi, India
# 325                      Seed       1500000           Gurgaon, Haryana, India
# 326                  Series A       1600000        Mumbai, Maharashtra, India
# 346                      Seed             —        Chennai, Tamil Nadu, India
# 398                      Seed             —       Bengaluru, Karnataka, India
# 457  Venture - Series Unknown  ₹800,000,000           Gurgaon, Haryana, India
# 472  Venture - Series Unknown       3700000        Mumbai, Maharashtra, India
# 473           Corporate Round       1300000        Mumbai, Maharashtra, India
# 476           Corporate Round  ₹260,000,000       Bengaluru, Karnataka, India
# 478                  Series A  ₹150,000,000         Ahmedabad, Gujarat, India
# 480  Venture - Series Unknown             —           Gurgaon, Haryana, India
# 510                  Pre-Seed             —       Bengaluru, Karnataka, India
#
#                                          About Company
# 58   MissMalini Entertainment is a multi-platform n...
# 105  Jagaran Microfin is a Microfinance institution...
# 121            FLEECA is a Tyre Care Provider company.
# 146  WheelsEMI is the brand name of NBFC, WheelsEMI...
# 153  Fric Bergen is a leader in the specialty food ...
# 174  Deftouch is a mobile game development company ...
# 181  Corefactors is a leading campaign management, ...
# 210  Cell Propulsion is an electric mobility startu...
# 230                    FInd your Customized Home here.
# 235  dishq leverages food science and machine learn...
# 238  Trell is a location based network which helps ...
# 242        New Apartments, Flats for Sale in Bangalore
# 243  It is a fabless semiconductor company focused ...
# 247  SaffronStays connects travellers to India's In...
# 251  Inner Being Wellness manufactures beauty, well...
# 257  SEO, PPC, Search Engine Marketing, Social Medi...
# 258                           Digital Marketing Agency
# 259  Scale Labs is a cross border e-commerce soluti...
# 294  Transforming the way businesses deliver. Work-...
# 325  Toffee is a bite size, micro-event & contextua...
# 326                  Online wealth management platform
# 346  Finwego partners with Small and Medium Busines...
# 398  Cred is a platform to celebrate and reward the...
# 457  Origo Commodities, a complete post-harvest man...
# 472            Sequretek is a cyber security start-up.
# 473  Avenues Payments is an IT solutions provider f...
# 476  Planet11 is backed by SK Planet, which is a pa...
# 478       Iba Halal Care is a cosmetics brand company.
# 480  Togedr is an activity discovery & booking plat...
# 510                                            Edutech

# %%
# Replace Dashes(-) in all columns with NaN
df18 =df18.replace('—',np.nan)

# %%
##confirm the "-"
# Find the missing values
df18[df18['Industry']=='—']
# Out:
# Empty DataFrame
# Columns: [Company Name, Industry, Round/Series, Amount, Location, About Company]
# Index: []

# %% [markdown]
# #### Exploring 'About Company' column

# %%
df18['About Company'].head()
# Out:
# 0    TheCollegeFever is a hub for fun, fiesta and f...
# 1    A startup which aggregates milk from dairy far...
# 2            Leading Online Loans Marketplace in India
# 3    PayMe India is an innovative FinTech organizat...
# 4    Eunimart is a one stop solution for merchants ...
# Name: About Company, dtype: object

# %% [markdown]
# #### About Company' column has categorical data that will not be needed for the analysis and can be dropped

# %%
df18.drop(columns='About Company', axis=1,inplace = True)
df18.columns
# Out:
# Index(['Company Name', 'Industry', 'Round/Series', 'Amount', 'Location'], dtype='object')

# %% [markdown]
# #### Exploring 'Industry' column

# %%
df18['Industry']
# Out:
# 0      Brand Marketing, Event Promotion, Marketing, S...
# 1                                   Agriculture, Farming
# 2       Credit, Financial Services, Lending, Marketplace
# 3                            Financial Services, FinTech
# 4                     E-Commerce Platforms, Retail, SaaS
#                              ...
# 521     B2B, Business Development, Internet, Marketplace
# 522                                      Tourism, Travel
# 523           Food and Beverage, Food Delivery, Internet
# 524                               Information Technology
# 525           Biotechnology, Health Care, Pharmaceutical
# Name: Industry, Length: 526, dtype: object

# %% [markdown]
# #### Most of the entries in the Industry column contain more than 1 industry so keep the first industry in every entry

# %%
df18['Industry'] = df18['Industry'].str.split(',').str[0]
df18['Industry']
# Out:
# 0             Brand Marketing
# 1                 Agriculture
# 2                      Credit
# 3          Financial Services
# 4        E-Commerce Platforms
#                 ...
# 521                       B2B
# 522                   Tourism
# 523         Food and Beverage
# 524    Information Technology
# 525             Biotechnology
# Name: Industry, Length: 526, dtype: object

# %%
# Check for unique entries in Industry column
df18['Industry'].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        nan, 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear'], dtype=object)

# %%
# Check number of unique Industries
df18['Industry'].nunique()
# Out:
# 147

# %% [markdown]
# #### Industry column has many unique values. Some values may be inputted under synonyms so aggregate column into fewer unique values or categories

# %%
# Loop to get the values in the unique values in the Industry column

industry_name_list = df18['Industry'].tolist()

unique_industries = []
for industry in industry_name_list:
    if industry not in unique_industries:
        unique_industries.append(industry)


        
for industry in unique_industries:
    print(industry)
# Out:
# Brand Marketing
# Agriculture
# Credit
# Financial Services
# E-Commerce Platforms
# Cloud Infrastructure
# Internet
# Market Research
# Information Services
# Mobile Payments
# B2B
# Apps
# Food Delivery
# Industrial Automation
# Automotive
# Finance
# Accounting
# Artificial Intelligence
# Internet of Things
# Air Transportation
# Food and Beverage
# Autonomous Vehicles
# Enterprise Software
# Logistics
# Insurance
# Information Technology
# Blockchain
# Education
# E-Commerce
# Renewable Energy
# E-Learning
# Clean Energy
# Transportation
# Fitness
# Hospitality
# Media and Entertainment
# Broadcasting
# EdTech
# Health Care
# nan
# Sports
# Big Data
# Cloud Computing
# Food Processing
# Trading Platform
# Consumer Goods
# Wellness
# Fashion
# Consulting
# Biotechnology
# Communities
# Consumer
# Consumer Applications
# Mobile
# Advertising
# Marketplace
# Aerospace
# Home Decor
# Energy
# Digital Marketing
# Creative Agency
# Consumer Lending
# Health Diagnostics
# Banking
# Embedded Systems
# Beauty
# AgTech
# Credit Cards
# Software
# Manufacturing
# Hospital
# Events
# 3D Printing
# Digital Entertainment
# Funding Platform
# Classifieds
# Enterprise Resource Planning (ERP)
# Audio
# Government
# Digital Media
# Business Intelligence
# Children
# Rental
# Travel
# Wealth Management
# Veterinary
# Tourism
# Consumer Electronics
# Analytics
# Facilities Support Services
# Medical
# Music Streaming
# Retail
# Business Development
# Human Resources
# Customer Service
# Training
# Dietary Supplements
# Collaboration
# Nanotechnology
# File Sharing
# Crowdfunding
# Catering
# Computer
# Android
# Delivery
# Environmental Consulting
# Commercial Real Estate
# Delivery Service
# Basketball
# Fraud Detection
# Cryptocurrency
# Wedding
# Crowdsourcing
# Farming
# Business Travel
# Career Planning
# Medical Device
# Alternative Medicine
# Dental
# CleanTech
# Marketing
# Commercial
# Continuing Education
# Smart Cities
# Social Media
# Biopharma
# Child Care
# Health Insurance
# Gaming
# Search Engine
# Battery
# Cosmetics
# eSports
# Reading Apps
# Electric Vehicle
# Packaging Services
# Last Mile Transportation
# Cooking
# FinTech
# Online Games
# Online Portals
# Music
# News
# Industrial
# Dating
# Fantasy Sports
# Eyewear

# %%
# Create categories as lists

Agriculture = ['Agriculture','Farming']

Marketing = ['Brand Marketing','Market Research','Advertising','Digital Marketing']

Technology = ['Reading Apps','Search Engine','Smart Cities','Fraud Detection','File Sharing','Nanotechnology','Enterprise Software','E-Commerce Platforms','E-Commerce','Cloud Infrastructure','Internet','Apps','Industrial Automation','Artificial Intelligence','Internet of Things','Autonomous Vehicles','Enterprise Software','Information Technology','Industrial Automation','E-Commerce','Big Data','Cloud Computing','Trading Platform','Biotechnology','Mobile','Aerospace','Embedded Systems','AgTech','Software','Information Services','3D Printing']

Bank_Fin = ['Crowdfunding','Wealth Management','Mobile','Credit','Financial Services','Mobile Payments','Finance','Blockchain','Consumer Lending','Banking','Credit Cards','Credit']

Accounting = ['Accounting']

Insurance = ['Insurance','Health Insurance']

Food = ['Food Delivery','Food and Beverage','Food Processing']

Transport = ['Last Mile Transportation','Automotive','Air Transportation','Logistics','Transportation','Logistics']

Energy = ['Renewable Energy','Clean Energy','Energy']

Health = ['Health Care','Wellness','Health Diagnostics','Hospital','Veterinary','Medical Device','Alternative Medicine','Dental']

Sport_Fit = ['Fantasy Sports','Fitness','Sports','Basketball']

Manufacturing = ['Manufacturing', 'Industrial']

Beauty = ['Beauty','Cosmetics']

Info_media = ['Dating','News','Music','Online Portals','Online Games','eSports','Music Streaming','Digital Entertainment','Information Services','Media and Entertainment','Broadcasting']

Services = ['Packaging Services','Rental','Enterprise Resource Planning (ERP)','Consumer','Communities','Consumer Applications','Home Decor','Child care','Consumer Goods','Consulting','Marketplace','Creative Agency']

Government = ['Government','Classifieds']

Tourism = ['Tourism','Business Travel']

Events = ['Events','Wedding']

Edu = ['Education','E-Learning','EdTech','Continuing Education']

Hospitality = ['Hospitality']

Fashion = ['Fashion','Eyewear']

B2B = ['B2B']

nan = ['nan', 'Nan', 'NaN',None]

# %%
# Write function to put values into new categories
def new_cat(Industry):
    if Industry in Marketing:
        return 'Marketing'
    elif Industry in Agriculture:
        return 'Agriculture'
    elif Industry in Bank_Fin:
        return 'Banking & Finance'
    elif Industry in Accounting:
        return 'Accounting'
    elif Industry in Insurance:
        return 'Insurance'
    elif Industry in Technology:
        return 'Technology'
    elif Industry in Food:
        return 'Food & Beverage'
    elif Industry in Transport :
        return 'Logistics'
    elif Industry in Energy:
        return 'Energy'
    elif Industry in Health:
        return 'Health'
    elif Industry in Sport_Fit :
        return 'Sports & Fitness'
    elif Industry in Manufacturing:
        return 'Manufacturing'
    elif Industry in Beauty:
        return 'Beauty'
    elif Industry in Info_media:
        return 'Media & Entertainment'
    elif Industry in Services:
        return 'Services'
    elif Industry in Government:
        return 'Government'
    elif Industry in Tourism:
        return 'Tourism'
    elif Industry in Events:
        return 'Events'
    elif Industry in Edu:
        return 'Education'
    elif Industry in nan:
        return 'NaN'
    elif Industry in Hospitality:
        return 'Hospitality'
    elif Industry in Fashion:
        return 'Fashion'
    elif Industry in B2B:
        return 'B2B'

# %%
df18['Sector'] = df18['Industry'].apply(new_cat)

# %%
df18['Sector'].nunique()
# Out:
# 22

# %%
df18['Sector'].isna().sum()
# Out:
# 98

# %%
# Drop Industry column 
df18.drop('Industry', axis=1, inplace=True)

# %% [markdown]
# #### Exploring Round/Series Column

# %%
# Check for unique values
df18['Round/Series'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round'], dtype=object)

# %% [markdown]
# ##### One of the unique values is a google docs link. Drop it

# %%
# Drop the row that has google docs link
df18 = df18[df18['Round/Series'] != 'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593']

# Reset the row index
df18.reset_index(drop=True, inplace=True)

# %%
# Check for number of unique values 
df18['Round/Series'].nunique()
# Out:
# 20

# %%
df18.columns
# Out:
# Index(['Company Name', 'Round/Series', 'Amount', 'Location', 'Sector'], dtype='object')

# %% [markdown]
# #### Exploring Amount column

# %%
# Check for missing values
df18['Amount'].isna().sum()
# Out:
# 148

# %%
df18['Amount']
# Out:
# 0           250000
# 1      ₹40,000,000
# 2      ₹65,000,000
# 3          2000000
# 4              NaN
#           ...
# 520      225000000
# 521            NaN
# 522           7500
# 523    ₹35,000,000
# 524       35000000
# Name: Amount, Length: 525, dtype: object

# %%
# Remove commas
df18['Amount'] = df18['Amount'].replace(',','')

# %% [markdown]
# #### Amount column contains currency signs and rupee amounts. Remove currency signs, convert to float and replace with dollar equivalen

# %%
# Create separate dataframe for rupee amounts
df_rupees = df18[df18['Amount'].astype(str).str.contains('₹')]

# %%
# convert rupees to dollars
df_rupees['Amount'] = df_rupees['Amount'].apply(lambda x: x.replace('₹','').replace(',','')).astype('float')
df_rupees['Amount'] = df_rupees['Amount']*0.0146

# update the original dataframe
df18.loc[df18['Amount'].isin(df_rupees['Amount'])] = df_rupees
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\1110927561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rupees['Amount'] = df_rupees['Amount'].apply(lambda x: x.replace('₹','').replace(',','')).astype('float')
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\1110927561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rupees['Amount'] = df_rupees['Amount']*0.0146

# %%
# update the original dataframe 
df18.update(df_rupees)
# Remove dollar sign
df18['Amount'] = df18['Amount'].str.replace('$', '')
# Replace commas
df18['Amount'] = df18['Amount'].str.replace(',','')
df18['Amount'] = df18['Amount'].astype(float)
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\3342934674.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df18['Amount'] = df18['Amount'].str.replace('$', '')

# %%
# Replace all the NaN values with the mean 
df18['Amount'].replace(to_replace = np.nan, value = df18['Amount'].mean(), inplace = True)

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  525 non-null    object
#  1   Round/Series  525 non-null    object
#  2   Amount        525 non-null    float64
#  3   Location      525 non-null    object
#  4   Sector        428 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 20.6+ KB

# %%
# Rename Amount column to reflect currency
df18.rename(columns={'Amount':'Amount($)'},inplace = True)

# %%
df18.columns
# Out:
# Index(['Company Name', 'Round/Series', 'Amount($)', 'Location', 'Sector'], dtype='object')

# %% [markdown]
# #### Exploring Location column

# %%
df18['Location']
# Out:
# 0           Bangalore, Karnataka, India
# 1            Mumbai, Maharashtra, India
# 2               Gurgaon, Haryana, India
# 3           Noida, Uttar Pradesh, India
# 4      Hyderabad, Andhra Pradesh, India
#                      ...
# 520         Bangalore, Karnataka, India
# 521             Haryana, Haryana, India
# 522          Mumbai, Maharashtra, India
# 523          Mumbai, Maharashtra, India
# 524          Chennai, Tamil Nadu, India
# Name: Location, Length: 525, dtype: object

# %% [markdown]
# #### Location column contains more info than needed. Trim each entry to show only city

# %%
df18['Location'] = df18['Location'].str.split(',').str[0]
df18.head(20)
# Out:
#                         Company Name Round/Series     Amount($)   Location  \
# 0                    TheCollegeFever         Seed  2.500000e+05  Bangalore
# 1                    Happy Cow Dairy         Seed  2.317039e+07     Mumbai
# 2                         MyLoanCare     Series A  2.317039e+07    Gurgaon
# 3                        PayMe India        Angel  2.000000e+06      Noida
# 4                           Eunimart         Seed  2.317039e+07  Hyderabad
# 5                             Hasura         Seed  1.600000e+06  Bengaluru
# 6                          Tripshelf         Seed  2.317039e+07    Kalkaji
# 7                       Hyperdata.IO        Angel  2.317039e+07  Hyderabad
# 8                       Freightwalla         Seed  2.317039e+07     Mumbai
# 9                 Microchip Payments         Seed  2.317039e+07  Bangalore
# 10        BizCrum Infotech Pvt. Ltd.         Seed  2.317039e+07      Delhi
# 11                           Emojifi         Seed  2.317039e+07  Bengaluru
# 12                             Flock         Seed  2.317039e+07      India
# 13                         Freshboxx         Seed  2.317039e+07      Hubli
# 14        Wide Mobility Mechatronics         Seed  2.317039e+07  Bangalore
# 15                           Pitstop         Seed  2.317039e+07  Bengaluru
# 16                            Mihuru         Seed  1.500000e+05     Mumbai
# 17                              Fyle         Seed  1.100000e+06  Bengaluru
# 18                          AppWharf         Seed  2.317039e+07  New Delhi
# 19  Antariksh Waste Ventures Pvt ltd         Seed  2.317039e+07    Chennai
#
#                Sector
# 0           Marketing
# 1         Agriculture
# 2   Banking & Finance
# 3   Banking & Finance
# 4          Technology
# 5          Technology
# 6          Technology
# 7           Marketing
# 8          Technology
# 9   Banking & Finance
# 10                B2B
# 11         Technology
# 12         Technology
# 13    Food & Beverage
# 14         Technology
# 15          Logistics
# 16  Banking & Finance
# 17         Accounting
# 18         Technology
# 19         Technology

# %%
# Replace Bengaluru with Bangalore

df18['Location'].replace('Bengaluru', 'Bangalore', inplace=True)
df18['Location'].replace('New Delhi', 'Delhi', inplace=True)

# %%
df18.head(20)
# Out:
#                         Company Name Round/Series     Amount($)   Location  \
# 0                    TheCollegeFever         Seed  2.500000e+05  Bangalore
# 1                    Happy Cow Dairy         Seed  2.317039e+07     Mumbai
# 2                         MyLoanCare     Series A  2.317039e+07    Gurgaon
# 3                        PayMe India        Angel  2.000000e+06      Noida
# 4                           Eunimart         Seed  2.317039e+07  Hyderabad
# 5                             Hasura         Seed  1.600000e+06  Bangalore
# 6                          Tripshelf         Seed  2.317039e+07    Kalkaji
# 7                       Hyperdata.IO        Angel  2.317039e+07  Hyderabad
# 8                       Freightwalla         Seed  2.317039e+07     Mumbai
# 9                 Microchip Payments         Seed  2.317039e+07  Bangalore
# 10        BizCrum Infotech Pvt. Ltd.         Seed  2.317039e+07      Delhi
# 11                           Emojifi         Seed  2.317039e+07  Bangalore
# 12                             Flock         Seed  2.317039e+07      India
# 13                         Freshboxx         Seed  2.317039e+07      Hubli
# 14        Wide Mobility Mechatronics         Seed  2.317039e+07  Bangalore
# 15                           Pitstop         Seed  2.317039e+07  Bangalore
# 16                            Mihuru         Seed  1.500000e+05     Mumbai
# 17                              Fyle         Seed  1.100000e+06  Bangalore
# 18                          AppWharf         Seed  2.317039e+07      Delhi
# 19  Antariksh Waste Ventures Pvt ltd         Seed  2.317039e+07    Chennai
#
#                Sector
# 0           Marketing
# 1         Agriculture
# 2   Banking & Finance
# 3   Banking & Finance
# 4          Technology
# 5          Technology
# 6          Technology
# 7           Marketing
# 8          Technology
# 9   Banking & Finance
# 10                B2B
# 11         Technology
# 12         Technology
# 13    Food & Beverage
# 14         Technology
# 15          Logistics
# 16  Banking & Finance
# 17         Accounting
# 18         Technology
# 19         Technology

# %% [markdown]
# #### Exploring Company Name column

# %%
df18['Company Name']
# Out:
# 0        TheCollegeFever
# 1        Happy Cow Dairy
# 2             MyLoanCare
# 3            PayMe India
# 4               Eunimart
#              ...
# 520                Udaan
# 521    Happyeasygo Group
# 522               Mombay
# 523           Droni Tech
# 524              Netmeds
# Name: Company Name, Length: 525, dtype: object

# %%
# Find number of duplicates
df18.duplicated().sum()
# Out:
# 1

# %%
# Drop duplicate
df18.drop_duplicates()
# Out:
#           Company Name Round/Series     Amount($)   Location  \
# 0      TheCollegeFever         Seed  2.500000e+05  Bangalore
# 1      Happy Cow Dairy         Seed  2.317039e+07     Mumbai
# 2           MyLoanCare     Series A  2.317039e+07    Gurgaon
# 3          PayMe India        Angel  2.000000e+06      Noida
# 4             Eunimart         Seed  2.317039e+07  Hyderabad
# ..                 ...          ...           ...        ...
# 520              Udaan     Series C  2.250000e+08  Bangalore
# 521  Happyeasygo Group     Series A  2.317039e+07    Haryana
# 522             Mombay         Seed  7.500000e+03     Mumbai
# 523         Droni Tech         Seed  2.317039e+07     Mumbai
# 524            Netmeds     Series C  3.500000e+07    Chennai
#
#                 Sector
# 0            Marketing
# 1          Agriculture
# 2    Banking & Finance
# 3    Banking & Finance
# 4           Technology
# ..                 ...
# 520                B2B
# 521            Tourism
# 522    Food & Beverage
# 523         Technology
# 524         Technology
#
# [524 rows x 5 columns]

# %% [markdown]
# #### Rename some of the columns to match the other datasets

# %%
df18.rename(columns={'Round/Series':'Stage'}, inplace = True)
df18.rename(columns={'Location':'HeadQuarter'}, inplace = True)
df18.rename(columns={'Company Name':'Company/Brand'}, inplace = True)

# %%
df18.columns
# Out:
# Index(['Company/Brand', 'Stage', 'Amount($)', 'HeadQuarter', 'Sector'], dtype='object')

# %%
# Create new column 'Funding Year' with year 2018 to distinguish from other datasets when joining

df18["Funding Year"] = "2018"

# %%
df18.head(10)
# Out:
#         Company/Brand     Stage     Amount($) HeadQuarter             Sector  \
# 0     TheCollegeFever      Seed  2.500000e+05   Bangalore          Marketing
# 1     Happy Cow Dairy      Seed  2.317039e+07      Mumbai        Agriculture
# 2          MyLoanCare  Series A  2.317039e+07     Gurgaon  Banking & Finance
# 3         PayMe India     Angel  2.000000e+06       Noida  Banking & Finance
# 4            Eunimart      Seed  2.317039e+07   Hyderabad         Technology
# 5              Hasura      Seed  1.600000e+06   Bangalore         Technology
# 6           Tripshelf      Seed  2.317039e+07     Kalkaji         Technology
# 7        Hyperdata.IO     Angel  2.317039e+07   Hyderabad          Marketing
# 8        Freightwalla      Seed  2.317039e+07      Mumbai         Technology
# 9  Microchip Payments      Seed  2.317039e+07   Bangalore  Banking & Finance
#
#   Funding Year
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# 5         2018
# 6         2018
# 7         2018
# 8         2018
# 9         2018

# %%
df18 = df18.reindex(columns=['Company/Brand', 'HeadQuarter', 'Sector', 'Amount($)', 'Stage', 'Funding Year'])

# %%
df18.head()
# Out:
#      Company/Brand HeadQuarter             Sector     Amount($)     Stage  \
# 0  TheCollegeFever   Bangalore          Marketing  2.500000e+05      Seed
# 1  Happy Cow Dairy      Mumbai        Agriculture  2.317039e+07      Seed
# 2       MyLoanCare     Gurgaon  Banking & Finance  2.317039e+07  Series A
# 3      PayMe India       Noida  Banking & Finance  2.000000e+06     Angel
# 4         Eunimart   Hyderabad         Technology  2.317039e+07      Seed
#
#   Funding Year
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  525 non-null    object
#  1   HeadQuarter    525 non-null    object
#  2   Sector         428 non-null    object
#  3   Amount($)      525 non-null    float64
#  4   Stage          525 non-null    object
#  5   Funding Year   525 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 24.7+ KB

# %%
df18.to_csv("India_funding2018_cleaned.csv", index=False)

# %% [markdown]
# ## Combing 2019, 2020 and 2021 data sets into a single data frame.

# %%
#combining data into one called startup_dataset
sets= [ df19, df20, df21]
startup_dataset = pd.concat(sets)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
startup_dataset.to_csv("India_funding901_cleaned.csv", index=False)

# %% [markdown]
# ###### Have a look at the loaded datsets using the following methods: .head(), .info()

# %%
# Set display option to suppress scientific notation

startup_dataset.head()
# Out:
#     Company/Brand Founded HeadQuarter       Sector  \
# 0  Bombay Shaving       0         NaN   Technology
# 1       Ruangguru    2014      Mumbai    Education
# 2        Eduisfun       0      Mumbai    Education
# 3        HomeLane    2014     Chennai     Services
# 4        Nu Genes    2004   Telangana  Agriculture
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor    Amount($)  \
# 0                               Sixth Sense Ventures   6300000.00
# 1                                   General Atlantic 150000000.00
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey  28000000.00
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...  30000000.00
# 4           Innovation in Food and Agriculture (IFA)   6000000.00
#
#            Stage Funding Year
# 0            NaN         2019
# 1       Series C         2019
# 2  Fresh funding         2019
# 3       Series D         2019
# 4            NaN         2019

# %% [markdown]
# ## Univariate Analysis
#
# Univariate analysis focuses on analyzing and summarizing individual variables to gain insights into their distribution,
# central tendency, and variability.It helps to explore the characteristics of a single variable in isolation, allowing us to understand its frequency, trends, and patterns. It also provides a foundation for further statistical analysis and can aid in making data-driven decisions by providing a comprehensive understanding of the variable's behavior and characteristics.

# %%
startup_dataset.shape
# Out:
# (2329, 9)

# %%
startup_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2329 non-null   object
#  1   Founded        2116 non-null   object
#  2   HeadQuarter    2210 non-null   object
#  3   Sector         1640 non-null   object
#  4   Founders       2310 non-null   object
#  5   Investor       2224 non-null   object
#  6   Amount($)      2329 non-null   float64
#  7   Stage          1398 non-null   object
#  8   Funding Year   2329 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 182.0+ KB

# %%
# Display the descriptive statistics for the columns
#startup_dataset['Amount($)'].describe()
startup_dataset.describe()
# Out:
#             Amount($)
# count         2329.00
# mean     150777104.08
# std     3459747585.96
# min              9.60
# 25%        1100000.00
# 50%        5500000.00
# 75%       55000000.00
# max   150000000000.00

# %% [markdown]
# #### From the describe of the amount column above the money given to the startups range from  9.6 to  150 billion US dollars

# %%
#assess for missing values
startup_dataset.isna().sum()
# Out:
# Company/Brand      0
# Founded          213
# HeadQuarter      119
# Sector           689
# Founders          19
# Investor         105
# Amount($)          0
# Stage            931
# Funding Year       0
# dtype: int64

# %%
#check for duplicates
startup_dataset.duplicated().sum()
# Out:
# 0

# %%
#replace missing values in the Sector column with O
startup_dataset["Sector"].replace(np.NaN, 'N/A', inplace = True)
startup_dataset.isna().sum()
# Out:
# Company/Brand      0
# Founded          213
# HeadQuarter      119
# Sector             0
# Founders          19
# Investor         105
# Amount($)          0
# Stage            931
# Funding Year       0
# dtype: int64

# %%
startup_dataset['Sector'].unique()
# Out:
# array(['Technology', 'Education', 'Services', 'Agriculture',
#        'Food & Beverage', 'Health', 'N/A', 'Insurance', 'Logistics',
#        'Manufacturing', 'Media & Entertainment', 'Beauty', 'B2B',
#        'Fashion', 'Banking & Finance', 'Sports & Fitness', 'Marketing',
#        'Hospitality', 'Food & Beverages', 'Digital_Platform',
#        'Sport & Fitness', 'Energy', 'Housing', 'Transport', 'Automotive',
#        'Legal', 'Construction', 'Data_Science_ Analytics', 'Accounting',
#        'Tourism', 'Music', 'Others', 'D2C'], dtype=object)

# %%
sum_of_unique = len(startup_dataset['Sector'].unique())
print("The total of sectors:", sum_of_unique)
# Out:
# The total of sectors: 33

# %%
#replace the nan values with mean 
#startup_dataset.fillna(startup_dataset.mean(), inplace=True)

# %% [markdown]
# ## Bivariate Analysis
#
# Bivariate analysis examines the relationship between two variables to understand how they interact and influence each other.It helps to identify patterns, correlations, and dependencies between variables, providing insights into their joint behavior.
# It gain a deeper understanding of the connections between different factors and make informed decisions based on these relationships.

# %%
#Heat map showing correlation between all numerical columns 
sns.heatmap(startup_dataset.corr())
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\680365191.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(startup_dataset.corr())
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Select the columns of interest
columns_of_interest = ['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'Founders', 'Investor', 'Amount($)', 'Stage', 'Funding Year']

# Create a subset dataframe with the selected columns
subset_df = startup_dataset[columns_of_interest]

# Drop any rows with missing values
subset_df = subset_df.dropna()
plt.figure(figsize=(8, 6))
# Set the size of the plot
sns.set(rc={'figure.figsize': (12, 8)})

# Create a pair plot with increased size and color by 'Sector'
sns.pairplot(subset_df, height=6, aspect=1.2, hue='Sector')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Convert 'Funding Year' to string
funding_year = startup_dataset['Funding Year'].astype(str)
amount = startup_dataset['Amount($)']
plt.figure(figsize=(8, 6))

# Create a scatter plot with color
scatter = plt.scatter(funding_year, amount, s=amount/100000000, c=amount, cmap='coolwarm', alpha=0.5)

# Add colorbar
colorbar = plt.colorbar(scatter)
colorbar.set_label('Amount ($)')

# Customize the plot
plt.title('Funding Amount by Year')
plt.xlabel('Funding Year')
plt.ylabel('Amount ($)')
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# Group the dataset by 'Funding Year' and calculate the sum of 'Amount($)' for each year
total_amount_by_year = startup_dataset.groupby('Funding Year')['Amount($)'].sum()

# Create a line plot
plt.plot(total_amount_by_year.index, total_amount_by_year)

# Customize the plot
plt.title('Total Funding Amount by Year')
plt.xlabel('Funding Year')
plt.ylabel('Total Funding Amount ($)')

# Display the plot
plt.show()

# %% [markdown]
# # Answering the questions.

# %% [markdown]
# ### 1. Which company received the most funding?

# %%
startup_dataset.sort_values(['Amount($)'], ascending = False, inplace=True)
startup_dataset.head(10)
# Out:
#                     Company/Brand Founded HeadQuarter            Sector  \
# 73                Alteria Capital    2018      Mumbai        Technology
# 280  Reliance Retail Ventures Ltd    2006      Mumbai          Services
# 242            Fullife Healthcare    2009         NaN               N/A
# 317                     Snowflake    2012  California               N/A
# 328                      Reliance    1973      Mumbai               N/A
# 346              VerSe Innovation    2007   Bangalore          Services
# 935                  Dream Sports    2008      Mumbai  Sports & Fitness
# 53                         Swiggy    2014   Bangalore   Food & Beverage
# 472                      Eruditus    2010      Mumbai               N/A
# 302      Reliance Retail Ventures    2006      Mumbai  Digital_Platform
#
#                                               Founders  \
# 73                                        Vinod Murali
# 280                                      Mukesh Ambani
# 242                 Morgan Stanley Private Equity Asia
# 317  Benoit Dageville, Bob Muglia, Marcin Zukowski,...
# 328                                   Dhirubhai Ambani
# 346                                     Virendra Gupta
# 935                                         Harsh Jain
# 53       Nandan Reddy, Rahul Jaimini, Sriharsha Majety
# 472               Chaitanya Kalipatnapu, Ashwin Damera
# 302                                      Mukesh Ambani
#
#                                               Investor       Amount($)  \
# 73                                                 NaN 150000000000.00
# 280           Silver Lake, Mubadala Investment Company  70000000000.00
# 242                                                NaN  22000000000.00
# 317    Salesforce Ventures, Dragoneer Investment Group   3000000000.00
# 328                 Facebook, Google, KKR, Silver Lake   2200000000.00
# 346  Canaan Valley Capital, Glade Brook Capital Par...   1000000000.00
# 935  Falcon Edge, DST Global, D1 Capital, Redbird C...    840000000.00
# 53                      Carmignac, Falcon Edge Capital    800000000.00
# 472  Bertelsmann India Investments, Sequoia Capital...    800000000.00
# 302          General Atlantic, Kohlberg Kravis Roberts    800000000.00
#
#         Stage Funding Year
# 73       Debt         2021
# 280       NaN         2020
# 242  Series C         2021
# 317       NaN         2020
# 328       NaN         2020
# 346  Series H         2021
# 935       NaN         2021
# 53        NaN         2021
# 472       NaN         2020
# 302       NaN         2020

# %%
Company = startup_dataset['Company/Brand'].head(10)
Amount = startup_dataset['Amount($)'].head(10)
plt.figure(figsize=(8, 6))

# Reset the index of Amount and Company
Amount = Amount.reset_index(drop=True)
Company = Company.reset_index(drop=True)

# Sort the data based on the amount in descending order
sorted_indices = Amount.argsort()[::1]
Amount_sorted = Amount[sorted_indices]
Company_sorted = Company[sorted_indices]

plt.xlabel('Amount of Funding Received')
plt.ylabel('Company/Brand')
plt.title('Top 10 Companies that Received Funding')
plt.barh(Company_sorted, Amount_sorted, color='green')
plt.show()

# %% [markdown]
# #### From the above, the company that received the highest fund is Alteria Capital with an amount of  $150 billion

# %% [markdown]
# ### 2. Which company received the lowest amount of funding?

# %%
startup_dataset.sort_values(['Amount($)'], ascending = False, inplace=True)
startup_dataset.tail(10)
# Out:
#            Company/Brand Founded HeadQuarter       Sector  \
# 93               GetWork    2019    Gurugram          N/A
# 1007               Karfa     NaN   New Delhi          N/A
# 354                Fasal    2018   Bangalore  Agriculture
# 941            Krimanshi     NaN     Jodhpur          N/A
# 1002            Teach Us     NaN         NaN   Technology
# 1000             Medicus     NaN      Mumbai       Health
# 1001              Monech     NaN      Mumbai          N/A
# 308                 Glii    2020       Noida          N/A
# 834           Peel Works    2010      Mumbai          N/A
# 552   SATYA Microcapital    1995   New Delhi          N/A
#
#                                      Founders  \
# 93                              Rahul Veerwal
# 1007                           Kartikeya Goel
# 354   Ananda Prakash Verma, Shailendra Tiwari
# 941                              Nikhil Bohra
# 1002                                      NaN
# 1000                 Bhavesh Shah, Manav Shah
# 1001                                      NaN
# 308                            Shivam Kaushik
# 834        Sachin Chhabra, Nidhi Ramachandran
# 552                              Vivek Tiwari
#
#                                             Investor  Amount($)     Stage  \
# 93                                 India Accelerator   40000.00  Pre-Seed
# 1007                                     Undisclosed   25000.00      Seed
# 354                              Omnivore, Zeroth.AI   20000.00       NaN
# 941   Arunachal Pradesh Social Entrepreneurship Meet   20000.00       NaN
# 1002                                 Angel investors   12700.00      Seed
# 1000                                 Angel investors   12700.00       NaN
# 1001                                 Angel investors   12700.00      Seed
# 308                                We Founder Circle   10000.00      Seed
# 834                                    CESC Ventures      42.23  Series C
# 552                      BlueOrchard Finance Limited       9.60       NaN
#
#      Funding Year
# 93           2020
# 1007         2020
# 354          2020
# 941          2020
# 1002         2020
# 1000         2020
# 1001         2020
# 308          2021
# 834          2020
# 552          2020

# %%
Company = startup_dataset['Company/Brand'].tail(10)
Amount = startup_dataset['Amount($)'].tail(10)
plt.figure(figsize=(8, 6))

# Sort the data based on the amount in descending order
sorted_indices = Amount.argsort()[::-1]
Amount_sorted = Amount.iloc[sorted_indices]
Company_sorted = Company.iloc[sorted_indices]

plt.xlabel('Funding Received')
plt.ylabel('Company')
plt.title('Top 10 Companies with Lowest Funding')
plt.barh(Company_sorted, Amount_sorted, color='green')
plt.show()

# %% [markdown]
# ##### SATYA Microcapital received the lowers amount of $ 9.60

# %% [markdown]
# ### 3. Which Sector received the highest amount of funding?

# %%
# Sort and group the funds received by sector in descending order

Amount_sum = startup_dataset.groupby(['Sector'])['Amount($)'].sum().reset_index()
Amount_sum.sort_values(['Amount($)'], ascending = False, inplace=True)
Amount_sum.head(10)
# Out:
#                    Sector       Amount($)
# 30             Technology 179341997936.12
# 27               Services  74067668131.86
# 25                    N/A  53404579098.11
# 15                 Health   9568997901.25
# 21          Manufacturing   4510769061.71
# 4       Banking & Finance   3691181191.22
# 23  Media & Entertainment   3590615325.23
# 13        Food & Beverage   3547231796.06
# 14       Food & Beverages   2061479515.18
# 9        Digital_Platform   1905951384.48

# %%
Industry = Amount_sum['Sector'].head(5)
Amount = Amount_sum['Amount($)'].head(5)
plt.figure(figsize=(8, 6))

# Sort the data based on the amount in ascending order
sorted_indices = Amount.argsort()
Amount_sorted = Amount.iloc[sorted_indices]
Industry_sorted = Industry.iloc[sorted_indices]

plt.xlabel('Amount')
plt.ylabel('Sector')
plt.title(' Highest funded Sectors')
plt.barh(Industry_sorted, Amount_sorted, color='orange')
plt.show()

# %% [markdown]
# #### The most funded sector  is Technology sector with sum amount of $179.342 billion

# %% [markdown]
# ### 4. Which Sector received the lowest amount of funding?

# %%
Value_sum = startup_dataset.groupby(['Sector'])['Amount($)'].sum().reset_index()
Value_sum.sort_values(['Amount($)'], ascending = True, inplace=True)
Value_sum
# Out:
#                      Sector       Amount($)
# 6              Construction      3300000.00
# 22                Marketing     19500000.00
# 26                   Others     27200000.00
# 31                  Tourism    114208876.90
# 0                Accounting    123000000.00
# 24                    Music    194420186.84
# 17                  Housing    194776204.90
# 19                    Legal    231417753.79
# 8   Data_Science_ Analytics    231617753.79
# 18                Insurance    292967753.79
# 28          Sport & Fitness    458665507.59
# 20                Logistics    481200000.00
# 5                    Beauty    505118630.69
# 7                       D2C    577170186.84
# 2                Automotive    931343384.48
# 32                Transport   1042369581.28
# 3                       B2B   1069249738.73
# 12                  Fashion   1182680004.38
# 10                Education   1316093260.53
# 29         Sports & Fitness   1327070674.99
# 11                   Energy   1525389624.28
# 1               Agriculture   1771397191.22
# 16              Hospitality   1849247753.79
# 9          Digital_Platform   1905951384.48
# 14         Food & Beverages   2061479515.18
# 13          Food & Beverage   3547231796.06
# 23    Media & Entertainment   3590615325.23
# 4         Banking & Finance   3691181191.22
# 21            Manufacturing   4510769061.71
# 15                   Health   9568997901.25
# 25                      N/A  53404579098.11
# 27                 Services  74067668131.86
# 30               Technology 179341997936.12

# %%
Industry = Value_sum['Sector'].head(10)
Amount = Value_sum['Amount($)'].head(10)
plt.figure(figsize=(8, 6))

# Sort the data based on the amount in descending order
sorted_indices = Amount.argsort()[::-1]
Amount_sorted = Amount.iloc[sorted_indices]
Industry_sorted = Industry.iloc[sorted_indices]

plt.xlabel('Amount($)')
plt.ylabel('Sector')
plt.title('Top 10 Lowest funded Sectors')
plt.barh(Industry_sorted, Amount_sorted, color='orange')
plt.show()

# %% [markdown]
# #### The least funded sector is Construction, and it has received a sum of $ 3.3 million

# %% [markdown]
# ### 5. What is the total amount funding received each year?

# %%
amtby_year=startup_dataset.groupby(['Funding Year']).sum(numeric_only=True).reset_index()
amtby_year = amtby_year.reindex([2, 0, 1])
amtby_year
# Out:
#   Funding Year       Amount($)
# 2         2021 228482522345.09
# 0         2020 118820956249.37
# 1         2019   3856396815.58

# %%
plt.figure(figsize=(8, 6))
plt.title('Total Amount($) of funding received each year')
ax=sns.barplot(y=amtby_year['Amount($)'],x=amtby_year['Funding Year'],palette='Greens_d')
ax.set(xlabel='Year',ylabel='Amount($)')
plt.show()

# %% [markdown]
# #### The total amount received each year in 2019, 2020 and 2021 is  3,856.397 million, 118,821 million,  and 228,482.5 million Dollars respectively.

# %% [markdown]
# ### 7. what is the average amount received in 2019, 2020 and 2021

# %%
mean_amount_per_year = startup_dataset.groupby('Funding Year')['Amount($)'].mean()
mean_amount_per_year_sorted = mean_amount_per_year.reindex([2, 0, 1])

mean_amount_per_year
# Out:
# Funding Year
# 2020   113055143.91
# 2019    43330301.30
# 2021   192163601.64
# Name: Amount($), dtype: float64

# %%
# Group the dataset by 'Funding Year' and calculate the mean 'Amount($)' for each year
mean_amount_by_year = startup_dataset.groupby('Funding Year')['Amount($)'].mean()

# Convert the 'Funding Year' values to numeric data type
mean_amount_by_year.index = pd.to_numeric(mean_amount_by_year.index)

# Sort the mean_amount_by_year Series in ascending order
mean_amount_by_year_sorted = mean_amount_by_year.sort_values(ascending=True)
plt.figure(figsize=(8, 6))
# Create a bar chart
plt.bar(mean_amount_by_year_sorted.index, mean_amount_by_year_sorted)


# Customize the plot
plt.title('Average Amount($) by Funding Year')
plt.xlabel('Funding Year')
plt.ylabel('Average Amount($)')

# Display the plot
plt.show()

# %% [markdown]
# #### The Average amount received in 2019, 2020 and 2021 is 113.0551 million, 43.3303 million and 192.1636 million respectively.

# %% [markdown]
# ### 8. At what stage do startups receive the most funding?

# %%
# Group the data by stage and calculate the total funding amount for each stage
funding_by_stage = startup_dataset.groupby('Stage')['Amount($)'].sum()

# Sort the stages in descending order of funding amount and select the top 10 stages
top_10_stages = funding_by_stage.sort_values(ascending=False).head(10)

# Print the top 10 stages and their corresponding total funding amounts
for stage, funding in top_10_stages.items():
    print("Stage:", stage)
    print("Total Funding Amount:", funding)
    print()
# Out:
# Stage: Debt
# Total Funding Amount: 150587432000.0
#
# Stage: Series C
# Total Funding Amount: 26632213619.126938
#
# Stage: Seed
# Total Funding Amount: 14708562566.166952
#
# Stage: Pre-series A
# Total Funding Amount: 4013968550.047664
#
# Stage: Pre-Series A
# Total Funding Amount: 3888658337.598996
#
# Stage: Series B
# Total Funding Amount: 3597398679.494342
#
# Stage: Series E
# Total Funding Amount: 3407723186.844614
#
# Stage: Series D
# Total Funding Amount: 3348370000.0
#
# Stage: Series A
# Total Funding Amount: 3326792571.3293104
#
# Stage: Pre-seed
# Total Funding Amount: 1947641868.446139

# %%
# Group the data by stage and calculate the total funding amount for each stage
funding_by_stage = startup_dataset.groupby('Stage')['Amount($)'].sum()
plt.figure(figsize=(8, 6))

# Select the top 10 stages by funding amount
top_10_stages = funding_by_stage.nlargest(10)

# Create a bar chart
plt.bar(top_10_stages.index, top_10_stages)
plt.title(' Fund Received by Stages')
plt.xlabel('Stage')
plt.ylabel('Total Funding Amount ($)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Most of the fundings are recieved at the Debt stage.

# %% [markdown]
# ### 9. Does the location affect the funding received?

# %%
# Group the data by location and calculate the mean funding amount for each location
funding_by_location = startup_dataset.groupby('HeadQuarter')['Amount($)'].mean()

# Sort the locations in descending order of mean funding amount
sorted_locations = funding_by_location.sort_values(ascending=False)

# Print the top 10 locations with the highest mean funding amount
top_10_locations = sorted_locations.head(5)
print("Top 10 Locations with Highest Mean Funding Amount:")
print(top_10_locations)
print()
# Out:
# Top 10 Locations with Highest Mean Funding Amount:
# HeadQuarter
# Mumbai            639544237.82
# California        638301775.38
# Shanghai, China   400000000.00
# Faridabad         220000000.00
# Beijing           200000000.00
# Name: Amount($), dtype: float64

# %%
# Create a bar plot to visualize the mean funding amount by location
plt.figure(figsize=(8, 6))
sns.barplot(x=top_10_locations.index, y=top_10_locations.values)
plt.title('Most Funded HeadQuarters by Location ')
plt.xlabel('Location')
plt.ylabel('Mean Funding Amount ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Since there is a variation in the differences in the mean funding amounts represented by the heights of the bars among different locations, it suggests that location may have an impact on funding received.  It is evidenced that Companies in Mumbai have the receiived highest amount of funds.

# %% [markdown]
# ## Analysis of 2018 dataset
#
# Seperate analysis is done on 2018 dataset since it is not having similar features as 2019, 2018 and 2021.

# %% [markdown]
# #### Have a look at the loaded datsets and perrform a univariate analyysis using the following methods: .head(), .info()

# %%
df18.head()
# Out:
#      Company/Brand HeadQuarter             Sector   Amount($)     Stage  \
# 0  TheCollegeFever   Bangalore          Marketing   250000.00      Seed
# 1  Happy Cow Dairy      Mumbai        Agriculture 23170392.67      Seed
# 2       MyLoanCare     Gurgaon  Banking & Finance 23170392.67  Series A
# 3      PayMe India       Noida  Banking & Finance  2000000.00     Angel
# 4         Eunimart   Hyderabad         Technology 23170392.67      Seed
#
#   Funding Year
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  525 non-null    object
#  1   HeadQuarter    525 non-null    object
#  2   Sector         428 non-null    object
#  3   Amount($)      525 non-null    float64
#  4   Stage          525 non-null    object
#  5   Funding Year   525 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 24.7+ KB

# %%
# check basic statistics about the df18 dataset using describe
df18.describe()
# Out:
#           Amount($)
# count        525.00
# mean    23170392.67
# std     63634281.27
# min         7500.00
# 25%      2000000.00
# 50%     23170392.67
# 75%     23170392.67
# max   1000000000.00

# %% [raw]
# From the statistics above its clear that the amount received in 2018 ranges from $7500 to $1000000000

# %% [markdown]
# #### Bivariate analysis

# %%
plt.figure(figsize=(8, 6))

# Create a histogram using seaborn
sns.histplot(data=df18, x='Stage', bins=20, edgecolor='black')

# Add labels and title
plt.xlabel('Stage')
plt.ylabel('Frequency')
plt.title('Frequency of funding Stages')

# Rotate x values
plt.xticks(rotation=45, ha='right')

# Display the histogram
plt.show()

# %%
correlation_table = df18.corr()
print(correlation_table)
# Out:
#            Amount($)
# Amount($)       1.00
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\327674929.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_table = df18.corr()

# %%
plt.figure(figsize=(8, 6))
# Assuming you have a DataFrame called 'startup_dataset'
correlation_matrix = df18.corr()

# Create a heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Customize the plot
plt.title('Correlation Matrix')

# Display the plot
plt.show()
# Out:
# C:\Users\tkate\AppData\Local\Temp\ipykernel_59300\2780256769.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df18.corr()

# %% [markdown]
# #### 9. Which Sector received the highest funding in 2018?

# %%
# Group the funds received by sector and calculate the sum
funds_by_sector = df18.groupby('Sector')['Amount($)'].sum()

# Sort the funds in descending order
sorted_funds = funds_by_sector.sort_values(ascending=False)

# Display the sorted funds by sector
print(sorted_funds)
# Out:
# Sector
# Technology              2137482486.57
# Food & Beverage         1610604175.31
# Banking & Finance       1104784135.95
# Education                990285889.98
# Insurance                953000000.00
# Energy                   622052178.00
# Health                   616095998.30
# Logistics                595179950.65
# Services                 318464711.98
# B2B                      306050785.33
# Media & Entertainment    241023926.65
# Sports & Fitness         223851963.33
# Agriculture              163312748.66
# Marketing                162692748.66
# Hospitality              148340785.33
# Fashion                   96981570.66
# Beauty                    95921570.66
# Manufacturing             92681570.66
# Tourism                   48740785.33
# Accounting                47440785.33
# Events                    24670392.67
# Government                23270392.67
# Name: Amount($), dtype: float64

# %%
plt.figure(figsize=(8, 6))
# Group the funds received by sector and calculate the sum
funds_by_sector = df18.groupby('Sector')['Amount($)'].sum()
plt.figure(figsize=(8, 6))

# Sort the funds in descending order and select the top 10 sectors
top_10_sectors = funds_by_sector.sort_values(ascending=False).head(10)

# Create a bar plot for the top 10 sectors
plt.bar(top_10_sectors.index, top_10_sectors)

# Customize the plot
plt.xlabel('Sectors')
plt.ylabel('Funds')
plt.title('MOST FUNDED SECTOR IN 2018')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# #### It has also shown that that Technology sector was highly funded in 2018

# %% [markdown]
# ## Hypothesis
#
# NULL : Technological industries do not have a higher success rate of being funded
#
# ALTERNATE : Technological industries have a higher success rate of being funded
#
# Based on our analysis, we reject the Null Hypothesis because it is clear that Technological industries have a higher success rate of being funded.

# %% [markdown]
# ## Conclusion
# Therefore, leveraging the insights gained from the analysis, focusing on the Technology sector, and considering opportunities in Mumbai can enhance the chances of making successful investment decisions and fostering innovation in the startup ecosystem.
